# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json
import Levenshtein

# %%
def auth():
    with open(".creds.json") as f:
        creds = json.load(f)
    scope = [
        "playlist-read-private",
        "playlist-modify-private",
        "user-library-read",
        "user-read-private",
    ]
    spotify_creds = SpotifyOAuth(**creds, scope=scope)
    spotify = spotipy.Spotify(client_credentials_manager=spotify_creds)
    return spotify

# %%
spotify = auth()

# %%
def find_artist(name):
    result = spotify.search(q=f"artist:{name}", type="artist")
    items = result["artists"]["items"]
    return items

# %%
def get_playlists():
    playlists = spotify.current_user_playlists()["items"]
    pl_info = {}
    for pl in playlists:
        pl_info[pl["name"]] = pl["uri"]
    return pl_info

# %%
def get_liked_songs(batch_size=50):
    song_info = []
    offset = 0
    while True:
        print(offset)
        song_batch = spotify.current_user_saved_tracks(limit=batch_size, offset=offset)["items"]
        if len(song_batch) == 0:
            break
        for song in song_batch:
            artists = [artist_info["name"] for artist_info in song["track"]["artists"]]
            song_info.append(
                {
                    "name": song["track"]["name"],
                    "artists": artists,
                    "uri": song["track"]["uri"]
                }
            )
        offset += batch_size
    return song_info

# %%
songs = get_liked_songs()
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 songs = get_liked_songs()
#
# Cell In[6], line 6, in get_liked_songs(batch_size)
#       4 while True:
#       5     print(offset)
# ----> 6     song_batch = spotify.current_user_saved_tracks(limit=batch_size, offset=offset)["items"]
#       7     if len(song_batch) == 0:
#       8         break
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:1286, in Spotify.current_user_saved_tracks(self, limit, offset, market)
#    1276 def current_user_saved_tracks(self, limit=20, offset=0, market=None):
#    1277     """ Gets a list of the tracks saved in the current authorized user's
#    1278         "Your Music" library
#    1279
#    (...)
#    1284
#    1285     """
# -> 1286     return self._get("me/tracks", limit=limit, offset=offset, market=market)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
artists_with_songs = {}
for song in songs:
    for artist in song["artists"]:
        if artist in artists_with_songs:
            artists_with_songs[artist].append(song["name"])
        else:
            artists_with_songs[artist] = [song["name"]]
my_artists = list(artists_with_songs.keys())

# %%
artists_with_songs
# Out:
# {'Jordiz': ['Weekend!'],
#  'Connor Price': ['Start Again', 'Smooth'],
#  'Chloe Sagum': ['Start Again'],
#  'Arrested Youth': ['Brightside', 'Dig'],
#  'YUNGBLUD': ['Tissues',
#   'mars',
#   'I’m a Mess (with YUNGBLUD)',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   'parents',
#   'acting like that (feat. Machine Gun Kelly)',
#   'The Funeral',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Patience (feat. YUNGBLUD & Polo G)'],
#  'SK8': ['Shooting Star (feat. Sum 41)'],
#  'Sum 41': ['Shooting Star (feat. Sum 41)',
#   'With Me',
#   'In Too Deep',
#   'Fat Lip',
#   'Fat Lip',
#   'Still Waiting'],
#  'Sub Zero Project': ['HALO', 'Project X', 'Rockstar (feat. DV8)'],
#  'Kay One': ['Herz aus Stein', 'Senorita'],
#  'strike': ['Calling'],
#  'Ben Nicky': ['We Are The Ravers'],
#  'Olly James': ['We Are The Ravers'],
#  'MC Stretch': ['We Are The Ravers'],
#  'Korsakoff': ['Lyra - Broken Minds Remix'],
#  'Broken Minds': ['Lyra - Broken Minds Remix'],
#  'Machine Gun Kelly': ['bloody valentine',
#   'title track',
#   'Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   "don't sleep, repeat (feat. Machine Gun Kelly)",
#   'bloody valentine - Acoustic',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   "can't look back",
#   'kevin and barracuda - interlude',
#   'forget me too (feat. Halsey)',
#   'kiss kiss',
#   'concert for aliens',
#   "my ex's best friend (with blackbear)",
#   'hangover cure',
#   'WWIII',
#   "play this when i'm gone",
#   'lonely',
#   'split a pill',
#   'all I know (feat. Trippie Redd)',
#   'Misery Business',
#   'nothing inside (feat. iann dior)',
#   'banyan tree - interlude',
#   'jawbreaker',
#   'drunk face',
#   'papercuts - album edit',
#   'sid & nancy',
#   'die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'make up sex (feat. blackbear)',
#   '9 lives',
#   'twin flame',
#   'god save me',
#   'mainstream sellout',
#   '5150',
#   'drug dealer (feat. Lil Wayne)',
#   'emo girl (feat. WILLOW)',
#   'born with horns',
#   'more than life (feat. glaive)',
#   "fake love don't last (feat. iann dior)",
#   'maybe (feat. Bring Me The Horizon) - acoustic version',
#   'wall of fame - interlude',
#   'ay! (feat. Lil Wayne)',
#   'why are you here',
#   'maybe (feat. Bring Me The Horizon)',
#   'last november',
#   'WW4',
#   'papercuts - live from red rocks',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'twin flame',
#   'Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'ay! (feat. Lil Wayne)',
#   'maybe (feat. Bring Me The Horizon)',
#   'acting like that (feat. Machine Gun Kelly)',
#   'emo girl (feat. WILLOW)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'Sueco': ['Paralyzed',
#   'POS',
#   'fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]',
#   'fast',
#   'It Was Fun While It Lasted',
#   'PRIMADONA',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Motel 666',
#   'SOS (feat. Travis Barker)',
#   'Toxic Therapy',
#   'Drunk Dial',
#   'Loser',
#   'Hate You Too',
#   'It’s Going Good!',
#   'Today',
#   'Bad Vibes',
#   'Next Ex',
#   'Salt',
#   'AITA',
#   'Funeral',
#   'Up in Smoke',
#   'Last Thing I Do',
#   'Salt',
#   'SOS (feat. Travis Barker)',
#   'Loser',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Paralyzed'],
#  'Jon Caryl': ['Alone'],
#  "Fresh Til' Death": ['In Too Deep (Firelite Remix)'],
#  'MYLKI': ['In Too Deep (Firelite Remix)'],
#  'Firelite': ['In Too Deep (Firelite Remix)'],
#  'In The Valley Below': ['Peaches'],
#  'Hollywood Undead': ['Whatever It Takes'],
#  'Mac Miller': ['Love Lost', 'The Spins'],
#  'The Temper Trap': ['Love Lost'],
#  'Avril Lavigne': ['I’m a Mess (with YUNGBLUD)',
#   'Love Sux',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'All I Wanted (feat. Mark Hoppus)',
#   'Bite Me',
#   'Head Above Water',
#   'Sk8er Boi',
#   'Sk8er Boi'],
#  'The Home Team': ["She's Quiet"],
#  'Mayberg': ['Hilferuf'],
#  'Panic! At The Disco': ['The Ballad of Mona Lisa',
#   'Crazy = Genius',
#   'I Write Sins Not Tragedies',
#   'High Hopes'],
#  'Harris & Ford': ['99 Luftballons',
#   'Hard, Style & Volksmusik',
#   'Break the Beat'],
#  'Zombic': ['Human Error'],
#  'Danimal': ['Human Error'],
#  'Influencerz': ['Human Error'],
#  'iann dior': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'nothing inside (feat. iann dior)',
#   "fake love don't last (feat. iann dior)",
#   'Mood (feat. iann dior)'],
#  'Travis Barker': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   'bloody valentine - Acoustic',
#   'Misery Business',
#   'Drop Dead (with Kesha and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'KXXMA': ['Get Shaky', 'Herz an Herz'],
#  'TurboKevin': ['Get Shaky'],
#  'Nic D': ['Serotonin'],
#  'Bryce Vine': ['American Dream', 'The Fall'],
#  'Weezer': ['Beverly Hills'],
#  'The Bangles': ['Eternal Flame'],
#  'Cassyette': ['Sad Girl Summer'],
#  'Tammy Wynette': ['Stand By Your Man - Official Audio'],
#  'Wolfpack': ['Phatt Bass 2016 (Mixed)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'Ocarina'],
#  'Warp Brothers': ['Phatt Bass 2016 (Mixed)'],
#  'NWYR': ['The Lone Ranger'],
#  'W&W': ['The Lone Ranger',
#   'Skydance',
#   'Rave Culture',
#   'Chakra - Wildstylez Remix',
#   'God Is a Girl',
#   'Live the Night',
#   'Long Way Down',
#   "Don't Let Me Down (feat. Daya) - W&W Remix",
#   'Supa Dupa Fly 2018',
#   'How Many',
#   'Rave After Rave',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Crowd Control - Radio Edit',
#   'Arcade Mammoth',
#   'Rave Culture'],
#  'Hoodie Allen': ['Call Me Never'],
#  'Oberg': ['Sun Goes Down', 'Take My Hand'],
#  'Joakim Lundell': ['Sun Goes Down'],
#  'Hardwell': ['PACMAN',
#   'I FEEL LIKE DANCING',
#   'Bigroom Never Dies',
#   'Live the Night',
#   'The Underground',
#   'Bella Ciao',
#   'Power',
#   'Ze Willen Mee',
#   'Out of This Town',
#   'Shine a Light',
#   'This Is Love',
#   "Don't Let Me Down (feat. Daya) - Hardwell & Sephyx Remix",
#   'The Underground - Mix Cut',
#   'Bigroom Never Dies - Mix Cut',
#   'Off The Hook',
#   'Unity'],
#  'YROR?': ['Rotten'],
#  'Ben Joel': ['Rotten'],
#  'Carta': ['EDM'],
#  'Canadian Softball': ['Ohio Is for Emo Kids'],
#  'Cher': ['If I Could Turn Back Time'],
#  'Hardstyle Germany': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'High Level': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'Peach Pit': ['Alrighty Aphrodite'],
#  'Ruby Waters': ['Quantum Physics'],
#  'SEB': ['seaside_demo'],
#  'Jnr Choi': ['TO THE MOON'],
#  'Sam Tompkins': ['TO THE MOON'],
#  'Dubdogz': ['Everybody Wants To Party'],
#  'JØRD': ['Everybody Wants To Party'],
#  'Timmy Trumpet': ['Ininna Tora',
#   'Mad World',
#   'Project X',
#   'Dumb (Feat. BOSS)',
#   'The Anthem (Der Alte)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'The King',
#   'The Prayer (feat. Zafrir)',
#   'Bleed',
#   'Garden of Madness 2020 Megamix',
#   'Toca',
#   'Flamenco (feat. Rage)',
#   'Mufasa',
#   'The People',
#   'Hava',
#   'Nah Nah',
#   'World At Our Feet',
#   'Wassup (Listen To The Horns)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Baddest Behaviour',
#   'Scarborough Fair - Spotify Version',
#   'Rockstar (feat. DV8)',
#   'Nightmare - Radio Edit',
#   'Freaks - Extended Mix',
#   'Freaks - Instrumental Mix',
#   'Freaks - Radio Instrumental',
#   'Mantra',
#   'Hipsta',
#   'Take Your Call',
#   'Deja-Vu - Extended Version',
#   'Deja-Vu',
#   'The Underground',
#   'Booty Shake',
#   'Infinity - Original',
#   'Oracle',
#   'PSY or DIE',
#   'The Prophecy',
#   'Punjabi',
#   'Trumpets',
#   'Freaks - Radio Edit',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Al Pacino',
#   'Attention',
#   'The Underground - Mix Cut',
#   'Narco'],
#  'KSHMR': ['Ininna Tora',
#   'Invisible Children',
#   'The Prayer (feat. Zafrir)',
#   'Over and Out (feat. Charlott Boss)',
#   'Toca',
#   'The People',
#   'My Best Life (feat. Mike Waters)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Voices',
#   'Good Vibes Soldier (feat. Head Quattaz)',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Wildcard (feat. Sidnie Tipton)',
#   'Neverland',
#   'Harder',
#   'Carry Me Home (feat. Jake Reese)',
#   'Power',
#   'Memories (feat. Sirah) - Radio Edit',
#   'Opa'],
#  'Mildenhaus': ['Ininna Tora'],
#  'Butterfly Boucher': ['Changes'],
#  'David Bowie': ['Changes',
#   'Heroes - Single Version; 1990 Remaster',
#   'Heroes - 2017 Remaster',
#   'Starman - 2012 Remaster',
#   'Under Pressure'],
#  'Coldplay': ['Paradise',
#   'Fix You',
#   'Hymn for the Weekend',
#   'Viva La Vida',
#   'Yellow',
#   'The Scientist',
#   'Viva La Vida',
#   'Hymn for the Weekend - Seeb Remix',
#   'Viva La Vida',
#   'Something Just Like This'],
#  'Eddie Vedder': ['Brother the Cloud'],
#  'RØRY': ['UNCOMPLICATED'],
#  'HBz': ['Gästeliste +1'],
#  'Royal Blood': ['Trouble’s Coming', 'Figure It Out'],
#  'Mr. Green': ['Welcome'],
#  'Dave East': ['Welcome'],
#  'Xzibit': ['My Name (feat. Eminem & Nate Dogg)'],
#  'Eminem': ['My Name (feat. Eminem & Nate Dogg)',
#   'Stan',
#   "When I'm Gone",
#   'Like Toy Soldiers',
#   'Without Me',
#   'Stan - Live At 43rd Grammy Awards',
#   'Mockingbird',
#   'Lose Yourself - From "8 Mile" Soundtrack',
#   'Sing For The Moment',
#   'Intro',
#   'FACK',
#   'My Name Is',
#   'Shake That',
#   "Cleanin' Out My Closet",
#   'Just Lose It',
#   'Guilty Conscience',
#   'The Real Slim Shady',
#   'The Way I Am',
#   'Venom - Remix',
#   'Kings Never Die',
#   'Love The Way You Lie',
#   'Not Afraid',
#   'Remind Me',
#   'Lose Yourself - From "8 Mile" Soundtrack'],
#  'Nate Dogg': ['My Name (feat. Eminem & Nate Dogg)',
#   'Shake That',
#   'Party We Will Throw Now!'],
#  'jxdn': ['ANGELS & DEMONS'],
#  'Graham Lake': ['Run em Down'],
#  'Avelino': ['Run em Down'],
#  'loafers': ['Lay All Your Love On Me'],
#  'Badjack': ['Lay All Your Love On Me'],
#  'Maxim Schunk': ['Lay All Your Love On Me'],
#  'ABBA': ['Lay All Your Love On Me', 'Super Trouper'],
#  'Mark Dekoda': ['Rave Harder Techno Bass'],
#  'Rnbstylerz': ['Like Wooh Wooh'],
#  'TITUS': ['Love Myself'],
#  'Max Bennett Kelly': ['Happy, Healthy, Well-Adjusted'],
#  'Oliver Tree': ['Let Me Down (feat. blink-182)'],
#  'blink-182': ['Let Me Down (feat. blink-182)',
#   'Scumbag (feat. blink-182)',
#   'Bored To Death',
#   'Sober',
#   "She's Out Of Her Mind",
#   'Ransom',
#   'Black Rain',
#   'Run Away',
#   'Remember To Forget Me',
#   'Pin the Grenade',
#   'Darkside',
#   'The First Time',
#   'Heaven',
#   'Blame It On My Youth',
#   'Happy Days',
#   'I Really Wish I Hated You',
#   'No Heart To Speak Of',
#   'On Some Emo Shit',
#   'Generational Divide',
#   'Hungover You',
#   'Home Is Such A Lonely Place',
#   'California',
#   'Teenage Satellites',
#   'Bored To Death',
#   'Misery',
#   "Can't Get You More Pregnant",
#   'Cynical',
#   'Bored To Death (Acoustic)',
#   "Don't Mean Anything",
#   'Built This Pool',
#   '6/8',
#   'Last Train Home',
#   'Good Old Days',
#   'Sober',
#   'Wildfire',
#   'Bottom Of The Ocean',
#   'Los Angeles',
#   "She's Out Of Her Mind",
#   'The Only Thing That Matters',
#   'Long Lost Feeling',
#   'Rabbit Hole',
#   'Brohemian Rhapsody',
#   'Parking Lot',
#   'No Future',
#   "Hey I'm Sorry",
#   'Left Alone',
#   'Kings of the Weekend',
#   'San Diego',
#   'Go',
#   'Easy Target',
#   'Asthenia',
#   'I Miss You',
#   'The Fallen Interlude',
#   'Obvious',
#   "Here's Your Letter",
#   'Feeling This',
#   'Always',
#   'Stockholm Syndrome Interlude',
#   'Anthem Part Two - Live In Chicago',
#   'Down',
#   'Stockholm Syndrome',
#   'All Of This',
#   'Violence',
#   "I'm Lost Without You",
#   'Every Time I Look For You',
#   'Roller Coaster',
#   'First Date',
#   'Anthem Part Two',
#   'Online Songs',
#   'The Rock Show',
#   'Shut Up',
#   'Stay Together For The Kids',
#   'Reckless Abandon',
#   'Happy Holidays, You Bastard',
#   'Story Of A Lonely Guy',
#   'Give Me One Good Reason',
#   'Please Take Me Home',
#   'Going Away To College',
#   'Anthem',
#   'Dysentery Gary',
#   'Mutt',
#   'Dumpweed',
#   'Wendy Clear',
#   "Don't Leave Me",
#   'The Party Song',
#   'Aliens Exist',
#   "Adam's Song",
#   "What's My Age Again?",
#   'All The Small Things'],
#  'Lustra': ["Scotty Doesn't Know"],
#  't-low': ['We Made It', 'Sehnsucht', 'Crashen'],
#  'Miksu / Macloud': ['We Made It', 'Sehnsucht', 'Nachts wach'],
#  'charlieonnafriday': ['Enough'],
#  'Anastacia': ['Left Outside Alone'],
#  'DaCav5': ['Tetris'],
#  'A Boogie Wit da Hoodie': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Offset': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Arizona Zervas': ['Sober/Hungover (feat. Arizona Zervas)',
#   'Sober/Hungover (feat. Arizona Zervas)'],
#  'Sunrise Skater Kids': ['All the Old Things'],
#  'Christina Rotondo': ['All the Old Things'],
#  'Chri$tian Gate$': ['NUMB'],
#  'Nxvy': ['Emo Chick'],
#  'ALX8': ['Emo Chick'],
#  'JAY-Z': ['Empire State Of Mind', 'Numb / Encore'],
#  'Alicia Keys': ['Empire State Of Mind'],
#  'makko': ['Nachts wach'],
#  '44phantom': ["don't sleep, repeat (feat. Machine Gun Kelly)"],
#  'Matthias Reim': ['Verdammt, ich lieb Dich - 2020 Remastered'],
#  'Electric Callboy': ['Best Day'],
#  'Sido': ['Best Day',
#   'Liebe',
#   'Tausend Tattoos',
#   'Die Nacht von Freitag auf Montag'],
#  'Labrinth': ['When I R.I.P.',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Jealous'],
#  'The Used': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Bert McCracken': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Halsey': ['forget me too (feat. Halsey)',
#   'Sorry',
#   'Eastside (with Halsey & Khalid)',
#   'Closer'],
#  'blackbear': ["my ex's best friend (with blackbear)",
#   'make up sex (feat. blackbear)'],
#  'Trippie Redd': ['all I know (feat. Trippie Redd)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Wake Up Call (feat. Trippie Redd)'],
#  'Gunna': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Young Thug': ['die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'Havana (feat. Young Thug)'],
#  'Landon Barker': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Lil Wayne': ['drug dealer (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Let It Rock'],
#  'WILLOW': ['emo girl (feat. WILLOW)', 'emo girl (feat. WILLOW)'],
#  'glaive': ['more than life (feat. glaive)'],
#  'Bring Me The Horizon': ['maybe (feat. Bring Me The Horizon) - acoustic version',
#   'maybe (feat. Bring Me The Horizon)',
#   'maybe (feat. Bring Me The Horizon)',
#   'Can You Feel My Heart',
#   'Throne'],
#  'Mark Hoppus': ['All I Wanted (feat. Mark Hoppus)',
#   'Re-Entry (feat. Mark Hoppus)'],
#  'X Ambassadors': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'Unsteady'],
#  'Bebe Rexha': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   "I'm a Mess",
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix',
#   'In the Name of Love'],
#  'Dame': ['Mein Haus'],
#  'Solence': ['Good F**King Music'],
#  'The White Stripes': ['Astro',
#   'Seven Nation Army',
#   'Seven Nation Army',
#   'Icky Thump'],
#  'Stand Atlantic': ['deathwish (feat. nothing,nowhere.)'],
#  'nothing,nowhere.': ['deathwish (feat. nothing,nowhere.)'],
#  'Kode': ['Drunk Texts'],
#  'André De Shields': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Hadestown Original Broadway Company': ['Wait for Me (Reprise)',
#   'Wait for Me'],
#  'Anaïs Mitchell': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Reeve Carney': ['Wait for Me'],
#  'Jewelle Blackman': ['Wait for Me'],
#  'Yvette Gonzalez-Nacer': ['Wait for Me'],
#  'Kay Trinidad': ['Wait for Me'],
#  'Kimberly Marable': ['Wait for Me'],
#  'Timothy Hughes': ['Wait for Me'],
#  'Malcolm Armwood': ['Wait for Me'],
#  'Jessie Shelton': ['Wait for Me'],
#  'Khaila Wilcoxon': ['Wait for Me'],
#  'Ahmad Simmons': ['Wait for Me'],
#  'Afra Hines': ['Wait for Me'],
#  'T. Oliver Reid': ['Wait for Me'],
#  'John Krause': ['Wait for Me'],
#  'AMIICCA': ['Wait for Me'],
#  'Polo G': ['Martin & Gina', 'Patience (feat. YUNGBLUD & Polo G)'],
#  'Nelly Furtado': ['All Good Things (Come To An End)',
#   'Maneater',
#   'Broken Strings'],
#  'Akros': ['Lie'],
#  'Madonna': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Hung Up - Radio Version'],
#  'Justin Timberlake': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Timbaland': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Gabry Ponte': ['Mad World',
#   'Monster',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'AXMO': ['Skydance'],
#  'Giin': ['Skydance', 'Long Way Down'],
#  'Kate Bush': ['Running Up That Hill (A Deal With God)'],
#  'Ion Miles': ['Powerade'],
#  'SIRA': ['Powerade'],
#  'BHZ': ['Powerade'],
#  'Goody Grace': ['Scumbag (feat. blink-182)'],
#  'Jay Hoodie': ['Someone That You Hated'],
#  'Alligatoah': ['Trauerfeier Lied', 'Du bist schön'],
#  'Weedmane 2pac Dr Dre SnoopDogg': ['Bad and Boujee'],
#  'Butterfly Migos': ['Bad and Boujee'],
#  'Crazy Town': ['Bad and Boujee', 'Butterfly', 'Butterfly'],
#  'The Offspring': ['Behind Your Walls',
#   "You're Gonna Go Far, Kid",
#   'Self Esteem',
#   'Want You Bad',
#   "The Kids Aren't Alright"],
#  'Glass Animals': ['Heat Waves', 'Heat Waves'],
#  'We Three': ['Sara'],
#  'Sam Smith': ['Stay With Me', 'Dancing With A Stranger (with Normani)'],
#  'Christopher Lawrence': ['Rush Hour'],
#  'YONAKA': ['Seize the Power'],
#  'One Direction': ['Night Changes'],
#  'Cameron Sanderson': ['What Do You Want?'],
#  '4 Non Blondes': ["What's Up?"],
#  'The Bucketheads': ['The Bomb! (These Sounds Fall Into My Mind) - Radio Edit'],
#  'Vigiland': ['Buss It',
#   'Pong Dance',
#   'Another Shot\u202c\u202c\u202c',
#   'Addicted',
#   'Take This Ride',
#   'Be Your Friend\u202c\u202c',
#   'Never Going Home',
#   'Shots & Squats',
#   'Friday Night\u202c\u202c\u202c',
#   'Nice To Meet You',
#   'UFO - Radio Edit'],
#  'M24': ['Buss It'],
#  'Kraftklub': ['Ein Song reicht',
#   'Ganz schön okay (feat. Kraftklub)',
#   'Ich will nicht nach Berlin',
#   '500 K',
#   'Randale - Live'],
#  'Michael Jackson': ["They Don't Care About Us"],
#  'Des Rocs': ['Hanging by a Thread', 'Let Me Live / Let Me Die'],
#  'The Mysterines': ['Hung Up'],
#  'Bassjackers': ['De La Sol',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'The Fever',
#   'Block',
#   'Derp',
#   'Fireflies (feat. Luciana)',
#   'These Heights (feat. Caroline Pennell)',
#   'Memories (feat. Sirah) - Radio Edit',
#   'The Riddle',
#   'The Riddle - Extended Mix',
#   'Switch',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MAKJ': ['De La Sol',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Knockout',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Derp'],
#  'flora cash': ['Feeling So Down', "You're Somebody Else"],
#  'Austin George': ['Hands On You'],
#  'Betterov': ['Bring mich nach Hause', 'Viertel vor Irgendwas', 'Dussmann'],
#  'Mother Mother': ['Hayloft II'],
#  'Royal & the Serpent': ['FUCKBOI REJECTS'],
#  'grandson': ['Drop Dead (with Kesha and Travis Barker)', 'Blood // Water'],
#  'Kesha': ['Drop Dead (with Kesha and Travis Barker)',
#   'Good Old Days (feat. Kesha)',
#   'Praying',
#   'TiK ToK',
#   'Right Round (feat. Ke$ha)',
#   'Body Talks (feat. Kesha)'],
#  'Crawlers': ['Come Over (Again)'],
#  'A Day To Remember': ['Re-Entry (feat. Mark Hoppus)'],
#  'Fettes Brot': ['An Tagen wie diesen',
#   'Emanuela',
#   'Schwule Mädchen',
#   'Bettina, zieh dir bitte etwas an',
#   'Emanuela'],
#  'Dallerium': ['How Do I Sleep Now'],
#  'Olive': ['How Do I Sleep Now'],
#  'KUMMER': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Fred Rabe': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Lil Nas X': ['INDUSTRY BABY (feat. Jack Harlow)', 'THATS WHAT I WANT'],
#  'Jack Harlow': ['INDUSTRY BABY (feat. Jack Harlow)'],
#  'Jessie J': ['Wild', 'Price Tag', 'Wild - No Rap Edit', 'Who You Are'],
#  'Sofi Tukker': ['House Arrest'],
#  'Gorgon City': ['House Arrest'],
#  'Pixies': ['Where Is My Mind? - Remastered'],
#  'Nickelback': ['Burn it to the Ground',
#   'How You Remind Me',
#   'How You Remind Me'],
#  'Noah Cyrus': ['July', 'Lonely', 'All Falls Down (feat. Juliander)'],
#  'GAYLE': ['abcdefu', 'abcdefu (angrier)'],
#  'Beartooth': ['Hated'],
#  'Zedline': ['Polozhenie - Zedline Remix'],
#  'Pete Yorn': ['Ever Fallen In Love - From the Motion Picture "Shrek 2"'],
#  'Foreigner': ['I Want to Know What Love Is - 1999 Remaster'],
#  'Lostboi Lino': ['Wenn Du weinst'],
#  'Montez': ['Auf & Ab'],
#  'Scooter': ['Suck My Megamix - The Longest Scooter Single In The World',
#   'How Much Is The Fish?',
#   'Hyper Hyper',
#   'Suck My Megamix - The Longest Scooter Single in the World'],
#  'Tom Walker': ['Leave a Light On', 'Just You and I'],
#  'Van Halen': ["Can't Stop Lovin' You"],
#  'Bowling For Soup': ['Girl All the Bad Guys Want',
#   'Almost',
#   'Right About Now',
#   '1985'],
#  'We Were Promised Jetpacks': ['Quiet Little Voices'],
#  'Kid Cudi': ['Erase Me - Main',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix'],
#  'Kanye West': ['Erase Me - Main',
#   'POWER',
#   'Dark Fantasy',
#   'Stronger',
#   'Gold Digger'],
#  'Dido': ['Stan'],
#  'Elton John': ['Stan - Live At 43rd Grammy Awards'],
#  'Dr. Dre': ['Guilty Conscience'],
#  'Dexys Midnight Runners': ['Come On Eileen'],
#  'Counting Crows': ['Accidentally In Love'],
#  'AC/DC': ["It's a Long Way to the Top (If You Wanna Rock 'N' Roll)",
#   'Highway to Hell',
#   'You Shook Me All Night Long'],
#  'Beach House': ['Take Care'],
#  'Alesso': ['When I’m Gone (with Katy Perry)',
#   'Calling (Lose My Mind) - Radio Edit'],
#  'Katy Perry': ['When I’m Gone (with Katy Perry)',
#   'The One That Got Away - Acoustic',
#   'The One That Got Away - Acoustic',
#   'I Kissed A Girl',
#   'Firework'],
#  'Billy Idol': ['White Wedding',
#   'Dancing with Myself - 2001 Remaster',
#   'Dancing With Myself'],
#  'Generation X': ['Dancing with Myself - 2001 Remaster'],
#  'Slade': ['Merry Xmas Everybody'],
#  'Band Aid 30': ["Do They Know It's Christmas? - 2014"],
#  'Watsky': ['Sloppy Seconds'],
#  'Macklemore': ['Penis Song',
#   'Good Old Days (feat. Kesha)',
#   'Glorious (feat. Skylar Grey)',
#   "Can't Hold Us (feat. Ray Dalton)"],
#  'The Airborne Toxic Event': ['Sometime Around Midnight'],
#  'MOD SUN': ['Internet Killed The Rockstar'],
#  'G-Eazy': ['Still Be Friends (feat. Tory Lanez & Tyga)',
#   'My Year',
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix'],
#  'Tory Lanez': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Tyga': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Steve Aoki': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Hava',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Pretender (feat. Lil Yachty & AJR)',
#   'Mayhem',
#   'Be Somebody',
#   'Just Hold On',
#   'Lie To Me',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix',
#   'Azukita (Steve Aoki, Daddy Yankee, Play-N-Skillz & Elvis Crespo) (feat. Elvis Crespo)',
#   'Jaleo',
#   'MIC Drop (Steve Aoki Remix) [Full Length Edition]',
#   'MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Chris Lake': ['Delirious (Boneless) (feat. Kid Ink)'],
#  'Tujamo': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Grapevine - Tujamo Remix'],
#  'Kid Ink': ['Delirious (Boneless) (feat. Kid Ink)', 'Hey Baby', 'I Love You'],
#  'All Time Low': ['Dear Maria, Count Me In', 'Umbrella'],
#  'The All-American Rejects': ['Dirty Little Secret',
#   'Swing, Swing',
#   'Gives You Hell',
#   'Gives You Hell'],
#  'We The Kings': ['Check Yes, Juliet', 'Sad Song (feat. Elena Coats)'],
#  'Love A': ['Too Doof to Fuck'],
#  'Jules Ahoi': ['Robinson Crusoe'],
#  'Bushido': ['Alles wird gut'],
#  'Warren G': ['Party We Will Throw Now!'],
#  'The Game': ['Party We Will Throw Now!'],
#  'Mumford & Sons': ['Ditmas', 'Little Lion Man', 'I Will Wait'],
#  'Axel Black & White': ['Somebody To Love'],
#  'KSI': ['Holiday',
#   'Keep Up',
#   'Creature',
#   'Loose (feat. KSI)',
#   'Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'Patience (feat. YUNGBLUD & Polo G)',
#   'Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Jump Around',
#   'Touch Down',
#   'Uncontrollable (feat. Big Zuu)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)',
#   'Wake Up Call (feat. Trippie Redd)',
#   'Friends With Benefits (KSI vs MNDM)',
#   'Creature',
#   'Earthquake',
#   'Little Boy',
#   "Adam's Apple",
#   'Lamborghini',
#   'Two Birds, One Stone'],
#  'Donots': ['So Long'],
#  'Frank Turner': ['So Long'],
#  'Red Hot Chili Peppers': ['By the Way',
#   'Snow (Hey Oh)',
#   'Californication',
#   "Can't Stop"],
#  'Powfu': ['death bed (coffee for your head)'],
#  'beabadoobee': ['death bed (coffee for your head)'],
#  'Edwin Rosen': ['leichter//kälter'],
#  'Thees Uhlmann': ['Zum Laichen und Sterben ziehen die Lachse den Fluss hinauf'],
#  'Blond': ['Match'],
#  'Saint Motel': ['My Type'],
#  'Philipp Poisel': ['Wie soll ein Mensch das ertragen',
#   'Mein Amerika',
#   'Erkläre mir die Liebe',
#   'Ich will nur - Live',
#   'Liebe meines Lebens',
#   'Wolke 7',
#   'Wie soll ein Mensch das ertragen'],
#  'DJ Gollum': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Scarlet': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'DJ THT': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Ced Tecknoboy': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Tate McRae': ['you broke me first'],
#  'Razz': ['Youth & Enjoyment'],
#  'Twenty One Pilots': ['Addict With A Pen'],
#  'Quietdrive': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'Droo Hastings From Drrt': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'P!nk': ['Try',
#   'Walk Me Home',
#   'Raise Your Glass',
#   'So What',
#   'What About Us - Cash Cash Remix'],
#  'NF': ['Lie', 'Paralyzed', 'Let You Down'],
#  'Emil Bulls': ['The Jaws of Oblivion'],
#  'ANA': ['Whiskey'],
#  '100 Kilo Herz': ['Laternensong'],
#  'The Weeknd': ['Save Your Tears', 'Blinding Lights', 'The Hills'],
#  'Die Toten Hosen': ['Oberhausen',
#   'Vogelfrei',
#   'Herz brennt',
#   'Steh auf, wenn du am Boden bist',
#   'Auswärtsspiel',
#   'Hier kommt Alex',
#   'Bonnie & Clyde',
#   'Wannsee',
#   'Alles passiert',
#   'Alles aus Liebe'],
#  'Jennifer Rostock': ['K.B.A.G.', 'Alles Cool', 'Hengstin'],
#  'Rainbirds': ['Blueprint'],
#  'Bananafishbones': ['für immer', 'Vanessa'],
#  'Ran-D': ['Zombie - Original Mix'],
#  'Dvbbs': ['Raveology'],
#  'VINAI': ['Raveology', 'Break the Beat', 'Out of This Town'],
#  'Emily Watts': ['La Vie En Rose'],
#  'Metro Station': ['Shake It', 'Shake It'],
#  'Neonschwarz': ['On a Journey'],
#  'The Vamps': ['Somebody To You'],
#  'Kina': ['Can We Kiss Forever?'],
#  'Adriana Proenza': ['Can We Kiss Forever?'],
#  'Alec Benjamin': ['Let Me Down Slowly'],
#  'The Fray': ['You Found Me', 'How to Save a Life'],
#  'Ida Corr': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Fedde Le Grand': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Iggy Pop': ['Lust For Life'],
#  'Olivia Rodrigo': ['All I Want', 'good 4 u', 'drivers license'],
#  'Disney': ['All I Want'],
#  'Sarah Connor': ['Wie schön du bist', 'Vincent'],
#  'Ed Sheeran': ['Bad Habits',
#   'Galway Girl',
#   'Castle on the Hill',
#   'Perfect - Robin Schulz Remix',
#   'Photograph',
#   'Happier - Tiësto’s AFTR:HRS Remix'],
#  'Lukas Graham': ['Mama Said'],
#  'Drake': ['One Dance', "God's Plan"],
#  'Wizkid': ['One Dance'],
#  'Kyla': ['One Dance'],
#  'The Kid LAROI': ['STAY (with Justin Bieber)'],
#  'Justin Bieber': ['STAY (with Justin Bieber)'],
#  'Lost Frequencies': ['Love to Go',
#   'Reality',
#   'Reality - Gestört aber GeiL Remix',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Are You With Me - Radio Edit',
#   'Are You With Me - Gestört aber GeiL Remix',
#   'Melody',
#   'So Much Better - Lost Frequencies Remix',
#   'Paris - Lost Frequencies Remix',
#   'Crazy',
#   'Run - Lost Frequencies Radio Edit',
#   'Here with You',
#   'Beautiful Life',
#   'Are You with Me',
#   'Melody',
#   'Like I Love You',
#   'Reality - Gestört aber GeiL Remix',
#   'Are You with Me - Gestört aber GeiL Remix'],
#  'Zonderling': ['Love to Go', 'Crazy'],
#  'Kelvin Jones': ['Love to Go'],
#  'Lipps Inc.': ['Funkytown'],
#  'Cheap Trick': ['Just Got Back'],
#  'Hot Chocolate': ["Every 1's a Winner - Single Version"],
#  'Juju': ['Vermissen (feat. Henning May)'],
#  'Henning May': ['Vermissen (feat. Henning May)'],
#  'Tobi & Manny': ['Rhythm & Vibes',
#   'Destined For Greatness',
#   'Destined For Greatness'],
#  'Irie Révoltés': ['Fäuste hoch'],
#  'Robbie Williams': ['Candy', 'Angels', 'Rock DJ'],
#  'Florence + The Machine': ['Shake It Out'],
#  'Papa Roach': ['Scars', 'Help'],
#  'Radical Face': ['Welcome Home, Son', 'Welcome Home'],
#  'Radiohead': ['Fake Plastic Trees', 'Creep'],
#  'Masked Wolf': ['Astronaut In The Ocean'],
#  'Neil Patrick Harris': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'How I Met Your Mother Cast': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'Tom Petty': ["Free Fallin'"],
#  'Julia Michaels': ['All Your Exes',
#   'Hurt Somebody',
#   'Into You',
#   'Lie To Me (feat. Julia Michaels)',
#   'Hurt Somebody'],
#  'Måneskin': ['I WANNA BE YOUR SLAVE'],
#  'Noah Kahan': ['Hurt Somebody', 'False Confidence', 'Hurt Somebody'],
#  'Provinz': ['Chaos'],
#  'Tai Verdes': ['Stuck In The Middle'],
#  'Dua Lipa': ['Levitating (feat. DaBaby)',
#   'Physical - Alok Remix',
#   'Electricity (with Dua Lipa)',
#   'IDGAF',
#   'One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   'Scared to Be Lonely - Acoustic Version',
#   'Scared to Be Lonely'],
#  'DaBaby': ['Levitating (feat. DaBaby)', 'ROCKSTAR (feat. Roddy Ricch)'],
#  'Harry Styles': ['Falling', 'Watermelon Sugar', 'Sign of the Times'],
#  'Finn': ['In Luv With U'],
#  'The Neighbourhood': ['Sweater Weather'],
#  'Moby': ['Extreme Ways', 'Lift Me Up'],
#  'Da Tweekaz': ['Heroes Of Today', 'D.W.X. (10 Years Dirty Workz Mix)'],
#  'Riverdale Cast': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Ashleigh Murray': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Camila Mendes': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Madelaine Petsch': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Asha Bromfield': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Hayley Law': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'KJ Apa': ['Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Kelis': ['Milkshake'],
#  'Juice WRLD': ['Lucid Dreams', 'Come & Go (with Marshmello)'],
#  'ElyOtto': ['SugarCrash!'],
#  'Basstrologe': ['Somebody To Love'],
#  'Marlon Roudette': ['New Age'],
#  'Tears For Fears': ['Shout'],
#  'Prinz Pi': ['Letzte Liebe', 'Kompass ohne Norden', '1,40m'],
#  'Roddy Ricch': ['ROCKSTAR (feat. Roddy Ricch)'],
#  'Bonnie Tyler': ['Holding Out for a Hero - From "Footloose" Soundtrack'],
#  'Marshmello': ['Come & Go (with Marshmello)',
#   'Here With Me',
#   'BIBA',
#   'Everyday',
#   'FRIENDS',
#   'Danger (with Migos & Marshmello)',
#   'Wolves',
#   'Alone',
#   'Bayen Habeit',
#   'Happier',
#   'You Can Cry',
#   'Everyday',
#   'Spotlight',
#   'Silence'],
#  'A$ton Wyld': ['Next Level'],
#  'Jme': ['Keep Up'],
#  'S1mba': ['Loose (feat. KSI)'],
#  'Craig David': ['Really Love (feat. Craig David & Digital Farm Animals)'],
#  'Digital Farm Animals': ['Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'All Falls Down (feat. Juliander)'],
#  'Anne-Marie': ["Don't Play",
#   '2002',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Ciao Adios - Burak Yeter Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'FRIENDS'],
#  'Zedd': ['The Middle', 'The Middle', 'Beautiful Now', 'Happy Now'],
#  'Maren Morris': ['The Middle', 'GIRL', 'The Middle'],
#  'Grey': ['The Middle', 'The Middle'],
#  '24kGoldn': ['Mood (feat. iann dior)'],
#  'Our Last Night': ['drivers license'],
#  'Creedence Clearwater Revival': ['Fortunate Son'],
#  'Mark Ronson': ['Valerie (feat. Amy Winehouse) - Version Revisited',
#   'Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Electricity (with Dua Lipa)'],
#  'Amy Winehouse': ['Valerie (feat. Amy Winehouse) - Version Revisited'],
#  'Cornershop': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'Norman Cook': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'NEIKED': ['Sexual'],
#  'Dyo': ['Sexual'],
#  'Capital Cities': ['Safe And Sound'],
#  'George Ezra': ['Hold My Girl', 'Paradise'],
#  'Vance Joy': ['Mess Is Mine'],
#  'Lil Glock Rouge': ['Merry Merry Christmas'],
#  'Sidemen': ['Merry Merry Christmas', 'The Gift'],
#  'Linkin Park': ['Shadow of the Day',
#   'CASTLE OF GLASS',
#   'Numb / Encore',
#   'In the End',
#   'Numb'],
#  'Duncan Laurence': ['Arcade'],
#  'flipturn': ['Chicago'],
#  'Ava Max': ['Kings & Queens',
#   'Sweet but Psycho',
#   'Let It Be Me (feat. Ava Max)'],
#  'Camila Cabello': ['Havana (feat. Young Thug)'],
#  'Silbermond': ['Irgendwas bleibt'],
#  'Jaymes Young': ["I'll Be Good"],
#  'Blue October': ['Hate Me'],
#  'Pickle': ['Sing It'],
#  'Endor': ['Pump It Up'],
#  'Outkast': ['Roses', 'Ms. Jackson'],
#  'Otto Knows': ['Million Voices - Radio Edit'],
#  'Jetta': ["I'd Love To Change The World - Matstubs Remix"],
#  'Matstubs': ["I'd Love To Change The World - Matstubs Remix"],
#  'John Newman': ['Love Me Again'],
#  'Rihanna': ['Disturbia', 'Stay', 'Love The Way You Lie', 'Live Your Life'],
#  'Die Firma': ['Die Eine 2005'],
#  'The Smiths': ['Asleep - 2011 Remaster'],
#  'Edward Sharpe & The Magnetic Zeros': ['Home'],
#  'lovelytheband': ['broken'],
#  'Johnny Cash': ['Hurt'],
#  'James Bay': ['Hold Back The River'],
#  'BANNERS': ['Shine A Light', 'Someone To You', 'Ghosts'],
#  'U2': ['Bad - Remastered 2009',
#   'Beautiful Day',
#   'With Or Without You - Remastered'],
#  'Casper': ['Ganz schön okay (feat. Kraftklub)', 'So perfekt'],
#  'Lewis Capaldi': ['Someone You Loved', 'Bruises'],
#  'Chip Taylor': ['On the Radio (Music from the Netflix Original Series Sex Education)'],
#  'Jerome': ['Light'],
#  'DVBBS': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Dropgun': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Sanjin': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Emeli Sandé': ['Clown', 'Read All About It, Pt. III'],
#  'Gwen Stefani': ['Kings Never Die', 'Hollaback Girl'],
#  '5 Seconds of Summer': ['She Looks So Perfect',
#   'Youngblood',
#   'Lie To Me (feat. Julia Michaels)',
#   'Youngblood - R3HAB Remix'],
#  'GAMPER & DADONI': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Emily Roberts': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Purple Disco Machine': ['Exotica', 'Hypnotized'],
#  'Mind Enterprises': ['Exotica'],
#  'Fritz Kalkbrenner': ['Good Things', 'Sky and Sand'],
#  'Martin Solveig': ['All Stars'],
#  'ALMA': ['All Stars'],
#  'AWOLNATION': ['Sail'],
#  'Sophie and the Giants': ['Hypnotized'],
#  'Neptunica': ['San Francisco'],
#  'Ellipso': ['San Francisco'],
#  'Emy Perez': ['San Francisco'],
#  'Chord Overstreet': ['Hold On'],
#  'Dimitri Vegas & Like Mike': ['Body Talk (feat. Julian Perretta)',
#   'The Anthem (Der Alte)',
#   'Beast (All as One)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'Wakanda',
#   'Mammoth',
#   'Ocarina',
#   'The Hum - Original Mix',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix',
#   'Hey Baby',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'Ready For Action',
#   'He\'s a Pirate (VIP Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate (Extended Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate - From "Pirates of the Caribbean: Dead Men Tell No Tales" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'Complicated (feat. Kiiara)',
#   'Crowd Control - Radio Edit',
#   'Slow Down (feat. Boef, Ronnie Flex, Ali B & I Am Aisha)',
#   'Patser Bounce',
#   'The House Of House',
#   'All I Need (with Gucci Mane)',
#   'When I Grow Up (feat. Wiz Khalifa)',
#   'Unity',
#   'Here We Go (Hey Boy, Hey Girl)',
#   'Opa',
#   'Arcade Mammoth',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MOGUAI': ['Body Talk (feat. Julian Perretta)', 'Mammoth', 'Arcade Mammoth'],
#  'Julian Perretta': ['Body Talk (feat. Julian Perretta)'],
#  'Krunk!': ['La Menta', 'Al Pacino'],
#  'Max Herre': ['Wolke 7'],
#  'Revolverheld': ['Halt dich an mir fest'],
#  'David Guetta': ['Where Them Girls At (feat. Nicki Minaj & Flo Rida)',
#   "Club Can't Handle Me (feat. David Guetta)",
#   'Let It Be Me (feat. Ava Max)',
#   'Flames',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Like I Do',
#   'Titanium (feat. Sia)',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Like I Do',
#   'Complicated (feat. Kiiara)'],
#  'Sean Paul': ['Temperature'],
#  'Toploader': ['Dancing in the Moonlight'],
#  'Bruce Springsteen': ['Dancing In the Dark'],
#  'Lister': ['Pathways'],
#  'The Lumineers': ['Ophelia'],
#  'Vinnie Paz': ['The Ghost I Used to Be'],
#  'Eamon': ['The Ghost I Used to Be'],
#  'Elena Coats': ['Sad Song (feat. Elena Coats)'],
#  'Dean Lewis': ['Half A Man'],
#  'Pitbull': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Back in Time - featured in "Men In Black 3"',
#   'Bailar (feat. Pitbull & Elvis Crespo)'],
#  'Ne-Yo': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'AFROJACK': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Ten Feet Tall',
#   'Turn up the Speakers - Radio Edit'],
#  'Nayer': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'Coone': ['D.W.X. (10 Years Dirty Workz Mix)',
#   'Words From The Gang (2014 Remix) - Radio Version',
#   'Pump up the Jam'],
#  'Imagine Dragons': ["It's Time",
#   'On Top Of The World',
#   'Thunder',
#   'Thunder',
#   'Radioactive',
#   'Thunder',
#   'Believer - Kaskade Remix'],
#  'Lord Huron': ['The Night We Met'],
#  'Tungevaag': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'Wicked Wonderland',
#   'All For Love - Luca Schreiner Remix'],
#  'Raaban': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'All For Love - Luca Schreiner Remix'],
#  'Emila': ['Samsara (feat. Emila)'],
#  'Brynny': ['Thinking Too Much'],
#  'DJ Antoine': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'The Beatshakers': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'Herbert Grönemeyer': ['Glück', 'Flugzeuge im Bauch'],
#  'Elliott Smith': ['Say Yes', 'Say Yes'],
#  'Gloria Gaynor': ['I Will Survive - Single Version'],
#  'Good Charlotte': ['I Just Wanna Live',
#   'The River',
#   'Girls & Boys',
#   'Lifestyles of the Rich & Famous'],
#  'Frittenbude': ['Mindestens in 1000 Jahren'],
#  'Jessica Ricca': ["Hey It’s Delilah (Plain White T's Cover)"],
#  'Adele': ['Someone Like You', 'When We Were Young'],
#  'LUM!X': ['Monster'],
#  'Rosa Anschütz': ['Rigid - Kobosil 44 Rush Mix'],
#  'Kobosil': ['Rigid - Kobosil 44 Rush Mix'],
#  'Stanfour': ['Wishing You Well - Radio Version'],
#  'Bloodhound Gang': ['Uhn Tiss Uhn Tiss Uhn Tiss',
#   'The Ballad Of Chasey Lain',
#   'The Bad Touch',
#   'Foxtrot Uniform Charlie Kilo'],
#  'Drunkenmunky': ['E'],
#  'ZAYN': ['Dusk Till Dawn (feat. Sia) - Radio Edit'],
#  'Sia': ['Dusk Till Dawn (feat. Sia) - Radio Edit',
#   'The Greatest',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Flames',
#   'Titanium (feat. Sia)'],
#  'Diddy - Dirty Money': ['Coming Home'],
#  'Skylar Grey': ['Coming Home', 'Glorious (feat. Skylar Grey)'],
#  'Snow Patrol': ['Called Out In The Dark',
#   'Chasing Cars',
#   'Chasing Cars',
#   'Chasing Cars'],
#  'B.o.B': ['Price Tag', 'Airplanes (feat. Hayley Williams of Paramore)'],
#  'David Gray': ["This Year's Love"],
#  'The Who': ["Baba O'Riley"],
#  'Broilers': ['Tanzt du noch einmal mit mir?'],
#  'Route 94': ['My Love (feat. Jess Glynne)'],
#  'Jess Glynne': ['My Love (feat. Jess Glynne)', 'Take Me Home'],
#  'My Chemical Romance': ['The Only Hope for Me Is You',
#   "I Don't Love You",
#   'Disenchanted - Live Demo',
#   'Kill All Your Friends - Live Demo',
#   'All the Angels - Live Demo',
#   'House of Wolves - Version 2; Live Demo',
#   'Famous Last Words',
#   'Cancer',
#   'Party at the End of the World - Live Demo',
#   'Dead!',
#   'Emily - Rough Mix',
#   'Not That Kind of Girl - Live Demo',
#   'The Five of Us Are Dying - Rough Mix',
#   'House of Wolves',
#   'The Sharpest Lives',
#   'Sleep',
#   'Blood - Hidden Track',
#   'Disenchanted',
#   'Teenagers',
#   'House of Wolves - Version 1; Live Demo',
#   'Mama - Live Demo',
#   'Welcome to the Black Parade',
#   'Mama',
#   'The End.',
#   'My Way Home Is Through You - Live Demo',
#   'This Is How I Disappear',
#   'Vampire Money',
#   'DESTROYA',
#   'The Only Hope for Me Is You',
#   'Goodnite, Dr. Death',
#   'Party Poison',
#   'Look Alive, Sunshine',
#   'SING',
#   'Bulletproof Heart',
#   'Jet-Star and the Kobra Kid / Traffic Report',
#   "Save Yourself, I'll Hold Them Back",
#   'Planetary (GO!)',
#   'S/C/A/R/E/C/R/O/W',
#   'The Kids from Yesterday',
#   'Summertime',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Drowning Lessons',
#   'Cubicles',
#   'Romance',
#   'Demolition Lovers',
#   'This Is the Best Day Ever',
#   'Early Sunsets Over Monroeville',
#   'Skylines and Turnstiles',
#   'Our Lady of Sorrows',
#   'Headfirst for Halos',
#   "Honey, This Mirror Isn't Big Enough for the Two of Us",
#   'Vampires Will Never Hurt You',
#   'Thank You for the Venom',
#   "Give 'Em Hell, Kid",
#   'To the End',
#   "Hang 'Em High",
#   'Cemetery Drive',
#   "It's Not a Fashion Statement, It's a Deathwish",
#   'Interlude',
#   'You Know What They Do to Guys Like Us in Prison',
#   'I Never Told You What I Do for a Living',
#   'The Jetset Life Is Gonna Kill You',
#   'This Is How I Disappear',
#   'Dead!',
#   'Blood - Hidden Track',
#   'The Sharpest Lives',
#   'Sleep',
#   'Disenchanted',
#   'The End.',
#   'House of Wolves',
#   'Kill All Your Friends',
#   'Cancer',
#   'Mama',
#   'The Ghost of You',
#   'Famous Last Words',
#   "I Don't Love You",
#   'Helena',
#   'Welcome to the Black Parade',
#   "I'm Not Okay (I Promise)",
#   'Na Na Na (Na Na Na Na Na Na Na Na Na)',
#   'Teenagers',
#   'Fake Your Death'],
#  'James Arthur': ['Can I Be Him', 'You Can Cry'],
#  'Thomas Rhett': ['Die A Happy Man'],
#  'Anis Don Demina': ['Uno Dos Tres Shurda'],
#  'VOLAC': ['In A Club'],
#  'illusionize': ['In A Club'],
#  'Andre Longo': ['In A Club'],
#  'Popp & Popp': ['Lieblingsfarbe Sonne'],
#  'Flowa': ['Lieblingsfarbe Sonne'],
#  'Neelix': ['You',
#   'Before - Neelix Well Done Remix',
#   'Waterfall',
#   'Makeup (feat. Caroline Harrison)',
#   'Looking Like We Usually Look',
#   'Mosquito',
#   'The Sun',
#   'Angels of Destruction - Neelix Remix',
#   'Expect What',
#   'History',
#   '1000 Sterne'],
#  'AJR': ["I'm Ready", '100 Bad Days', 'Pretender (feat. Lil Yachty & AJR)'],
#  'Calum Scott': ['Dancing On My Own',
#   'Dancing On My Own',
#   'Dancing On My Own - Tiësto Remix'],
#  'Hayley Williams': ['Airplanes (feat. Hayley Williams of Paramore)'],
#  'You Me At Six': ['Underdog'],
#  'Mattafix': ['Big City Life'],
#  'Wrabel': ['Ten Feet Tall', 'Written in the Scars (feat. Wrabel)'],
#  'Yeah Yeah Yeahs': ['Heads Will Roll - A-Trak Remix'],
#  'A-Trak': ['Heads Will Roll - A-Trak Remix'],
#  'DJ Blyatman': ['Gopnik'],
#  'Dom Dolla': ['San Frandisco'],
#  'Ricky Desktop': ['The Banjo Beat, Pt. 1'],
#  'Nathan Dawe': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)'],
#  'Ella Henderson': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Yours'],
#  'Boyce Avenue': ['The One That Got Away'],
#  'Armin van Buuren': ['You Are',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'Turn It Up',
#   'Blah Blah Blah',
#   'Great Spirit',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Blah Blah Blah',
#   'Therapy',
#   'This Is What It Feels Like',
#   'Drowning - Avicii Remix',
#   'United',
#   'Sunny Days',
#   'Wild Wild Son',
#   'Another You',
#   'Off The Hook'],
#  'Sunnery James & Ryan Marciano': ['You Are'],
#  'Will Sparks': ['My Spine Is Tingling',
#   '#SELFIE - Will Sparks Remix',
#   '#Selfie - Will Sparks Remix',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Take Me (feat. Gloria Kim)',
#   'Sick Like That (feat. Luciana)',
#   'Ah Yeah So What - Radio Edit',
#   'Senseless',
#   'Leave The Lights On - Will Sparks Remix',
#   'My Time',
#   'Voices'],
#  'Luciana': ['My Spine Is Tingling',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Sick Like That (feat. Luciana)',
#   'Fireflies (feat. Luciana)'],
#  'Sonar': ['Sonar'],
#  'SCNDL': ['Sonar', 'Bleed'],
#  'Mikky Ekko': ['Stay'],
#  'Alok': ["Don't Ya - Fabio Fusco Remix",
#   'Physical - Alok Remix',
#   'Piece Of Your Heart - Alok Remix',
#   'United'],
#  'FractaLL': ["Don't Ya - Fabio Fusco Remix"],
#  'Bea Jourdan': ["Don't Ya - Fabio Fusco Remix"],
#  'Fabio Fusco': ["Don't Ya - Fabio Fusco Remix"],
#  'Tiësto': ['God Is A Dancer - James Hype Remix',
#   'Grapevine - Tujamo Remix',
#   'On My Way',
#   'Happier - Tiësto’s AFTR:HRS Remix',
#   'BOOM',
#   'Dancing On My Own - Tiësto Remix',
#   'WOW',
#   'Jackie Chan',
#   'Red Lights',
#   'Split (Only U)',
#   'Carry You Home',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Harder'],
#  'Mabel': ['God Is A Dancer - James Hype Remix'],
#  'James Hype': ['God Is A Dancer - James Hype Remix'],
#  'Chiddy Bang': ['Opposite of Adults'],
#  'Tigerlily': ['Invisible Children', 'Spice Temple - Overdrive Remix'],
#  'BOSS': ['Dumb (Feat. BOSS)', 'Over and Out (feat. Charlott Boss)'],
#  'Mike Williams': ['Wait Another Day', 'The Beat', 'Lullaby'],
#  'Mesto': ['Wait Another Day'],
#  'Angels & Airwaves': ['Surrender',
#   'Chasing Shadows',
#   'The Adventure',
#   'Surrender'],
#  'R3HAB': ['Flashlight',
#   'Wrong Move (feat. Olivia Holt)',
#   'Rumors',
#   'Radio Silence',
#   'Tequila - R3HAB Remix',
#   'Starflight',
#   'Youngblood - R3HAB Remix',
#   'Lullaby',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'Freak',
#   "I Just Can't"],
#  'Deorro': ['Flashlight',
#   'Melbourne Bounce - Deorro Remix',
#   'Bootie in Your Face - No Rock Drop',
#   'Focus',
#   'Focus (feat. Lena Leon)',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'I Can Be Somebody (feat. Erin McCarley)',
#   'Bailar (feat. Pitbull & Elvis Crespo)',
#   'Bailar (feat. Elvis Crespo) - Radio Edit',
#   'Five More Hours',
#   'DFTF',
#   'Perdoname (feat. DyCy & Adrian Delgado)',
#   'Tell Me Lies (feat. Lesley Roy)',
#   'Five Hours',
#   'Knockout'],
#  'Von Wegen Lisbeth': ['Bitch'],
#  'Showtek': ['Booyah - Radio Edit', 'We Like to Party - Original Mix'],
#  'We Are Loud': ['Booyah - Radio Edit'],
#  'Sonny Wilson': ['Booyah - Radio Edit'],
#  'Club Madness': ['Pumped Up Kicks - Smithee Hard Edit'],
#  'Snoop Dogg': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Hollywood (feat. Snoop Dogg & Jamie Principle)',
#   'Bounce (feat. Snoop Dogg)'],
#  'Wiz Khalifa': ['Young, Wild & Free (feat. Bruno Mars)',
#   "Don't Kill My High (feat. Wiz Khalifa & Social House)",
#   'Payphone',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'When I Grow Up (feat. Wiz Khalifa)'],
#  'Bruno Mars': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Finesse - Remix; feat. Cardi B'],
#  'Ummet Ozcan': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Change My Heart',
#   'The Hum - Short Edit',
#   'The Hum - Original Mix',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Brennan Heart': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix'],
#  'Keane': ['Somewhere Only We Know'],
#  'Curtis Waters': ["Stunnin' (feat. Harm Franklin)"],
#  'Harm Franklin': ["Stunnin' (feat. Harm Franklin)"],
#  'Ali As': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Namika': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Gnarls Barkley': ['Crazy'],
# ...
#  'The Prince Karma': ['Later Bitches'],
#  'Ozzy Osbourne': ["Mama, I'm Coming Home", 'Dreamer'],
#  'Boston': ['More Than a Feeling'],
#  'Fall Out Boy': ["This Ain't A Scene, It's An Arms Race",
#   "Sugar, We're Goin Down",
#   'Centuries',
#   "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'The Last Of The Real Ones'],
#  'Fitz and The Tantrums': ['HandClap'],
#  'Die Ärzte': ['Ist das noch Punkrock?', 'Deine Schuld'],
#  'Kodaline': ['All I Want'],
#  'Green Day': ['Holiday',
#   'Holiday / Boulevard of Broken Dreams',
#   'Still Breathing',
#   'When I Come Around',
#   'Boulevard of Broken Dreams',
#   'Wake Me up When September Ends',
#   'Welcome to Paradise',
#   'Basket Case',
#   'Good Riddance (Time of Your Life)',
#   'American Idiot',
#   'Restless Heart Syndrome',
#   'East Jesus Nowhere',
#   '21st Century Breakdown',
#   "Christian's Inferno",
#   'Before the Lobotomy',
#   'The Static Age',
#   'American Eulogy: Mass Hysteria / Modern World',
#   '¿Viva La Gloria? (Little Girl)',
#   'Horseshoes and Handgrenades',
#   'Murder City',
#   '¡Viva La Gloria!',
#   'Last of the American Girls',
#   'Last Night on Earth',
#   'See the Light',
#   'Peacemaker',
#   'Know Your Enemy',
#   '21 Guns',
#   'Song of the Century',
#   'Makeout Party - Demo',
#   '99 Revolutions - Demo',
#   'Stray Heart - Demo',
#   'Angel Blue - Demo',
#   'Nuclear Family - Demo',
#   'Ashley - Demo',
#   'A Little Boy Named Train - Demo',
#   'Oh Love - Demo',
#   'Sex, Drugs & Violence - Demo',
#   'Stay the Night - Acoustic',
#   'Baby Eyes - Demo',
#   'Missing You - Demo',
#   'Carpe Diem - Demo',
#   'Rusty James - Demo',
#   'State of Shock - Demo',
#   'Let Yourself Go - Demo',
#   'Fell for You - Demo',
#   'Stay the Night - Demo',
#   'Drama Queen',
#   'A Little Boy Named Train',
#   'The Forgotten',
#   'Dirty Rotten Bastards',
#   'Sex, Drugs & Violence',
#   'Missing You',
#   'Amanda',
#   '99 Revolutions',
#   'X-Kid',
#   '8th Avenue Serenade',
#   'Brutal Love',
#   'Walk Away',
#   'Fuck Time',
#   'Baby Eyes',
#   "Wow! That's Loud",
#   'Stray Heart',
#   'Lazy Bones',
#   'Stop When the Red Lights Flash',
#   'Ashley',
#   'Nightlife',
#   'Makeout Party',
#   'Lady Cobra',
#   'Wild One',
#   'Amy',
#   'See You Tonight',
#   'Troublemaker',
#   'Sweet 16',
#   'Rusty James',
#   'Oh Love',
#   'Fell for You',
#   'Nuclear Family',
#   'Angel Blue',
#   'Loss of Control',
#   'Let Yourself Go',
#   'Stay the Night',
#   'Carpe Diem',
#   'Kill the DJ',
#   'Holiday / Boulevard of Broken Dreams',
#   'Jesus of Suburbia',
#   "Give Me Novacaine / She's a Rebel",
#   'Homecoming',
#   'Extraordinary Girl / Letterbomb',
#   'Too Much Too Soon',
#   'Wake Me up When September Ends',
#   'American Idiot',
#   'Governator',
#   'Shoplifter',
#   'Whatsername'],
#  'MICAR': ["This Time It's My Life - Radio Edit"],
#  'Breathe Carolina': ['My Love', 'The Fever'],
#  'Robert Falcon': ['My Love'],
#  'The Cure': ["Friday I'm In Love"],
#  'Jon Boden': ['How Long Will I Love You'],
#  'Sam Sweeney': ['How Long Will I Love You'],
#  'Ben Coleman': ['How Long Will I Love You'],
#  'G.R.L.': ['Ugly Heart'],
#  'T.I.': ['Live Your Life'],
#  'Die Antwoord': ['Banana Brain'],
#  'Belik Boom': ['Avada Kadabra'],
#  'Bag Raiders': ['Shooting Stars'],
#  'Alle Farben': ['H.O.L.Y.', 'Please Tell Rosie', 'Fading'],
#  'RHODES': ['H.O.L.Y.'],
#  'YouNotUs': ['Please Tell Rosie'],
#  'Hoobastank': ['The Reason', 'The Reason'],
#  'Three Days Grace': ['I Hate Everything About You'],
#  'Thirty Seconds To Mars': ['The Kill'],
#  'Bon Jovi': ["It's My Life",
#   'You Give Love A Bad Name',
#   "Livin' On A Prayer"],
#  'The Subways': ['Rock & Roll Queen'],
#  'Puddle Of Mudd': ['She Hates Me'],
#  'Third Eye Blind': ['Semi-Charmed Life'],
#  'Caesars': ['Jerk It Out', 'Jerk It Out'],
#  'Nirvana': ['Smells Like Teen Spirit',
#   'Come As You Are',
#   'Smells Like Teen Spirit'],
#  'Escape the Fate': ['Broken Heart'],
#  'Andrew Rayel': ['Horizon'],
#  'Lola Blanc': ['Horizon'],
#  'Philipp Dittberner': ['1,40m'],
#  'John De Sohn': ['Forever Young', 'Happy Kids'],
#  'LIAMOO': ['Forever Young'],
#  'Fox Blanco': ['Change the World'],
#  'Davai': ['Replay (feat. CIRE)'],
#  'CIRE': ['Replay (feat. CIRE)'],
#  'Alvaro Soler': ['La Cintura'],
#  'Matt Simons': ['We Can Do Better'],
#  'Swedish House Mafia': ["Don't You Worry Child (Radio Edit) [feat. John Martin]"],
#  'MIKA': ['Grace Kelly'],
#  'Laurell': ['Change My Heart', 'Good Vibes (feat. Laurell)'],
#  'Kris Kross Amsterdam': ['Whenever (feat. Conor Maynard)'],
#  'The Boy Next Door': ['Whenever (feat. Conor Maynard)'],
#  'Conor Maynard': ['Whenever (feat. Conor Maynard)'],
#  'ItaloBrothers': ['Summer Air', 'Till You Drop'],
#  'Blur': ['Song 2', 'Song 2 - 2012 Remaster'],
#  'XO Cupid': ['True Colors (feat. Maya Avedis)'],
#  'Maya Avedis': ['True Colors (feat. Maya Avedis)'],
#  'Alice Merton': ['Why So Serious', 'Funny Business'],
#  'Richard Smitt': ['All For Love', 'All For Love - Luca Schreiner Remix'],
#  'Smith & Thell': ['Toast', 'Forgive Me Friend'],
#  'Dzeko': ['Heaven (feat. Veronica)', 'Jackie Chan'],
#  'Riggi & Piros': ['Heaven (feat. Veronica)'],
#  'Veronica': ['Heaven (feat. Veronica)'],
#  'Westlife': ["When You're Looking Like That - Single Remix"],
#  'Nico Santos': ['Rooftop', 'Rooftop - HUGEL Remix'],
#  'Swedish Jam Factory': ['Forgive Me Friend'],
#  'A7S': ['Hey Baby (feat. A7S)'],
#  'Train': ['Hey, Soul Sister', 'Hey, Soul Sister'],
#  'Journey': ["Don't Stop Believin'", "Don't Stop Believin'"],
#  'Vargas & Lagola': ['Roads'],
#  'Katrina & The Waves': ['Walking On Sunshine'],
#  'T-Pain': ['Low (feat. T-Pain)'],
#  'Tom Cochrane': ['Life Is A Highway'],
#  'The Cranberries': ['Zombie'],
#  'Spice Girls': ['Wannabe'],
#  'Eurythmics': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Annie Lennox': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Dave Stewart': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'will.i.am': ['Hall of Fame (feat. will.i.am)'],
#  'TOTO': ['Africa'],
#  'The Rembrandts': ['I\'ll Be There for You (Theme from "Friends\')',
#   "I'll Be There for You (Theme from Friends) - Single Version"],
#  "Guns N' Roses": ["Sweet Child O' Mine"],
#  'Chumbawamba': ['Tubthumping'],
#  'Shakira': ['Whenever, Wherever', "Hips Don't Lie (feat. Wyclef Jean)"],
#  'John Denver': ['Take Me Home, Country Roads - Rerecorded'],
#  'Smash Mouth': ['All Star'],
#  'Hanson': ['MMMBop - Single Version', 'MMMBop'],
#  'Gavin DeGraw': ["I Don't Want to Be - Stripped Version"],
#  'WALK THE MOON': ['Shut Up and Dance'],
#  'Tenacious D': ['Tribute'],
#  'Bryan Adams': ["Summer Of '69", "Summer Of '69"],
#  'American Authors': ['Best Day Of My Life', 'Best Day Of My Life'],
#  'Eiffel 65': ['Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'Backstreet Boys': ["Everybody (Backstreet's Back) - Extended Version",
#   'I Want It That Way',
#   'I Want It That Way - Anstandslos & Durchgeknallt Remix'],
#  'Rascal Flatts': ['Life is a Highway - From "Cars"'],
#  'The Verve': ['Bitter Sweet Symphony'],
#  'Alien Ant Farm': ['Smooth Criminal'],
#  'The Proclaimers': ["I'm Gonna Be (500 Miles)"],
#  'Kid Rock': ['All Summer Long', 'All Summer Long'],
#  'The Goo Goo Dolls': ['Iris'],
#  '3 Doors Down': ['Kryptonite'],
#  'OneRepublic': ['Counting Stars', 'Bones (feat. OneRepublic)'],
#  'fun.': ['Some Nights', 'We Are Young (feat. Janelle Monáe)'],
#  'R.E.M.': ['Losing My Religion'],
#  'Janelle Monáe': ['We Are Young (feat. Janelle Monáe)'],
#  'Lynyrd Skynyrd': ['Sweet Home Alabama'],
#  'Khalid': ['Vertigo',
#   'Saturday Nights REMIX',
#   'Eastside (with Halsey & Khalid)',
#   'Better',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Ocean (feat. Khalid)',
#   'Silence'],
#  'Pritam': ['BIBA'],
#  'Kane Brown': ['Saturday Nights REMIX'],
#  'benny blanco': ['Eastside (with Halsey & Khalid)'],
#  'Lost Kings': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Social House': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Lizzo': ['Juice'],
#  'Kygo': ['Happy Now'],
#  'Sandro Cavazza': ['Happy Now',
#   'Without You (feat. Sandro Cavazza)',
#   'So Much Better - Lost Frequencies Remix',
#   'Beautiful Life'],
#  'Post Malone': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Wow.',
#   'Better Now',
#   'Jackie Chan'],
#  'Swae Lee': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Arms Around You (feat. Maluma & Swae Lee)',
#   'Close To Me (with Diplo) (feat. Swae Lee)'],
#  'Ty James': ['Splash'],
#  'unheard': ['Splash'],
#  'Alec Bailey': ['Grip'],
#  'AUSTN': ["In Betweenin'"],
#  'MOTi': ['Hooked', 'Valencia - Original Mix'],
#  'Sheezan': ['Hooked'],
#  'Emma Sameth': ['Spin With You (feat. Jeremy Zucker)'],
#  'WOLFE': ['Spin With You (feat. Jeremy Zucker)'],
#  'Jeremy Zucker': ['Spin With You (feat. Jeremy Zucker)'],
#  'Galantis': ['Bones (feat. OneRepublic)',
#   'Love on Me',
#   "Don't Care",
#   'In My Head',
#   'Water',
#   "Dancin' to the Sound of a Broken Heart",
#   'Louder, Harder, Better',
#   'Gold Dust',
#   'Forever Tonight',
#   "Kill 'Em with the Love",
#   'Call If You Need Me',
#   'Firebird',
#   'You',
#   'Written in the Scars (feat. Wrabel)',
#   'Hey Alligator',
#   'Call Me Home',
#   'Salvage (Up All Night) (feat. Poo Bear)',
#   'Pillow Fight',
#   'Girls on Boys',
#   'Hello',
#   'Tell Me You Love Me',
#   'True Feeling',
#   'Hunter',
#   'Peanut Butter Jelly',
#   'Love on Me',
#   'Mama Look at Me Now',
#   'Spaceship (feat. Uffie)',
#   'Satisfied (feat. MAX)',
#   'No Money',
#   'Runaway (U & I)'],
#  'Robin Schulz': ['Speechless (feat. Erika Sirola)',
#   'Sugar (feat. Francesco Yates)',
#   'Perfect - Robin Schulz Remix'],
#  'Erika Sirola': ['Speechless (feat. Erika Sirola)'],
#  'Dominic Fike': ['3 Nights'],
#  'Miley Cyrus': ['Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Party In The U.S.A.'],
#  'Rita Ora': ['Only Want You',
#   'Let You Love Me',
#   'Anywhere',
#   'Lonely Together (feat. Rita Ora)'],
#  'Jack & Jack': ['Day Dreaming'],
#  'XXXTENTACION': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Lil Pump': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Maluma': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Snakehips': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Rivers Cuomo': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'KYLE': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Lennon Stella': ['La Di Da', 'Polaroid'],
#  'Chris Burton': ['Love Letters'],
#  'Chantel Jeffries': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'YG': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Rich The Kid': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'BIA': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Ariana Grande': ['thank u, next', '7 rings (feat. 2 Chainz) - Remix'],
#  'Lil Peep': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'Spotlight'],
#  'ILOVEMAKONNEN': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Niall Horan': ['Slow Hands'],
#  'Gryffin': ['Remember (with ZOHARA)'],
#  'ZOHARA': ['Remember (with ZOHARA)'],
#  'Cardi B': ['Finesse - Remix; feat. Cardi B',
#   'Girls Like You (feat. Cardi B) - Cardi B Version'],
#  'Sabrina Carpenter': ['Sue Me'],
#  'Lauren Daigle': ['Look Up Child'],
#  'Drax Project': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'Hailee Steinfeld': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'shy martin': ['Forget to Forget'],
#  'Mallrat': ["Nobody's Home"],
#  'Basenji': ["Nobody's Home"],
#  'ARTY': ['Save Me Tonight'],
#  'Maggie Rogers': ['Light On'],
#  'Ellie Goulding': ['Close To Me (with Diplo) (feat. Swae Lee)', 'Burn'],
#  'Silk City': ['Electricity (with Dua Lipa)'],
#  'LÉON': ['You And I'],
#  '2 Chainz': ['7 rings (feat. 2 Chainz) - Remix'],
#  'GASHI': ['My Year'],
#  'Normani': ['Dancing With A Stranger (with Normani)'],
#  'Zeina': ['In My Head'],
#  "Why Don't We": ['Big Plans'],
#  'Big Boi': ["Doin' It (feat. Sleepy Brown)"],
#  'Sleepy Brown': ["Doin' It (feat. Sleepy Brown)"],
#  'Lauv': ["i'm so tired..."],
#  'Troye Sivan': ["i'm so tired...", 'There for You'],
#  'Tyla Yaweh': ['She Bad'],
#  'COIN': ['I Want It All'],
#  'Kehlani': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Ty Dolla $ign': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Hozier': ['Almost (Sweet Music)'],
#  'Dan + Shay': ['Speechless', 'Tequila - R3HAB Remix'],
#  'Shoffy': ['Cool Again'],
#  'Bazzi': ['Mine'],
#  'Matoma': ['Lonely (feat. MAX)'],
#  'MAX': ['Lonely (feat. MAX)', 'Satisfied (feat. MAX)'],
#  'Shania Twain': ['Man! I Feel Like A Woman!'],
#  'Taylor Swift': ['Shake It Off',
#   'Look What You Made Me Do',
#   'We Are Never Ever Getting Back Together'],
#  'MKTO': ['Classic'],
#  'Little Mix': ['Shout Out to My Ex'],
#  'Keala Settle': ['This Is Me'],
#  'The Greatest Showman Ensemble': ['This Is Me'],
#  'Rachel Platten': ['Fight Song'],
#  'Shawn Mendes': ['Treat You Better', "There's Nothing Holdin' Me Back"],
#  'Wyclef Jean': ["Hips Don't Lie (feat. Wyclef Jean)"],
#  'Kelsea Ballerini': ['This Feeling', 'This Feeling (feat. Kelsea Ballerini)'],
#  'Clean Bandit': ['Symphony (feat. Zara Larsson)'],
#  'Zara Larsson': ['Symphony (feat. Zara Larsson)'],
#  'MØ': ['Final Song'],
#  'Francesco Yates': ['Sugar (feat. Francesco Yates)'],
#  'Kelly Clarkson': ['Since U Been Gone'],
#  'Martin Garrix': ['Like I Do',
#   'Animals',
#   'Turn up the Speakers - Radio Edit',
#   'Forbidden Voices',
#   'Poison',
#   'Forever',
#   'Pizza',
#   'Game Over',
#   'Breach (Walk Alone)',
#   'Yottabyte',
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'In the Name of Love',
#   'Scared to Be Lonely - Acoustic Version',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Scared to Be Lonely',
#   'Ocean (feat. Khalid)',
#   'Like I Do',
#   'High On Life (feat. Bonn)',
#   'There for You',
#   'Burn Out (feat. Dewain Whitmore)'],
#  'Brooks': ['Like I Do', 'Like I Do'],
#  'Jonas Blue': ['Polaroid'],
#  'Liam Payne': ['Polaroid'],
#  'Logic': ['Everyday', 'Everyday'],
#  'Calvin Harris': ['One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix'],
#  'Natasha Bedingfield': ['Unwritten'],
#  "Destiny's Child": ['Survivor'],
#  'Sam And The Womp': ['Bom Bom - Radio Edit'],
#  'Daniel Powter': ['Bad Day'],
#  'Scatman John': ['Scatman (ski-ba-bop-ba-dop-bop)'],
#  'Newton Faulkner': ['Dream Catch Me'],
#  'Baha Men': ['Who Let The Dogs Out'],
#  'Gina G': ['Just a Little Bit - Radio Edit'],
#  'Los Del Rio': ['Macarena'],
#  'Gotye': ['Somebody That I Used To Know'],
#  'Kimbra': ['Somebody That I Used To Know'],
#  'Tomcraft': ['Loneliness - Radio Cut'],
#  'Wheatus': ['Teenage Dirtbag', 'Teenage Dirtbag'],
#  'Chesney Hawkes': ['The One and Only'],
#  'Haddaway': ['What Is Love - 7" Mix', 'What Is Love - 7" Mix'],
#  'Of Monsters and Men': ['Little Talks'],
#  'Jet': ['Are You Gonna Be My Girl'],
#  'Andreas Johnson': ['Glorious'],
#  'Icona Pop': ['I Love It (feat. Charli XCX)'],
#  'Charli XCX': ['I Love It (feat. Charli XCX)'],
#  'Lou Bega': ['Mambo No. 5 (A Little Bit of...)'],
#  'Meredith Brooks': ['Bitch'],
#  'Yolanda Be Cool': ['We No Speak Americano'],
#  'Andrew Stanley': ['We No Speak Americano'],
#  'DCup': ['We No Speak Americano'],
#  'Matt Handles': ['We No Speak Americano'],
#  'Carl Douglas': ['Kung Fu Fighting'],
#  'Iglu & Hartly': ['In This City'],
#  'Rogue Traders': ['Voodoo Child'],
#  'Men Without Hats': ['The Safety Dance'],
#  'Marc Cohn': ['Walking in Memphis'],
#  'The Holloways': ['Generator'],
#  'Nizlopi': ['JCB'],
#  'Nena': ['99 Luftballons'],
#  'Bingo Players': ['Get Up (Rattle) - Radio Edit'],
#  'Faul & Wad': ['Changes - Radio Mix'],
#  'PNAU': ['Changes - Radio Mix'],
#  'Kevin Rudolf': ['Let It Rock'],
#  'Vanessa Carlton': ['A Thousand Miles - Single Version'],
#  'Passenger': ['Let Her Go'],
#  'Joan Osborne': ['One Of Us'],
#  'Ian Carey Project': ['Get Shaky'],
#  'The Buggles': ['Video Killed The Radio Star'],
#  'M.V.P.': ['Roc Ya Body (Mic Check 1, 2)'],
#  'DJ Zinc': ['Roc Ya Body (Mic Check 1, 2)'],
#  'Safri Duo': ['Played-A-Live (The Bongo Song)'],
#  'Rednex': ['Cotton Eye Joe'],
#  'Captain Jack': ['Captain Jack - Short Mix'],
#  'A Touch Of Class': ['Around the World (La La La La La) - Radio Version'],
#  'Pete Konemann': ['Around the World (La La La La La) - Radio Version'],
#  'Kaiser Chiefs': ['Ruby'],
#  'Culcha Candela': ['Hamma! - Single Edit'],
#  'Vengaboys': ['We’re Going to Ibiza!', 'Boom, Boom, Boom, Boom!!'],
#  'Spider Murphy Gang': ['Skandal im Sperrbezirk'],
#  'Throttle': ['Baddest Behaviour', 'Tell Me You Love Me'],
#  'Burak Yeter': ['Ciao Adios - Burak Yeter Remix'],
#  'Jan Delay': ['Oh Jonny'],
#  ...}

# %%
lolla_artists = []
with open("lolla_artists.txt") as f:
    lines = f.readlines()
    for line in lines:
        if line[-1:] == "\n":
            line = line[:-1]
        if line == "":
            continue
        lolla_artists.append(line)

# %%
def check_str_in_list(s, ls, max_dist=1):
    matches = []
    for _s in ls:
        if Levenshtein.distance(s, _s, processor=str.upper) <= max_dist:
            matches.append(_s)
    return matches

# %%
for artist in lolla_artists:
    matches = check_str_in_list(artist, my_artists, max_dist=1)
    if matches != []:
        print(artist)
        for m in matches:
            print("\t", m)
            for song in artists_with_songs[m]:
                print("\t\t", song)
# Out:
# Billie Eilish
# 	 Billie Eilish
# 		 bad guy
# Sabrina Carpenter
# 	 Sabrina Carpenter
# 		 Sue Me
# Lana Del Rey
# 	 Lana Del Rey
# 		 Freak
# Red Hot Chili Peppers
# 	 Red Hot Chili Peppers
# 		 By the Way
# 		 Snow (Hey Oh)
# 		 Californication
# 		 Can't Stop
# Kendrick Lamar
# 	 Kendrick Lamar
# 		 Don't Wanna Know (feat. Kendrick Lamar)
# beabadoobee
# 	 beabadoobee
# 		 death bed (coffee for your head)
# Alan Walker
# 	 Alan Walker
# 		 Alone
# 		 Ignite (feat. SEUNGRI)
# 		 Darkside
# 		 The Spectre
# 		 Sing Me to Sleep
# 		 Strongest (Alan Walker Remix)
# 		 Tired
# 		 Diamond Heart
# 		 All Falls Down (feat. Juliander)
# 		 Faded
# Thirty Seconds to Mars
# 	 Thirty Seconds To Mars
# 		 The Kill
# Diplo
# 	 Diplo
# 		 Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix
# 		 Genius - Lil Wayne Remix
# 		 Close To Me (with Diplo) (feat. Swae Lee)
# 		 Electricity (with Dua Lipa)
# 		 Hey Baby
# Lil Yachty
# 	 Lil Yachty
# 		 Pretender (feat. Lil Yachty & AJR)
# Maggie Rogers
# 	 Maggie Rogers
# 		 Light On
# Dom Dolla
# 	 Dom Dolla
# 		 San Frandisco
# Gorgon City
# 	 Gorgon City
# 		 House Arrest
# Giant Rooks
# 	 Giant Rooks
# 		 Wild Stare
# Sueco
# 	 Sueco
# 		 Paralyzed
# 		 POS
# 		 fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]
# 		 fast
# 		 It Was Fun While It Lasted
# 		 PRIMADONA
# 		 Sober/Hungover (feat. Arizona Zervas)
# 		 Motel 666
# 		 SOS (feat. Travis Barker)
# 		 Toxic Therapy
# 		 Drunk Dial
# 		 Loser
# 		 Hate You Too
# 		 It’s Going Good!
# 		 Today
# 		 Bad Vibes
# 		 Next Ex
# 		 Salt
# 		 AITA
# 		 Funeral
# 		 Up in Smoke
# 		 Last Thing I Do
# 		 Salt
# 		 SOS (feat. Travis Barker)
# 		 Loser
# 		 Sober/Hungover (feat. Arizona Zervas)
# 		 Paralyzed
# Noah Kahan
# 	 Noah Kahan
# 		 Hurt Somebody
# 		 False Confidence
# 		 Hurt Somebody
# Afrojack
# 	 AFROJACK
# 		 Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)
# 		 Ten Feet Tall
# 		 Turn up the Speakers - Radio Edit
# SOFI TUKKER
# 	 Sofi Tukker
# 		 House Arrest
# Tom Odell
# 	 Tom Odell
# 		 Another Love
# Timmy Trumpet
# 	 Timmy Trumpet
# 		 Ininna Tora
# 		 Mad World
# 		 Project X
# 		 Dumb (Feat. BOSS)
# 		 The Anthem (Der Alte)
# 		 Carnival - Dimitri Vegas & Like Mike Edit
# 		 The King
# 		 The Prayer (feat. Zafrir)
# 		 Bleed
# 		 Garden of Madness 2020 Megamix
# 		 Toca
# 		 Flamenco (feat. Rage)
# 		 Mufasa
# 		 The People
# 		 Hava
# 		 Nah Nah
# 		 World At Our Feet
# 		 Wassup (Listen To The Horns)
# 		 Toca (feat. Timmy Trumpet & KSHMR)
# 		 Baddest Behaviour
# 		 Scarborough Fair - Spotify Version
# 		 Rockstar (feat. DV8)
# 		 Nightmare - Radio Edit
# 		 Freaks - Extended Mix
# 		 Freaks - Instrumental Mix
# 		 Freaks - Radio Instrumental
# 		 Mantra
# 		 Hipsta
# 		 Take Your Call
# 		 Deja-Vu - Extended Version
# 		 Deja-Vu
# 		 The Underground
# 		 Booty Shake
# 		 Infinity - Original
# 		 Oracle
# 		 PSY or DIE
# 		 The Prophecy
# 		 Punjabi
# 		 Trumpets
# 		 Freaks - Radio Edit
# 		 Party Till We Die (feat. Andrew W.K.)
# 		 Al Pacino
# 		 Attention
# 		 The Underground - Mix Cut
# 		 Narco
# Portugal. The Man
# 	 Portugal. The Man
# 		 Feel It Still
# 		 Feel It Still
# Peach Pit
# 	 Peach Pit
# 		 Alrighty Aphrodite
# Chri$tian Gate$
# 	 Chri$tian Gate$
# 		 NUMB
# Meduza
# 	 MEDUZA
# 		 Lose Control
# 		 Piece Of Your Heart - Alok Remix
# 		 Piece Of Your Heart
# A Boogie Wit Da Hoodie
# 	 A Boogie Wit da Hoodie
# 		 fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]

# %%
artists_with_songs
# Out:
# {'Jordiz': ['Weekend!'],
#  'Connor Price': ['Start Again', 'Smooth'],
#  'Chloe Sagum': ['Start Again'],
#  'Arrested Youth': ['Brightside', 'Dig'],
#  'YUNGBLUD': ['Tissues',
#   'mars',
#   'I’m a Mess (with YUNGBLUD)',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   'parents',
#   'acting like that (feat. Machine Gun Kelly)',
#   'The Funeral',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Patience (feat. YUNGBLUD & Polo G)'],
#  'SK8': ['Shooting Star (feat. Sum 41)'],
#  'Sum 41': ['Shooting Star (feat. Sum 41)',
#   'With Me',
#   'In Too Deep',
#   'Fat Lip',
#   'Fat Lip',
#   'Still Waiting'],
#  'Sub Zero Project': ['HALO', 'Project X', 'Rockstar (feat. DV8)'],
#  'Kay One': ['Herz aus Stein', 'Senorita'],
#  'strike': ['Calling'],
#  'Ben Nicky': ['We Are The Ravers'],
#  'Olly James': ['We Are The Ravers'],
#  'MC Stretch': ['We Are The Ravers'],
#  'Korsakoff': ['Lyra - Broken Minds Remix'],
#  'Broken Minds': ['Lyra - Broken Minds Remix'],
#  'Machine Gun Kelly': ['bloody valentine',
#   'title track',
#   'Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   "don't sleep, repeat (feat. Machine Gun Kelly)",
#   'bloody valentine - Acoustic',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   "can't look back",
#   'kevin and barracuda - interlude',
#   'forget me too (feat. Halsey)',
#   'kiss kiss',
#   'concert for aliens',
#   "my ex's best friend (with blackbear)",
#   'hangover cure',
#   'WWIII',
#   "play this when i'm gone",
#   'lonely',
#   'split a pill',
#   'all I know (feat. Trippie Redd)',
#   'Misery Business',
#   'nothing inside (feat. iann dior)',
#   'banyan tree - interlude',
#   'jawbreaker',
#   'drunk face',
#   'papercuts - album edit',
#   'sid & nancy',
#   'die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'make up sex (feat. blackbear)',
#   '9 lives',
#   'twin flame',
#   'god save me',
#   'mainstream sellout',
#   '5150',
#   'drug dealer (feat. Lil Wayne)',
#   'emo girl (feat. WILLOW)',
#   'born with horns',
#   'more than life (feat. glaive)',
#   "fake love don't last (feat. iann dior)",
#   'maybe (feat. Bring Me The Horizon) - acoustic version',
#   'wall of fame - interlude',
#   'ay! (feat. Lil Wayne)',
#   'why are you here',
#   'maybe (feat. Bring Me The Horizon)',
#   'last november',
#   'WW4',
#   'papercuts - live from red rocks',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'twin flame',
#   'Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'ay! (feat. Lil Wayne)',
#   'maybe (feat. Bring Me The Horizon)',
#   'acting like that (feat. Machine Gun Kelly)',
#   'emo girl (feat. WILLOW)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'Sueco': ['Paralyzed',
#   'POS',
#   'fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]',
#   'fast',
#   'It Was Fun While It Lasted',
#   'PRIMADONA',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Motel 666',
#   'SOS (feat. Travis Barker)',
#   'Toxic Therapy',
#   'Drunk Dial',
#   'Loser',
#   'Hate You Too',
#   'It’s Going Good!',
#   'Today',
#   'Bad Vibes',
#   'Next Ex',
#   'Salt',
#   'AITA',
#   'Funeral',
#   'Up in Smoke',
#   'Last Thing I Do',
#   'Salt',
#   'SOS (feat. Travis Barker)',
#   'Loser',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Paralyzed'],
#  'Jon Caryl': ['Alone'],
#  "Fresh Til' Death": ['In Too Deep (Firelite Remix)'],
#  'MYLKI': ['In Too Deep (Firelite Remix)'],
#  'Firelite': ['In Too Deep (Firelite Remix)'],
#  'In The Valley Below': ['Peaches'],
#  'Hollywood Undead': ['Whatever It Takes'],
#  'Mac Miller': ['Love Lost', 'The Spins'],
#  'The Temper Trap': ['Love Lost'],
#  'Avril Lavigne': ['I’m a Mess (with YUNGBLUD)',
#   'Love Sux',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'All I Wanted (feat. Mark Hoppus)',
#   'Bite Me',
#   'Head Above Water',
#   'Sk8er Boi',
#   'Sk8er Boi'],
#  'The Home Team': ["She's Quiet"],
#  'Mayberg': ['Hilferuf'],
#  'Panic! At The Disco': ['The Ballad of Mona Lisa',
#   'Crazy = Genius',
#   'I Write Sins Not Tragedies',
#   'High Hopes'],
#  'Harris & Ford': ['99 Luftballons',
#   'Hard, Style & Volksmusik',
#   'Break the Beat'],
#  'Zombic': ['Human Error'],
#  'Danimal': ['Human Error'],
#  'Influencerz': ['Human Error'],
#  'iann dior': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'nothing inside (feat. iann dior)',
#   "fake love don't last (feat. iann dior)",
#   'Mood (feat. iann dior)'],
#  'Travis Barker': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   'bloody valentine - Acoustic',
#   'Misery Business',
#   'Drop Dead (with Kesha and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'KXXMA': ['Get Shaky', 'Herz an Herz'],
#  'TurboKevin': ['Get Shaky'],
#  'Nic D': ['Serotonin'],
#  'Bryce Vine': ['American Dream', 'The Fall'],
#  'Weezer': ['Beverly Hills'],
#  'The Bangles': ['Eternal Flame'],
#  'Cassyette': ['Sad Girl Summer'],
#  'Tammy Wynette': ['Stand By Your Man - Official Audio'],
#  'Wolfpack': ['Phatt Bass 2016 (Mixed)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'Ocarina'],
#  'Warp Brothers': ['Phatt Bass 2016 (Mixed)'],
#  'NWYR': ['The Lone Ranger'],
#  'W&W': ['The Lone Ranger',
#   'Skydance',
#   'Rave Culture',
#   'Chakra - Wildstylez Remix',
#   'God Is a Girl',
#   'Live the Night',
#   'Long Way Down',
#   "Don't Let Me Down (feat. Daya) - W&W Remix",
#   'Supa Dupa Fly 2018',
#   'How Many',
#   'Rave After Rave',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Crowd Control - Radio Edit',
#   'Arcade Mammoth',
#   'Rave Culture'],
#  'Hoodie Allen': ['Call Me Never'],
#  'Oberg': ['Sun Goes Down', 'Take My Hand'],
#  'Joakim Lundell': ['Sun Goes Down'],
#  'Hardwell': ['PACMAN',
#   'I FEEL LIKE DANCING',
#   'Bigroom Never Dies',
#   'Live the Night',
#   'The Underground',
#   'Bella Ciao',
#   'Power',
#   'Ze Willen Mee',
#   'Out of This Town',
#   'Shine a Light',
#   'This Is Love',
#   "Don't Let Me Down (feat. Daya) - Hardwell & Sephyx Remix",
#   'The Underground - Mix Cut',
#   'Bigroom Never Dies - Mix Cut',
#   'Off The Hook',
#   'Unity'],
#  'YROR?': ['Rotten'],
#  'Ben Joel': ['Rotten'],
#  'Carta': ['EDM'],
#  'Canadian Softball': ['Ohio Is for Emo Kids'],
#  'Cher': ['If I Could Turn Back Time'],
#  'Hardstyle Germany': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'High Level': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'Peach Pit': ['Alrighty Aphrodite'],
#  'Ruby Waters': ['Quantum Physics'],
#  'SEB': ['seaside_demo'],
#  'Jnr Choi': ['TO THE MOON'],
#  'Sam Tompkins': ['TO THE MOON'],
#  'Dubdogz': ['Everybody Wants To Party'],
#  'JØRD': ['Everybody Wants To Party'],
#  'Timmy Trumpet': ['Ininna Tora',
#   'Mad World',
#   'Project X',
#   'Dumb (Feat. BOSS)',
#   'The Anthem (Der Alte)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'The King',
#   'The Prayer (feat. Zafrir)',
#   'Bleed',
#   'Garden of Madness 2020 Megamix',
#   'Toca',
#   'Flamenco (feat. Rage)',
#   'Mufasa',
#   'The People',
#   'Hava',
#   'Nah Nah',
#   'World At Our Feet',
#   'Wassup (Listen To The Horns)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Baddest Behaviour',
#   'Scarborough Fair - Spotify Version',
#   'Rockstar (feat. DV8)',
#   'Nightmare - Radio Edit',
#   'Freaks - Extended Mix',
#   'Freaks - Instrumental Mix',
#   'Freaks - Radio Instrumental',
#   'Mantra',
#   'Hipsta',
#   'Take Your Call',
#   'Deja-Vu - Extended Version',
#   'Deja-Vu',
#   'The Underground',
#   'Booty Shake',
#   'Infinity - Original',
#   'Oracle',
#   'PSY or DIE',
#   'The Prophecy',
#   'Punjabi',
#   'Trumpets',
#   'Freaks - Radio Edit',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Al Pacino',
#   'Attention',
#   'The Underground - Mix Cut',
#   'Narco'],
#  'KSHMR': ['Ininna Tora',
#   'Invisible Children',
#   'The Prayer (feat. Zafrir)',
#   'Over and Out (feat. Charlott Boss)',
#   'Toca',
#   'The People',
#   'My Best Life (feat. Mike Waters)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Voices',
#   'Good Vibes Soldier (feat. Head Quattaz)',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Wildcard (feat. Sidnie Tipton)',
#   'Neverland',
#   'Harder',
#   'Carry Me Home (feat. Jake Reese)',
#   'Power',
#   'Memories (feat. Sirah) - Radio Edit',
#   'Opa'],
#  'Mildenhaus': ['Ininna Tora'],
#  'Butterfly Boucher': ['Changes'],
#  'David Bowie': ['Changes',
#   'Heroes - Single Version; 1990 Remaster',
#   'Heroes - 2017 Remaster',
#   'Starman - 2012 Remaster',
#   'Under Pressure'],
#  'Coldplay': ['Paradise',
#   'Fix You',
#   'Hymn for the Weekend',
#   'Viva La Vida',
#   'Yellow',
#   'The Scientist',
#   'Viva La Vida',
#   'Hymn for the Weekend - Seeb Remix',
#   'Viva La Vida',
#   'Something Just Like This'],
#  'Eddie Vedder': ['Brother the Cloud'],
#  'RØRY': ['UNCOMPLICATED'],
#  'HBz': ['Gästeliste +1'],
#  'Royal Blood': ['Trouble’s Coming', 'Figure It Out'],
#  'Mr. Green': ['Welcome'],
#  'Dave East': ['Welcome'],
#  'Xzibit': ['My Name (feat. Eminem & Nate Dogg)'],
#  'Eminem': ['My Name (feat. Eminem & Nate Dogg)',
#   'Stan',
#   "When I'm Gone",
#   'Like Toy Soldiers',
#   'Without Me',
#   'Stan - Live At 43rd Grammy Awards',
#   'Mockingbird',
#   'Lose Yourself - From "8 Mile" Soundtrack',
#   'Sing For The Moment',
#   'Intro',
#   'FACK',
#   'My Name Is',
#   'Shake That',
#   "Cleanin' Out My Closet",
#   'Just Lose It',
#   'Guilty Conscience',
#   'The Real Slim Shady',
#   'The Way I Am',
#   'Venom - Remix',
#   'Kings Never Die',
#   'Love The Way You Lie',
#   'Not Afraid',
#   'Remind Me',
#   'Lose Yourself - From "8 Mile" Soundtrack'],
#  'Nate Dogg': ['My Name (feat. Eminem & Nate Dogg)',
#   'Shake That',
#   'Party We Will Throw Now!'],
#  'jxdn': ['ANGELS & DEMONS'],
#  'Graham Lake': ['Run em Down'],
#  'Avelino': ['Run em Down'],
#  'loafers': ['Lay All Your Love On Me'],
#  'Badjack': ['Lay All Your Love On Me'],
#  'Maxim Schunk': ['Lay All Your Love On Me'],
#  'ABBA': ['Lay All Your Love On Me', 'Super Trouper'],
#  'Mark Dekoda': ['Rave Harder Techno Bass'],
#  'Rnbstylerz': ['Like Wooh Wooh'],
#  'TITUS': ['Love Myself'],
#  'Max Bennett Kelly': ['Happy, Healthy, Well-Adjusted'],
#  'Oliver Tree': ['Let Me Down (feat. blink-182)'],
#  'blink-182': ['Let Me Down (feat. blink-182)',
#   'Scumbag (feat. blink-182)',
#   'Bored To Death',
#   'Sober',
#   "She's Out Of Her Mind",
#   'Ransom',
#   'Black Rain',
#   'Run Away',
#   'Remember To Forget Me',
#   'Pin the Grenade',
#   'Darkside',
#   'The First Time',
#   'Heaven',
#   'Blame It On My Youth',
#   'Happy Days',
#   'I Really Wish I Hated You',
#   'No Heart To Speak Of',
#   'On Some Emo Shit',
#   'Generational Divide',
#   'Hungover You',
#   'Home Is Such A Lonely Place',
#   'California',
#   'Teenage Satellites',
#   'Bored To Death',
#   'Misery',
#   "Can't Get You More Pregnant",
#   'Cynical',
#   'Bored To Death (Acoustic)',
#   "Don't Mean Anything",
#   'Built This Pool',
#   '6/8',
#   'Last Train Home',
#   'Good Old Days',
#   'Sober',
#   'Wildfire',
#   'Bottom Of The Ocean',
#   'Los Angeles',
#   "She's Out Of Her Mind",
#   'The Only Thing That Matters',
#   'Long Lost Feeling',
#   'Rabbit Hole',
#   'Brohemian Rhapsody',
#   'Parking Lot',
#   'No Future',
#   "Hey I'm Sorry",
#   'Left Alone',
#   'Kings of the Weekend',
#   'San Diego',
#   'Go',
#   'Easy Target',
#   'Asthenia',
#   'I Miss You',
#   'The Fallen Interlude',
#   'Obvious',
#   "Here's Your Letter",
#   'Feeling This',
#   'Always',
#   'Stockholm Syndrome Interlude',
#   'Anthem Part Two - Live In Chicago',
#   'Down',
#   'Stockholm Syndrome',
#   'All Of This',
#   'Violence',
#   "I'm Lost Without You",
#   'Every Time I Look For You',
#   'Roller Coaster',
#   'First Date',
#   'Anthem Part Two',
#   'Online Songs',
#   'The Rock Show',
#   'Shut Up',
#   'Stay Together For The Kids',
#   'Reckless Abandon',
#   'Happy Holidays, You Bastard',
#   'Story Of A Lonely Guy',
#   'Give Me One Good Reason',
#   'Please Take Me Home',
#   'Going Away To College',
#   'Anthem',
#   'Dysentery Gary',
#   'Mutt',
#   'Dumpweed',
#   'Wendy Clear',
#   "Don't Leave Me",
#   'The Party Song',
#   'Aliens Exist',
#   "Adam's Song",
#   "What's My Age Again?",
#   'All The Small Things'],
#  'Lustra': ["Scotty Doesn't Know"],
#  't-low': ['We Made It', 'Sehnsucht', 'Crashen'],
#  'Miksu / Macloud': ['We Made It', 'Sehnsucht', 'Nachts wach'],
#  'charlieonnafriday': ['Enough'],
#  'Anastacia': ['Left Outside Alone'],
#  'DaCav5': ['Tetris'],
#  'A Boogie Wit da Hoodie': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Offset': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Arizona Zervas': ['Sober/Hungover (feat. Arizona Zervas)',
#   'Sober/Hungover (feat. Arizona Zervas)'],
#  'Sunrise Skater Kids': ['All the Old Things'],
#  'Christina Rotondo': ['All the Old Things'],
#  'Chri$tian Gate$': ['NUMB'],
#  'Nxvy': ['Emo Chick'],
#  'ALX8': ['Emo Chick'],
#  'JAY-Z': ['Empire State Of Mind', 'Numb / Encore'],
#  'Alicia Keys': ['Empire State Of Mind'],
#  'makko': ['Nachts wach'],
#  '44phantom': ["don't sleep, repeat (feat. Machine Gun Kelly)"],
#  'Matthias Reim': ['Verdammt, ich lieb Dich - 2020 Remastered'],
#  'Electric Callboy': ['Best Day'],
#  'Sido': ['Best Day',
#   'Liebe',
#   'Tausend Tattoos',
#   'Die Nacht von Freitag auf Montag'],
#  'Labrinth': ['When I R.I.P.',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Jealous'],
#  'The Used': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Bert McCracken': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Halsey': ['forget me too (feat. Halsey)',
#   'Sorry',
#   'Eastside (with Halsey & Khalid)',
#   'Closer'],
#  'blackbear': ["my ex's best friend (with blackbear)",
#   'make up sex (feat. blackbear)'],
#  'Trippie Redd': ['all I know (feat. Trippie Redd)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Wake Up Call (feat. Trippie Redd)'],
#  'Gunna': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Young Thug': ['die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'Havana (feat. Young Thug)'],
#  'Landon Barker': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Lil Wayne': ['drug dealer (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Let It Rock'],
#  'WILLOW': ['emo girl (feat. WILLOW)', 'emo girl (feat. WILLOW)'],
#  'glaive': ['more than life (feat. glaive)'],
#  'Bring Me The Horizon': ['maybe (feat. Bring Me The Horizon) - acoustic version',
#   'maybe (feat. Bring Me The Horizon)',
#   'maybe (feat. Bring Me The Horizon)',
#   'Can You Feel My Heart',
#   'Throne'],
#  'Mark Hoppus': ['All I Wanted (feat. Mark Hoppus)',
#   'Re-Entry (feat. Mark Hoppus)'],
#  'X Ambassadors': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'Unsteady'],
#  'Bebe Rexha': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   "I'm a Mess",
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix',
#   'In the Name of Love'],
#  'Dame': ['Mein Haus'],
#  'Solence': ['Good F**King Music'],
#  'The White Stripes': ['Astro',
#   'Seven Nation Army',
#   'Seven Nation Army',
#   'Icky Thump'],
#  'Stand Atlantic': ['deathwish (feat. nothing,nowhere.)'],
#  'nothing,nowhere.': ['deathwish (feat. nothing,nowhere.)'],
#  'Kode': ['Drunk Texts'],
#  'André De Shields': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Hadestown Original Broadway Company': ['Wait for Me (Reprise)',
#   'Wait for Me'],
#  'Anaïs Mitchell': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Reeve Carney': ['Wait for Me'],
#  'Jewelle Blackman': ['Wait for Me'],
#  'Yvette Gonzalez-Nacer': ['Wait for Me'],
#  'Kay Trinidad': ['Wait for Me'],
#  'Kimberly Marable': ['Wait for Me'],
#  'Timothy Hughes': ['Wait for Me'],
#  'Malcolm Armwood': ['Wait for Me'],
#  'Jessie Shelton': ['Wait for Me'],
#  'Khaila Wilcoxon': ['Wait for Me'],
#  'Ahmad Simmons': ['Wait for Me'],
#  'Afra Hines': ['Wait for Me'],
#  'T. Oliver Reid': ['Wait for Me'],
#  'John Krause': ['Wait for Me'],
#  'AMIICCA': ['Wait for Me'],
#  'Polo G': ['Martin & Gina', 'Patience (feat. YUNGBLUD & Polo G)'],
#  'Nelly Furtado': ['All Good Things (Come To An End)',
#   'Maneater',
#   'Broken Strings'],
#  'Akros': ['Lie'],
#  'Madonna': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Hung Up - Radio Version'],
#  'Justin Timberlake': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Timbaland': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Gabry Ponte': ['Mad World',
#   'Monster',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'AXMO': ['Skydance'],
#  'Giin': ['Skydance', 'Long Way Down'],
#  'Kate Bush': ['Running Up That Hill (A Deal With God)'],
#  'Ion Miles': ['Powerade'],
#  'SIRA': ['Powerade'],
#  'BHZ': ['Powerade'],
#  'Goody Grace': ['Scumbag (feat. blink-182)'],
#  'Jay Hoodie': ['Someone That You Hated'],
#  'Alligatoah': ['Trauerfeier Lied', 'Du bist schön'],
#  'Weedmane 2pac Dr Dre SnoopDogg': ['Bad and Boujee'],
#  'Butterfly Migos': ['Bad and Boujee'],
#  'Crazy Town': ['Bad and Boujee', 'Butterfly', 'Butterfly'],
#  'The Offspring': ['Behind Your Walls',
#   "You're Gonna Go Far, Kid",
#   'Self Esteem',
#   'Want You Bad',
#   "The Kids Aren't Alright"],
#  'Glass Animals': ['Heat Waves', 'Heat Waves'],
#  'We Three': ['Sara'],
#  'Sam Smith': ['Stay With Me', 'Dancing With A Stranger (with Normani)'],
#  'Christopher Lawrence': ['Rush Hour'],
#  'YONAKA': ['Seize the Power'],
#  'One Direction': ['Night Changes'],
#  'Cameron Sanderson': ['What Do You Want?'],
#  '4 Non Blondes': ["What's Up?"],
#  'The Bucketheads': ['The Bomb! (These Sounds Fall Into My Mind) - Radio Edit'],
#  'Vigiland': ['Buss It',
#   'Pong Dance',
#   'Another Shot\u202c\u202c\u202c',
#   'Addicted',
#   'Take This Ride',
#   'Be Your Friend\u202c\u202c',
#   'Never Going Home',
#   'Shots & Squats',
#   'Friday Night\u202c\u202c\u202c',
#   'Nice To Meet You',
#   'UFO - Radio Edit'],
#  'M24': ['Buss It'],
#  'Kraftklub': ['Ein Song reicht',
#   'Ganz schön okay (feat. Kraftklub)',
#   'Ich will nicht nach Berlin',
#   '500 K',
#   'Randale - Live'],
#  'Michael Jackson': ["They Don't Care About Us"],
#  'Des Rocs': ['Hanging by a Thread', 'Let Me Live / Let Me Die'],
#  'The Mysterines': ['Hung Up'],
#  'Bassjackers': ['De La Sol',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'The Fever',
#   'Block',
#   'Derp',
#   'Fireflies (feat. Luciana)',
#   'These Heights (feat. Caroline Pennell)',
#   'Memories (feat. Sirah) - Radio Edit',
#   'The Riddle',
#   'The Riddle - Extended Mix',
#   'Switch',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MAKJ': ['De La Sol',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Knockout',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Derp'],
#  'flora cash': ['Feeling So Down', "You're Somebody Else"],
#  'Austin George': ['Hands On You'],
#  'Betterov': ['Bring mich nach Hause', 'Viertel vor Irgendwas', 'Dussmann'],
#  'Mother Mother': ['Hayloft II'],
#  'Royal & the Serpent': ['FUCKBOI REJECTS'],
#  'grandson': ['Drop Dead (with Kesha and Travis Barker)', 'Blood // Water'],
#  'Kesha': ['Drop Dead (with Kesha and Travis Barker)',
#   'Good Old Days (feat. Kesha)',
#   'Praying',
#   'TiK ToK',
#   'Right Round (feat. Ke$ha)',
#   'Body Talks (feat. Kesha)'],
#  'Crawlers': ['Come Over (Again)'],
#  'A Day To Remember': ['Re-Entry (feat. Mark Hoppus)'],
#  'Fettes Brot': ['An Tagen wie diesen',
#   'Emanuela',
#   'Schwule Mädchen',
#   'Bettina, zieh dir bitte etwas an',
#   'Emanuela'],
#  'Dallerium': ['How Do I Sleep Now'],
#  'Olive': ['How Do I Sleep Now'],
#  'KUMMER': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Fred Rabe': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Lil Nas X': ['INDUSTRY BABY (feat. Jack Harlow)', 'THATS WHAT I WANT'],
#  'Jack Harlow': ['INDUSTRY BABY (feat. Jack Harlow)'],
#  'Jessie J': ['Wild', 'Price Tag', 'Wild - No Rap Edit', 'Who You Are'],
#  'Sofi Tukker': ['House Arrest'],
#  'Gorgon City': ['House Arrest'],
#  'Pixies': ['Where Is My Mind? - Remastered'],
#  'Nickelback': ['Burn it to the Ground',
#   'How You Remind Me',
#   'How You Remind Me'],
#  'Noah Cyrus': ['July', 'Lonely', 'All Falls Down (feat. Juliander)'],
#  'GAYLE': ['abcdefu', 'abcdefu (angrier)'],
#  'Beartooth': ['Hated'],
#  'Zedline': ['Polozhenie - Zedline Remix'],
#  'Pete Yorn': ['Ever Fallen In Love - From the Motion Picture "Shrek 2"'],
#  'Foreigner': ['I Want to Know What Love Is - 1999 Remaster'],
#  'Lostboi Lino': ['Wenn Du weinst'],
#  'Montez': ['Auf & Ab'],
#  'Scooter': ['Suck My Megamix - The Longest Scooter Single In The World',
#   'How Much Is The Fish?',
#   'Hyper Hyper',
#   'Suck My Megamix - The Longest Scooter Single in the World'],
#  'Tom Walker': ['Leave a Light On', 'Just You and I'],
#  'Van Halen': ["Can't Stop Lovin' You"],
#  'Bowling For Soup': ['Girl All the Bad Guys Want',
#   'Almost',
#   'Right About Now',
#   '1985'],
#  'We Were Promised Jetpacks': ['Quiet Little Voices'],
#  'Kid Cudi': ['Erase Me - Main',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix'],
#  'Kanye West': ['Erase Me - Main',
#   'POWER',
#   'Dark Fantasy',
#   'Stronger',
#   'Gold Digger'],
#  'Dido': ['Stan'],
#  'Elton John': ['Stan - Live At 43rd Grammy Awards'],
#  'Dr. Dre': ['Guilty Conscience'],
#  'Dexys Midnight Runners': ['Come On Eileen'],
#  'Counting Crows': ['Accidentally In Love'],
#  'AC/DC': ["It's a Long Way to the Top (If You Wanna Rock 'N' Roll)",
#   'Highway to Hell',
#   'You Shook Me All Night Long'],
#  'Beach House': ['Take Care'],
#  'Alesso': ['When I’m Gone (with Katy Perry)',
#   'Calling (Lose My Mind) - Radio Edit'],
#  'Katy Perry': ['When I’m Gone (with Katy Perry)',
#   'The One That Got Away - Acoustic',
#   'The One That Got Away - Acoustic',
#   'I Kissed A Girl',
#   'Firework'],
#  'Billy Idol': ['White Wedding',
#   'Dancing with Myself - 2001 Remaster',
#   'Dancing With Myself'],
#  'Generation X': ['Dancing with Myself - 2001 Remaster'],
#  'Slade': ['Merry Xmas Everybody'],
#  'Band Aid 30': ["Do They Know It's Christmas? - 2014"],
#  'Watsky': ['Sloppy Seconds'],
#  'Macklemore': ['Penis Song',
#   'Good Old Days (feat. Kesha)',
#   'Glorious (feat. Skylar Grey)',
#   "Can't Hold Us (feat. Ray Dalton)"],
#  'The Airborne Toxic Event': ['Sometime Around Midnight'],
#  'MOD SUN': ['Internet Killed The Rockstar'],
#  'G-Eazy': ['Still Be Friends (feat. Tory Lanez & Tyga)',
#   'My Year',
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix'],
#  'Tory Lanez': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Tyga': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Steve Aoki': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Hava',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Pretender (feat. Lil Yachty & AJR)',
#   'Mayhem',
#   'Be Somebody',
#   'Just Hold On',
#   'Lie To Me',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix',
#   'Azukita (Steve Aoki, Daddy Yankee, Play-N-Skillz & Elvis Crespo) (feat. Elvis Crespo)',
#   'Jaleo',
#   'MIC Drop (Steve Aoki Remix) [Full Length Edition]',
#   'MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Chris Lake': ['Delirious (Boneless) (feat. Kid Ink)'],
#  'Tujamo': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Grapevine - Tujamo Remix'],
#  'Kid Ink': ['Delirious (Boneless) (feat. Kid Ink)', 'Hey Baby', 'I Love You'],
#  'All Time Low': ['Dear Maria, Count Me In', 'Umbrella'],
#  'The All-American Rejects': ['Dirty Little Secret',
#   'Swing, Swing',
#   'Gives You Hell',
#   'Gives You Hell'],
#  'We The Kings': ['Check Yes, Juliet', 'Sad Song (feat. Elena Coats)'],
#  'Love A': ['Too Doof to Fuck'],
#  'Jules Ahoi': ['Robinson Crusoe'],
#  'Bushido': ['Alles wird gut'],
#  'Warren G': ['Party We Will Throw Now!'],
#  'The Game': ['Party We Will Throw Now!'],
#  'Mumford & Sons': ['Ditmas', 'Little Lion Man', 'I Will Wait'],
#  'Axel Black & White': ['Somebody To Love'],
#  'KSI': ['Holiday',
#   'Keep Up',
#   'Creature',
#   'Loose (feat. KSI)',
#   'Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'Patience (feat. YUNGBLUD & Polo G)',
#   'Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Jump Around',
#   'Touch Down',
#   'Uncontrollable (feat. Big Zuu)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)',
#   'Wake Up Call (feat. Trippie Redd)',
#   'Friends With Benefits (KSI vs MNDM)',
#   'Creature',
#   'Earthquake',
#   'Little Boy',
#   "Adam's Apple",
#   'Lamborghini',
#   'Two Birds, One Stone'],
#  'Donots': ['So Long'],
#  'Frank Turner': ['So Long'],
#  'Red Hot Chili Peppers': ['By the Way',
#   'Snow (Hey Oh)',
#   'Californication',
#   "Can't Stop"],
#  'Powfu': ['death bed (coffee for your head)'],
#  'beabadoobee': ['death bed (coffee for your head)'],
#  'Edwin Rosen': ['leichter//kälter'],
#  'Thees Uhlmann': ['Zum Laichen und Sterben ziehen die Lachse den Fluss hinauf'],
#  'Blond': ['Match'],
#  'Saint Motel': ['My Type'],
#  'Philipp Poisel': ['Wie soll ein Mensch das ertragen',
#   'Mein Amerika',
#   'Erkläre mir die Liebe',
#   'Ich will nur - Live',
#   'Liebe meines Lebens',
#   'Wolke 7',
#   'Wie soll ein Mensch das ertragen'],
#  'DJ Gollum': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Scarlet': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'DJ THT': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Ced Tecknoboy': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Tate McRae': ['you broke me first'],
#  'Razz': ['Youth & Enjoyment'],
#  'Twenty One Pilots': ['Addict With A Pen'],
#  'Quietdrive': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'Droo Hastings From Drrt': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'P!nk': ['Try',
#   'Walk Me Home',
#   'Raise Your Glass',
#   'So What',
#   'What About Us - Cash Cash Remix'],
#  'NF': ['Lie', 'Paralyzed', 'Let You Down'],
#  'Emil Bulls': ['The Jaws of Oblivion'],
#  'ANA': ['Whiskey'],
#  '100 Kilo Herz': ['Laternensong'],
#  'The Weeknd': ['Save Your Tears', 'Blinding Lights', 'The Hills'],
#  'Die Toten Hosen': ['Oberhausen',
#   'Vogelfrei',
#   'Herz brennt',
#   'Steh auf, wenn du am Boden bist',
#   'Auswärtsspiel',
#   'Hier kommt Alex',
#   'Bonnie & Clyde',
#   'Wannsee',
#   'Alles passiert',
#   'Alles aus Liebe'],
#  'Jennifer Rostock': ['K.B.A.G.', 'Alles Cool', 'Hengstin'],
#  'Rainbirds': ['Blueprint'],
#  'Bananafishbones': ['für immer', 'Vanessa'],
#  'Ran-D': ['Zombie - Original Mix'],
#  'Dvbbs': ['Raveology'],
#  'VINAI': ['Raveology', 'Break the Beat', 'Out of This Town'],
#  'Emily Watts': ['La Vie En Rose'],
#  'Metro Station': ['Shake It', 'Shake It'],
#  'Neonschwarz': ['On a Journey'],
#  'The Vamps': ['Somebody To You'],
#  'Kina': ['Can We Kiss Forever?'],
#  'Adriana Proenza': ['Can We Kiss Forever?'],
#  'Alec Benjamin': ['Let Me Down Slowly'],
#  'The Fray': ['You Found Me', 'How to Save a Life'],
#  'Ida Corr': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Fedde Le Grand': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Iggy Pop': ['Lust For Life'],
#  'Olivia Rodrigo': ['All I Want', 'good 4 u', 'drivers license'],
#  'Disney': ['All I Want'],
#  'Sarah Connor': ['Wie schön du bist', 'Vincent'],
#  'Ed Sheeran': ['Bad Habits',
#   'Galway Girl',
#   'Castle on the Hill',
#   'Perfect - Robin Schulz Remix',
#   'Photograph',
#   'Happier - Tiësto’s AFTR:HRS Remix'],
#  'Lukas Graham': ['Mama Said'],
#  'Drake': ['One Dance', "God's Plan"],
#  'Wizkid': ['One Dance'],
#  'Kyla': ['One Dance'],
#  'The Kid LAROI': ['STAY (with Justin Bieber)'],
#  'Justin Bieber': ['STAY (with Justin Bieber)'],
#  'Lost Frequencies': ['Love to Go',
#   'Reality',
#   'Reality - Gestört aber GeiL Remix',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Are You With Me - Radio Edit',
#   'Are You With Me - Gestört aber GeiL Remix',
#   'Melody',
#   'So Much Better - Lost Frequencies Remix',
#   'Paris - Lost Frequencies Remix',
#   'Crazy',
#   'Run - Lost Frequencies Radio Edit',
#   'Here with You',
#   'Beautiful Life',
#   'Are You with Me',
#   'Melody',
#   'Like I Love You',
#   'Reality - Gestört aber GeiL Remix',
#   'Are You with Me - Gestört aber GeiL Remix'],
#  'Zonderling': ['Love to Go', 'Crazy'],
#  'Kelvin Jones': ['Love to Go'],
#  'Lipps Inc.': ['Funkytown'],
#  'Cheap Trick': ['Just Got Back'],
#  'Hot Chocolate': ["Every 1's a Winner - Single Version"],
#  'Juju': ['Vermissen (feat. Henning May)'],
#  'Henning May': ['Vermissen (feat. Henning May)'],
#  'Tobi & Manny': ['Rhythm & Vibes',
#   'Destined For Greatness',
#   'Destined For Greatness'],
#  'Irie Révoltés': ['Fäuste hoch'],
#  'Robbie Williams': ['Candy', 'Angels', 'Rock DJ'],
#  'Florence + The Machine': ['Shake It Out'],
#  'Papa Roach': ['Scars', 'Help'],
#  'Radical Face': ['Welcome Home, Son', 'Welcome Home'],
#  'Radiohead': ['Fake Plastic Trees', 'Creep'],
#  'Masked Wolf': ['Astronaut In The Ocean'],
#  'Neil Patrick Harris': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'How I Met Your Mother Cast': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'Tom Petty': ["Free Fallin'"],
#  'Julia Michaels': ['All Your Exes',
#   'Hurt Somebody',
#   'Into You',
#   'Lie To Me (feat. Julia Michaels)',
#   'Hurt Somebody'],
#  'Måneskin': ['I WANNA BE YOUR SLAVE'],
#  'Noah Kahan': ['Hurt Somebody', 'False Confidence', 'Hurt Somebody'],
#  'Provinz': ['Chaos'],
#  'Tai Verdes': ['Stuck In The Middle'],
#  'Dua Lipa': ['Levitating (feat. DaBaby)',
#   'Physical - Alok Remix',
#   'Electricity (with Dua Lipa)',
#   'IDGAF',
#   'One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   'Scared to Be Lonely - Acoustic Version',
#   'Scared to Be Lonely'],
#  'DaBaby': ['Levitating (feat. DaBaby)', 'ROCKSTAR (feat. Roddy Ricch)'],
#  'Harry Styles': ['Falling', 'Watermelon Sugar', 'Sign of the Times'],
#  'Finn': ['In Luv With U'],
#  'The Neighbourhood': ['Sweater Weather'],
#  'Moby': ['Extreme Ways', 'Lift Me Up'],
#  'Da Tweekaz': ['Heroes Of Today', 'D.W.X. (10 Years Dirty Workz Mix)'],
#  'Riverdale Cast': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Ashleigh Murray': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Camila Mendes': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Madelaine Petsch': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Asha Bromfield': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Hayley Law': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'KJ Apa': ['Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Kelis': ['Milkshake'],
#  'Juice WRLD': ['Lucid Dreams', 'Come & Go (with Marshmello)'],
#  'ElyOtto': ['SugarCrash!'],
#  'Basstrologe': ['Somebody To Love'],
#  'Marlon Roudette': ['New Age'],
#  'Tears For Fears': ['Shout'],
#  'Prinz Pi': ['Letzte Liebe', 'Kompass ohne Norden', '1,40m'],
#  'Roddy Ricch': ['ROCKSTAR (feat. Roddy Ricch)'],
#  'Bonnie Tyler': ['Holding Out for a Hero - From "Footloose" Soundtrack'],
#  'Marshmello': ['Come & Go (with Marshmello)',
#   'Here With Me',
#   'BIBA',
#   'Everyday',
#   'FRIENDS',
#   'Danger (with Migos & Marshmello)',
#   'Wolves',
#   'Alone',
#   'Bayen Habeit',
#   'Happier',
#   'You Can Cry',
#   'Everyday',
#   'Spotlight',
#   'Silence'],
#  'A$ton Wyld': ['Next Level'],
#  'Jme': ['Keep Up'],
#  'S1mba': ['Loose (feat. KSI)'],
#  'Craig David': ['Really Love (feat. Craig David & Digital Farm Animals)'],
#  'Digital Farm Animals': ['Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'All Falls Down (feat. Juliander)'],
#  'Anne-Marie': ["Don't Play",
#   '2002',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Ciao Adios - Burak Yeter Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'FRIENDS'],
#  'Zedd': ['The Middle', 'The Middle', 'Beautiful Now', 'Happy Now'],
#  'Maren Morris': ['The Middle', 'GIRL', 'The Middle'],
#  'Grey': ['The Middle', 'The Middle'],
#  '24kGoldn': ['Mood (feat. iann dior)'],
#  'Our Last Night': ['drivers license'],
#  'Creedence Clearwater Revival': ['Fortunate Son'],
#  'Mark Ronson': ['Valerie (feat. Amy Winehouse) - Version Revisited',
#   'Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Electricity (with Dua Lipa)'],
#  'Amy Winehouse': ['Valerie (feat. Amy Winehouse) - Version Revisited'],
#  'Cornershop': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'Norman Cook': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'NEIKED': ['Sexual'],
#  'Dyo': ['Sexual'],
#  'Capital Cities': ['Safe And Sound'],
#  'George Ezra': ['Hold My Girl', 'Paradise'],
#  'Vance Joy': ['Mess Is Mine'],
#  'Lil Glock Rouge': ['Merry Merry Christmas'],
#  'Sidemen': ['Merry Merry Christmas', 'The Gift'],
#  'Linkin Park': ['Shadow of the Day',
#   'CASTLE OF GLASS',
#   'Numb / Encore',
#   'In the End',
#   'Numb'],
#  'Duncan Laurence': ['Arcade'],
#  'flipturn': ['Chicago'],
#  'Ava Max': ['Kings & Queens',
#   'Sweet but Psycho',
#   'Let It Be Me (feat. Ava Max)'],
#  'Camila Cabello': ['Havana (feat. Young Thug)'],
#  'Silbermond': ['Irgendwas bleibt'],
#  'Jaymes Young': ["I'll Be Good"],
#  'Blue October': ['Hate Me'],
#  'Pickle': ['Sing It'],
#  'Endor': ['Pump It Up'],
#  'Outkast': ['Roses', 'Ms. Jackson'],
#  'Otto Knows': ['Million Voices - Radio Edit'],
#  'Jetta': ["I'd Love To Change The World - Matstubs Remix"],
#  'Matstubs': ["I'd Love To Change The World - Matstubs Remix"],
#  'John Newman': ['Love Me Again'],
#  'Rihanna': ['Disturbia', 'Stay', 'Love The Way You Lie', 'Live Your Life'],
#  'Die Firma': ['Die Eine 2005'],
#  'The Smiths': ['Asleep - 2011 Remaster'],
#  'Edward Sharpe & The Magnetic Zeros': ['Home'],
#  'lovelytheband': ['broken'],
#  'Johnny Cash': ['Hurt'],
#  'James Bay': ['Hold Back The River'],
#  'BANNERS': ['Shine A Light', 'Someone To You', 'Ghosts'],
#  'U2': ['Bad - Remastered 2009',
#   'Beautiful Day',
#   'With Or Without You - Remastered'],
#  'Casper': ['Ganz schön okay (feat. Kraftklub)', 'So perfekt'],
#  'Lewis Capaldi': ['Someone You Loved', 'Bruises'],
#  'Chip Taylor': ['On the Radio (Music from the Netflix Original Series Sex Education)'],
#  'Jerome': ['Light'],
#  'DVBBS': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Dropgun': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Sanjin': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Emeli Sandé': ['Clown', 'Read All About It, Pt. III'],
#  'Gwen Stefani': ['Kings Never Die', 'Hollaback Girl'],
#  '5 Seconds of Summer': ['She Looks So Perfect',
#   'Youngblood',
#   'Lie To Me (feat. Julia Michaels)',
#   'Youngblood - R3HAB Remix'],
#  'GAMPER & DADONI': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Emily Roberts': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Purple Disco Machine': ['Exotica', 'Hypnotized'],
#  'Mind Enterprises': ['Exotica'],
#  'Fritz Kalkbrenner': ['Good Things', 'Sky and Sand'],
#  'Martin Solveig': ['All Stars'],
#  'ALMA': ['All Stars'],
#  'AWOLNATION': ['Sail'],
#  'Sophie and the Giants': ['Hypnotized'],
#  'Neptunica': ['San Francisco'],
#  'Ellipso': ['San Francisco'],
#  'Emy Perez': ['San Francisco'],
#  'Chord Overstreet': ['Hold On'],
#  'Dimitri Vegas & Like Mike': ['Body Talk (feat. Julian Perretta)',
#   'The Anthem (Der Alte)',
#   'Beast (All as One)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'Wakanda',
#   'Mammoth',
#   'Ocarina',
#   'The Hum - Original Mix',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix',
#   'Hey Baby',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'Ready For Action',
#   'He\'s a Pirate (VIP Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate (Extended Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate - From "Pirates of the Caribbean: Dead Men Tell No Tales" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'Complicated (feat. Kiiara)',
#   'Crowd Control - Radio Edit',
#   'Slow Down (feat. Boef, Ronnie Flex, Ali B & I Am Aisha)',
#   'Patser Bounce',
#   'The House Of House',
#   'All I Need (with Gucci Mane)',
#   'When I Grow Up (feat. Wiz Khalifa)',
#   'Unity',
#   'Here We Go (Hey Boy, Hey Girl)',
#   'Opa',
#   'Arcade Mammoth',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MOGUAI': ['Body Talk (feat. Julian Perretta)', 'Mammoth', 'Arcade Mammoth'],
#  'Julian Perretta': ['Body Talk (feat. Julian Perretta)'],
#  'Krunk!': ['La Menta', 'Al Pacino'],
#  'Max Herre': ['Wolke 7'],
#  'Revolverheld': ['Halt dich an mir fest'],
#  'David Guetta': ['Where Them Girls At (feat. Nicki Minaj & Flo Rida)',
#   "Club Can't Handle Me (feat. David Guetta)",
#   'Let It Be Me (feat. Ava Max)',
#   'Flames',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Like I Do',
#   'Titanium (feat. Sia)',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Like I Do',
#   'Complicated (feat. Kiiara)'],
#  'Sean Paul': ['Temperature'],
#  'Toploader': ['Dancing in the Moonlight'],
#  'Bruce Springsteen': ['Dancing In the Dark'],
#  'Lister': ['Pathways'],
#  'The Lumineers': ['Ophelia'],
#  'Vinnie Paz': ['The Ghost I Used to Be'],
#  'Eamon': ['The Ghost I Used to Be'],
#  'Elena Coats': ['Sad Song (feat. Elena Coats)'],
#  'Dean Lewis': ['Half A Man'],
#  'Pitbull': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Back in Time - featured in "Men In Black 3"',
#   'Bailar (feat. Pitbull & Elvis Crespo)'],
#  'Ne-Yo': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'AFROJACK': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Ten Feet Tall',
#   'Turn up the Speakers - Radio Edit'],
#  'Nayer': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'Coone': ['D.W.X. (10 Years Dirty Workz Mix)',
#   'Words From The Gang (2014 Remix) - Radio Version',
#   'Pump up the Jam'],
#  'Imagine Dragons': ["It's Time",
#   'On Top Of The World',
#   'Thunder',
#   'Thunder',
#   'Radioactive',
#   'Thunder',
#   'Believer - Kaskade Remix'],
#  'Lord Huron': ['The Night We Met'],
#  'Tungevaag': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'Wicked Wonderland',
#   'All For Love - Luca Schreiner Remix'],
#  'Raaban': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'All For Love - Luca Schreiner Remix'],
#  'Emila': ['Samsara (feat. Emila)'],
#  'Brynny': ['Thinking Too Much'],
#  'DJ Antoine': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'The Beatshakers': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'Herbert Grönemeyer': ['Glück', 'Flugzeuge im Bauch'],
#  'Elliott Smith': ['Say Yes', 'Say Yes'],
#  'Gloria Gaynor': ['I Will Survive - Single Version'],
#  'Good Charlotte': ['I Just Wanna Live',
#   'The River',
#   'Girls & Boys',
#   'Lifestyles of the Rich & Famous'],
#  'Frittenbude': ['Mindestens in 1000 Jahren'],
#  'Jessica Ricca': ["Hey It’s Delilah (Plain White T's Cover)"],
#  'Adele': ['Someone Like You', 'When We Were Young'],
#  'LUM!X': ['Monster'],
#  'Rosa Anschütz': ['Rigid - Kobosil 44 Rush Mix'],
#  'Kobosil': ['Rigid - Kobosil 44 Rush Mix'],
#  'Stanfour': ['Wishing You Well - Radio Version'],
#  'Bloodhound Gang': ['Uhn Tiss Uhn Tiss Uhn Tiss',
#   'The Ballad Of Chasey Lain',
#   'The Bad Touch',
#   'Foxtrot Uniform Charlie Kilo'],
#  'Drunkenmunky': ['E'],
#  'ZAYN': ['Dusk Till Dawn (feat. Sia) - Radio Edit'],
#  'Sia': ['Dusk Till Dawn (feat. Sia) - Radio Edit',
#   'The Greatest',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Flames',
#   'Titanium (feat. Sia)'],
#  'Diddy - Dirty Money': ['Coming Home'],
#  'Skylar Grey': ['Coming Home', 'Glorious (feat. Skylar Grey)'],
#  'Snow Patrol': ['Called Out In The Dark',
#   'Chasing Cars',
#   'Chasing Cars',
#   'Chasing Cars'],
#  'B.o.B': ['Price Tag', 'Airplanes (feat. Hayley Williams of Paramore)'],
#  'David Gray': ["This Year's Love"],
#  'The Who': ["Baba O'Riley"],
#  'Broilers': ['Tanzt du noch einmal mit mir?'],
#  'Route 94': ['My Love (feat. Jess Glynne)'],
#  'Jess Glynne': ['My Love (feat. Jess Glynne)', 'Take Me Home'],
#  'My Chemical Romance': ['The Only Hope for Me Is You',
#   "I Don't Love You",
#   'Disenchanted - Live Demo',
#   'Kill All Your Friends - Live Demo',
#   'All the Angels - Live Demo',
#   'House of Wolves - Version 2; Live Demo',
#   'Famous Last Words',
#   'Cancer',
#   'Party at the End of the World - Live Demo',
#   'Dead!',
#   'Emily - Rough Mix',
#   'Not That Kind of Girl - Live Demo',
#   'The Five of Us Are Dying - Rough Mix',
#   'House of Wolves',
#   'The Sharpest Lives',
#   'Sleep',
#   'Blood - Hidden Track',
#   'Disenchanted',
#   'Teenagers',
#   'House of Wolves - Version 1; Live Demo',
#   'Mama - Live Demo',
#   'Welcome to the Black Parade',
#   'Mama',
#   'The End.',
#   'My Way Home Is Through You - Live Demo',
#   'This Is How I Disappear',
#   'Vampire Money',
#   'DESTROYA',
#   'The Only Hope for Me Is You',
#   'Goodnite, Dr. Death',
#   'Party Poison',
#   'Look Alive, Sunshine',
#   'SING',
#   'Bulletproof Heart',
#   'Jet-Star and the Kobra Kid / Traffic Report',
#   "Save Yourself, I'll Hold Them Back",
#   'Planetary (GO!)',
#   'S/C/A/R/E/C/R/O/W',
#   'The Kids from Yesterday',
#   'Summertime',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Drowning Lessons',
#   'Cubicles',
#   'Romance',
#   'Demolition Lovers',
#   'This Is the Best Day Ever',
#   'Early Sunsets Over Monroeville',
#   'Skylines and Turnstiles',
#   'Our Lady of Sorrows',
#   'Headfirst for Halos',
#   "Honey, This Mirror Isn't Big Enough for the Two of Us",
#   'Vampires Will Never Hurt You',
#   'Thank You for the Venom',
#   "Give 'Em Hell, Kid",
#   'To the End',
#   "Hang 'Em High",
#   'Cemetery Drive',
#   "It's Not a Fashion Statement, It's a Deathwish",
#   'Interlude',
#   'You Know What They Do to Guys Like Us in Prison',
#   'I Never Told You What I Do for a Living',
#   'The Jetset Life Is Gonna Kill You',
#   'This Is How I Disappear',
#   'Dead!',
#   'Blood - Hidden Track',
#   'The Sharpest Lives',
#   'Sleep',
#   'Disenchanted',
#   'The End.',
#   'House of Wolves',
#   'Kill All Your Friends',
#   'Cancer',
#   'Mama',
#   'The Ghost of You',
#   'Famous Last Words',
#   "I Don't Love You",
#   'Helena',
#   'Welcome to the Black Parade',
#   "I'm Not Okay (I Promise)",
#   'Na Na Na (Na Na Na Na Na Na Na Na Na)',
#   'Teenagers',
#   'Fake Your Death'],
#  'James Arthur': ['Can I Be Him', 'You Can Cry'],
#  'Thomas Rhett': ['Die A Happy Man'],
#  'Anis Don Demina': ['Uno Dos Tres Shurda'],
#  'VOLAC': ['In A Club'],
#  'illusionize': ['In A Club'],
#  'Andre Longo': ['In A Club'],
#  'Popp & Popp': ['Lieblingsfarbe Sonne'],
#  'Flowa': ['Lieblingsfarbe Sonne'],
#  'Neelix': ['You',
#   'Before - Neelix Well Done Remix',
#   'Waterfall',
#   'Makeup (feat. Caroline Harrison)',
#   'Looking Like We Usually Look',
#   'Mosquito',
#   'The Sun',
#   'Angels of Destruction - Neelix Remix',
#   'Expect What',
#   'History',
#   '1000 Sterne'],
#  'AJR': ["I'm Ready", '100 Bad Days', 'Pretender (feat. Lil Yachty & AJR)'],
#  'Calum Scott': ['Dancing On My Own',
#   'Dancing On My Own',
#   'Dancing On My Own - Tiësto Remix'],
#  'Hayley Williams': ['Airplanes (feat. Hayley Williams of Paramore)'],
#  'You Me At Six': ['Underdog'],
#  'Mattafix': ['Big City Life'],
#  'Wrabel': ['Ten Feet Tall', 'Written in the Scars (feat. Wrabel)'],
#  'Yeah Yeah Yeahs': ['Heads Will Roll - A-Trak Remix'],
#  'A-Trak': ['Heads Will Roll - A-Trak Remix'],
#  'DJ Blyatman': ['Gopnik'],
#  'Dom Dolla': ['San Frandisco'],
#  'Ricky Desktop': ['The Banjo Beat, Pt. 1'],
#  'Nathan Dawe': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)'],
#  'Ella Henderson': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Yours'],
#  'Boyce Avenue': ['The One That Got Away'],
#  'Armin van Buuren': ['You Are',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'Turn It Up',
#   'Blah Blah Blah',
#   'Great Spirit',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Blah Blah Blah',
#   'Therapy',
#   'This Is What It Feels Like',
#   'Drowning - Avicii Remix',
#   'United',
#   'Sunny Days',
#   'Wild Wild Son',
#   'Another You',
#   'Off The Hook'],
#  'Sunnery James & Ryan Marciano': ['You Are'],
#  'Will Sparks': ['My Spine Is Tingling',
#   '#SELFIE - Will Sparks Remix',
#   '#Selfie - Will Sparks Remix',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Take Me (feat. Gloria Kim)',
#   'Sick Like That (feat. Luciana)',
#   'Ah Yeah So What - Radio Edit',
#   'Senseless',
#   'Leave The Lights On - Will Sparks Remix',
#   'My Time',
#   'Voices'],
#  'Luciana': ['My Spine Is Tingling',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Sick Like That (feat. Luciana)',
#   'Fireflies (feat. Luciana)'],
#  'Sonar': ['Sonar'],
#  'SCNDL': ['Sonar', 'Bleed'],
#  'Mikky Ekko': ['Stay'],
#  'Alok': ["Don't Ya - Fabio Fusco Remix",
#   'Physical - Alok Remix',
#   'Piece Of Your Heart - Alok Remix',
#   'United'],
#  'FractaLL': ["Don't Ya - Fabio Fusco Remix"],
#  'Bea Jourdan': ["Don't Ya - Fabio Fusco Remix"],
#  'Fabio Fusco': ["Don't Ya - Fabio Fusco Remix"],
#  'Tiësto': ['God Is A Dancer - James Hype Remix',
#   'Grapevine - Tujamo Remix',
#   'On My Way',
#   'Happier - Tiësto’s AFTR:HRS Remix',
#   'BOOM',
#   'Dancing On My Own - Tiësto Remix',
#   'WOW',
#   'Jackie Chan',
#   'Red Lights',
#   'Split (Only U)',
#   'Carry You Home',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Harder'],
#  'Mabel': ['God Is A Dancer - James Hype Remix'],
#  'James Hype': ['God Is A Dancer - James Hype Remix'],
#  'Chiddy Bang': ['Opposite of Adults'],
#  'Tigerlily': ['Invisible Children', 'Spice Temple - Overdrive Remix'],
#  'BOSS': ['Dumb (Feat. BOSS)', 'Over and Out (feat. Charlott Boss)'],
#  'Mike Williams': ['Wait Another Day', 'The Beat', 'Lullaby'],
#  'Mesto': ['Wait Another Day'],
#  'Angels & Airwaves': ['Surrender',
#   'Chasing Shadows',
#   'The Adventure',
#   'Surrender'],
#  'R3HAB': ['Flashlight',
#   'Wrong Move (feat. Olivia Holt)',
#   'Rumors',
#   'Radio Silence',
#   'Tequila - R3HAB Remix',
#   'Starflight',
#   'Youngblood - R3HAB Remix',
#   'Lullaby',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'Freak',
#   "I Just Can't"],
#  'Deorro': ['Flashlight',
#   'Melbourne Bounce - Deorro Remix',
#   'Bootie in Your Face - No Rock Drop',
#   'Focus',
#   'Focus (feat. Lena Leon)',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'I Can Be Somebody (feat. Erin McCarley)',
#   'Bailar (feat. Pitbull & Elvis Crespo)',
#   'Bailar (feat. Elvis Crespo) - Radio Edit',
#   'Five More Hours',
#   'DFTF',
#   'Perdoname (feat. DyCy & Adrian Delgado)',
#   'Tell Me Lies (feat. Lesley Roy)',
#   'Five Hours',
#   'Knockout'],
#  'Von Wegen Lisbeth': ['Bitch'],
#  'Showtek': ['Booyah - Radio Edit', 'We Like to Party - Original Mix'],
#  'We Are Loud': ['Booyah - Radio Edit'],
#  'Sonny Wilson': ['Booyah - Radio Edit'],
#  'Club Madness': ['Pumped Up Kicks - Smithee Hard Edit'],
#  'Snoop Dogg': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Hollywood (feat. Snoop Dogg & Jamie Principle)',
#   'Bounce (feat. Snoop Dogg)'],
#  'Wiz Khalifa': ['Young, Wild & Free (feat. Bruno Mars)',
#   "Don't Kill My High (feat. Wiz Khalifa & Social House)",
#   'Payphone',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'When I Grow Up (feat. Wiz Khalifa)'],
#  'Bruno Mars': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Finesse - Remix; feat. Cardi B'],
#  'Ummet Ozcan': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Change My Heart',
#   'The Hum - Short Edit',
#   'The Hum - Original Mix',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Brennan Heart': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix'],
#  'Keane': ['Somewhere Only We Know'],
#  'Curtis Waters': ["Stunnin' (feat. Harm Franklin)"],
#  'Harm Franklin': ["Stunnin' (feat. Harm Franklin)"],
#  'Ali As': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Namika': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Gnarls Barkley': ['Crazy'],
# ...
#  'The Prince Karma': ['Later Bitches'],
#  'Ozzy Osbourne': ["Mama, I'm Coming Home", 'Dreamer'],
#  'Boston': ['More Than a Feeling'],
#  'Fall Out Boy': ["This Ain't A Scene, It's An Arms Race",
#   "Sugar, We're Goin Down",
#   'Centuries',
#   "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'The Last Of The Real Ones'],
#  'Fitz and The Tantrums': ['HandClap'],
#  'Die Ärzte': ['Ist das noch Punkrock?', 'Deine Schuld'],
#  'Kodaline': ['All I Want'],
#  'Green Day': ['Holiday',
#   'Holiday / Boulevard of Broken Dreams',
#   'Still Breathing',
#   'When I Come Around',
#   'Boulevard of Broken Dreams',
#   'Wake Me up When September Ends',
#   'Welcome to Paradise',
#   'Basket Case',
#   'Good Riddance (Time of Your Life)',
#   'American Idiot',
#   'Restless Heart Syndrome',
#   'East Jesus Nowhere',
#   '21st Century Breakdown',
#   "Christian's Inferno",
#   'Before the Lobotomy',
#   'The Static Age',
#   'American Eulogy: Mass Hysteria / Modern World',
#   '¿Viva La Gloria? (Little Girl)',
#   'Horseshoes and Handgrenades',
#   'Murder City',
#   '¡Viva La Gloria!',
#   'Last of the American Girls',
#   'Last Night on Earth',
#   'See the Light',
#   'Peacemaker',
#   'Know Your Enemy',
#   '21 Guns',
#   'Song of the Century',
#   'Makeout Party - Demo',
#   '99 Revolutions - Demo',
#   'Stray Heart - Demo',
#   'Angel Blue - Demo',
#   'Nuclear Family - Demo',
#   'Ashley - Demo',
#   'A Little Boy Named Train - Demo',
#   'Oh Love - Demo',
#   'Sex, Drugs & Violence - Demo',
#   'Stay the Night - Acoustic',
#   'Baby Eyes - Demo',
#   'Missing You - Demo',
#   'Carpe Diem - Demo',
#   'Rusty James - Demo',
#   'State of Shock - Demo',
#   'Let Yourself Go - Demo',
#   'Fell for You - Demo',
#   'Stay the Night - Demo',
#   'Drama Queen',
#   'A Little Boy Named Train',
#   'The Forgotten',
#   'Dirty Rotten Bastards',
#   'Sex, Drugs & Violence',
#   'Missing You',
#   'Amanda',
#   '99 Revolutions',
#   'X-Kid',
#   '8th Avenue Serenade',
#   'Brutal Love',
#   'Walk Away',
#   'Fuck Time',
#   'Baby Eyes',
#   "Wow! That's Loud",
#   'Stray Heart',
#   'Lazy Bones',
#   'Stop When the Red Lights Flash',
#   'Ashley',
#   'Nightlife',
#   'Makeout Party',
#   'Lady Cobra',
#   'Wild One',
#   'Amy',
#   'See You Tonight',
#   'Troublemaker',
#   'Sweet 16',
#   'Rusty James',
#   'Oh Love',
#   'Fell for You',
#   'Nuclear Family',
#   'Angel Blue',
#   'Loss of Control',
#   'Let Yourself Go',
#   'Stay the Night',
#   'Carpe Diem',
#   'Kill the DJ',
#   'Holiday / Boulevard of Broken Dreams',
#   'Jesus of Suburbia',
#   "Give Me Novacaine / She's a Rebel",
#   'Homecoming',
#   'Extraordinary Girl / Letterbomb',
#   'Too Much Too Soon',
#   'Wake Me up When September Ends',
#   'American Idiot',
#   'Governator',
#   'Shoplifter',
#   'Whatsername'],
#  'MICAR': ["This Time It's My Life - Radio Edit"],
#  'Breathe Carolina': ['My Love', 'The Fever'],
#  'Robert Falcon': ['My Love'],
#  'The Cure': ["Friday I'm In Love"],
#  'Jon Boden': ['How Long Will I Love You'],
#  'Sam Sweeney': ['How Long Will I Love You'],
#  'Ben Coleman': ['How Long Will I Love You'],
#  'G.R.L.': ['Ugly Heart'],
#  'T.I.': ['Live Your Life'],
#  'Die Antwoord': ['Banana Brain'],
#  'Belik Boom': ['Avada Kadabra'],
#  'Bag Raiders': ['Shooting Stars'],
#  'Alle Farben': ['H.O.L.Y.', 'Please Tell Rosie', 'Fading'],
#  'RHODES': ['H.O.L.Y.'],
#  'YouNotUs': ['Please Tell Rosie'],
#  'Hoobastank': ['The Reason', 'The Reason'],
#  'Three Days Grace': ['I Hate Everything About You'],
#  'Thirty Seconds To Mars': ['The Kill'],
#  'Bon Jovi': ["It's My Life",
#   'You Give Love A Bad Name',
#   "Livin' On A Prayer"],
#  'The Subways': ['Rock & Roll Queen'],
#  'Puddle Of Mudd': ['She Hates Me'],
#  'Third Eye Blind': ['Semi-Charmed Life'],
#  'Caesars': ['Jerk It Out', 'Jerk It Out'],
#  'Nirvana': ['Smells Like Teen Spirit',
#   'Come As You Are',
#   'Smells Like Teen Spirit'],
#  'Escape the Fate': ['Broken Heart'],
#  'Andrew Rayel': ['Horizon'],
#  'Lola Blanc': ['Horizon'],
#  'Philipp Dittberner': ['1,40m'],
#  'John De Sohn': ['Forever Young', 'Happy Kids'],
#  'LIAMOO': ['Forever Young'],
#  'Fox Blanco': ['Change the World'],
#  'Davai': ['Replay (feat. CIRE)'],
#  'CIRE': ['Replay (feat. CIRE)'],
#  'Alvaro Soler': ['La Cintura'],
#  'Matt Simons': ['We Can Do Better'],
#  'Swedish House Mafia': ["Don't You Worry Child (Radio Edit) [feat. John Martin]"],
#  'MIKA': ['Grace Kelly'],
#  'Laurell': ['Change My Heart', 'Good Vibes (feat. Laurell)'],
#  'Kris Kross Amsterdam': ['Whenever (feat. Conor Maynard)'],
#  'The Boy Next Door': ['Whenever (feat. Conor Maynard)'],
#  'Conor Maynard': ['Whenever (feat. Conor Maynard)'],
#  'ItaloBrothers': ['Summer Air', 'Till You Drop'],
#  'Blur': ['Song 2', 'Song 2 - 2012 Remaster'],
#  'XO Cupid': ['True Colors (feat. Maya Avedis)'],
#  'Maya Avedis': ['True Colors (feat. Maya Avedis)'],
#  'Alice Merton': ['Why So Serious', 'Funny Business'],
#  'Richard Smitt': ['All For Love', 'All For Love - Luca Schreiner Remix'],
#  'Smith & Thell': ['Toast', 'Forgive Me Friend'],
#  'Dzeko': ['Heaven (feat. Veronica)', 'Jackie Chan'],
#  'Riggi & Piros': ['Heaven (feat. Veronica)'],
#  'Veronica': ['Heaven (feat. Veronica)'],
#  'Westlife': ["When You're Looking Like That - Single Remix"],
#  'Nico Santos': ['Rooftop', 'Rooftop - HUGEL Remix'],
#  'Swedish Jam Factory': ['Forgive Me Friend'],
#  'A7S': ['Hey Baby (feat. A7S)'],
#  'Train': ['Hey, Soul Sister', 'Hey, Soul Sister'],
#  'Journey': ["Don't Stop Believin'", "Don't Stop Believin'"],
#  'Vargas & Lagola': ['Roads'],
#  'Katrina & The Waves': ['Walking On Sunshine'],
#  'T-Pain': ['Low (feat. T-Pain)'],
#  'Tom Cochrane': ['Life Is A Highway'],
#  'The Cranberries': ['Zombie'],
#  'Spice Girls': ['Wannabe'],
#  'Eurythmics': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Annie Lennox': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Dave Stewart': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'will.i.am': ['Hall of Fame (feat. will.i.am)'],
#  'TOTO': ['Africa'],
#  'The Rembrandts': ['I\'ll Be There for You (Theme from "Friends\')',
#   "I'll Be There for You (Theme from Friends) - Single Version"],
#  "Guns N' Roses": ["Sweet Child O' Mine"],
#  'Chumbawamba': ['Tubthumping'],
#  'Shakira': ['Whenever, Wherever', "Hips Don't Lie (feat. Wyclef Jean)"],
#  'John Denver': ['Take Me Home, Country Roads - Rerecorded'],
#  'Smash Mouth': ['All Star'],
#  'Hanson': ['MMMBop - Single Version', 'MMMBop'],
#  'Gavin DeGraw': ["I Don't Want to Be - Stripped Version"],
#  'WALK THE MOON': ['Shut Up and Dance'],
#  'Tenacious D': ['Tribute'],
#  'Bryan Adams': ["Summer Of '69", "Summer Of '69"],
#  'American Authors': ['Best Day Of My Life', 'Best Day Of My Life'],
#  'Eiffel 65': ['Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'Backstreet Boys': ["Everybody (Backstreet's Back) - Extended Version",
#   'I Want It That Way',
#   'I Want It That Way - Anstandslos & Durchgeknallt Remix'],
#  'Rascal Flatts': ['Life is a Highway - From "Cars"'],
#  'The Verve': ['Bitter Sweet Symphony'],
#  'Alien Ant Farm': ['Smooth Criminal'],
#  'The Proclaimers': ["I'm Gonna Be (500 Miles)"],
#  'Kid Rock': ['All Summer Long', 'All Summer Long'],
#  'The Goo Goo Dolls': ['Iris'],
#  '3 Doors Down': ['Kryptonite'],
#  'OneRepublic': ['Counting Stars', 'Bones (feat. OneRepublic)'],
#  'fun.': ['Some Nights', 'We Are Young (feat. Janelle Monáe)'],
#  'R.E.M.': ['Losing My Religion'],
#  'Janelle Monáe': ['We Are Young (feat. Janelle Monáe)'],
#  'Lynyrd Skynyrd': ['Sweet Home Alabama'],
#  'Khalid': ['Vertigo',
#   'Saturday Nights REMIX',
#   'Eastside (with Halsey & Khalid)',
#   'Better',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Ocean (feat. Khalid)',
#   'Silence'],
#  'Pritam': ['BIBA'],
#  'Kane Brown': ['Saturday Nights REMIX'],
#  'benny blanco': ['Eastside (with Halsey & Khalid)'],
#  'Lost Kings': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Social House': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Lizzo': ['Juice'],
#  'Kygo': ['Happy Now'],
#  'Sandro Cavazza': ['Happy Now',
#   'Without You (feat. Sandro Cavazza)',
#   'So Much Better - Lost Frequencies Remix',
#   'Beautiful Life'],
#  'Post Malone': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Wow.',
#   'Better Now',
#   'Jackie Chan'],
#  'Swae Lee': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Arms Around You (feat. Maluma & Swae Lee)',
#   'Close To Me (with Diplo) (feat. Swae Lee)'],
#  'Ty James': ['Splash'],
#  'unheard': ['Splash'],
#  'Alec Bailey': ['Grip'],
#  'AUSTN': ["In Betweenin'"],
#  'MOTi': ['Hooked', 'Valencia - Original Mix'],
#  'Sheezan': ['Hooked'],
#  'Emma Sameth': ['Spin With You (feat. Jeremy Zucker)'],
#  'WOLFE': ['Spin With You (feat. Jeremy Zucker)'],
#  'Jeremy Zucker': ['Spin With You (feat. Jeremy Zucker)'],
#  'Galantis': ['Bones (feat. OneRepublic)',
#   'Love on Me',
#   "Don't Care",
#   'In My Head',
#   'Water',
#   "Dancin' to the Sound of a Broken Heart",
#   'Louder, Harder, Better',
#   'Gold Dust',
#   'Forever Tonight',
#   "Kill 'Em with the Love",
#   'Call If You Need Me',
#   'Firebird',
#   'You',
#   'Written in the Scars (feat. Wrabel)',
#   'Hey Alligator',
#   'Call Me Home',
#   'Salvage (Up All Night) (feat. Poo Bear)',
#   'Pillow Fight',
#   'Girls on Boys',
#   'Hello',
#   'Tell Me You Love Me',
#   'True Feeling',
#   'Hunter',
#   'Peanut Butter Jelly',
#   'Love on Me',
#   'Mama Look at Me Now',
#   'Spaceship (feat. Uffie)',
#   'Satisfied (feat. MAX)',
#   'No Money',
#   'Runaway (U & I)'],
#  'Robin Schulz': ['Speechless (feat. Erika Sirola)',
#   'Sugar (feat. Francesco Yates)',
#   'Perfect - Robin Schulz Remix'],
#  'Erika Sirola': ['Speechless (feat. Erika Sirola)'],
#  'Dominic Fike': ['3 Nights'],
#  'Miley Cyrus': ['Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Party In The U.S.A.'],
#  'Rita Ora': ['Only Want You',
#   'Let You Love Me',
#   'Anywhere',
#   'Lonely Together (feat. Rita Ora)'],
#  'Jack & Jack': ['Day Dreaming'],
#  'XXXTENTACION': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Lil Pump': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Maluma': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Snakehips': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Rivers Cuomo': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'KYLE': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Lennon Stella': ['La Di Da', 'Polaroid'],
#  'Chris Burton': ['Love Letters'],
#  'Chantel Jeffries': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'YG': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Rich The Kid': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'BIA': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Ariana Grande': ['thank u, next', '7 rings (feat. 2 Chainz) - Remix'],
#  'Lil Peep': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'Spotlight'],
#  'ILOVEMAKONNEN': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Niall Horan': ['Slow Hands'],
#  'Gryffin': ['Remember (with ZOHARA)'],
#  'ZOHARA': ['Remember (with ZOHARA)'],
#  'Cardi B': ['Finesse - Remix; feat. Cardi B',
#   'Girls Like You (feat. Cardi B) - Cardi B Version'],
#  'Sabrina Carpenter': ['Sue Me'],
#  'Lauren Daigle': ['Look Up Child'],
#  'Drax Project': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'Hailee Steinfeld': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'shy martin': ['Forget to Forget'],
#  'Mallrat': ["Nobody's Home"],
#  'Basenji': ["Nobody's Home"],
#  'ARTY': ['Save Me Tonight'],
#  'Maggie Rogers': ['Light On'],
#  'Ellie Goulding': ['Close To Me (with Diplo) (feat. Swae Lee)', 'Burn'],
#  'Silk City': ['Electricity (with Dua Lipa)'],
#  'LÉON': ['You And I'],
#  '2 Chainz': ['7 rings (feat. 2 Chainz) - Remix'],
#  'GASHI': ['My Year'],
#  'Normani': ['Dancing With A Stranger (with Normani)'],
#  'Zeina': ['In My Head'],
#  "Why Don't We": ['Big Plans'],
#  'Big Boi': ["Doin' It (feat. Sleepy Brown)"],
#  'Sleepy Brown': ["Doin' It (feat. Sleepy Brown)"],
#  'Lauv': ["i'm so tired..."],
#  'Troye Sivan': ["i'm so tired...", 'There for You'],
#  'Tyla Yaweh': ['She Bad'],
#  'COIN': ['I Want It All'],
#  'Kehlani': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Ty Dolla $ign': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Hozier': ['Almost (Sweet Music)'],
#  'Dan + Shay': ['Speechless', 'Tequila - R3HAB Remix'],
#  'Shoffy': ['Cool Again'],
#  'Bazzi': ['Mine'],
#  'Matoma': ['Lonely (feat. MAX)'],
#  'MAX': ['Lonely (feat. MAX)', 'Satisfied (feat. MAX)'],
#  'Shania Twain': ['Man! I Feel Like A Woman!'],
#  'Taylor Swift': ['Shake It Off',
#   'Look What You Made Me Do',
#   'We Are Never Ever Getting Back Together'],
#  'MKTO': ['Classic'],
#  'Little Mix': ['Shout Out to My Ex'],
#  'Keala Settle': ['This Is Me'],
#  'The Greatest Showman Ensemble': ['This Is Me'],
#  'Rachel Platten': ['Fight Song'],
#  'Shawn Mendes': ['Treat You Better', "There's Nothing Holdin' Me Back"],
#  'Wyclef Jean': ["Hips Don't Lie (feat. Wyclef Jean)"],
#  'Kelsea Ballerini': ['This Feeling', 'This Feeling (feat. Kelsea Ballerini)'],
#  'Clean Bandit': ['Symphony (feat. Zara Larsson)'],
#  'Zara Larsson': ['Symphony (feat. Zara Larsson)'],
#  'MØ': ['Final Song'],
#  'Francesco Yates': ['Sugar (feat. Francesco Yates)'],
#  'Kelly Clarkson': ['Since U Been Gone'],
#  'Martin Garrix': ['Like I Do',
#   'Animals',
#   'Turn up the Speakers - Radio Edit',
#   'Forbidden Voices',
#   'Poison',
#   'Forever',
#   'Pizza',
#   'Game Over',
#   'Breach (Walk Alone)',
#   'Yottabyte',
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'In the Name of Love',
#   'Scared to Be Lonely - Acoustic Version',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Scared to Be Lonely',
#   'Ocean (feat. Khalid)',
#   'Like I Do',
#   'High On Life (feat. Bonn)',
#   'There for You',
#   'Burn Out (feat. Dewain Whitmore)'],
#  'Brooks': ['Like I Do', 'Like I Do'],
#  'Jonas Blue': ['Polaroid'],
#  'Liam Payne': ['Polaroid'],
#  'Logic': ['Everyday', 'Everyday'],
#  'Calvin Harris': ['One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix'],
#  'Natasha Bedingfield': ['Unwritten'],
#  "Destiny's Child": ['Survivor'],
#  'Sam And The Womp': ['Bom Bom - Radio Edit'],
#  'Daniel Powter': ['Bad Day'],
#  'Scatman John': ['Scatman (ski-ba-bop-ba-dop-bop)'],
#  'Newton Faulkner': ['Dream Catch Me'],
#  'Baha Men': ['Who Let The Dogs Out'],
#  'Gina G': ['Just a Little Bit - Radio Edit'],
#  'Los Del Rio': ['Macarena'],
#  'Gotye': ['Somebody That I Used To Know'],
#  'Kimbra': ['Somebody That I Used To Know'],
#  'Tomcraft': ['Loneliness - Radio Cut'],
#  'Wheatus': ['Teenage Dirtbag', 'Teenage Dirtbag'],
#  'Chesney Hawkes': ['The One and Only'],
#  'Haddaway': ['What Is Love - 7" Mix', 'What Is Love - 7" Mix'],
#  'Of Monsters and Men': ['Little Talks'],
#  'Jet': ['Are You Gonna Be My Girl'],
#  'Andreas Johnson': ['Glorious'],
#  'Icona Pop': ['I Love It (feat. Charli XCX)'],
#  'Charli XCX': ['I Love It (feat. Charli XCX)'],
#  'Lou Bega': ['Mambo No. 5 (A Little Bit of...)'],
#  'Meredith Brooks': ['Bitch'],
#  'Yolanda Be Cool': ['We No Speak Americano'],
#  'Andrew Stanley': ['We No Speak Americano'],
#  'DCup': ['We No Speak Americano'],
#  'Matt Handles': ['We No Speak Americano'],
#  'Carl Douglas': ['Kung Fu Fighting'],
#  'Iglu & Hartly': ['In This City'],
#  'Rogue Traders': ['Voodoo Child'],
#  'Men Without Hats': ['The Safety Dance'],
#  'Marc Cohn': ['Walking in Memphis'],
#  'The Holloways': ['Generator'],
#  'Nizlopi': ['JCB'],
#  'Nena': ['99 Luftballons'],
#  'Bingo Players': ['Get Up (Rattle) - Radio Edit'],
#  'Faul & Wad': ['Changes - Radio Mix'],
#  'PNAU': ['Changes - Radio Mix'],
#  'Kevin Rudolf': ['Let It Rock'],
#  'Vanessa Carlton': ['A Thousand Miles - Single Version'],
#  'Passenger': ['Let Her Go'],
#  'Joan Osborne': ['One Of Us'],
#  'Ian Carey Project': ['Get Shaky'],
#  'The Buggles': ['Video Killed The Radio Star'],
#  'M.V.P.': ['Roc Ya Body (Mic Check 1, 2)'],
#  'DJ Zinc': ['Roc Ya Body (Mic Check 1, 2)'],
#  'Safri Duo': ['Played-A-Live (The Bongo Song)'],
#  'Rednex': ['Cotton Eye Joe'],
#  'Captain Jack': ['Captain Jack - Short Mix'],
#  'A Touch Of Class': ['Around the World (La La La La La) - Radio Version'],
#  'Pete Konemann': ['Around the World (La La La La La) - Radio Version'],
#  'Kaiser Chiefs': ['Ruby'],
#  'Culcha Candela': ['Hamma! - Single Edit'],
#  'Vengaboys': ['We’re Going to Ibiza!', 'Boom, Boom, Boom, Boom!!'],
#  'Spider Murphy Gang': ['Skandal im Sperrbezirk'],
#  'Throttle': ['Baddest Behaviour', 'Tell Me You Love Me'],
#  'Burak Yeter': ['Ciao Adios - Burak Yeter Remix'],
#  'Jan Delay': ['Oh Jonny'],
#  ...}

# %%
me_id = spotify.me()["id"]
me_id
# Out:
# '0gvflng5qihycq9keswkzvzgh'

# %%
def get_top_tracks(artist_name):
    if artist_name[:2] == "??":
        print(f"{artist_name[2:]} not on Spotify - skipped")
        return None
    print(f"search for: {artist_name}")
    artist_result = spotify.search(q=f"artist:{artist_name}", type="artist")
    best_match = artist_result["artists"]["items"][0]
    print(f"\tbest artist match: {best_match['name']}")
    artist_uri = best_match["uri"]
    tracks = spotify.artist_top_tracks(artist_uri)["tracks"]
    track_info = {track["name"]: track["uri"] for track in tracks}
    return track_info

# %%
with open("lolla_friday.txt") as f:
    lolla_artists = [line.strip() for line in f.readlines()]

# %%
lolla_artist_tracks = {}
for artist_name in lolla_artists:
    track_info = get_top_tracks(artist_name)
    if track_info is not None:
        lolla_artist_tracks[artist_name] = track_info
# Out:
# search for: FRED AGAIN...
# 	best artist match: Fred again..
# search for: THIRTY SECONDS TO MARS
# 	best artist match: Thirty Seconds To Mars
# search for: SUBTRONICS
# 	best artist match: Subtronics
# search for: SVDDEN DEATH
# 	best artist match: SVDDEN DEATH
# search for: TEMS
# 	best artist match: Tems
# search for: KENDRICK LAMAR
# 	best artist match: Kendrick Lamar
# search for: BEABADOOBEE
# 	best artist match: beabadoobee
# search for: BIG WILD
# 	best artist match: Big Wild
# search for: SABRINA CARPENTER
# 	best artist match: Sabrina Carpenter
# search for: JESSIE REYEZ
# 	best artist match: Jessie Reyez
# search for: KNOCKED LOOSE
# 	best artist match: Knocked Loose
# search for: FOALS
# 	best artist match: Foals
# search for: DIESEL
# 	best artist match: Diesel
# search for: PEACH PIT
# 	best artist match: Peach Pit
# search for: KEN CARSON
# 	best artist match: Ken Carson
# search for: ARMNHMR
# 	best artist match: ARMNHMR
# search for: DECLAN MCKENNA
# 	best artist match: Declan McKenna
# search for: SUDAN ARCHIVES
# 	best artist match: Sudan Archives
# EMO NITE not on Spotify - skipped
# search for: RAY VOLPE
# 	best artist match: Ray Volpe
# search for: BLANKE
# 	best artist match: Blanke
# search for: HAIRITAGE
# 	best artist match: Hairitage
# search for: SUECO
# 	best artist match: Sueco
# search for: THE 502S
# 	best artist match: The 502s
# search for: BAND-MAID
# 	best artist match: BAND-MAID
# search for: LOVELESS
# 	best artist match: Loveless
# search for: CAFUNE
# 	best artist match: Cafuné
# search for: SKIZZY MARS
# 	best artist match: Skizzy Mars
# search for: EKKSTACY
# 	best artist match: EKKSTACY
# search for: GIANT ROOKS
# 	best artist match: Giant Rooks
# search for: SINCERE ENGINEER
# 	best artist match: Sincere Engineer
# search for: TIACORINE
# 	best artist match: TiaCorine
# search for: ANNIE DIRUSSO
# 	best artist match: Annie DiRusso
# search for: SOMADINA
# 	best artist match: Somadina
# search for: THE 1975
# 	best artist match: The 1975
# search for: TALK
# 	best artist match: TALK
# search for: HEMLOCKE SPRINGS
# 	best artist match: hemlocke springs
# search for: CYDEWAYS
# 	best artist match: Cydeways
# search for: CHARLOTTE SANDS
# 	best artist match: Charlotte Sands
# search for: TYLER CHRISTIAN
# 	best artist match: Tyler Christian
# search for: LOVIET
# 	best artist match: Loviet
# search for: JUNIOR MESA
# 	best artist match: Junior Mesa
# search for: NINAJIRACHI
# 	best artist match: Ninajirachi

# %%
lolla_artist_tracks
# Out:
# {'FRED AGAIN...': {'Rumble': 'spotify:track:74fmYjFwt9CqEFAh8ybeBD',
#   'Turn On The Lights again.. (feat. Future)': 'spotify:track:0UZFTyq4ogQ5RvfOHGPVdZ',
#   'Marea (we’ve lost dancing)': 'spotify:track:5Z8Dj3LtbyCMiwE86rhg2f',
#   'Delilah (pull me out of this)': 'spotify:track:5w9upngVRHNjdZcRC7Xxr2',
#   'Baby again..': 'spotify:track:6dVgCHMZrWG0tQ4HPeu4aw',
#   'Jungle': 'spotify:track:74yA2S6c71vhUvfh8VkCBY',
#   'Danielle (smile on my face)': 'spotify:track:09Rv6ctDE0t9z8zk5FINg8',
#   'Turn On The Lights again.. (feat. Future) - Anyma Remix': 'spotify:track:4ptnQ0kQnN1U1Ig8TSslj6',
#   'Mike (desert island duvet)': 'spotify:track:6cqcmtaxNL7YCKKsuYAPJo',
#   'Strong': 'spotify:track:5bF00VrMY3FwnQDgoP4Gnk'},
#  'THIRTY SECONDS TO MARS': {'The Kill': 'spotify:track:0lP4HYLmvowOKdsQ7CVkuq',
#   'This Is War': 'spotify:track:2D52zjCyqEIQa221lhw6uk',
#   'Attack': 'spotify:track:0lHSJ0ZP8uUPnJXhMdGjOK',
#   'Walk On Water': 'spotify:track:6FT9FZccFD6nE8dMNslz2n',
#   'Kings And Queens': 'spotify:track:4sjLcE0GQ6urc4iUXsUPe9',
#   'From Yesterday': 'spotify:track:1JBa9B1iA4yNVpJ5wVGrZH',
#   'Closer To The Edge': 'spotify:track:0UZwcRQAk4QR09HtGRZhYC',
#   'A Beautiful Lie': 'spotify:track:0mmaX70fKuhgg0hDrfsS29',
#   'Hurricane': 'spotify:track:7FLVnDMOZXKRFgRM3C4aUG',
#   'Up In The Air': 'spotify:track:0zqwz7SNny9fwqSDpIu4qN'},
#  'SUBTRONICS': {'Puzzle Box': 'spotify:track:5EhnuLMer8qAXEDwmLtyrW',
#   'Griztronics': 'spotify:track:6OTClxme7EYRZGO6An3SMc',
#   'Gassed Up': 'spotify:track:6uwjDA0Qi6hk8C6lPJIMc9',
#   'Griztronics II (Another Level)': 'spotify:track:2il9NDpW87Hk2L9AjeDf8r',
#   'Spacetime (feat. NEVVE)': 'spotify:track:0yotOi6EFaBal5Gy7YVcuI',
#   'GodLovesUgly - Remix': 'spotify:track:76xfSfbw0byLqMHykJyPru',
#   'Escape - Subtronics Remix': 'spotify:track:11IQ89bxoC3bklnfP5TZiM',
#   'Runaway (U & I) - Subtronics Remix': 'spotify:track:0yz6PylgDjlUDkOZayhwOs',
#   'Into Pieces - Wooli x Grabbitz Remix': 'spotify:track:00aIKTpRUwcoGvOfCUMYQr',
#   'Scream Saver': 'spotify:track:3svdq1Crgj8IMezbI1K6cO'},
#  'SVDDEN DEATH': {'Crusade': 'spotify:track:29Dvkvp7Wgd1VJdDvVJlvf',
#   'Pursuit of Violence': 'spotify:track:1qVXfRnJLyNufjtjTXsqQa',
#   'Behemoth VIP': 'spotify:track:0tkwUKjhuBA5UuA95JY2bU',
#   'Behemoth': 'spotify:track:4o7Rszx7VVCzrCr1RPlPot',
#   'Blood On Me': 'spotify:track:4dblKUfR2u2iQXCQ82awv6',
#   'Confusion Spell': 'spotify:track:22IGm6PYN1THrPe1jFT5u6',
#   'Comprehension Barrier': 'spotify:track:311YHO61J97y3NEmzgXslq',
#   'Bleed': 'spotify:track:0xoP7caCgKlnT9JhnPbcXe',
#   'Born To Suffer': 'spotify:track:3Kp2CX12syJgLsmMV9ozCm',
#   'Purgatory - Dion Timmer Remix': 'spotify:track:2TerlFysDwhLHgl6FShK1l'},
#  'TEMS': {'WAIT FOR U (feat. Drake & Tems)': 'spotify:track:59nOXPmaKlBfGMDeOVGrIK',
#   'Essence (feat. Tems)': 'spotify:track:5FG7Tl93LdH117jEKYl3Cm',
#   'Free Mind': 'spotify:track:2mzM4Y0Rnx2BDZqRnhQ5Q6',
#   'Higher': 'spotify:track:2QdSb68BzZGMgCbsrFmSLc',
#   'Fountains (with Tems)': 'spotify:track:08XWh5c0BMyD1nKVxxl91z',
#   'Found (feat. Brent Faiyaz)': 'spotify:track:0GGfGINoVYiSFXPOjg3RHj',
#   'Damages': 'spotify:track:3Xfwu3xtPqmJ4nM4jpBm8O',
#   'Essence (feat. Justin Bieber & Tems)': 'spotify:track:1MZtr7IH5qtjIkqrXj8WOJ',
#   'Replay': 'spotify:track:2dFqK2ZkYB9Xc47gr3xXWl',
#   'The Key': 'spotify:track:4w4EJ9EaeogHLLEYlUXFDo'},
#  'KENDRICK LAMAR': {'Money Trees': 'spotify:track:74tLlkN3rgVzRqQJgPfink',
#   'family ties (with Kendrick Lamar)': 'spotify:track:3QFInJAm9eyaho5vBzxInN',
#   'HUMBLE.': 'spotify:track:7KXjTSCq5nL1LoYtL7XAwS',
#   'All The Stars (with SZA)': 'spotify:track:3GCdLUSnKSMJhs4Tj6CV3s',
#   'LOVE. FEAT. ZACARI.': 'spotify:track:6PGoSes0D9eUDeeAafB2As',
#   'PRIDE.': 'spotify:track:6IZvVAP7VPPnsGX6bvgkqg',
#   'Pray For Me': 'spotify:track:6huNf4dutXRjJyGn7f5BPS',
#   'Alright': 'spotify:track:3iVcZ5G6tvkXZkZKlMpIUs',
#   'N95': 'spotify:track:0fX4oNGBWO3dSGUZcVdVV2',
#   'DNA.': 'spotify:track:6HZILIRieu8S0iqY8kIKhj'},
#  'BEABADOOBEE': {'Glue Song': 'spotify:track:3iBgrkexCzVuPy4O9vx7Mf',
#   'death bed (coffee for your head)': 'spotify:track:7eJMfftS33KTjuF7lTsMCx',
#   'the perfect pair': 'spotify:track:41P6Tnd8KIHqON0QIydx6a',
#   'Tired': 'spotify:track:6F5mZpEEjhsAW8UEqbIpz1',
#   'Coffee': 'spotify:track:429NtPmr12aypzFH3FkN9l',
#   'Cologne': 'spotify:track:1NaDK3atogQEn9glK5fYuy',
#   'Apple Cider': 'spotify:track:5xA5MggKc3aQxuOzNzPUWB',
#   'Sunny day': 'spotify:track:12UQIJePnGeLmpVReYpG2w',
#   'Talk': 'spotify:track:4tf04WrZTy60CawyvueIdK',
#   'The Moon Song': 'spotify:track:3s9eWdn8IymCPvVLcKpjww'},
#  'BIG WILD': {"6's to 9's": 'spotify:track:4DAaQ5InUO23d8yNRbB0Yj',
#   'When I Get There': 'spotify:track:7nYClzzNY6f3EcfeDFNqhS',
#   'Awaken': 'spotify:track:4oYzwOTWpP3JTyKrTHJtqw',
#   "6's to 9's - Day Wave Remix": 'spotify:track:1WDfxOe0HN6NtNujMRZ498',
#   'Purple Sand (My Home)': 'spotify:track:4knUlOyIeFGKH1ObRzfRcl',
#   'Touch': 'spotify:track:57v4cMu70Wx4oG9rFp2lMq',
#   'Pale Blue Dot': 'spotify:track:3XmNMIucTYuXOEpAjcaeVi',
#   'Crickets': 'spotify:track:3M1wrmH2DCIR3syOfjPoxW',
#   'Empty Room - Cabu Remix': 'spotify:track:64c7VPaG2oVXyhfq57peBd',
#   'Show Me': 'spotify:track:7iFlBjOuNfp8oFozovA777'},
#  'SABRINA CARPENTER': {'Nonsense': 'spotify:track:6dgUya35uo964z7GZXM07g',
#   'Feather': 'spotify:track:2Zo1PcszsT9WQ0ANntJbID',
#   'On My Way': 'spotify:track:3BomnHfqKZCdPJC9bkGBjE',
#   'Looking at Me': 'spotify:track:59tskctgqUmjCWAwhzYAFm',
#   'because i liked a boy': 'spotify:track:32FhTAAjKZaBein150o3Px',
#   'emails i can’t send': 'spotify:track:2qLyo5FeWquE7HBUbcVnEy',
#   'Thumbs': 'spotify:track:6WC5fhc9XMaCrUNKNjm9xE',
#   'Nonsense - Sped Up Version': 'spotify:track:5KeI897tZgjezHKvxlaOaR',
#   'Vicious': 'spotify:track:6Alp15t6urC4opjJiyOqZu',
#   'opposite': 'spotify:track:27Jko74ZSVY1kwt0vMY6Pu'},
#  'JESSIE REYEZ': {"I'm Not Here To Make Friends": 'spotify:track:3i0FkJYlU4MFfYkjFHXXAM',
#   'Promises (with Sam Smith)': 'spotify:track:5N5k9nd479b1xpDZ4usjrg',
#   'Gimme (feat. Koffee & Jessie Reyez)': 'spotify:track:7o44vqiznJAsLZpSZwtCkV',
#   'FOREVER (with 6LACK)': 'spotify:track:2lVYLiHGIX6GajMqYXF1Un',
#   'FIGURES': 'spotify:track:3U3J5v3rkx89WnFEQvAJD5',
#   'IMPORTED (with 6LACK)': 'spotify:track:2shEeQzAAL3nnOXfB5pJXx',
#   'Perfect (feat. Jessie Reyez)': 'spotify:track:0mL3oQwd5ZoLDpdoVuzrbg',
#   'Ocean - Remix': 'spotify:track:3Z5fGV8tIdwx3W0CgR9JTx',
#   'Rain (from The Suicide Squad)': 'spotify:track:6gi7qsHSH2JWZsTRHndxqm',
#   'ONLY ONE': 'spotify:track:04xnC2Uwq38RPrwCLv6f0G'},
#  'KNOCKED LOOSE': {'Slaughterhouse (feat. Bryan Garris Of Knocked Loose)': 'spotify:track:2ClgEn1FZxchrqRZ04JZzj',
#   'Counting Worms': 'spotify:track:6QjmnLmLqwjJzHSDCRTACU',
#   'God Knows': 'spotify:track:3idDCx8VXTkqPL6UQTK4bl',
#   'Billy No Mates': 'spotify:track:20Ov9PW41YrzgpGdvbARfE',
#   'Mistakes Like Fractures': 'spotify:track:1STzQvlMovhX8WOn8TcKmZ',
#   'Deadringer': 'spotify:track:1HD11vDTcCQB2n1pUKSEdc',
#   'Where Light Divides the Holler': 'spotify:track:6BVH6nyMBj601mSaUbbqKc',
#   'Belleville': 'spotify:track:7vN4s56DFYoDs7plSPkthe',
#   'Oblivions Peak': 'spotify:track:0KD6jtb6aJONOh3wrClVRk',
#   'Small Victories': 'spotify:track:6ievSA46HVzZv3QvHMCLLn'},
#  'FOALS': {'My Number': 'spotify:track:04caEZhAsQKnWqKsMwk9ud',
#   'Mountain at My Gates': 'spotify:track:3f7OyfSoDbQC0LRDQiytPp',
#   '2am': 'spotify:track:0Tyi56S51KsufCIcqRHWCN',
#   'Late Night - Solomun Remix': 'spotify:track:5WDrfryQ0KUGqj5rMSmyCY',
#   'Birch Tree': 'spotify:track:0BPKqNWOKQam19tKWoZQwu',
#   'Spanish Sahara': 'spotify:track:3SJWVMRwk5z4Uaff7kGs0d',
#   '2001': 'spotify:track:18mdHJIozzktPJ93oXk39A',
#   'Wake Me Up': 'spotify:track:4kSCNra5VuD1ZfiwAe8bTD',
#   'The Runner': 'spotify:track:0AS03vnvXv9m0ZFxtuvOBW',
#   'What Went Down': 'spotify:track:78tgXRq9Q6tPNP9hKCpgwB'},
#  'DIESEL': {'Sausolito Summernight - Digitally Remastered 2017': 'spotify:track:3dH6lT5EAlUdF0QLm6uCNh',
#   'Down In The Silvermine - Digitally Remastered 2017': 'spotify:track:2eymsHsSb0rwSrRFotoOsq',
#   "Goin' Back To China - Digitally Remastered 2017": 'spotify:track:6nOtUPXENbfeBTrlKxIiYQ',
#   'Sausalito Summernight': 'spotify:track:2HOQhOWfkg4oFHNY1LD7lf',
#   'I Put A Spell On You': 'spotify:track:0v240ogPHMm5Y1jFQRSeFw',
#   'Free Ride': 'spotify:track:4XZHOrAxyVcyY3dwDaMFmA',
#   'Fortunate Son': 'spotify:track:19ptHzkBraaOXbSkCghcnM',
#   'All Because Of You - Digitally Remastered 2017': 'spotify:track:72TjfPDdMjvPO6xdz2wOKb',
#   'Alibi - Digitally Remastered 2017': 'spotify:track:5xGbeTym2hbYPAZgnKOLOk',
#   'My Kind Of Woman - Digitally Remastered 2017': 'spotify:track:3fngbi0b6rhs6NG4VagRFa'},
#  'PEACH PIT': {'Alrighty Aphrodite': 'spotify:track:6OiRh4kttAs1YWglvTcYkB',
#   'Shampoo Bottles': 'spotify:track:2INUkDPCO1eQlOFmIN5VAC',
#   "Tommy's Party": 'spotify:track:5OuJTtNve7FxUX82eEBupN',
#   'Give Up Baby Go': 'spotify:track:6DIMM15oo3kxnCuVypaYGy',
#   'Peach Pit': 'spotify:track:0ZK8TGOsngrstVPsnrHbK1',
#   'Drop the Guillotine': 'spotify:track:1gpBDeONibvJyQYEv5HJh9',
#   'Look Out!': 'spotify:track:72BIYdOmoytW14M7BQYyZu',
#   'Vickie': 'spotify:track:2Q18HgXzNB1jB85EuXFgNn',
#   'Techno Show': 'spotify:track:0a0EYuSVqeVqV8kjN9bFYC',
#   'Being so Normal': 'spotify:track:65sNrvOp2HLlhGTeLJ0nnk'},
#  'KEN CARSON': {'Yale': 'spotify:track:0HTIrbUwwFn984RzVZm5Fk',
#   'Hell Yeah': 'spotify:track:3QHGfxhjexLaMKGHXagfRs',
#   'i need u': 'spotify:track:2gSPHSdf0vrk2Psxmn8sUn',
#   'Freestyle 2': 'spotify:track:28niVl6iodHnHpE1bCeJiV',
#   'Rock N Roll': 'spotify:track:1V0jEAE4UreyX8KYxGLnLP',
#   'Murda Musik (feat. Destroy Lonely)': 'spotify:track:6N0I4EqoaIHib3W1LFPMzC',
#   'MDMA (feat. Destroy Lonely)': 'spotify:track:6hJjp4IbXc5bddl6RKutJr',
#   'Freestyle 3': 'spotify:track:3ZuKr1NfTecyfGuYwuXb7c',
#   'Teen Bean': 'spotify:track:4jx9GqqVMPacAOKHaFlsLb',
#   'Run + Ran': 'spotify:track:3kB7daTMGpX2hPRXdZww6M'},
#  'ARMNHMR': {"IT'S YOU - ARMNHMR Remix": 'spotify:track:6EmRDtmAq556gtaj0rOjsW',
#   'Falling Apart': 'spotify:track:5TQDtOeQ3IU2VqKbCn6Rwq',
#   "Won't Make A Sound": 'spotify:track:1mgsWGf69P448vP0md1Z8e',
#   'Drowning': 'spotify:track:6ay07MXOmggaJyMoLT1fqC',
#   'Saving Lives': 'spotify:track:6OK7OQyyvNPd2XQIHCB1wz',
#   'Fragile (feat. Melanie Fontana)': 'spotify:track:1UqkLxHHcQixRPYesIkHXu',
#   'WANT U': 'spotify:track:4gA8RYIv4IG31JqKUM0QnW',
#   'SET ME FREE (ARMNHMR Remix) (ENG)': 'spotify:track:6rEskoR1IPe8099gp8N5AL',
#   'Falling Apart - Acoustic': 'spotify:track:5hdxWJkiBKH6STOH7na5zB',
#   'Anywhere': 'spotify:track:381rMi03g10XRTZJXGu0SR'},
#  'DECLAN MCKENNA': {'Brazil': 'spotify:track:4sNG6zQBmtq7M8aeeKJRMQ',
#   'Why Do You Feel So Down': 'spotify:track:5Bge1Dsqjc14hhGguYML5w',
#   'Make Me Your Queen': 'spotify:track:5QJuMhGWTUB4t9BqR7ndL3',
#   'British Bombs': 'spotify:track:4ZdmTNaBTErD8n9AQE0YaX',
#   'The Key to Life on Earth': 'spotify:track:7sNcXwdbrtMfiYZPiQm2kf',
#   'Isombard': 'spotify:track:3aP1BuaScFyqfqST2KB3VN',
#   'Listen to Your Friends': 'spotify:track:4mvPRLDf0ZedTzzXaXEavJ',
#   'My House': 'spotify:track:2zsmJ1AE5MlLfVrwaCytiD',
#   'Beautiful Faces': 'spotify:track:5AdSNoVSGDmStmQSDis3gz',
#   'Humongous': 'spotify:track:7zI1PDpYJ1yEyAINS604Zs'},
#  'SUDAN ARCHIVES': {'Selfish Soul': 'spotify:track:3XqP0HAPdDN3Lkdoufds20',
#   'Come Meh Way': 'spotify:track:62wAc90VNxtcNJQJrPaeJQ',
#   'Home Maker': 'spotify:track:5vGZX134ZZktjCEYoDm462',
#   'Confessions': 'spotify:track:5myhxurOhMaIi8jAbT5Wgy',
#   'Nont For Sale': 'spotify:track:1dSUiYNjblQ2Vd142K8kjn',
#   'NBPQ (Topless)': 'spotify:track:70yrA4MULoEVLT8GpSoL2A',
#   'OMG BRITT': 'spotify:track:5rNrBpL3zpgv5eEosejMR1',
#   'Ciara': 'spotify:track:1jSZYE0DyzD8jDke47YZWi',
#   'Yellow Brick Road': 'spotify:track:7MYJYInfkV4Jp1CnY2bihc',
#   'Loyal (EDD)': 'spotify:track:2FRK1eHAnb4C2OcZicjGUH'},
#  'RAY VOLPE': {'Old School': 'spotify:track:6ctmKiHf2CcHQLwT7g4jpc',
#   'Laserbeam': 'spotify:track:30MdAjBfVTvBCS3vID38At',
#   'The Dead March': 'spotify:track:4fo7f7s4YJ0KTZ0ECWEg1N',
#   "Laserbeam - Blanke's ÆON:REMIX": 'spotify:track:4DVkTvbzmQKB31PciE7X2a',
#   'Meant To Be Lonely': 'spotify:track:2VaOJEHR9U3Q6SlG8TZN5j',
#   'Laserbeam - Sullivan King Remix': 'spotify:track:0VnfaVKFyKNQGm9Sk7RrOX',
#   'Feeling This Way': 'spotify:track:7ykMS6DBrx2yVP6izrS2KR',
#   'Don’t Look Down (feat. Linney)': 'spotify:track:6Rzv2CVwDi7hYnVU5wKcXe',
#   'Elbow Grease': 'spotify:track:1v8QHnM1K1wa6qg3DuL2SO',
#   'Signal': 'spotify:track:3QcdD1zivRiuTCu1XZnGkY'},
#  'BLANKE': {'Colors (with Eyelar)': 'spotify:track:6ur4bHIfXz7v38Ug4c7sb9',
#   "Laserbeam - Blanke's ÆON:REMIX": 'spotify:track:4DVkTvbzmQKB31PciE7X2a',
#   'Death Rattle': 'spotify:track:09PXdHV9UTx8IdyC5RNyC8',
#   'The Machines': 'spotify:track:3SH8GHdwJGXnoEmnCbPpJQ',
#   'One More Day (with Chandler Leighton)': 'spotify:track:7hCZVX8ogwzgszIKtkD6Bv',
#   'Breathe': 'spotify:track:6Ijgotp139ahnNIFw4Vr1N',
#   'Used to Losing You': 'spotify:track:0A4VK9bpXxGWyHQPm8D81s',
#   'Gorgeous (& Blanke with Bipolar Sunshine)': 'spotify:track:6YeUIhr2njkkCBaBBrRK9j',
#   'Flatline': 'spotify:track:0D8n26VxzYSDIMhDO5JPjO',
#   'Mitosis': 'spotify:track:1F1yF2KSilU2YLOMuYYf71'},
#  'HAIRITAGE': {'40 Cal': 'spotify:track:0EB5fgdGQXZOiOMdRhKeCZ',
#   'Cheatcode': 'spotify:track:1XYCWk1IBt0qA8BaQPV0VM',
#   'Hustle': 'spotify:track:64e18c1c1QPwUi2EBWaYZx',
#   'Resistance': 'spotify:track:46Eg3aa1RZttnZ3sd4u3fd',
#   'The Uncrowned King': 'spotify:track:6S0HcckkiDavLekQGotRSM',
#   'High Life': 'spotify:track:2N6qMBL0E2G55pKKmkCDce',
#   'CYBER DETHHH (Hairitage Remix)': 'spotify:track:0UUNO5KYvPrnO66I6u6bKZ',
#   'Hypnosis': 'spotify:track:2IbHh1QadQ45tKXwD2Ihqd',
#   'Double Dipping': 'spotify:track:4alPbFkCasI3admYNY3JvO',
#   'Cheatcode - Jessica Audiffred Remix': 'spotify:track:4fbOSSjocOB5PpAk1sHbmg'},
#  'SUECO': {'POS': 'spotify:track:2dGj0K0iIrgb3ie1QSLtSL',
#   'Loser': 'spotify:track:01VbCa15MmvNg3KMOfoHa2',
#   'Paralyzed': 'spotify:track:7l4mdOTSYwOayDaHc3s0PV',
#   'Story Of My Life (feat. Trippie Redd)': 'spotify:track:1g7j5AxiNKTGjryhFIlAsA',
#   'PRIMADONA': 'spotify:track:3iwyzJwNmrZPb7dq4zYa4l',
#   'fast': 'spotify:track:1FOINGDWa0dPgCpMabLT4Y',
#   'Sober/Hungover (feat. Arizona Zervas)': 'spotify:track:26LC5cEC5qPsZJ2B7A2Jcp',
#   'Ride It Hard': 'spotify:track:6zqSYGnRnqwpNpCGI5dVfL',
#   'Speed Me Up (with Ty Dolla $ign, Lil Yachty & Sueco the Child)': 'spotify:track:15eWNa3kpCPKILbSvvzSWl',
#   'Next Ex': 'spotify:track:6pkDDxuxe9gkkLRI33mQFn'},
#  'THE 502S': {'Just A Little While': 'spotify:track:4ofr8ORQ9w1QuxGLBwRiQk',
#   'Magdalene': 'spotify:track:7MNsTjkgyA32BetybYx742',
#   'Hey Julia': 'spotify:track:4ITcbrMbYwD3kuIG304nxO',
#   'Waves': 'spotify:track:5luLMIQajTbWm2Zz4EsO9D',
#   'Enjoy the Ride': 'spotify:track:34tvoeX5zWJu4hcnFzgtnL',
#   'Backstage in Glasgow': 'spotify:track:5suIDwVxRuLiSI1RBrFbjP',
#   'Magdalene - Live': 'spotify:track:2VHPMt2EwZNOdEC5lacH6W',
#   'Bad Haircuts': 'spotify:track:0SeQufmeqieCAS4Sevon2c',
#   'Friday Night': 'spotify:track:3xCN6mFnwnpOb6trGnheKT',
#   'Inside Joke': 'spotify:track:4fBttsXaSmYd9oY33NDHea'},
#  'BAND-MAID': {'Sense': 'spotify:track:6Nawx5sqYFIbcx2qQgrA67',
#   'Choose me': 'spotify:track:130dsYbbXp9jQnETiJ7axI',
#   'Unleash!!!!!': 'spotify:track:5Ti8I2TZIE0CM625nT9e0H',
#   'Different': 'spotify:track:23taGXZI9sFYIxdBrqeVaz',
#   'DOMINATION': 'spotify:track:2VxoDPnyxNF976DK9rlVU6',
#   'DICE': 'spotify:track:26P0PvxuRYcgzxeHZ4rjD0',
#   'Memorable': 'spotify:track:5RjEJEBvz2WmO7vmfk07aR',
#   'Thrill': 'spotify:track:7wBVGv4ZncSobd8fCu0WM1',
#   'Hate?': 'spotify:track:1gTErh8Un4YQFfeaIS2KNi',
#   'Influencer': 'spotify:track:1bgpOs3FeHhbpFSZkApGkZ'},
#  'LOVELESS': {'MIDDLE OF THE NIGHT': 'spotify:track:0CwiF8zPjl7ESC6nDnBvPo',
#   'happier than ever': 'spotify:track:4Mojr5CSSZnupTOaPHkal4',
#   'Supernova': 'spotify:track:3P6ittiEouCDcNIloFCjK0',
#   'Running Up That Hill (A Deal With God)': 'spotify:track:4gt4zVee9wMut043fpB9vg',
#   'The Credits': 'spotify:track:7LeRrm1Cg4yCLe3YtrxC3n',
#   'Someone Else': 'spotify:track:2t52LXtpJ6mfoUNg0cbn3w',
#   'Lighthouse': 'spotify:track:7HgmtBZim3P8sZd0yv1pDZ',
#   'STAY': 'spotify:track:5S4iysXioZLt6sqcNpwOpS',
#   'Haunting Me': 'spotify:track:43CuqvRA0PTkSj825h2asQ',
#   'If You Have My Voodoo Doll, Give Me A Hug': 'spotify:track:1sACXjHcXs17HJXlwpXfMk'},
#  'CAFUNE': {'Tek It - Sped Up': 'spotify:track:0MnTkIEP4zZN1IUSu8MvIz',
#   'Tek It': 'spotify:track:751srcHf5tUqcEa9pRCQwP',
#   'Tek It - Slowed': 'spotify:track:0J52jV8skPWcKhZmK7aK6Q',
#   'Perspective': 'spotify:track:1WcVAZYGMKdd2cqeDpuDGI',
#   'Tek It - Acoustic': 'spotify:track:6t3Lvi7J8BfU2wzgckQ6D3',
#   'High': 'spotify:track:3ZphrQX0N2mg16cwCYj7tM',
#   'Friction': 'spotify:track:4mAwxhMBANouZbcrgvgxeY',
#   'Reconsider': 'spotify:track:5xtENt0Tbps029zM5UTTyi',
#   'Talk': 'spotify:track:5LObf6Nh0vN2skSnFSDsIZ',
#   'Want Me Out': 'spotify:track:3nzbZ5bOFNNA2kbQruXl5t'},
#  'SKIZZY MARS': {'Leave Me (feat. Marc E. Bassy)': 'spotify:track:7gNRYLOwgmzMEpgXARSnX9',
#   'Girl on a Train': 'spotify:track:6M1nfYPKy7DRk3IrhFVViQ',
#   'Steady 1234 (feat. Jasmine Thompson & Skizzy Mars)': 'spotify:track:6Z6quH5WcwOkmgGPGrGUPL',
#   'STROBE LIGHTS': 'spotify:track:5YSu5bnAHeB7pn43F9wdbm',
#   'Time (feat. G-Eazy & Olivver the Kid)': 'spotify:track:1UmqCjLXjTwPmuTeaopDQh',
#   'Lucy': 'spotify:track:6GvMQIbZJLv7DczrwXTv43',
#   'Calabasas': 'spotify:track:4TXdMmTNsCETBK0D7PCYsL',
#   'Do You There (feat. Marc E. Bassy)': 'spotify:track:0MuqFuh4MerIiFsYWuEFaP',
#   'Primadonna (with Marc E. Bassy & Skizzy Mars)': 'spotify:track:64DbSkUEqYO0Tjgx1ExZfV',
#   '2006': 'spotify:track:11WVHlpPUHxg7CmbBxWJRr'},
#  'EKKSTACY': {'i walk this earth all by myself': 'spotify:track:6oofvZ4K8vBHnCT1oKERcd',
#   'Uncomparable': 'spotify:track:53F62yfHICseGNOBAH0QUR',
#   'then i met her': 'spotify:track:5sFIYKbII6QzRT57hCza5Z',
#   'it only gets worse, i promise': 'spotify:track:5H0BawU5IlPVzLTiresJwa',
#   'im so happy': 'spotify:track:76EfqbJHiagsv41TNAf4Ko',
#   'See You Later': 'spotify:track:1xHrPq8WvLKiO6lT94Ks2F',
#   'for forever': 'spotify:track:5LUnJSLbd8zXEGgnswctRX',
#   'Starry Eyes': 'spotify:track:5HBWCKsCLz1RQDnSN3OYky',
#   'wish i was dead': 'spotify:track:5Pu42rdkSXGzT528BAQRFO',
#   'i want to sleep for 1000 years': 'spotify:track:7mkzJI9BqAO3twUNuv4Nen'},
#  'GIANT ROOKS': {"Tom's Diner": 'spotify:track:0oA9wBGDY4uyILLg4GymWP',
#   'Bedroom Exile': 'spotify:track:2VudXzMgyFNDLydViVrQ7e',
#   'Morning Blue': 'spotify:track:71qr4SoRZ61SKxhH4XhAqP',
#   'Wild Stare': 'spotify:track:11cjKlgVaUvbBjEAAGv9MZ',
#   'New Estate': 'spotify:track:7muYz7kx7Z37Bnfg7eYbtv',
#   'Watershed': 'spotify:track:2CfWHcw3H18SdyX4PcwJV2',
#   'Bedroom Exile - Spotify Singles': 'spotify:track:41nuWG6XRUTGlFSOumec21',
#   'Bubble Gum - Spotify Singles': 'spotify:track:2kWvxORGE9opGvBigmJsRq',
#   'Heat Up': 'spotify:track:2xxpA9Bd8TaKIv0RGKFr9I',
#   'All Good Things (Come To An End) - Home Session': 'spotify:track:4JgT8muqC8qOOzvrbi04dI'},
#  'SINCERE ENGINEER': {'Trust Me': 'spotify:track:2MJ99N6jENvKonfgegDtZx',
#   'Overbite': 'spotify:track:14GTv5GRI487rzjgC1DjTK',
#   'Corn Dog Sonnet No. 7': 'spotify:track:27LPG7cAd5fOTNdp7noNWW',
#   'Ceramic Tile': 'spotify:track:6TBYAolwMmVmhGKLpIGCpf',
#   'Coming in Last': 'spotify:track:7stoTh39vTsyetRdwTg79u',
#   'Tourniquet': 'spotify:track:14aKoJsJYKvUeYkghDhvbM',
#   'Shattering': 'spotify:track:5DrO4fEEMcunrEE5Nkyan4',
#   'Bottle Lightning Twice': 'spotify:track:1aAFcxtf0hFZ58F4zuXwVY',
#   'Library Of Broken Bindings': 'spotify:track:53gVj6cwOhDqbjufY30J7c',
#   'Out of Reach': 'spotify:track:7EV2qA76LiowdjZakPdEuz'},
#  'TIACORINE': {'FreakyT': 'spotify:track:4CCrZzRdeWYrWJ0DoN4XCa',
#   'Lotto': 'spotify:track:5F8zXCNHA4Xzoqi3NR9kUK',
#   'FreakyT (Sped Up)': 'spotify:track:5ora1hAeubOxDDE29Jw4Er',
#   'LUV ME': 'spotify:track:5R05zM2A2BUuTyPvyf6SsZ',
#   '30': 'spotify:track:2fTGh0imCRgP2FcsLLlj01',
#   'Chaka Khan (feat. Kenny Beats)': 'spotify:track:1DyUdvmTqhzy0RzCJdGvxd',
#   'Luigi': 'spotify:track:3WiaVc2oa9imq75hhTqlw4',
#   'Dipset': 'spotify:track:5JTeYXe0tG3ZIk6qKa9bHc',
#   'Boogie (feat. Tony Shhnow)': 'spotify:track:6YtF0BZzddOW1P9seEJhrr',
#   'Rocket': 'spotify:track:4TFZypZrRA6DV5DZNz7iO0'},
#  'ANNIE DIRUSSO': {'Coming Soon': 'spotify:track:5E3MdeoNZ674MtNa06z3nN',
#   'Emerson': 'spotify:track:1C6xfW2M2qUzo0ZxF9KboZ',
#   "Don't Swerve": 'spotify:track:1vjNpmWDEDMbGXm9ziftkH',
#   'Hybrid': 'spotify:track:1KcSoLTbW95AiUj8RLcPxr',
#   'Nauseous': 'spotify:track:3ZvrBVewa8fdjQ8srDvM9R',
#   'Nine Months': 'spotify:track:2EfklTNRQDQAAhgaC9XyWA',
#   'Body': 'spotify:track:09tc8sP1yi1AGC8JmtS8pd',
#   'Infinite Jest': 'spotify:track:4qH2jxgvGcGuxh2JReRte4',
#   'Frisco Forever': 'spotify:track:0x8u3RlaZCbFHKnsGAzp80',
#   'Call It All Off': 'spotify:track:0n7kj6OJDR39SEHXaYsCJt'},
#  'SOMADINA': {'Cruel Love': 'spotify:track:2z4Im0b5lCgNwLHshx2vkW',
#   'I Saw An Angel On The Roof & Wept': 'spotify:track:0bDSVRBBZDLCVHhCH3mMXz',
#   'Rolling Loud': 'spotify:track:6ySKC2g5tI9PE26OrUs3XN',
#   'Y I Want U': 'spotify:track:07BT6pHeHuXycLNH4Jr2zD',
#   'Citrus Tears': 'spotify:track:5T17angrfy3Gdmh4Y3aeQR',
#   'SUPERSOMA': 'spotify:track:5vDcs1FIAN79cELRo0P2SB',
#   'Small Paradise (feat. The Cavemen)': 'spotify:track:6lVPuUgAyWkTeJhL2g64Fn',
#   'Time 2 Time': 'spotify:track:1T4dktLXrfPxUH9pa3Qp2y',
#   'Everybody Bleeds': 'spotify:track:6McAJmgPbpSNhMV21rTlsI',
#   'Imagine Giving A Fvck (feat. Chi Virgo)': 'spotify:track:2pkjhMo0EfNYvUeZrOEJdp'},
#  'THE 1975': {'About You': 'spotify:track:1fDFHXcykq4iw8Gg7s5hG9',
#   'Somebody Else': 'spotify:track:4m0q0xQ2BNl9SCAGKyfiGZ',
#   "I'm In Love With You": 'spotify:track:12g9IeQzX7xECLNxz8dpb5',
#   'Robbers': 'spotify:track:73jVPicY2G9YHmzgjk69ae',
#   "It's Not Living (If It's Not With You)": 'spotify:track:3TgMcrV32NUKjEG2ujn9eh',
#   'Chocolate': 'spotify:track:4WiiRw2PHMNQE0ad6y6GdD',
#   'Oh Caroline': 'spotify:track:14dJexYlvd3t3XAtD1pYW1',
#   'Love It If We Made It': 'spotify:track:6WmIyn2fx1PKQ0XDpYj4VR',
#   'Be My Mistake': 'spotify:track:18UsAG7SfOQ5sxJEdjAMH0',
#   'The Sound': 'spotify:track:7h6lpVuSGPW6RNjDXKpYDh'},
#  'TALK': {'Run Away to Mars': 'spotify:track:6G1Mz5yMgn0ydOlIvTrZ65',
#   'How To Save A Life': 'spotify:track:73TAUoeGvM7YPA8huwA9Yp',
#   'Save Me': 'spotify:track:05HRj9r5hQZtEpJaudtPjW',
#   'How Long': 'spotify:track:2eJJjAWSBltPvGHEbAmZ3I',
#   'Train': 'spotify:track:5ZbBeHAf5jyUsefV6yJn9h',
#   'Run Away to Mars (Strings Version)': 'spotify:track:5h7CacBkyFOH0mgSOrxwfe',
#   'Talk to Me': 'spotify:track:3OgOAcw0sBZGtrX5Dp0oze',
#   'Hollywood': 'spotify:track:20hBPFURsyy6eK2YpQebm5'},
#  'HEMLOCKE SPRINGS': {'girlfriend': 'spotify:track:0Dl965SLJGi9bB0SrvtPRx',
#   'gimme all ur luv': 'spotify:track:7bKMO3og5pWUJV5g6VtZwp',
#   'stranger danger!': 'spotify:track:4yk0t3ZG8vkoligoo7iAQB'},
#  'CYDEWAYS': {'Shadows': 'spotify:track:6pEVKSSibRs7xkItRUL1j2',
#   'Are You Down': 'spotify:track:4xxVCn2iw0ATeYs6nQoJKo',
#   "We Won't Run (feat. Pepper)": 'spotify:track:6sSGjpLs4EgPUDUGj3m3iB',
#   "Sun Goes Down (feat. Kash'd Out)": 'spotify:track:3Um6ZhkGYzYumj7iZsEAXo',
#   'Take Flight (feat. Surfer Girl)': 'spotify:track:5EaVTTeYi5gMg8qUH5zgT4',
#   'Gold': 'spotify:track:5hAlGvpuPo7i0ISm63XrXV',
#   'Fantasy': 'spotify:track:5Nuje2ApPfnEDkyPx6gmjl',
#   'Come Alive': 'spotify:track:2Xvf4n4Et2Ou2soBxoJUhV',
#   'Dream': 'spotify:track:4zw0IlYgzssPS3JkkBW3EH',
#   'Rip Away': 'spotify:track:4jIMI0Lk5Tltl1gCC1Nmjo'},
#  'CHARLOTTE SANDS': {'Dress': 'spotify:track:2ptbBxMTCbFBefVMXwrdSC',
#   'Loved You A Little (with Taking Back Sunday and Charlotte Sands)': 'spotify:track:0IPKskRI33eRXjUhNUr9b5',
#   'Bad Day': 'spotify:track:5IzJBDURDhsfIWXE2kGvWb',
#   'Crash': 'spotify:track:2K2Fn8vJzgGUG9JMmPFYC3',
#   'Six Feet Under': 'spotify:track:2Q9pJ2YJOB6jENpyqqkqZf',
#   'Let You Down (feat. Charlotte Sands)': 'spotify:track:0TwK4x6GMaX8oXj8kRocku',
#   'Tantrum': 'spotify:track:0hInN3yci5wTnqCl1DXShW',
#   'Alright': 'spotify:track:6ZBr8E9XczoqgMRXyXUe6b',
#   'Want You Like That': 'spotify:track:0aKWr5K7ydkegVoxd3dBeM',
#   "I Don't Care": 'spotify:track:2PFhevKRsRROz9DjQWBcYV'},
#  'TYLER CHRISTIAN': {'Get Your Way': 'spotify:track:40KmYADIg5IS6tms1C9ulq',
#   'Caught Up': 'spotify:track:7lY74dCRqHAuMRwlRppgRt',
#   'Animals': 'spotify:track:15SEtTkR3UdLHfvfN7gTLi',
#   'Do You Really Want To Hurt Me': 'spotify:track:5zcnHHhjGhl9CG9901CQ0G'},
#  'LOVIET': {'Some Kind Of Drug': 'spotify:track:04ff2QCyhRMdSRrC7TTmis',
#   'Broken Lips': 'spotify:track:1mdTH74i6OFp8oph3Dm4CR',
#   'January': 'spotify:track:1jLpgEdWLJPipCU3QGP712',
#   'Star Treatment': 'spotify:track:0CTwOCANFyBlRw85E1sh3X',
#   'Wide Eyes': 'spotify:track:0KlGJ6EiBQ82iEZGCBrG5o',
#   'Picture': 'spotify:track:29uRvsIZRqwnLILLbEVEIb',
#   'One': 'spotify:track:3HFEKhLZvNJc3W1FuIrsp5',
#   'Dullshine': 'spotify:track:6nQHFNVRwnW208EY0jmybB',
#   'The Thrill': 'spotify:track:0nt0syiL8lKfKJPf3D294k',
#   "When It's Over": 'spotify:track:6a2gqazbvPWq9dGMnmudc5'},
#  'JUNIOR MESA': {"What's Enough pt.2": 'spotify:track:38lANCGNjZV7zBfkjrqrO3',
#   'Losing My Grip': 'spotify:track:7LF6lyquW55Mro9sKd9U4w',
#   'Caroline': 'spotify:track:4kF6vMdpBPnNnlTqYN30X8',
#   'All Or Nothin': 'spotify:track:20FRfVbFCCFUk9VyIpWaXY',
#   'Pushing Away': 'spotify:track:3RwkdgVj2psiIlVGfJLLZF',
#   '3 AM': 'spotify:track:0ngQu344zEU6uo6UReoF9h',
#   'Listen Close': 'spotify:track:32f5O0U9hax2OLL7rEN6Kc',
#   'Paranoia Dreams': 'spotify:track:1c5e5PqzUpLFn2CfNBe040',
#   'Far Out': 'spotify:track:2zAh3xlMOHoPF9COiRM7WL',
#   'Past Life - Junior Mesa Remix': 'spotify:track:2B9JYOW35NVItKUCUn51OZ'},
#  'NINAJIRACHI': {'Pure Luck': 'spotify:track:6QAqohrWfXLQzeHm8kcYZh',
#   'Start Small - Lamorn Remix': 'spotify:track:79HLHHL8xuSumcE6ZV2tOP',
#   'One Long Firework in the Sky': 'spotify:track:7LQhqFOOXEVcjLG6W9XULb',
#   'Keep Me Safe - Ninajirachi Remix': 'spotify:track:4jaJZnBGeCkBcKlUTDJPzt',
#   'Things I Never Nu': 'spotify:track:1NAYrYgd473ua418mz32xb',
#   'Dracodraco': 'spotify:track:1989YquYFYsPa4PutqJunf',
#   'Petroleum': 'spotify:track:7ukOEET9ARORbbq3pZtr8S',
#   'Crush Me - Yash Bansal Remix': 'spotify:track:4TEhqvkBE6amkZZ0K3y2NS',
#   'Alight': 'spotify:track:3k1hFoRs37GSu6yhkQAYPb',
#   'Diva - Ninajirachi Remix': 'spotify:track:4NfXNOil3k5Foo948cVNqF'}}

# %%
playlist = spotify.user_playlist_create(me_id, "Lolla Friday", public=False)
playlist
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/66z1KWCIh7J5RzyvEcAgqb'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/66z1KWCIh7J5RzyvEcAgqb',
#  'id': '66z1KWCIh7J5RzyvEcAgqb',
#  'images': [],
#  'name': 'Lolla Friday',
#  'owner': {'display_name': 'makzator',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/0gvflng5qihycq9keswkzvzgh'},
#   'href': 'https://api.spotify.com/v1/users/0gvflng5qihycq9keswkzvzgh',
#   'id': '0gvflng5qihycq9keswkzvzgh',
#   'type': 'user',
#   'uri': 'spotify:user:0gvflng5qihycq9keswkzvzgh'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'MSwyMzdjNjBlM2IxODdiZDRjZDM5Njk3ZGIwNGI4NDlhNWUxNzkzOTk4',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/66z1KWCIh7J5RzyvEcAgqb/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:66z1KWCIh7J5RzyvEcAgqb'}

# %%
playlist_id = playlist["id"]
playlist_id
# Out:
# '66z1KWCIh7J5RzyvEcAgqb'

# %%
for artist_name, track_info in lolla_artist_tracks.items():
    print(f"adding tracks from {artist_name}")
    track_uris = list(track_info.values())
    spotify.playlist_add_items(playlist_id, track_uris)
    for track_name in track_info.keys():
        print(f"\tadded track {track_name}")
# Out:
# adding tracks from FRED AGAIN...
# 	added track Rumble
# 	added track Turn On The Lights again.. (feat. Future)
# 	added track Marea (we’ve lost dancing)
# 	added track Delilah (pull me out of this)
# 	added track Baby again..
# 	added track Jungle
# 	added track Danielle (smile on my face)
# 	added track Turn On The Lights again.. (feat. Future) - Anyma Remix
# 	added track Mike (desert island duvet)
# 	added track Strong
# adding tracks from THIRTY SECONDS TO MARS
# 	added track The Kill
# 	added track This Is War
# 	added track Attack
# 	added track Walk On Water
# 	added track Kings And Queens
# 	added track From Yesterday
# 	added track Closer To The Edge
# 	added track A Beautiful Lie
# 	added track Hurricane
# 	added track Up In The Air
# adding tracks from SUBTRONICS
# 	added track Puzzle Box
# 	added track Griztronics
# 	added track Gassed Up
# 	added track Griztronics II (Another Level)
# 	added track Spacetime (feat. NEVVE)
# 	added track GodLovesUgly - Remix
# 	added track Escape - Subtronics Remix
# 	added track Runaway (U & I) - Subtronics Remix
# 	added track Into Pieces - Wooli x Grabbitz Remix
# 	added track Scream Saver
# adding tracks from SVDDEN DEATH
# 	added track Crusade
# 	added track Pursuit of Violence
# 	added track Behemoth VIP
# 	added track Behemoth
# 	added track Blood On Me
# 	added track Confusion Spell
# 	added track Comprehension Barrier
# 	added track Bleed
# 	added track Born To Suffer
# 	added track Purgatory - Dion Timmer Remix
# adding tracks from TEMS
# 	added track WAIT FOR U (feat. Drake & Tems)
# 	added track Essence (feat. Tems)
# 	added track Free Mind
# 	added track Higher
# 	added track Fountains (with Tems)
# 	added track Found (feat. Brent Faiyaz)
# 	added track Damages
# 	added track Essence (feat. Justin Bieber & Tems)
# 	added track Replay
# 	added track The Key
# adding tracks from KENDRICK LAMAR
# 	added track Money Trees
# 	added track family ties (with Kendrick Lamar)
# 	added track HUMBLE.
# 	added track All The Stars (with SZA)
# 	added track LOVE. FEAT. ZACARI.
# 	added track PRIDE.
# 	added track Pray For Me
# 	added track Alright
# 	added track N95
# 	added track DNA.
# adding tracks from BEABADOOBEE
# 	added track Glue Song
# 	added track death bed (coffee for your head)
# 	added track the perfect pair
# 	added track Tired
# 	added track Coffee
# 	added track Cologne
# 	added track Apple Cider
# 	added track Sunny day
# 	added track Talk
# 	added track The Moon Song
# adding tracks from BIG WILD
# 	added track 6's to 9's
# 	added track When I Get There
# 	added track Awaken
# 	added track 6's to 9's - Day Wave Remix
# 	added track Purple Sand (My Home)
# 	added track Touch
# 	added track Pale Blue Dot
# 	added track Crickets
# 	added track Empty Room - Cabu Remix
# 	added track Show Me
# adding tracks from SABRINA CARPENTER
# 	added track Nonsense
# 	added track Feather
# 	added track On My Way
# 	added track Looking at Me
# 	added track because i liked a boy
# 	added track emails i can’t send
# 	added track Thumbs
# 	added track Nonsense - Sped Up Version
# 	added track Vicious
# 	added track opposite
# adding tracks from JESSIE REYEZ
# 	added track I'm Not Here To Make Friends
# 	added track Promises (with Sam Smith)
# 	added track Gimme (feat. Koffee & Jessie Reyez)
# 	added track FOREVER (with 6LACK)
# 	added track FIGURES
# 	added track IMPORTED (with 6LACK)
# 	added track Perfect (feat. Jessie Reyez)
# 	added track Ocean - Remix
# 	added track Rain (from The Suicide Squad)
# 	added track ONLY ONE
# adding tracks from KNOCKED LOOSE
# 	added track Slaughterhouse (feat. Bryan Garris Of Knocked Loose)
# 	added track Counting Worms
# 	added track God Knows
# 	added track Billy No Mates
# 	added track Mistakes Like Fractures
# 	added track Deadringer
# 	added track Where Light Divides the Holler
# 	added track Belleville
# 	added track Oblivions Peak
# 	added track Small Victories
# adding tracks from FOALS
# 	added track My Number
# 	added track Mountain at My Gates
# 	added track 2am
# 	added track Late Night - Solomun Remix
# 	added track Birch Tree
# 	added track Spanish Sahara
# 	added track 2001
# 	added track Wake Me Up
# 	added track The Runner
# 	added track What Went Down
# adding tracks from DIESEL
# 	added track Sausolito Summernight - Digitally Remastered 2017
# 	added track Down In The Silvermine - Digitally Remastered 2017
# 	added track Goin' Back To China - Digitally Remastered 2017
# 	added track Sausalito Summernight
# 	added track I Put A Spell On You
# 	added track Free Ride
# 	added track Fortunate Son
# 	added track All Because Of You - Digitally Remastered 2017
# 	added track Alibi - Digitally Remastered 2017
# 	added track My Kind Of Woman - Digitally Remastered 2017
# adding tracks from PEACH PIT
# 	added track Alrighty Aphrodite
# 	added track Shampoo Bottles
# 	added track Tommy's Party
# 	added track Give Up Baby Go
# 	added track Peach Pit
# 	added track Drop the Guillotine
# 	added track Look Out!
# 	added track Vickie
# 	added track Techno Show
# 	added track Being so Normal
# adding tracks from KEN CARSON
# 	added track Yale
# 	added track Hell Yeah
# 	added track i need u
# 	added track Freestyle 2
# 	added track Rock N Roll
# 	added track Murda Musik (feat. Destroy Lonely)
# 	added track MDMA (feat. Destroy Lonely)
# 	added track Freestyle 3
# 	added track Teen Bean
# 	added track Run + Ran
# adding tracks from ARMNHMR
# 	added track IT'S YOU - ARMNHMR Remix
# 	added track Falling Apart
# 	added track Won't Make A Sound
# 	added track Drowning
# 	added track Saving Lives
# 	added track Fragile (feat. Melanie Fontana)
# 	added track WANT U
# 	added track SET ME FREE (ARMNHMR Remix) (ENG)
# 	added track Falling Apart - Acoustic
# 	added track Anywhere
# adding tracks from DECLAN MCKENNA
# 	added track Brazil
# 	added track Why Do You Feel So Down
# 	added track Make Me Your Queen
# 	added track British Bombs
# 	added track The Key to Life on Earth
# 	added track Isombard
# 	added track Listen to Your Friends
# 	added track My House
# 	added track Beautiful Faces
# 	added track Humongous
# adding tracks from SUDAN ARCHIVES
# 	added track Selfish Soul
# 	added track Come Meh Way
# 	added track Home Maker
# 	added track Confessions
# 	added track Nont For Sale
# 	added track NBPQ (Topless)
# 	added track OMG BRITT
# 	added track Ciara
# 	added track Yellow Brick Road
# 	added track Loyal (EDD)
# adding tracks from RAY VOLPE
# 	added track Old School
# 	added track Laserbeam
# 	added track The Dead March
# 	added track Laserbeam - Blanke's ÆON:REMIX
# 	added track Meant To Be Lonely
# 	added track Laserbeam - Sullivan King Remix
# 	added track Feeling This Way
# 	added track Don’t Look Down (feat. Linney)
# 	added track Elbow Grease
# 	added track Signal
# adding tracks from BLANKE
# 	added track Colors (with Eyelar)
# 	added track Laserbeam - Blanke's ÆON:REMIX
# 	added track Death Rattle
# 	added track The Machines
# 	added track One More Day (with Chandler Leighton)
# 	added track Breathe
# 	added track Used to Losing You
# 	added track Gorgeous (& Blanke with Bipolar Sunshine)
# 	added track Flatline
# 	added track Mitosis
# adding tracks from HAIRITAGE
# 	added track 40 Cal
# 	added track Cheatcode
# 	added track Hustle
# 	added track Resistance
# 	added track The Uncrowned King
# 	added track High Life
# 	added track CYBER DETHHH (Hairitage Remix)
# 	added track Hypnosis
# 	added track Double Dipping
# 	added track Cheatcode - Jessica Audiffred Remix
# adding tracks from SUECO
# 	added track POS
# 	added track Loser
# 	added track Paralyzed
# 	added track Story Of My Life (feat. Trippie Redd)
# 	added track PRIMADONA
# 	added track fast
# 	added track Sober/Hungover (feat. Arizona Zervas)
# 	added track Ride It Hard
# 	added track Speed Me Up (with Ty Dolla $ign, Lil Yachty & Sueco the Child)
# 	added track Next Ex
# adding tracks from THE 502S
# 	added track Just A Little While
# 	added track Magdalene
# 	added track Hey Julia
# 	added track Waves
# 	added track Enjoy the Ride
# 	added track Backstage in Glasgow
# 	added track Magdalene - Live
# 	added track Bad Haircuts
# 	added track Friday Night
# 	added track Inside Joke
# adding tracks from BAND-MAID
# 	added track Sense
# 	added track Choose me
# 	added track Unleash!!!!!
# 	added track Different
# 	added track DOMINATION
# 	added track DICE
# 	added track Memorable
# 	added track Thrill
# 	added track Hate?
# 	added track Influencer
# adding tracks from LOVELESS
# 	added track MIDDLE OF THE NIGHT
# 	added track happier than ever
# 	added track Supernova
# 	added track Running Up That Hill (A Deal With God)
# 	added track The Credits
# 	added track Someone Else
# 	added track Lighthouse
# 	added track STAY
# 	added track Haunting Me
# 	added track If You Have My Voodoo Doll, Give Me A Hug
# adding tracks from CAFUNE
# 	added track Tek It - Sped Up
# 	added track Tek It
# 	added track Tek It - Slowed
# 	added track Perspective
# 	added track Tek It - Acoustic
# 	added track High
# 	added track Friction
# 	added track Reconsider
# 	added track Talk
# 	added track Want Me Out
# adding tracks from SKIZZY MARS
# 	added track Leave Me (feat. Marc E. Bassy)
# 	added track Girl on a Train
# 	added track Steady 1234 (feat. Jasmine Thompson & Skizzy Mars)
# 	added track STROBE LIGHTS
# 	added track Time (feat. G-Eazy & Olivver the Kid)
# 	added track Lucy
# 	added track Calabasas
# 	added track Do You There (feat. Marc E. Bassy)
# 	added track Primadonna (with Marc E. Bassy & Skizzy Mars)
# 	added track 2006
# adding tracks from EKKSTACY
# 	added track i walk this earth all by myself
# 	added track Uncomparable
# 	added track then i met her
# 	added track it only gets worse, i promise
# 	added track im so happy
# 	added track See You Later
# 	added track for forever
# 	added track Starry Eyes
# 	added track wish i was dead
# 	added track i want to sleep for 1000 years
# adding tracks from GIANT ROOKS
# 	added track Tom's Diner
# 	added track Bedroom Exile
# 	added track Morning Blue
# 	added track Wild Stare
# 	added track New Estate
# 	added track Watershed
# 	added track Bedroom Exile - Spotify Singles
# 	added track Bubble Gum - Spotify Singles
# 	added track Heat Up
# 	added track All Good Things (Come To An End) - Home Session
# adding tracks from SINCERE ENGINEER
# 	added track Trust Me
# 	added track Overbite
# 	added track Corn Dog Sonnet No. 7
# 	added track Ceramic Tile
# 	added track Coming in Last
# 	added track Tourniquet
# 	added track Shattering
# 	added track Bottle Lightning Twice
# 	added track Library Of Broken Bindings
# 	added track Out of Reach
# adding tracks from TIACORINE
# 	added track FreakyT
# 	added track Lotto
# 	added track FreakyT (Sped Up)
# 	added track LUV ME
# 	added track 30
# 	added track Chaka Khan (feat. Kenny Beats)
# 	added track Luigi
# 	added track Dipset
# 	added track Boogie (feat. Tony Shhnow)
# 	added track Rocket
# adding tracks from ANNIE DIRUSSO
# 	added track Coming Soon
# 	added track Emerson
# 	added track Don't Swerve
# 	added track Hybrid
# 	added track Nauseous
# 	added track Nine Months
# 	added track Body
# 	added track Infinite Jest
# 	added track Frisco Forever
# 	added track Call It All Off
# adding tracks from SOMADINA
# 	added track Cruel Love
# 	added track I Saw An Angel On The Roof & Wept
# 	added track Rolling Loud
# 	added track Y I Want U
# 	added track Citrus Tears
# 	added track SUPERSOMA
# 	added track Small Paradise (feat. The Cavemen)
# 	added track Time 2 Time
# 	added track Everybody Bleeds
# 	added track Imagine Giving A Fvck (feat. Chi Virgo)
# adding tracks from THE 1975
# 	added track About You
# 	added track Somebody Else
# 	added track I'm In Love With You
# 	added track Robbers
# 	added track It's Not Living (If It's Not With You)
# 	added track Chocolate
# 	added track Oh Caroline
# 	added track Love It If We Made It
# 	added track Be My Mistake
# 	added track The Sound
# adding tracks from TALK
# 	added track Run Away to Mars
# 	added track How To Save A Life
# 	added track Save Me
# 	added track How Long
# 	added track Train
# 	added track Run Away to Mars (Strings Version)
# 	added track Talk to Me
# 	added track Hollywood
# adding tracks from HEMLOCKE SPRINGS
# 	added track girlfriend
# 	added track gimme all ur luv
# 	added track stranger danger!
# adding tracks from CYDEWAYS
# 	added track Shadows
# 	added track Are You Down
# 	added track We Won't Run (feat. Pepper)
# 	added track Sun Goes Down (feat. Kash'd Out)
# 	added track Take Flight (feat. Surfer Girl)
# 	added track Gold
# 	added track Fantasy
# 	added track Come Alive
# 	added track Dream
# 	added track Rip Away
# adding tracks from CHARLOTTE SANDS
# 	added track Dress
# 	added track Loved You A Little (with Taking Back Sunday and Charlotte Sands)
# 	added track Bad Day
# 	added track Crash
# 	added track Six Feet Under
# 	added track Let You Down (feat. Charlotte Sands)
# 	added track Tantrum
# 	added track Alright
# 	added track Want You Like That
# 	added track I Don't Care
# adding tracks from TYLER CHRISTIAN
# 	added track Get Your Way
# 	added track Caught Up
# 	added track Animals
# 	added track Do You Really Want To Hurt Me
# adding tracks from LOVIET
# 	added track Some Kind Of Drug
# 	added track Broken Lips
# 	added track January
# 	added track Star Treatment
# 	added track Wide Eyes
# 	added track Picture
# 	added track One
# 	added track Dullshine
# 	added track The Thrill
# 	added track When It's Over
# adding tracks from JUNIOR MESA
# 	added track What's Enough pt.2
# 	added track Losing My Grip
# 	added track Caroline
# 	added track All Or Nothin
# 	added track Pushing Away
# 	added track 3 AM
# 	added track Listen Close
# 	added track Paranoia Dreams
# 	added track Far Out
# 	added track Past Life - Junior Mesa Remix
# adding tracks from NINAJIRACHI
# 	added track Pure Luck
# 	added track Start Small - Lamorn Remix
# 	added track One Long Firework in the Sky
# 	added track Keep Me Safe - Ninajirachi Remix
# 	added track Things I Never Nu
# 	added track Dracodraco
# 	added track Petroleum
# 	added track Crush Me - Yash Bansal Remix
# 	added track Alight
# 	added track Diva - Ninajirachi Remix
