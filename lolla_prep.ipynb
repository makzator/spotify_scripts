# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import json
import Levenshtein

# %%
def auth():
    with open(".creds.json") as f:
        creds = json.load(f)
    scope = [
        "playlist-read-private",
        "playlist-modify-private",
        "user-library-read",
        "user-read-private",
    ]
    spotify_creds = SpotifyOAuth(**creds, scope=scope)
    spotify = spotipy.Spotify(client_credentials_manager=spotify_creds)
    return spotify

# %%
spotify = auth()

# %%
def find_artist(name):
    result = spotify.search(q=f"artist:{name}", type="artist")
    items = result["artists"]["items"]
    return items

# %%
def get_playlists():
    playlists = spotify.current_user_playlists()["items"]
    pl_info = {}
    for pl in playlists:
        pl_info[pl["name"]] = pl["uri"]
    return pl_info

# %%
def get_liked_songs(batch_size=50):
    song_info = []
    offset = 0
    while True:
        print(offset)
        song_batch = spotify.current_user_saved_tracks(limit=batch_size, offset=offset)["items"]
        if len(song_batch) == 0:
            break
        for song in song_batch:
            artists = [artist_info["name"] for artist_info in song["track"]["artists"]]
            song_info.append(
                {
                    "name": song["track"]["name"],
                    "artists": artists,
                    "uri": song["track"]["uri"]
                }
            )
        offset += batch_size
    return song_info

# %%
songs = get_liked_songs()
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 songs = get_liked_songs()
#
# Cell In[6], line 6, in get_liked_songs(batch_size)
#       4 while True:
#       5     print(offset)
# ----> 6     song_batch = spotify.current_user_saved_tracks(limit=batch_size, offset=offset)["items"]
#       7     if len(song_batch) == 0:
#       8         break
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:1286, in Spotify.current_user_saved_tracks(self, limit, offset, market)
#    1276 def current_user_saved_tracks(self, limit=20, offset=0, market=None):
#    1277     """ Gets a list of the tracks saved in the current authorized user's
#    1278         "Your Music" library
#    1279
#    (...)
#    1284
#    1285     """
# -> 1286     return self._get("me/tracks", limit=limit, offset=offset, market=market)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Python_venvs/Spotify_venv/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.9/3.9.6/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
artists_with_songs = {}
for song in songs:
    for artist in song["artists"]:
        if artist in artists_with_songs:
            artists_with_songs[artist].append(song["name"])
        else:
            artists_with_songs[artist] = [song["name"]]
my_artists = list(artists_with_songs.keys())

# %%
artists_with_songs
# Out:
# {'Jordiz': ['Weekend!'],
#  'Connor Price': ['Start Again', 'Smooth'],
#  'Chloe Sagum': ['Start Again'],
#  'Arrested Youth': ['Brightside', 'Dig'],
#  'YUNGBLUD': ['Tissues',
#   'mars',
#   'I’m a Mess (with YUNGBLUD)',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   'parents',
#   'acting like that (feat. Machine Gun Kelly)',
#   'The Funeral',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Patience (feat. YUNGBLUD & Polo G)'],
#  'SK8': ['Shooting Star (feat. Sum 41)'],
#  'Sum 41': ['Shooting Star (feat. Sum 41)',
#   'With Me',
#   'In Too Deep',
#   'Fat Lip',
#   'Fat Lip',
#   'Still Waiting'],
#  'Sub Zero Project': ['HALO', 'Project X', 'Rockstar (feat. DV8)'],
#  'Kay One': ['Herz aus Stein', 'Senorita'],
#  'strike': ['Calling'],
#  'Ben Nicky': ['We Are The Ravers'],
#  'Olly James': ['We Are The Ravers'],
#  'MC Stretch': ['We Are The Ravers'],
#  'Korsakoff': ['Lyra - Broken Minds Remix'],
#  'Broken Minds': ['Lyra - Broken Minds Remix'],
#  'Machine Gun Kelly': ['bloody valentine',
#   'title track',
#   'Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   "don't sleep, repeat (feat. Machine Gun Kelly)",
#   'bloody valentine - Acoustic',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   "can't look back",
#   'kevin and barracuda - interlude',
#   'forget me too (feat. Halsey)',
#   'kiss kiss',
#   'concert for aliens',
#   "my ex's best friend (with blackbear)",
#   'hangover cure',
#   'WWIII',
#   "play this when i'm gone",
#   'lonely',
#   'split a pill',
#   'all I know (feat. Trippie Redd)',
#   'Misery Business',
#   'nothing inside (feat. iann dior)',
#   'banyan tree - interlude',
#   'jawbreaker',
#   'drunk face',
#   'papercuts - album edit',
#   'sid & nancy',
#   'die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'make up sex (feat. blackbear)',
#   '9 lives',
#   'twin flame',
#   'god save me',
#   'mainstream sellout',
#   '5150',
#   'drug dealer (feat. Lil Wayne)',
#   'emo girl (feat. WILLOW)',
#   'born with horns',
#   'more than life (feat. glaive)',
#   "fake love don't last (feat. iann dior)",
#   'maybe (feat. Bring Me The Horizon) - acoustic version',
#   'wall of fame - interlude',
#   'ay! (feat. Lil Wayne)',
#   'why are you here',
#   'maybe (feat. Bring Me The Horizon)',
#   'last november',
#   'WW4',
#   'papercuts - live from red rocks',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'twin flame',
#   'Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'ay! (feat. Lil Wayne)',
#   'maybe (feat. Bring Me The Horizon)',
#   'acting like that (feat. Machine Gun Kelly)',
#   'emo girl (feat. WILLOW)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'Sueco': ['Paralyzed',
#   'POS',
#   'fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]',
#   'fast',
#   'It Was Fun While It Lasted',
#   'PRIMADONA',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Motel 666',
#   'SOS (feat. Travis Barker)',
#   'Toxic Therapy',
#   'Drunk Dial',
#   'Loser',
#   'Hate You Too',
#   'It’s Going Good!',
#   'Today',
#   'Bad Vibes',
#   'Next Ex',
#   'Salt',
#   'AITA',
#   'Funeral',
#   'Up in Smoke',
#   'Last Thing I Do',
#   'Salt',
#   'SOS (feat. Travis Barker)',
#   'Loser',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Paralyzed'],
#  'Jon Caryl': ['Alone'],
#  "Fresh Til' Death": ['In Too Deep (Firelite Remix)'],
#  'MYLKI': ['In Too Deep (Firelite Remix)'],
#  'Firelite': ['In Too Deep (Firelite Remix)'],
#  'In The Valley Below': ['Peaches'],
#  'Hollywood Undead': ['Whatever It Takes'],
#  'Mac Miller': ['Love Lost', 'The Spins'],
#  'The Temper Trap': ['Love Lost'],
#  'Avril Lavigne': ['I’m a Mess (with YUNGBLUD)',
#   'Love Sux',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'All I Wanted (feat. Mark Hoppus)',
#   'Bite Me',
#   'Head Above Water',
#   'Sk8er Boi',
#   'Sk8er Boi'],
#  'The Home Team': ["She's Quiet"],
#  'Mayberg': ['Hilferuf'],
#  'Panic! At The Disco': ['The Ballad of Mona Lisa',
#   'Crazy = Genius',
#   'I Write Sins Not Tragedies',
#   'High Hopes'],
#  'Harris & Ford': ['99 Luftballons',
#   'Hard, Style & Volksmusik',
#   'Break the Beat'],
#  'Zombic': ['Human Error'],
#  'Danimal': ['Human Error'],
#  'Influencerz': ['Human Error'],
#  'iann dior': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'nothing inside (feat. iann dior)',
#   "fake love don't last (feat. iann dior)",
#   'Mood (feat. iann dior)'],
#  'Travis Barker': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   'bloody valentine - Acoustic',
#   'Misery Business',
#   'Drop Dead (with Kesha and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'KXXMA': ['Get Shaky', 'Herz an Herz'],
#  'TurboKevin': ['Get Shaky'],
#  'Nic D': ['Serotonin'],
#  'Bryce Vine': ['American Dream', 'The Fall'],
#  'Weezer': ['Beverly Hills'],
#  'The Bangles': ['Eternal Flame'],
#  'Cassyette': ['Sad Girl Summer'],
#  'Tammy Wynette': ['Stand By Your Man - Official Audio'],
#  'Wolfpack': ['Phatt Bass 2016 (Mixed)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'Ocarina'],
#  'Warp Brothers': ['Phatt Bass 2016 (Mixed)'],
#  'NWYR': ['The Lone Ranger'],
#  'W&W': ['The Lone Ranger',
#   'Skydance',
#   'Rave Culture',
#   'Chakra - Wildstylez Remix',
#   'God Is a Girl',
#   'Live the Night',
#   'Long Way Down',
#   "Don't Let Me Down (feat. Daya) - W&W Remix",
#   'Supa Dupa Fly 2018',
#   'How Many',
#   'Rave After Rave',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Crowd Control - Radio Edit',
#   'Arcade Mammoth',
#   'Rave Culture'],
#  'Hoodie Allen': ['Call Me Never'],
#  'Oberg': ['Sun Goes Down', 'Take My Hand'],
#  'Joakim Lundell': ['Sun Goes Down'],
#  'Hardwell': ['PACMAN',
#   'I FEEL LIKE DANCING',
#   'Bigroom Never Dies',
#   'Live the Night',
#   'The Underground',
#   'Bella Ciao',
#   'Power',
#   'Ze Willen Mee',
#   'Out of This Town',
#   'Shine a Light',
#   'This Is Love',
#   "Don't Let Me Down (feat. Daya) - Hardwell & Sephyx Remix",
#   'The Underground - Mix Cut',
#   'Bigroom Never Dies - Mix Cut',
#   'Off The Hook',
#   'Unity'],
#  'YROR?': ['Rotten'],
#  'Ben Joel': ['Rotten'],
#  'Carta': ['EDM'],
#  'Canadian Softball': ['Ohio Is for Emo Kids'],
#  'Cher': ['If I Could Turn Back Time'],
#  'Hardstyle Germany': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'High Level': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'Peach Pit': ['Alrighty Aphrodite'],
#  'Ruby Waters': ['Quantum Physics'],
#  'SEB': ['seaside_demo'],
#  'Jnr Choi': ['TO THE MOON'],
#  'Sam Tompkins': ['TO THE MOON'],
#  'Dubdogz': ['Everybody Wants To Party'],
#  'JØRD': ['Everybody Wants To Party'],
#  'Timmy Trumpet': ['Ininna Tora',
#   'Mad World',
#   'Project X',
#   'Dumb (Feat. BOSS)',
#   'The Anthem (Der Alte)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'The King',
#   'The Prayer (feat. Zafrir)',
#   'Bleed',
#   'Garden of Madness 2020 Megamix',
#   'Toca',
#   'Flamenco (feat. Rage)',
#   'Mufasa',
#   'The People',
#   'Hava',
#   'Nah Nah',
#   'World At Our Feet',
#   'Wassup (Listen To The Horns)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Baddest Behaviour',
#   'Scarborough Fair - Spotify Version',
#   'Rockstar (feat. DV8)',
#   'Nightmare - Radio Edit',
#   'Freaks - Extended Mix',
#   'Freaks - Instrumental Mix',
#   'Freaks - Radio Instrumental',
#   'Mantra',
#   'Hipsta',
#   'Take Your Call',
#   'Deja-Vu - Extended Version',
#   'Deja-Vu',
#   'The Underground',
#   'Booty Shake',
#   'Infinity - Original',
#   'Oracle',
#   'PSY or DIE',
#   'The Prophecy',
#   'Punjabi',
#   'Trumpets',
#   'Freaks - Radio Edit',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Al Pacino',
#   'Attention',
#   'The Underground - Mix Cut',
#   'Narco'],
#  'KSHMR': ['Ininna Tora',
#   'Invisible Children',
#   'The Prayer (feat. Zafrir)',
#   'Over and Out (feat. Charlott Boss)',
#   'Toca',
#   'The People',
#   'My Best Life (feat. Mike Waters)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Voices',
#   'Good Vibes Soldier (feat. Head Quattaz)',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Wildcard (feat. Sidnie Tipton)',
#   'Neverland',
#   'Harder',
#   'Carry Me Home (feat. Jake Reese)',
#   'Power',
#   'Memories (feat. Sirah) - Radio Edit',
#   'Opa'],
#  'Mildenhaus': ['Ininna Tora'],
#  'Butterfly Boucher': ['Changes'],
#  'David Bowie': ['Changes',
#   'Heroes - Single Version; 1990 Remaster',
#   'Heroes - 2017 Remaster',
#   'Starman - 2012 Remaster',
#   'Under Pressure'],
#  'Coldplay': ['Paradise',
#   'Fix You',
#   'Hymn for the Weekend',
#   'Viva La Vida',
#   'Yellow',
#   'The Scientist',
#   'Viva La Vida',
#   'Hymn for the Weekend - Seeb Remix',
#   'Viva La Vida',
#   'Something Just Like This'],
#  'Eddie Vedder': ['Brother the Cloud'],
#  'RØRY': ['UNCOMPLICATED'],
#  'HBz': ['Gästeliste +1'],
#  'Royal Blood': ['Trouble’s Coming', 'Figure It Out'],
#  'Mr. Green': ['Welcome'],
#  'Dave East': ['Welcome'],
#  'Xzibit': ['My Name (feat. Eminem & Nate Dogg)'],
#  'Eminem': ['My Name (feat. Eminem & Nate Dogg)',
#   'Stan',
#   "When I'm Gone",
#   'Like Toy Soldiers',
#   'Without Me',
#   'Stan - Live At 43rd Grammy Awards',
#   'Mockingbird',
#   'Lose Yourself - From "8 Mile" Soundtrack',
#   'Sing For The Moment',
#   'Intro',
#   'FACK',
#   'My Name Is',
#   'Shake That',
#   "Cleanin' Out My Closet",
#   'Just Lose It',
#   'Guilty Conscience',
#   'The Real Slim Shady',
#   'The Way I Am',
#   'Venom - Remix',
#   'Kings Never Die',
#   'Love The Way You Lie',
#   'Not Afraid',
#   'Remind Me',
#   'Lose Yourself - From "8 Mile" Soundtrack'],
#  'Nate Dogg': ['My Name (feat. Eminem & Nate Dogg)',
#   'Shake That',
#   'Party We Will Throw Now!'],
#  'jxdn': ['ANGELS & DEMONS'],
#  'Graham Lake': ['Run em Down'],
#  'Avelino': ['Run em Down'],
#  'loafers': ['Lay All Your Love On Me'],
#  'Badjack': ['Lay All Your Love On Me'],
#  'Maxim Schunk': ['Lay All Your Love On Me'],
#  'ABBA': ['Lay All Your Love On Me', 'Super Trouper'],
#  'Mark Dekoda': ['Rave Harder Techno Bass'],
#  'Rnbstylerz': ['Like Wooh Wooh'],
#  'TITUS': ['Love Myself'],
#  'Max Bennett Kelly': ['Happy, Healthy, Well-Adjusted'],
#  'Oliver Tree': ['Let Me Down (feat. blink-182)'],
#  'blink-182': ['Let Me Down (feat. blink-182)',
#   'Scumbag (feat. blink-182)',
#   'Bored To Death',
#   'Sober',
#   "She's Out Of Her Mind",
#   'Ransom',
#   'Black Rain',
#   'Run Away',
#   'Remember To Forget Me',
#   'Pin the Grenade',
#   'Darkside',
#   'The First Time',
#   'Heaven',
#   'Blame It On My Youth',
#   'Happy Days',
#   'I Really Wish I Hated You',
#   'No Heart To Speak Of',
#   'On Some Emo Shit',
#   'Generational Divide',
#   'Hungover You',
#   'Home Is Such A Lonely Place',
#   'California',
#   'Teenage Satellites',
#   'Bored To Death',
#   'Misery',
#   "Can't Get You More Pregnant",
#   'Cynical',
#   'Bored To Death (Acoustic)',
#   "Don't Mean Anything",
#   'Built This Pool',
#   '6/8',
#   'Last Train Home',
#   'Good Old Days',
#   'Sober',
#   'Wildfire',
#   'Bottom Of The Ocean',
#   'Los Angeles',
#   "She's Out Of Her Mind",
#   'The Only Thing That Matters',
#   'Long Lost Feeling',
#   'Rabbit Hole',
#   'Brohemian Rhapsody',
#   'Parking Lot',
#   'No Future',
#   "Hey I'm Sorry",
#   'Left Alone',
#   'Kings of the Weekend',
#   'San Diego',
#   'Go',
#   'Easy Target',
#   'Asthenia',
#   'I Miss You',
#   'The Fallen Interlude',
#   'Obvious',
#   "Here's Your Letter",
#   'Feeling This',
#   'Always',
#   'Stockholm Syndrome Interlude',
#   'Anthem Part Two - Live In Chicago',
#   'Down',
#   'Stockholm Syndrome',
#   'All Of This',
#   'Violence',
#   "I'm Lost Without You",
#   'Every Time I Look For You',
#   'Roller Coaster',
#   'First Date',
#   'Anthem Part Two',
#   'Online Songs',
#   'The Rock Show',
#   'Shut Up',
#   'Stay Together For The Kids',
#   'Reckless Abandon',
#   'Happy Holidays, You Bastard',
#   'Story Of A Lonely Guy',
#   'Give Me One Good Reason',
#   'Please Take Me Home',
#   'Going Away To College',
#   'Anthem',
#   'Dysentery Gary',
#   'Mutt',
#   'Dumpweed',
#   'Wendy Clear',
#   "Don't Leave Me",
#   'The Party Song',
#   'Aliens Exist',
#   "Adam's Song",
#   "What's My Age Again?",
#   'All The Small Things'],
#  'Lustra': ["Scotty Doesn't Know"],
#  't-low': ['We Made It', 'Sehnsucht', 'Crashen'],
#  'Miksu / Macloud': ['We Made It', 'Sehnsucht', 'Nachts wach'],
#  'charlieonnafriday': ['Enough'],
#  'Anastacia': ['Left Outside Alone'],
#  'DaCav5': ['Tetris'],
#  'A Boogie Wit da Hoodie': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Offset': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Arizona Zervas': ['Sober/Hungover (feat. Arizona Zervas)',
#   'Sober/Hungover (feat. Arizona Zervas)'],
#  'Sunrise Skater Kids': ['All the Old Things'],
#  'Christina Rotondo': ['All the Old Things'],
#  'Chri$tian Gate$': ['NUMB'],
#  'Nxvy': ['Emo Chick'],
#  'ALX8': ['Emo Chick'],
#  'JAY-Z': ['Empire State Of Mind', 'Numb / Encore'],
#  'Alicia Keys': ['Empire State Of Mind'],
#  'makko': ['Nachts wach'],
#  '44phantom': ["don't sleep, repeat (feat. Machine Gun Kelly)"],
#  'Matthias Reim': ['Verdammt, ich lieb Dich - 2020 Remastered'],
#  'Electric Callboy': ['Best Day'],
#  'Sido': ['Best Day',
#   'Liebe',
#   'Tausend Tattoos',
#   'Die Nacht von Freitag auf Montag'],
#  'Labrinth': ['When I R.I.P.',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Jealous'],
#  'The Used': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Bert McCracken': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Halsey': ['forget me too (feat. Halsey)',
#   'Sorry',
#   'Eastside (with Halsey & Khalid)',
#   'Closer'],
#  'blackbear': ["my ex's best friend (with blackbear)",
#   'make up sex (feat. blackbear)'],
#  'Trippie Redd': ['all I know (feat. Trippie Redd)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Wake Up Call (feat. Trippie Redd)'],
#  'Gunna': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Young Thug': ['die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'Havana (feat. Young Thug)'],
#  'Landon Barker': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Lil Wayne': ['drug dealer (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Let It Rock'],
#  'WILLOW': ['emo girl (feat. WILLOW)', 'emo girl (feat. WILLOW)'],
#  'glaive': ['more than life (feat. glaive)'],
#  'Bring Me The Horizon': ['maybe (feat. Bring Me The Horizon) - acoustic version',
#   'maybe (feat. Bring Me The Horizon)',
#   'maybe (feat. Bring Me The Horizon)',
#   'Can You Feel My Heart',
#   'Throne'],
#  'Mark Hoppus': ['All I Wanted (feat. Mark Hoppus)',
#   'Re-Entry (feat. Mark Hoppus)'],
#  'X Ambassadors': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'Unsteady'],
#  'Bebe Rexha': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   "I'm a Mess",
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix',
#   'In the Name of Love'],
#  'Dame': ['Mein Haus'],
#  'Solence': ['Good F**King Music'],
#  'The White Stripes': ['Astro',
#   'Seven Nation Army',
#   'Seven Nation Army',
#   'Icky Thump'],
#  'Stand Atlantic': ['deathwish (feat. nothing,nowhere.)'],
#  'nothing,nowhere.': ['deathwish (feat. nothing,nowhere.)'],
#  'Kode': ['Drunk Texts'],
#  'André De Shields': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Hadestown Original Broadway Company': ['Wait for Me (Reprise)',
#   'Wait for Me'],
#  'Anaïs Mitchell': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Reeve Carney': ['Wait for Me'],
#  'Jewelle Blackman': ['Wait for Me'],
#  'Yvette Gonzalez-Nacer': ['Wait for Me'],
#  'Kay Trinidad': ['Wait for Me'],
#  'Kimberly Marable': ['Wait for Me'],
#  'Timothy Hughes': ['Wait for Me'],
#  'Malcolm Armwood': ['Wait for Me'],
#  'Jessie Shelton': ['Wait for Me'],
#  'Khaila Wilcoxon': ['Wait for Me'],
#  'Ahmad Simmons': ['Wait for Me'],
#  'Afra Hines': ['Wait for Me'],
#  'T. Oliver Reid': ['Wait for Me'],
#  'John Krause': ['Wait for Me'],
#  'AMIICCA': ['Wait for Me'],
#  'Polo G': ['Martin & Gina', 'Patience (feat. YUNGBLUD & Polo G)'],
#  'Nelly Furtado': ['All Good Things (Come To An End)',
#   'Maneater',
#   'Broken Strings'],
#  'Akros': ['Lie'],
#  'Madonna': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Hung Up - Radio Version'],
#  'Justin Timberlake': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Timbaland': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Gabry Ponte': ['Mad World',
#   'Monster',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'AXMO': ['Skydance'],
#  'Giin': ['Skydance', 'Long Way Down'],
#  'Kate Bush': ['Running Up That Hill (A Deal With God)'],
#  'Ion Miles': ['Powerade'],
#  'SIRA': ['Powerade'],
#  'BHZ': ['Powerade'],
#  'Goody Grace': ['Scumbag (feat. blink-182)'],
#  'Jay Hoodie': ['Someone That You Hated'],
#  'Alligatoah': ['Trauerfeier Lied', 'Du bist schön'],
#  'Weedmane 2pac Dr Dre SnoopDogg': ['Bad and Boujee'],
#  'Butterfly Migos': ['Bad and Boujee'],
#  'Crazy Town': ['Bad and Boujee', 'Butterfly', 'Butterfly'],
#  'The Offspring': ['Behind Your Walls',
#   "You're Gonna Go Far, Kid",
#   'Self Esteem',
#   'Want You Bad',
#   "The Kids Aren't Alright"],
#  'Glass Animals': ['Heat Waves', 'Heat Waves'],
#  'We Three': ['Sara'],
#  'Sam Smith': ['Stay With Me', 'Dancing With A Stranger (with Normani)'],
#  'Christopher Lawrence': ['Rush Hour'],
#  'YONAKA': ['Seize the Power'],
#  'One Direction': ['Night Changes'],
#  'Cameron Sanderson': ['What Do You Want?'],
#  '4 Non Blondes': ["What's Up?"],
#  'The Bucketheads': ['The Bomb! (These Sounds Fall Into My Mind) - Radio Edit'],
#  'Vigiland': ['Buss It',
#   'Pong Dance',
#   'Another Shot\u202c\u202c\u202c',
#   'Addicted',
#   'Take This Ride',
#   'Be Your Friend\u202c\u202c',
#   'Never Going Home',
#   'Shots & Squats',
#   'Friday Night\u202c\u202c\u202c',
#   'Nice To Meet You',
#   'UFO - Radio Edit'],
#  'M24': ['Buss It'],
#  'Kraftklub': ['Ein Song reicht',
#   'Ganz schön okay (feat. Kraftklub)',
#   'Ich will nicht nach Berlin',
#   '500 K',
#   'Randale - Live'],
#  'Michael Jackson': ["They Don't Care About Us"],
#  'Des Rocs': ['Hanging by a Thread', 'Let Me Live / Let Me Die'],
#  'The Mysterines': ['Hung Up'],
#  'Bassjackers': ['De La Sol',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'The Fever',
#   'Block',
#   'Derp',
#   'Fireflies (feat. Luciana)',
#   'These Heights (feat. Caroline Pennell)',
#   'Memories (feat. Sirah) - Radio Edit',
#   'The Riddle',
#   'The Riddle - Extended Mix',
#   'Switch',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MAKJ': ['De La Sol',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Knockout',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Derp'],
#  'flora cash': ['Feeling So Down', "You're Somebody Else"],
#  'Austin George': ['Hands On You'],
#  'Betterov': ['Bring mich nach Hause', 'Viertel vor Irgendwas', 'Dussmann'],
#  'Mother Mother': ['Hayloft II'],
#  'Royal & the Serpent': ['FUCKBOI REJECTS'],
#  'grandson': ['Drop Dead (with Kesha and Travis Barker)', 'Blood // Water'],
#  'Kesha': ['Drop Dead (with Kesha and Travis Barker)',
#   'Good Old Days (feat. Kesha)',
#   'Praying',
#   'TiK ToK',
#   'Right Round (feat. Ke$ha)',
#   'Body Talks (feat. Kesha)'],
#  'Crawlers': ['Come Over (Again)'],
#  'A Day To Remember': ['Re-Entry (feat. Mark Hoppus)'],
#  'Fettes Brot': ['An Tagen wie diesen',
#   'Emanuela',
#   'Schwule Mädchen',
#   'Bettina, zieh dir bitte etwas an',
#   'Emanuela'],
#  'Dallerium': ['How Do I Sleep Now'],
#  'Olive': ['How Do I Sleep Now'],
#  'KUMMER': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Fred Rabe': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Lil Nas X': ['INDUSTRY BABY (feat. Jack Harlow)', 'THATS WHAT I WANT'],
#  'Jack Harlow': ['INDUSTRY BABY (feat. Jack Harlow)'],
#  'Jessie J': ['Wild', 'Price Tag', 'Wild - No Rap Edit', 'Who You Are'],
#  'Sofi Tukker': ['House Arrest'],
#  'Gorgon City': ['House Arrest'],
#  'Pixies': ['Where Is My Mind? - Remastered'],
#  'Nickelback': ['Burn it to the Ground',
#   'How You Remind Me',
#   'How You Remind Me'],
#  'Noah Cyrus': ['July', 'Lonely', 'All Falls Down (feat. Juliander)'],
#  'GAYLE': ['abcdefu', 'abcdefu (angrier)'],
#  'Beartooth': ['Hated'],
#  'Zedline': ['Polozhenie - Zedline Remix'],
#  'Pete Yorn': ['Ever Fallen In Love - From the Motion Picture "Shrek 2"'],
#  'Foreigner': ['I Want to Know What Love Is - 1999 Remaster'],
#  'Lostboi Lino': ['Wenn Du weinst'],
#  'Montez': ['Auf & Ab'],
#  'Scooter': ['Suck My Megamix - The Longest Scooter Single In The World',
#   'How Much Is The Fish?',
#   'Hyper Hyper',
#   'Suck My Megamix - The Longest Scooter Single in the World'],
#  'Tom Walker': ['Leave a Light On', 'Just You and I'],
#  'Van Halen': ["Can't Stop Lovin' You"],
#  'Bowling For Soup': ['Girl All the Bad Guys Want',
#   'Almost',
#   'Right About Now',
#   '1985'],
#  'We Were Promised Jetpacks': ['Quiet Little Voices'],
#  'Kid Cudi': ['Erase Me - Main',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix'],
#  'Kanye West': ['Erase Me - Main',
#   'POWER',
#   'Dark Fantasy',
#   'Stronger',
#   'Gold Digger'],
#  'Dido': ['Stan'],
#  'Elton John': ['Stan - Live At 43rd Grammy Awards'],
#  'Dr. Dre': ['Guilty Conscience'],
#  'Dexys Midnight Runners': ['Come On Eileen'],
#  'Counting Crows': ['Accidentally In Love'],
#  'AC/DC': ["It's a Long Way to the Top (If You Wanna Rock 'N' Roll)",
#   'Highway to Hell',
#   'You Shook Me All Night Long'],
#  'Beach House': ['Take Care'],
#  'Alesso': ['When I’m Gone (with Katy Perry)',
#   'Calling (Lose My Mind) - Radio Edit'],
#  'Katy Perry': ['When I’m Gone (with Katy Perry)',
#   'The One That Got Away - Acoustic',
#   'The One That Got Away - Acoustic',
#   'I Kissed A Girl',
#   'Firework'],
#  'Billy Idol': ['White Wedding',
#   'Dancing with Myself - 2001 Remaster',
#   'Dancing With Myself'],
#  'Generation X': ['Dancing with Myself - 2001 Remaster'],
#  'Slade': ['Merry Xmas Everybody'],
#  'Band Aid 30': ["Do They Know It's Christmas? - 2014"],
#  'Watsky': ['Sloppy Seconds'],
#  'Macklemore': ['Penis Song',
#   'Good Old Days (feat. Kesha)',
#   'Glorious (feat. Skylar Grey)',
#   "Can't Hold Us (feat. Ray Dalton)"],
#  'The Airborne Toxic Event': ['Sometime Around Midnight'],
#  'MOD SUN': ['Internet Killed The Rockstar'],
#  'G-Eazy': ['Still Be Friends (feat. Tory Lanez & Tyga)',
#   'My Year',
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix'],
#  'Tory Lanez': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Tyga': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Steve Aoki': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Hava',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Pretender (feat. Lil Yachty & AJR)',
#   'Mayhem',
#   'Be Somebody',
#   'Just Hold On',
#   'Lie To Me',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix',
#   'Azukita (Steve Aoki, Daddy Yankee, Play-N-Skillz & Elvis Crespo) (feat. Elvis Crespo)',
#   'Jaleo',
#   'MIC Drop (Steve Aoki Remix) [Full Length Edition]',
#   'MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Chris Lake': ['Delirious (Boneless) (feat. Kid Ink)'],
#  'Tujamo': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Grapevine - Tujamo Remix'],
#  'Kid Ink': ['Delirious (Boneless) (feat. Kid Ink)', 'Hey Baby', 'I Love You'],
#  'All Time Low': ['Dear Maria, Count Me In', 'Umbrella'],
#  'The All-American Rejects': ['Dirty Little Secret',
#   'Swing, Swing',
#   'Gives You Hell',
#   'Gives You Hell'],
#  'We The Kings': ['Check Yes, Juliet', 'Sad Song (feat. Elena Coats)'],
#  'Love A': ['Too Doof to Fuck'],
#  'Jules Ahoi': ['Robinson Crusoe'],
#  'Bushido': ['Alles wird gut'],
#  'Warren G': ['Party We Will Throw Now!'],
#  'The Game': ['Party We Will Throw Now!'],
#  'Mumford & Sons': ['Ditmas', 'Little Lion Man', 'I Will Wait'],
#  'Axel Black & White': ['Somebody To Love'],
#  'KSI': ['Holiday',
#   'Keep Up',
#   'Creature',
#   'Loose (feat. KSI)',
#   'Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'Patience (feat. YUNGBLUD & Polo G)',
#   'Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Jump Around',
#   'Touch Down',
#   'Uncontrollable (feat. Big Zuu)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)',
#   'Wake Up Call (feat. Trippie Redd)',
#   'Friends With Benefits (KSI vs MNDM)',
#   'Creature',
#   'Earthquake',
#   'Little Boy',
#   "Adam's Apple",
#   'Lamborghini',
#   'Two Birds, One Stone'],
#  'Donots': ['So Long'],
#  'Frank Turner': ['So Long'],
#  'Red Hot Chili Peppers': ['By the Way',
#   'Snow (Hey Oh)',
#   'Californication',
#   "Can't Stop"],
#  'Powfu': ['death bed (coffee for your head)'],
#  'beabadoobee': ['death bed (coffee for your head)'],
#  'Edwin Rosen': ['leichter//kälter'],
#  'Thees Uhlmann': ['Zum Laichen und Sterben ziehen die Lachse den Fluss hinauf'],
#  'Blond': ['Match'],
#  'Saint Motel': ['My Type'],
#  'Philipp Poisel': ['Wie soll ein Mensch das ertragen',
#   'Mein Amerika',
#   'Erkläre mir die Liebe',
#   'Ich will nur - Live',
#   'Liebe meines Lebens',
#   'Wolke 7',
#   'Wie soll ein Mensch das ertragen'],
#  'DJ Gollum': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Scarlet': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'DJ THT': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Ced Tecknoboy': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Tate McRae': ['you broke me first'],
#  'Razz': ['Youth & Enjoyment'],
#  'Twenty One Pilots': ['Addict With A Pen'],
#  'Quietdrive': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'Droo Hastings From Drrt': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'P!nk': ['Try',
#   'Walk Me Home',
#   'Raise Your Glass',
#   'So What',
#   'What About Us - Cash Cash Remix'],
#  'NF': ['Lie', 'Paralyzed', 'Let You Down'],
#  'Emil Bulls': ['The Jaws of Oblivion'],
#  'ANA': ['Whiskey'],
#  '100 Kilo Herz': ['Laternensong'],
#  'The Weeknd': ['Save Your Tears', 'Blinding Lights', 'The Hills'],
#  'Die Toten Hosen': ['Oberhausen',
#   'Vogelfrei',
#   'Herz brennt',
#   'Steh auf, wenn du am Boden bist',
#   'Auswärtsspiel',
#   'Hier kommt Alex',
#   'Bonnie & Clyde',
#   'Wannsee',
#   'Alles passiert',
#   'Alles aus Liebe'],
#  'Jennifer Rostock': ['K.B.A.G.', 'Alles Cool', 'Hengstin'],
#  'Rainbirds': ['Blueprint'],
#  'Bananafishbones': ['für immer', 'Vanessa'],
#  'Ran-D': ['Zombie - Original Mix'],
#  'Dvbbs': ['Raveology'],
#  'VINAI': ['Raveology', 'Break the Beat', 'Out of This Town'],
#  'Emily Watts': ['La Vie En Rose'],
#  'Metro Station': ['Shake It', 'Shake It'],
#  'Neonschwarz': ['On a Journey'],
#  'The Vamps': ['Somebody To You'],
#  'Kina': ['Can We Kiss Forever?'],
#  'Adriana Proenza': ['Can We Kiss Forever?'],
#  'Alec Benjamin': ['Let Me Down Slowly'],
#  'The Fray': ['You Found Me', 'How to Save a Life'],
#  'Ida Corr': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Fedde Le Grand': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Iggy Pop': ['Lust For Life'],
#  'Olivia Rodrigo': ['All I Want', 'good 4 u', 'drivers license'],
#  'Disney': ['All I Want'],
#  'Sarah Connor': ['Wie schön du bist', 'Vincent'],
#  'Ed Sheeran': ['Bad Habits',
#   'Galway Girl',
#   'Castle on the Hill',
#   'Perfect - Robin Schulz Remix',
#   'Photograph',
#   'Happier - Tiësto’s AFTR:HRS Remix'],
#  'Lukas Graham': ['Mama Said'],
#  'Drake': ['One Dance', "God's Plan"],
#  'Wizkid': ['One Dance'],
#  'Kyla': ['One Dance'],
#  'The Kid LAROI': ['STAY (with Justin Bieber)'],
#  'Justin Bieber': ['STAY (with Justin Bieber)'],
#  'Lost Frequencies': ['Love to Go',
#   'Reality',
#   'Reality - Gestört aber GeiL Remix',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Are You With Me - Radio Edit',
#   'Are You With Me - Gestört aber GeiL Remix',
#   'Melody',
#   'So Much Better - Lost Frequencies Remix',
#   'Paris - Lost Frequencies Remix',
#   'Crazy',
#   'Run - Lost Frequencies Radio Edit',
#   'Here with You',
#   'Beautiful Life',
#   'Are You with Me',
#   'Melody',
#   'Like I Love You',
#   'Reality - Gestört aber GeiL Remix',
#   'Are You with Me - Gestört aber GeiL Remix'],
#  'Zonderling': ['Love to Go', 'Crazy'],
#  'Kelvin Jones': ['Love to Go'],
#  'Lipps Inc.': ['Funkytown'],
#  'Cheap Trick': ['Just Got Back'],
#  'Hot Chocolate': ["Every 1's a Winner - Single Version"],
#  'Juju': ['Vermissen (feat. Henning May)'],
#  'Henning May': ['Vermissen (feat. Henning May)'],
#  'Tobi & Manny': ['Rhythm & Vibes',
#   'Destined For Greatness',
#   'Destined For Greatness'],
#  'Irie Révoltés': ['Fäuste hoch'],
#  'Robbie Williams': ['Candy', 'Angels', 'Rock DJ'],
#  'Florence + The Machine': ['Shake It Out'],
#  'Papa Roach': ['Scars', 'Help'],
#  'Radical Face': ['Welcome Home, Son', 'Welcome Home'],
#  'Radiohead': ['Fake Plastic Trees', 'Creep'],
#  'Masked Wolf': ['Astronaut In The Ocean'],
#  'Neil Patrick Harris': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'How I Met Your Mother Cast': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'Tom Petty': ["Free Fallin'"],
#  'Julia Michaels': ['All Your Exes',
#   'Hurt Somebody',
#   'Into You',
#   'Lie To Me (feat. Julia Michaels)',
#   'Hurt Somebody'],
#  'Måneskin': ['I WANNA BE YOUR SLAVE'],
#  'Noah Kahan': ['Hurt Somebody', 'False Confidence', 'Hurt Somebody'],
#  'Provinz': ['Chaos'],
#  'Tai Verdes': ['Stuck In The Middle'],
#  'Dua Lipa': ['Levitating (feat. DaBaby)',
#   'Physical - Alok Remix',
#   'Electricity (with Dua Lipa)',
#   'IDGAF',
#   'One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   'Scared to Be Lonely - Acoustic Version',
#   'Scared to Be Lonely'],
#  'DaBaby': ['Levitating (feat. DaBaby)', 'ROCKSTAR (feat. Roddy Ricch)'],
#  'Harry Styles': ['Falling', 'Watermelon Sugar', 'Sign of the Times'],
#  'Finn': ['In Luv With U'],
#  'The Neighbourhood': ['Sweater Weather'],
#  'Moby': ['Extreme Ways', 'Lift Me Up'],
#  'Da Tweekaz': ['Heroes Of Today', 'D.W.X. (10 Years Dirty Workz Mix)'],
#  'Riverdale Cast': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Ashleigh Murray': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Camila Mendes': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Madelaine Petsch': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Asha Bromfield': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Hayley Law': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'KJ Apa': ['Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Kelis': ['Milkshake'],
#  'Juice WRLD': ['Lucid Dreams', 'Come & Go (with Marshmello)'],
#  'ElyOtto': ['SugarCrash!'],
#  'Basstrologe': ['Somebody To Love'],
#  'Marlon Roudette': ['New Age'],
#  'Tears For Fears': ['Shout'],
#  'Prinz Pi': ['Letzte Liebe', 'Kompass ohne Norden', '1,40m'],
#  'Roddy Ricch': ['ROCKSTAR (feat. Roddy Ricch)'],
#  'Bonnie Tyler': ['Holding Out for a Hero - From "Footloose" Soundtrack'],
#  'Marshmello': ['Come & Go (with Marshmello)',
#   'Here With Me',
#   'BIBA',
#   'Everyday',
#   'FRIENDS',
#   'Danger (with Migos & Marshmello)',
#   'Wolves',
#   'Alone',
#   'Bayen Habeit',
#   'Happier',
#   'You Can Cry',
#   'Everyday',
#   'Spotlight',
#   'Silence'],
#  'A$ton Wyld': ['Next Level'],
#  'Jme': ['Keep Up'],
#  'S1mba': ['Loose (feat. KSI)'],
#  'Craig David': ['Really Love (feat. Craig David & Digital Farm Animals)'],
#  'Digital Farm Animals': ['Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'All Falls Down (feat. Juliander)'],
#  'Anne-Marie': ["Don't Play",
#   '2002',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Ciao Adios - Burak Yeter Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'FRIENDS'],
#  'Zedd': ['The Middle', 'The Middle', 'Beautiful Now', 'Happy Now'],
#  'Maren Morris': ['The Middle', 'GIRL', 'The Middle'],
#  'Grey': ['The Middle', 'The Middle'],
#  '24kGoldn': ['Mood (feat. iann dior)'],
#  'Our Last Night': ['drivers license'],
#  'Creedence Clearwater Revival': ['Fortunate Son'],
#  'Mark Ronson': ['Valerie (feat. Amy Winehouse) - Version Revisited',
#   'Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Electricity (with Dua Lipa)'],
#  'Amy Winehouse': ['Valerie (feat. Amy Winehouse) - Version Revisited'],
#  'Cornershop': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'Norman Cook': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'NEIKED': ['Sexual'],
#  'Dyo': ['Sexual'],
#  'Capital Cities': ['Safe And Sound'],
#  'George Ezra': ['Hold My Girl', 'Paradise'],
#  'Vance Joy': ['Mess Is Mine'],
#  'Lil Glock Rouge': ['Merry Merry Christmas'],
#  'Sidemen': ['Merry Merry Christmas', 'The Gift'],
#  'Linkin Park': ['Shadow of the Day',
#   'CASTLE OF GLASS',
#   'Numb / Encore',
#   'In the End',
#   'Numb'],
#  'Duncan Laurence': ['Arcade'],
#  'flipturn': ['Chicago'],
#  'Ava Max': ['Kings & Queens',
#   'Sweet but Psycho',
#   'Let It Be Me (feat. Ava Max)'],
#  'Camila Cabello': ['Havana (feat. Young Thug)'],
#  'Silbermond': ['Irgendwas bleibt'],
#  'Jaymes Young': ["I'll Be Good"],
#  'Blue October': ['Hate Me'],
#  'Pickle': ['Sing It'],
#  'Endor': ['Pump It Up'],
#  'Outkast': ['Roses', 'Ms. Jackson'],
#  'Otto Knows': ['Million Voices - Radio Edit'],
#  'Jetta': ["I'd Love To Change The World - Matstubs Remix"],
#  'Matstubs': ["I'd Love To Change The World - Matstubs Remix"],
#  'John Newman': ['Love Me Again'],
#  'Rihanna': ['Disturbia', 'Stay', 'Love The Way You Lie', 'Live Your Life'],
#  'Die Firma': ['Die Eine 2005'],
#  'The Smiths': ['Asleep - 2011 Remaster'],
#  'Edward Sharpe & The Magnetic Zeros': ['Home'],
#  'lovelytheband': ['broken'],
#  'Johnny Cash': ['Hurt'],
#  'James Bay': ['Hold Back The River'],
#  'BANNERS': ['Shine A Light', 'Someone To You', 'Ghosts'],
#  'U2': ['Bad - Remastered 2009',
#   'Beautiful Day',
#   'With Or Without You - Remastered'],
#  'Casper': ['Ganz schön okay (feat. Kraftklub)', 'So perfekt'],
#  'Lewis Capaldi': ['Someone You Loved', 'Bruises'],
#  'Chip Taylor': ['On the Radio (Music from the Netflix Original Series Sex Education)'],
#  'Jerome': ['Light'],
#  'DVBBS': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Dropgun': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Sanjin': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Emeli Sandé': ['Clown', 'Read All About It, Pt. III'],
#  'Gwen Stefani': ['Kings Never Die', 'Hollaback Girl'],
#  '5 Seconds of Summer': ['She Looks So Perfect',
#   'Youngblood',
#   'Lie To Me (feat. Julia Michaels)',
#   'Youngblood - R3HAB Remix'],
#  'GAMPER & DADONI': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Emily Roberts': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Purple Disco Machine': ['Exotica', 'Hypnotized'],
#  'Mind Enterprises': ['Exotica'],
#  'Fritz Kalkbrenner': ['Good Things', 'Sky and Sand'],
#  'Martin Solveig': ['All Stars'],
#  'ALMA': ['All Stars'],
#  'AWOLNATION': ['Sail'],
#  'Sophie and the Giants': ['Hypnotized'],
#  'Neptunica': ['San Francisco'],
#  'Ellipso': ['San Francisco'],
#  'Emy Perez': ['San Francisco'],
#  'Chord Overstreet': ['Hold On'],
#  'Dimitri Vegas & Like Mike': ['Body Talk (feat. Julian Perretta)',
#   'The Anthem (Der Alte)',
#   'Beast (All as One)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'Wakanda',
#   'Mammoth',
#   'Ocarina',
#   'The Hum - Original Mix',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix',
#   'Hey Baby',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'Ready For Action',
#   'He\'s a Pirate (VIP Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate (Extended Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate - From "Pirates of the Caribbean: Dead Men Tell No Tales" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'Complicated (feat. Kiiara)',
#   'Crowd Control - Radio Edit',
#   'Slow Down (feat. Boef, Ronnie Flex, Ali B & I Am Aisha)',
#   'Patser Bounce',
#   'The House Of House',
#   'All I Need (with Gucci Mane)',
#   'When I Grow Up (feat. Wiz Khalifa)',
#   'Unity',
#   'Here We Go (Hey Boy, Hey Girl)',
#   'Opa',
#   'Arcade Mammoth',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MOGUAI': ['Body Talk (feat. Julian Perretta)', 'Mammoth', 'Arcade Mammoth'],
#  'Julian Perretta': ['Body Talk (feat. Julian Perretta)'],
#  'Krunk!': ['La Menta', 'Al Pacino'],
#  'Max Herre': ['Wolke 7'],
#  'Revolverheld': ['Halt dich an mir fest'],
#  'David Guetta': ['Where Them Girls At (feat. Nicki Minaj & Flo Rida)',
#   "Club Can't Handle Me (feat. David Guetta)",
#   'Let It Be Me (feat. Ava Max)',
#   'Flames',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Like I Do',
#   'Titanium (feat. Sia)',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Like I Do',
#   'Complicated (feat. Kiiara)'],
#  'Sean Paul': ['Temperature'],
#  'Toploader': ['Dancing in the Moonlight'],
#  'Bruce Springsteen': ['Dancing In the Dark'],
#  'Lister': ['Pathways'],
#  'The Lumineers': ['Ophelia'],
#  'Vinnie Paz': ['The Ghost I Used to Be'],
#  'Eamon': ['The Ghost I Used to Be'],
#  'Elena Coats': ['Sad Song (feat. Elena Coats)'],
#  'Dean Lewis': ['Half A Man'],
#  'Pitbull': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Back in Time - featured in "Men In Black 3"',
#   'Bailar (feat. Pitbull & Elvis Crespo)'],
#  'Ne-Yo': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'AFROJACK': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Ten Feet Tall',
#   'Turn up the Speakers - Radio Edit'],
#  'Nayer': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'Coone': ['D.W.X. (10 Years Dirty Workz Mix)',
#   'Words From The Gang (2014 Remix) - Radio Version',
#   'Pump up the Jam'],
#  'Imagine Dragons': ["It's Time",
#   'On Top Of The World',
#   'Thunder',
#   'Thunder',
#   'Radioactive',
#   'Thunder',
#   'Believer - Kaskade Remix'],
#  'Lord Huron': ['The Night We Met'],
#  'Tungevaag': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'Wicked Wonderland',
#   'All For Love - Luca Schreiner Remix'],
#  'Raaban': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'All For Love - Luca Schreiner Remix'],
#  'Emila': ['Samsara (feat. Emila)'],
#  'Brynny': ['Thinking Too Much'],
#  'DJ Antoine': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'The Beatshakers': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'Herbert Grönemeyer': ['Glück', 'Flugzeuge im Bauch'],
#  'Elliott Smith': ['Say Yes', 'Say Yes'],
#  'Gloria Gaynor': ['I Will Survive - Single Version'],
#  'Good Charlotte': ['I Just Wanna Live',
#   'The River',
#   'Girls & Boys',
#   'Lifestyles of the Rich & Famous'],
#  'Frittenbude': ['Mindestens in 1000 Jahren'],
#  'Jessica Ricca': ["Hey It’s Delilah (Plain White T's Cover)"],
#  'Adele': ['Someone Like You', 'When We Were Young'],
#  'LUM!X': ['Monster'],
#  'Rosa Anschütz': ['Rigid - Kobosil 44 Rush Mix'],
#  'Kobosil': ['Rigid - Kobosil 44 Rush Mix'],
#  'Stanfour': ['Wishing You Well - Radio Version'],
#  'Bloodhound Gang': ['Uhn Tiss Uhn Tiss Uhn Tiss',
#   'The Ballad Of Chasey Lain',
#   'The Bad Touch',
#   'Foxtrot Uniform Charlie Kilo'],
#  'Drunkenmunky': ['E'],
#  'ZAYN': ['Dusk Till Dawn (feat. Sia) - Radio Edit'],
#  'Sia': ['Dusk Till Dawn (feat. Sia) - Radio Edit',
#   'The Greatest',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Flames',
#   'Titanium (feat. Sia)'],
#  'Diddy - Dirty Money': ['Coming Home'],
#  'Skylar Grey': ['Coming Home', 'Glorious (feat. Skylar Grey)'],
#  'Snow Patrol': ['Called Out In The Dark',
#   'Chasing Cars',
#   'Chasing Cars',
#   'Chasing Cars'],
#  'B.o.B': ['Price Tag', 'Airplanes (feat. Hayley Williams of Paramore)'],
#  'David Gray': ["This Year's Love"],
#  'The Who': ["Baba O'Riley"],
#  'Broilers': ['Tanzt du noch einmal mit mir?'],
#  'Route 94': ['My Love (feat. Jess Glynne)'],
#  'Jess Glynne': ['My Love (feat. Jess Glynne)', 'Take Me Home'],
#  'My Chemical Romance': ['The Only Hope for Me Is You',
#   "I Don't Love You",
#   'Disenchanted - Live Demo',
#   'Kill All Your Friends - Live Demo',
#   'All the Angels - Live Demo',
#   'House of Wolves - Version 2; Live Demo',
#   'Famous Last Words',
#   'Cancer',
#   'Party at the End of the World - Live Demo',
#   'Dead!',
#   'Emily - Rough Mix',
#   'Not That Kind of Girl - Live Demo',
#   'The Five of Us Are Dying - Rough Mix',
#   'House of Wolves',
#   'The Sharpest Lives',
#   'Sleep',
#   'Blood - Hidden Track',
#   'Disenchanted',
#   'Teenagers',
#   'House of Wolves - Version 1; Live Demo',
#   'Mama - Live Demo',
#   'Welcome to the Black Parade',
#   'Mama',
#   'The End.',
#   'My Way Home Is Through You - Live Demo',
#   'This Is How I Disappear',
#   'Vampire Money',
#   'DESTROYA',
#   'The Only Hope for Me Is You',
#   'Goodnite, Dr. Death',
#   'Party Poison',
#   'Look Alive, Sunshine',
#   'SING',
#   'Bulletproof Heart',
#   'Jet-Star and the Kobra Kid / Traffic Report',
#   "Save Yourself, I'll Hold Them Back",
#   'Planetary (GO!)',
#   'S/C/A/R/E/C/R/O/W',
#   'The Kids from Yesterday',
#   'Summertime',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Drowning Lessons',
#   'Cubicles',
#   'Romance',
#   'Demolition Lovers',
#   'This Is the Best Day Ever',
#   'Early Sunsets Over Monroeville',
#   'Skylines and Turnstiles',
#   'Our Lady of Sorrows',
#   'Headfirst for Halos',
#   "Honey, This Mirror Isn't Big Enough for the Two of Us",
#   'Vampires Will Never Hurt You',
#   'Thank You for the Venom',
#   "Give 'Em Hell, Kid",
#   'To the End',
#   "Hang 'Em High",
#   'Cemetery Drive',
#   "It's Not a Fashion Statement, It's a Deathwish",
#   'Interlude',
#   'You Know What They Do to Guys Like Us in Prison',
#   'I Never Told You What I Do for a Living',
#   'The Jetset Life Is Gonna Kill You',
#   'This Is How I Disappear',
#   'Dead!',
#   'Blood - Hidden Track',
#   'The Sharpest Lives',
#   'Sleep',
#   'Disenchanted',
#   'The End.',
#   'House of Wolves',
#   'Kill All Your Friends',
#   'Cancer',
#   'Mama',
#   'The Ghost of You',
#   'Famous Last Words',
#   "I Don't Love You",
#   'Helena',
#   'Welcome to the Black Parade',
#   "I'm Not Okay (I Promise)",
#   'Na Na Na (Na Na Na Na Na Na Na Na Na)',
#   'Teenagers',
#   'Fake Your Death'],
#  'James Arthur': ['Can I Be Him', 'You Can Cry'],
#  'Thomas Rhett': ['Die A Happy Man'],
#  'Anis Don Demina': ['Uno Dos Tres Shurda'],
#  'VOLAC': ['In A Club'],
#  'illusionize': ['In A Club'],
#  'Andre Longo': ['In A Club'],
#  'Popp & Popp': ['Lieblingsfarbe Sonne'],
#  'Flowa': ['Lieblingsfarbe Sonne'],
#  'Neelix': ['You',
#   'Before - Neelix Well Done Remix',
#   'Waterfall',
#   'Makeup (feat. Caroline Harrison)',
#   'Looking Like We Usually Look',
#   'Mosquito',
#   'The Sun',
#   'Angels of Destruction - Neelix Remix',
#   'Expect What',
#   'History',
#   '1000 Sterne'],
#  'AJR': ["I'm Ready", '100 Bad Days', 'Pretender (feat. Lil Yachty & AJR)'],
#  'Calum Scott': ['Dancing On My Own',
#   'Dancing On My Own',
#   'Dancing On My Own - Tiësto Remix'],
#  'Hayley Williams': ['Airplanes (feat. Hayley Williams of Paramore)'],
#  'You Me At Six': ['Underdog'],
#  'Mattafix': ['Big City Life'],
#  'Wrabel': ['Ten Feet Tall', 'Written in the Scars (feat. Wrabel)'],
#  'Yeah Yeah Yeahs': ['Heads Will Roll - A-Trak Remix'],
#  'A-Trak': ['Heads Will Roll - A-Trak Remix'],
#  'DJ Blyatman': ['Gopnik'],
#  'Dom Dolla': ['San Frandisco'],
#  'Ricky Desktop': ['The Banjo Beat, Pt. 1'],
#  'Nathan Dawe': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)'],
#  'Ella Henderson': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Yours'],
#  'Boyce Avenue': ['The One That Got Away'],
#  'Armin van Buuren': ['You Are',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'Turn It Up',
#   'Blah Blah Blah',
#   'Great Spirit',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Blah Blah Blah',
#   'Therapy',
#   'This Is What It Feels Like',
#   'Drowning - Avicii Remix',
#   'United',
#   'Sunny Days',
#   'Wild Wild Son',
#   'Another You',
#   'Off The Hook'],
#  'Sunnery James & Ryan Marciano': ['You Are'],
#  'Will Sparks': ['My Spine Is Tingling',
#   '#SELFIE - Will Sparks Remix',
#   '#Selfie - Will Sparks Remix',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Take Me (feat. Gloria Kim)',
#   'Sick Like That (feat. Luciana)',
#   'Ah Yeah So What - Radio Edit',
#   'Senseless',
#   'Leave The Lights On - Will Sparks Remix',
#   'My Time',
#   'Voices'],
#  'Luciana': ['My Spine Is Tingling',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Sick Like That (feat. Luciana)',
#   'Fireflies (feat. Luciana)'],
#  'Sonar': ['Sonar'],
#  'SCNDL': ['Sonar', 'Bleed'],
#  'Mikky Ekko': ['Stay'],
#  'Alok': ["Don't Ya - Fabio Fusco Remix",
#   'Physical - Alok Remix',
#   'Piece Of Your Heart - Alok Remix',
#   'United'],
#  'FractaLL': ["Don't Ya - Fabio Fusco Remix"],
#  'Bea Jourdan': ["Don't Ya - Fabio Fusco Remix"],
#  'Fabio Fusco': ["Don't Ya - Fabio Fusco Remix"],
#  'Tiësto': ['God Is A Dancer - James Hype Remix',
#   'Grapevine - Tujamo Remix',
#   'On My Way',
#   'Happier - Tiësto’s AFTR:HRS Remix',
#   'BOOM',
#   'Dancing On My Own - Tiësto Remix',
#   'WOW',
#   'Jackie Chan',
#   'Red Lights',
#   'Split (Only U)',
#   'Carry You Home',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Harder'],
#  'Mabel': ['God Is A Dancer - James Hype Remix'],
#  'James Hype': ['God Is A Dancer - James Hype Remix'],
#  'Chiddy Bang': ['Opposite of Adults'],
#  'Tigerlily': ['Invisible Children', 'Spice Temple - Overdrive Remix'],
#  'BOSS': ['Dumb (Feat. BOSS)', 'Over and Out (feat. Charlott Boss)'],
#  'Mike Williams': ['Wait Another Day', 'The Beat', 'Lullaby'],
#  'Mesto': ['Wait Another Day'],
#  'Angels & Airwaves': ['Surrender',
#   'Chasing Shadows',
#   'The Adventure',
#   'Surrender'],
#  'R3HAB': ['Flashlight',
#   'Wrong Move (feat. Olivia Holt)',
#   'Rumors',
#   'Radio Silence',
#   'Tequila - R3HAB Remix',
#   'Starflight',
#   'Youngblood - R3HAB Remix',
#   'Lullaby',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'Freak',
#   "I Just Can't"],
#  'Deorro': ['Flashlight',
#   'Melbourne Bounce - Deorro Remix',
#   'Bootie in Your Face - No Rock Drop',
#   'Focus',
#   'Focus (feat. Lena Leon)',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'I Can Be Somebody (feat. Erin McCarley)',
#   'Bailar (feat. Pitbull & Elvis Crespo)',
#   'Bailar (feat. Elvis Crespo) - Radio Edit',
#   'Five More Hours',
#   'DFTF',
#   'Perdoname (feat. DyCy & Adrian Delgado)',
#   'Tell Me Lies (feat. Lesley Roy)',
#   'Five Hours',
#   'Knockout'],
#  'Von Wegen Lisbeth': ['Bitch'],
#  'Showtek': ['Booyah - Radio Edit', 'We Like to Party - Original Mix'],
#  'We Are Loud': ['Booyah - Radio Edit'],
#  'Sonny Wilson': ['Booyah - Radio Edit'],
#  'Club Madness': ['Pumped Up Kicks - Smithee Hard Edit'],
#  'Snoop Dogg': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Hollywood (feat. Snoop Dogg & Jamie Principle)',
#   'Bounce (feat. Snoop Dogg)'],
#  'Wiz Khalifa': ['Young, Wild & Free (feat. Bruno Mars)',
#   "Don't Kill My High (feat. Wiz Khalifa & Social House)",
#   'Payphone',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'When I Grow Up (feat. Wiz Khalifa)'],
#  'Bruno Mars': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Finesse - Remix; feat. Cardi B'],
#  'Ummet Ozcan': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Change My Heart',
#   'The Hum - Short Edit',
#   'The Hum - Original Mix',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Brennan Heart': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix'],
#  'Keane': ['Somewhere Only We Know'],
#  'Curtis Waters': ["Stunnin' (feat. Harm Franklin)"],
#  'Harm Franklin': ["Stunnin' (feat. Harm Franklin)"],
#  'Ali As': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Namika': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Gnarls Barkley': ['Crazy'],
# ...
#  'The Prince Karma': ['Later Bitches'],
#  'Ozzy Osbourne': ["Mama, I'm Coming Home", 'Dreamer'],
#  'Boston': ['More Than a Feeling'],
#  'Fall Out Boy': ["This Ain't A Scene, It's An Arms Race",
#   "Sugar, We're Goin Down",
#   'Centuries',
#   "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'The Last Of The Real Ones'],
#  'Fitz and The Tantrums': ['HandClap'],
#  'Die Ärzte': ['Ist das noch Punkrock?', 'Deine Schuld'],
#  'Kodaline': ['All I Want'],
#  'Green Day': ['Holiday',
#   'Holiday / Boulevard of Broken Dreams',
#   'Still Breathing',
#   'When I Come Around',
#   'Boulevard of Broken Dreams',
#   'Wake Me up When September Ends',
#   'Welcome to Paradise',
#   'Basket Case',
#   'Good Riddance (Time of Your Life)',
#   'American Idiot',
#   'Restless Heart Syndrome',
#   'East Jesus Nowhere',
#   '21st Century Breakdown',
#   "Christian's Inferno",
#   'Before the Lobotomy',
#   'The Static Age',
#   'American Eulogy: Mass Hysteria / Modern World',
#   '¿Viva La Gloria? (Little Girl)',
#   'Horseshoes and Handgrenades',
#   'Murder City',
#   '¡Viva La Gloria!',
#   'Last of the American Girls',
#   'Last Night on Earth',
#   'See the Light',
#   'Peacemaker',
#   'Know Your Enemy',
#   '21 Guns',
#   'Song of the Century',
#   'Makeout Party - Demo',
#   '99 Revolutions - Demo',
#   'Stray Heart - Demo',
#   'Angel Blue - Demo',
#   'Nuclear Family - Demo',
#   'Ashley - Demo',
#   'A Little Boy Named Train - Demo',
#   'Oh Love - Demo',
#   'Sex, Drugs & Violence - Demo',
#   'Stay the Night - Acoustic',
#   'Baby Eyes - Demo',
#   'Missing You - Demo',
#   'Carpe Diem - Demo',
#   'Rusty James - Demo',
#   'State of Shock - Demo',
#   'Let Yourself Go - Demo',
#   'Fell for You - Demo',
#   'Stay the Night - Demo',
#   'Drama Queen',
#   'A Little Boy Named Train',
#   'The Forgotten',
#   'Dirty Rotten Bastards',
#   'Sex, Drugs & Violence',
#   'Missing You',
#   'Amanda',
#   '99 Revolutions',
#   'X-Kid',
#   '8th Avenue Serenade',
#   'Brutal Love',
#   'Walk Away',
#   'Fuck Time',
#   'Baby Eyes',
#   "Wow! That's Loud",
#   'Stray Heart',
#   'Lazy Bones',
#   'Stop When the Red Lights Flash',
#   'Ashley',
#   'Nightlife',
#   'Makeout Party',
#   'Lady Cobra',
#   'Wild One',
#   'Amy',
#   'See You Tonight',
#   'Troublemaker',
#   'Sweet 16',
#   'Rusty James',
#   'Oh Love',
#   'Fell for You',
#   'Nuclear Family',
#   'Angel Blue',
#   'Loss of Control',
#   'Let Yourself Go',
#   'Stay the Night',
#   'Carpe Diem',
#   'Kill the DJ',
#   'Holiday / Boulevard of Broken Dreams',
#   'Jesus of Suburbia',
#   "Give Me Novacaine / She's a Rebel",
#   'Homecoming',
#   'Extraordinary Girl / Letterbomb',
#   'Too Much Too Soon',
#   'Wake Me up When September Ends',
#   'American Idiot',
#   'Governator',
#   'Shoplifter',
#   'Whatsername'],
#  'MICAR': ["This Time It's My Life - Radio Edit"],
#  'Breathe Carolina': ['My Love', 'The Fever'],
#  'Robert Falcon': ['My Love'],
#  'The Cure': ["Friday I'm In Love"],
#  'Jon Boden': ['How Long Will I Love You'],
#  'Sam Sweeney': ['How Long Will I Love You'],
#  'Ben Coleman': ['How Long Will I Love You'],
#  'G.R.L.': ['Ugly Heart'],
#  'T.I.': ['Live Your Life'],
#  'Die Antwoord': ['Banana Brain'],
#  'Belik Boom': ['Avada Kadabra'],
#  'Bag Raiders': ['Shooting Stars'],
#  'Alle Farben': ['H.O.L.Y.', 'Please Tell Rosie', 'Fading'],
#  'RHODES': ['H.O.L.Y.'],
#  'YouNotUs': ['Please Tell Rosie'],
#  'Hoobastank': ['The Reason', 'The Reason'],
#  'Three Days Grace': ['I Hate Everything About You'],
#  'Thirty Seconds To Mars': ['The Kill'],
#  'Bon Jovi': ["It's My Life",
#   'You Give Love A Bad Name',
#   "Livin' On A Prayer"],
#  'The Subways': ['Rock & Roll Queen'],
#  'Puddle Of Mudd': ['She Hates Me'],
#  'Third Eye Blind': ['Semi-Charmed Life'],
#  'Caesars': ['Jerk It Out', 'Jerk It Out'],
#  'Nirvana': ['Smells Like Teen Spirit',
#   'Come As You Are',
#   'Smells Like Teen Spirit'],
#  'Escape the Fate': ['Broken Heart'],
#  'Andrew Rayel': ['Horizon'],
#  'Lola Blanc': ['Horizon'],
#  'Philipp Dittberner': ['1,40m'],
#  'John De Sohn': ['Forever Young', 'Happy Kids'],
#  'LIAMOO': ['Forever Young'],
#  'Fox Blanco': ['Change the World'],
#  'Davai': ['Replay (feat. CIRE)'],
#  'CIRE': ['Replay (feat. CIRE)'],
#  'Alvaro Soler': ['La Cintura'],
#  'Matt Simons': ['We Can Do Better'],
#  'Swedish House Mafia': ["Don't You Worry Child (Radio Edit) [feat. John Martin]"],
#  'MIKA': ['Grace Kelly'],
#  'Laurell': ['Change My Heart', 'Good Vibes (feat. Laurell)'],
#  'Kris Kross Amsterdam': ['Whenever (feat. Conor Maynard)'],
#  'The Boy Next Door': ['Whenever (feat. Conor Maynard)'],
#  'Conor Maynard': ['Whenever (feat. Conor Maynard)'],
#  'ItaloBrothers': ['Summer Air', 'Till You Drop'],
#  'Blur': ['Song 2', 'Song 2 - 2012 Remaster'],
#  'XO Cupid': ['True Colors (feat. Maya Avedis)'],
#  'Maya Avedis': ['True Colors (feat. Maya Avedis)'],
#  'Alice Merton': ['Why So Serious', 'Funny Business'],
#  'Richard Smitt': ['All For Love', 'All For Love - Luca Schreiner Remix'],
#  'Smith & Thell': ['Toast', 'Forgive Me Friend'],
#  'Dzeko': ['Heaven (feat. Veronica)', 'Jackie Chan'],
#  'Riggi & Piros': ['Heaven (feat. Veronica)'],
#  'Veronica': ['Heaven (feat. Veronica)'],
#  'Westlife': ["When You're Looking Like That - Single Remix"],
#  'Nico Santos': ['Rooftop', 'Rooftop - HUGEL Remix'],
#  'Swedish Jam Factory': ['Forgive Me Friend'],
#  'A7S': ['Hey Baby (feat. A7S)'],
#  'Train': ['Hey, Soul Sister', 'Hey, Soul Sister'],
#  'Journey': ["Don't Stop Believin'", "Don't Stop Believin'"],
#  'Vargas & Lagola': ['Roads'],
#  'Katrina & The Waves': ['Walking On Sunshine'],
#  'T-Pain': ['Low (feat. T-Pain)'],
#  'Tom Cochrane': ['Life Is A Highway'],
#  'The Cranberries': ['Zombie'],
#  'Spice Girls': ['Wannabe'],
#  'Eurythmics': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Annie Lennox': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Dave Stewart': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'will.i.am': ['Hall of Fame (feat. will.i.am)'],
#  'TOTO': ['Africa'],
#  'The Rembrandts': ['I\'ll Be There for You (Theme from "Friends\')',
#   "I'll Be There for You (Theme from Friends) - Single Version"],
#  "Guns N' Roses": ["Sweet Child O' Mine"],
#  'Chumbawamba': ['Tubthumping'],
#  'Shakira': ['Whenever, Wherever', "Hips Don't Lie (feat. Wyclef Jean)"],
#  'John Denver': ['Take Me Home, Country Roads - Rerecorded'],
#  'Smash Mouth': ['All Star'],
#  'Hanson': ['MMMBop - Single Version', 'MMMBop'],
#  'Gavin DeGraw': ["I Don't Want to Be - Stripped Version"],
#  'WALK THE MOON': ['Shut Up and Dance'],
#  'Tenacious D': ['Tribute'],
#  'Bryan Adams': ["Summer Of '69", "Summer Of '69"],
#  'American Authors': ['Best Day Of My Life', 'Best Day Of My Life'],
#  'Eiffel 65': ['Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'Backstreet Boys': ["Everybody (Backstreet's Back) - Extended Version",
#   'I Want It That Way',
#   'I Want It That Way - Anstandslos & Durchgeknallt Remix'],
#  'Rascal Flatts': ['Life is a Highway - From "Cars"'],
#  'The Verve': ['Bitter Sweet Symphony'],
#  'Alien Ant Farm': ['Smooth Criminal'],
#  'The Proclaimers': ["I'm Gonna Be (500 Miles)"],
#  'Kid Rock': ['All Summer Long', 'All Summer Long'],
#  'The Goo Goo Dolls': ['Iris'],
#  '3 Doors Down': ['Kryptonite'],
#  'OneRepublic': ['Counting Stars', 'Bones (feat. OneRepublic)'],
#  'fun.': ['Some Nights', 'We Are Young (feat. Janelle Monáe)'],
#  'R.E.M.': ['Losing My Religion'],
#  'Janelle Monáe': ['We Are Young (feat. Janelle Monáe)'],
#  'Lynyrd Skynyrd': ['Sweet Home Alabama'],
#  'Khalid': ['Vertigo',
#   'Saturday Nights REMIX',
#   'Eastside (with Halsey & Khalid)',
#   'Better',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Ocean (feat. Khalid)',
#   'Silence'],
#  'Pritam': ['BIBA'],
#  'Kane Brown': ['Saturday Nights REMIX'],
#  'benny blanco': ['Eastside (with Halsey & Khalid)'],
#  'Lost Kings': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Social House': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Lizzo': ['Juice'],
#  'Kygo': ['Happy Now'],
#  'Sandro Cavazza': ['Happy Now',
#   'Without You (feat. Sandro Cavazza)',
#   'So Much Better - Lost Frequencies Remix',
#   'Beautiful Life'],
#  'Post Malone': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Wow.',
#   'Better Now',
#   'Jackie Chan'],
#  'Swae Lee': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Arms Around You (feat. Maluma & Swae Lee)',
#   'Close To Me (with Diplo) (feat. Swae Lee)'],
#  'Ty James': ['Splash'],
#  'unheard': ['Splash'],
#  'Alec Bailey': ['Grip'],
#  'AUSTN': ["In Betweenin'"],
#  'MOTi': ['Hooked', 'Valencia - Original Mix'],
#  'Sheezan': ['Hooked'],
#  'Emma Sameth': ['Spin With You (feat. Jeremy Zucker)'],
#  'WOLFE': ['Spin With You (feat. Jeremy Zucker)'],
#  'Jeremy Zucker': ['Spin With You (feat. Jeremy Zucker)'],
#  'Galantis': ['Bones (feat. OneRepublic)',
#   'Love on Me',
#   "Don't Care",
#   'In My Head',
#   'Water',
#   "Dancin' to the Sound of a Broken Heart",
#   'Louder, Harder, Better',
#   'Gold Dust',
#   'Forever Tonight',
#   "Kill 'Em with the Love",
#   'Call If You Need Me',
#   'Firebird',
#   'You',
#   'Written in the Scars (feat. Wrabel)',
#   'Hey Alligator',
#   'Call Me Home',
#   'Salvage (Up All Night) (feat. Poo Bear)',
#   'Pillow Fight',
#   'Girls on Boys',
#   'Hello',
#   'Tell Me You Love Me',
#   'True Feeling',
#   'Hunter',
#   'Peanut Butter Jelly',
#   'Love on Me',
#   'Mama Look at Me Now',
#   'Spaceship (feat. Uffie)',
#   'Satisfied (feat. MAX)',
#   'No Money',
#   'Runaway (U & I)'],
#  'Robin Schulz': ['Speechless (feat. Erika Sirola)',
#   'Sugar (feat. Francesco Yates)',
#   'Perfect - Robin Schulz Remix'],
#  'Erika Sirola': ['Speechless (feat. Erika Sirola)'],
#  'Dominic Fike': ['3 Nights'],
#  'Miley Cyrus': ['Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Party In The U.S.A.'],
#  'Rita Ora': ['Only Want You',
#   'Let You Love Me',
#   'Anywhere',
#   'Lonely Together (feat. Rita Ora)'],
#  'Jack & Jack': ['Day Dreaming'],
#  'XXXTENTACION': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Lil Pump': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Maluma': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Snakehips': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Rivers Cuomo': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'KYLE': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Lennon Stella': ['La Di Da', 'Polaroid'],
#  'Chris Burton': ['Love Letters'],
#  'Chantel Jeffries': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'YG': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Rich The Kid': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'BIA': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Ariana Grande': ['thank u, next', '7 rings (feat. 2 Chainz) - Remix'],
#  'Lil Peep': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'Spotlight'],
#  'ILOVEMAKONNEN': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Niall Horan': ['Slow Hands'],
#  'Gryffin': ['Remember (with ZOHARA)'],
#  'ZOHARA': ['Remember (with ZOHARA)'],
#  'Cardi B': ['Finesse - Remix; feat. Cardi B',
#   'Girls Like You (feat. Cardi B) - Cardi B Version'],
#  'Sabrina Carpenter': ['Sue Me'],
#  'Lauren Daigle': ['Look Up Child'],
#  'Drax Project': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'Hailee Steinfeld': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'shy martin': ['Forget to Forget'],
#  'Mallrat': ["Nobody's Home"],
#  'Basenji': ["Nobody's Home"],
#  'ARTY': ['Save Me Tonight'],
#  'Maggie Rogers': ['Light On'],
#  'Ellie Goulding': ['Close To Me (with Diplo) (feat. Swae Lee)', 'Burn'],
#  'Silk City': ['Electricity (with Dua Lipa)'],
#  'LÉON': ['You And I'],
#  '2 Chainz': ['7 rings (feat. 2 Chainz) - Remix'],
#  'GASHI': ['My Year'],
#  'Normani': ['Dancing With A Stranger (with Normani)'],
#  'Zeina': ['In My Head'],
#  "Why Don't We": ['Big Plans'],
#  'Big Boi': ["Doin' It (feat. Sleepy Brown)"],
#  'Sleepy Brown': ["Doin' It (feat. Sleepy Brown)"],
#  'Lauv': ["i'm so tired..."],
#  'Troye Sivan': ["i'm so tired...", 'There for You'],
#  'Tyla Yaweh': ['She Bad'],
#  'COIN': ['I Want It All'],
#  'Kehlani': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Ty Dolla $ign': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Hozier': ['Almost (Sweet Music)'],
#  'Dan + Shay': ['Speechless', 'Tequila - R3HAB Remix'],
#  'Shoffy': ['Cool Again'],
#  'Bazzi': ['Mine'],
#  'Matoma': ['Lonely (feat. MAX)'],
#  'MAX': ['Lonely (feat. MAX)', 'Satisfied (feat. MAX)'],
#  'Shania Twain': ['Man! I Feel Like A Woman!'],
#  'Taylor Swift': ['Shake It Off',
#   'Look What You Made Me Do',
#   'We Are Never Ever Getting Back Together'],
#  'MKTO': ['Classic'],
#  'Little Mix': ['Shout Out to My Ex'],
#  'Keala Settle': ['This Is Me'],
#  'The Greatest Showman Ensemble': ['This Is Me'],
#  'Rachel Platten': ['Fight Song'],
#  'Shawn Mendes': ['Treat You Better', "There's Nothing Holdin' Me Back"],
#  'Wyclef Jean': ["Hips Don't Lie (feat. Wyclef Jean)"],
#  'Kelsea Ballerini': ['This Feeling', 'This Feeling (feat. Kelsea Ballerini)'],
#  'Clean Bandit': ['Symphony (feat. Zara Larsson)'],
#  'Zara Larsson': ['Symphony (feat. Zara Larsson)'],
#  'MØ': ['Final Song'],
#  'Francesco Yates': ['Sugar (feat. Francesco Yates)'],
#  'Kelly Clarkson': ['Since U Been Gone'],
#  'Martin Garrix': ['Like I Do',
#   'Animals',
#   'Turn up the Speakers - Radio Edit',
#   'Forbidden Voices',
#   'Poison',
#   'Forever',
#   'Pizza',
#   'Game Over',
#   'Breach (Walk Alone)',
#   'Yottabyte',
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'In the Name of Love',
#   'Scared to Be Lonely - Acoustic Version',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Scared to Be Lonely',
#   'Ocean (feat. Khalid)',
#   'Like I Do',
#   'High On Life (feat. Bonn)',
#   'There for You',
#   'Burn Out (feat. Dewain Whitmore)'],
#  'Brooks': ['Like I Do', 'Like I Do'],
#  'Jonas Blue': ['Polaroid'],
#  'Liam Payne': ['Polaroid'],
#  'Logic': ['Everyday', 'Everyday'],
#  'Calvin Harris': ['One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix'],
#  'Natasha Bedingfield': ['Unwritten'],
#  "Destiny's Child": ['Survivor'],
#  'Sam And The Womp': ['Bom Bom - Radio Edit'],
#  'Daniel Powter': ['Bad Day'],
#  'Scatman John': ['Scatman (ski-ba-bop-ba-dop-bop)'],
#  'Newton Faulkner': ['Dream Catch Me'],
#  'Baha Men': ['Who Let The Dogs Out'],
#  'Gina G': ['Just a Little Bit - Radio Edit'],
#  'Los Del Rio': ['Macarena'],
#  'Gotye': ['Somebody That I Used To Know'],
#  'Kimbra': ['Somebody That I Used To Know'],
#  'Tomcraft': ['Loneliness - Radio Cut'],
#  'Wheatus': ['Teenage Dirtbag', 'Teenage Dirtbag'],
#  'Chesney Hawkes': ['The One and Only'],
#  'Haddaway': ['What Is Love - 7" Mix', 'What Is Love - 7" Mix'],
#  'Of Monsters and Men': ['Little Talks'],
#  'Jet': ['Are You Gonna Be My Girl'],
#  'Andreas Johnson': ['Glorious'],
#  'Icona Pop': ['I Love It (feat. Charli XCX)'],
#  'Charli XCX': ['I Love It (feat. Charli XCX)'],
#  'Lou Bega': ['Mambo No. 5 (A Little Bit of...)'],
#  'Meredith Brooks': ['Bitch'],
#  'Yolanda Be Cool': ['We No Speak Americano'],
#  'Andrew Stanley': ['We No Speak Americano'],
#  'DCup': ['We No Speak Americano'],
#  'Matt Handles': ['We No Speak Americano'],
#  'Carl Douglas': ['Kung Fu Fighting'],
#  'Iglu & Hartly': ['In This City'],
#  'Rogue Traders': ['Voodoo Child'],
#  'Men Without Hats': ['The Safety Dance'],
#  'Marc Cohn': ['Walking in Memphis'],
#  'The Holloways': ['Generator'],
#  'Nizlopi': ['JCB'],
#  'Nena': ['99 Luftballons'],
#  'Bingo Players': ['Get Up (Rattle) - Radio Edit'],
#  'Faul & Wad': ['Changes - Radio Mix'],
#  'PNAU': ['Changes - Radio Mix'],
#  'Kevin Rudolf': ['Let It Rock'],
#  'Vanessa Carlton': ['A Thousand Miles - Single Version'],
#  'Passenger': ['Let Her Go'],
#  'Joan Osborne': ['One Of Us'],
#  'Ian Carey Project': ['Get Shaky'],
#  'The Buggles': ['Video Killed The Radio Star'],
#  'M.V.P.': ['Roc Ya Body (Mic Check 1, 2)'],
#  'DJ Zinc': ['Roc Ya Body (Mic Check 1, 2)'],
#  'Safri Duo': ['Played-A-Live (The Bongo Song)'],
#  'Rednex': ['Cotton Eye Joe'],
#  'Captain Jack': ['Captain Jack - Short Mix'],
#  'A Touch Of Class': ['Around the World (La La La La La) - Radio Version'],
#  'Pete Konemann': ['Around the World (La La La La La) - Radio Version'],
#  'Kaiser Chiefs': ['Ruby'],
#  'Culcha Candela': ['Hamma! - Single Edit'],
#  'Vengaboys': ['We’re Going to Ibiza!', 'Boom, Boom, Boom, Boom!!'],
#  'Spider Murphy Gang': ['Skandal im Sperrbezirk'],
#  'Throttle': ['Baddest Behaviour', 'Tell Me You Love Me'],
#  'Burak Yeter': ['Ciao Adios - Burak Yeter Remix'],
#  'Jan Delay': ['Oh Jonny'],
#  ...}

# %%
lolla_artists = []
with open("lolla_artists.txt") as f:
    lines = f.readlines()
    for line in lines:
        if line[-1:] == "\n":
            line = line[:-1]
        if line == "":
            continue
        lolla_artists.append(line)

# %%
def check_str_in_list(s, ls, max_dist=1):
    matches = []
    for _s in ls:
        if Levenshtein.distance(s, _s, processor=str.upper) <= max_dist:
            matches.append(_s)
    return matches

# %%
for artist in lolla_artists:
    matches = check_str_in_list(artist, my_artists, max_dist=1)
    if matches != []:
        print(artist)
        for m in matches:
            print("\t", m)
            for song in artists_with_songs[m]:
                print("\t\t", song)
# Out:
# Billie Eilish
# 	 Billie Eilish
# 		 bad guy
# Sabrina Carpenter
# 	 Sabrina Carpenter
# 		 Sue Me
# Lana Del Rey
# 	 Lana Del Rey
# 		 Freak
# Red Hot Chili Peppers
# 	 Red Hot Chili Peppers
# 		 By the Way
# 		 Snow (Hey Oh)
# 		 Californication
# 		 Can't Stop
# Kendrick Lamar
# 	 Kendrick Lamar
# 		 Don't Wanna Know (feat. Kendrick Lamar)
# beabadoobee
# 	 beabadoobee
# 		 death bed (coffee for your head)
# Alan Walker
# 	 Alan Walker
# 		 Alone
# 		 Ignite (feat. SEUNGRI)
# 		 Darkside
# 		 The Spectre
# 		 Sing Me to Sleep
# 		 Strongest (Alan Walker Remix)
# 		 Tired
# 		 Diamond Heart
# 		 All Falls Down (feat. Juliander)
# 		 Faded
# Thirty Seconds to Mars
# 	 Thirty Seconds To Mars
# 		 The Kill
# Diplo
# 	 Diplo
# 		 Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix
# 		 Genius - Lil Wayne Remix
# 		 Close To Me (with Diplo) (feat. Swae Lee)
# 		 Electricity (with Dua Lipa)
# 		 Hey Baby
# Lil Yachty
# 	 Lil Yachty
# 		 Pretender (feat. Lil Yachty & AJR)
# Maggie Rogers
# 	 Maggie Rogers
# 		 Light On
# Dom Dolla
# 	 Dom Dolla
# 		 San Frandisco
# Gorgon City
# 	 Gorgon City
# 		 House Arrest
# Giant Rooks
# 	 Giant Rooks
# 		 Wild Stare
# Sueco
# 	 Sueco
# 		 Paralyzed
# 		 POS
# 		 fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]
# 		 fast
# 		 It Was Fun While It Lasted
# 		 PRIMADONA
# 		 Sober/Hungover (feat. Arizona Zervas)
# 		 Motel 666
# 		 SOS (feat. Travis Barker)
# 		 Toxic Therapy
# 		 Drunk Dial
# 		 Loser
# 		 Hate You Too
# 		 It’s Going Good!
# 		 Today
# 		 Bad Vibes
# 		 Next Ex
# 		 Salt
# 		 AITA
# 		 Funeral
# 		 Up in Smoke
# 		 Last Thing I Do
# 		 Salt
# 		 SOS (feat. Travis Barker)
# 		 Loser
# 		 Sober/Hungover (feat. Arizona Zervas)
# 		 Paralyzed
# Noah Kahan
# 	 Noah Kahan
# 		 Hurt Somebody
# 		 False Confidence
# 		 Hurt Somebody
# Afrojack
# 	 AFROJACK
# 		 Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)
# 		 Ten Feet Tall
# 		 Turn up the Speakers - Radio Edit
# SOFI TUKKER
# 	 Sofi Tukker
# 		 House Arrest
# Tom Odell
# 	 Tom Odell
# 		 Another Love
# Timmy Trumpet
# 	 Timmy Trumpet
# 		 Ininna Tora
# 		 Mad World
# 		 Project X
# 		 Dumb (Feat. BOSS)
# 		 The Anthem (Der Alte)
# 		 Carnival - Dimitri Vegas & Like Mike Edit
# 		 The King
# 		 The Prayer (feat. Zafrir)
# 		 Bleed
# 		 Garden of Madness 2020 Megamix
# 		 Toca
# 		 Flamenco (feat. Rage)
# 		 Mufasa
# 		 The People
# 		 Hava
# 		 Nah Nah
# 		 World At Our Feet
# 		 Wassup (Listen To The Horns)
# 		 Toca (feat. Timmy Trumpet & KSHMR)
# 		 Baddest Behaviour
# 		 Scarborough Fair - Spotify Version
# 		 Rockstar (feat. DV8)
# 		 Nightmare - Radio Edit
# 		 Freaks - Extended Mix
# 		 Freaks - Instrumental Mix
# 		 Freaks - Radio Instrumental
# 		 Mantra
# 		 Hipsta
# 		 Take Your Call
# 		 Deja-Vu - Extended Version
# 		 Deja-Vu
# 		 The Underground
# 		 Booty Shake
# 		 Infinity - Original
# 		 Oracle
# 		 PSY or DIE
# 		 The Prophecy
# 		 Punjabi
# 		 Trumpets
# 		 Freaks - Radio Edit
# 		 Party Till We Die (feat. Andrew W.K.)
# 		 Al Pacino
# 		 Attention
# 		 The Underground - Mix Cut
# 		 Narco
# Portugal. The Man
# 	 Portugal. The Man
# 		 Feel It Still
# 		 Feel It Still
# Peach Pit
# 	 Peach Pit
# 		 Alrighty Aphrodite
# Chri$tian Gate$
# 	 Chri$tian Gate$
# 		 NUMB
# Meduza
# 	 MEDUZA
# 		 Lose Control
# 		 Piece Of Your Heart - Alok Remix
# 		 Piece Of Your Heart
# A Boogie Wit Da Hoodie
# 	 A Boogie Wit da Hoodie
# 		 fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]

# %%
artists_with_songs
# Out:
# {'Jordiz': ['Weekend!'],
#  'Connor Price': ['Start Again', 'Smooth'],
#  'Chloe Sagum': ['Start Again'],
#  'Arrested Youth': ['Brightside', 'Dig'],
#  'YUNGBLUD': ['Tissues',
#   'mars',
#   'I’m a Mess (with YUNGBLUD)',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   'parents',
#   'acting like that (feat. Machine Gun Kelly)',
#   'The Funeral',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)",
#   'Patience (feat. YUNGBLUD & Polo G)'],
#  'SK8': ['Shooting Star (feat. Sum 41)'],
#  'Sum 41': ['Shooting Star (feat. Sum 41)',
#   'With Me',
#   'In Too Deep',
#   'Fat Lip',
#   'Fat Lip',
#   'Still Waiting'],
#  'Sub Zero Project': ['HALO', 'Project X', 'Rockstar (feat. DV8)'],
#  'Kay One': ['Herz aus Stein', 'Senorita'],
#  'strike': ['Calling'],
#  'Ben Nicky': ['We Are The Ravers'],
#  'Olly James': ['We Are The Ravers'],
#  'MC Stretch': ['We Are The Ravers'],
#  'Korsakoff': ['Lyra - Broken Minds Remix'],
#  'Broken Minds': ['Lyra - Broken Minds Remix'],
#  'Machine Gun Kelly': ['bloody valentine',
#   'title track',
#   'Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   "don't sleep, repeat (feat. Machine Gun Kelly)",
#   'bloody valentine - Acoustic',
#   'body bag (feat. YUNGBLUD & Bert McCracken of The Used)',
#   "can't look back",
#   'kevin and barracuda - interlude',
#   'forget me too (feat. Halsey)',
#   'kiss kiss',
#   'concert for aliens',
#   "my ex's best friend (with blackbear)",
#   'hangover cure',
#   'WWIII',
#   "play this when i'm gone",
#   'lonely',
#   'split a pill',
#   'all I know (feat. Trippie Redd)',
#   'Misery Business',
#   'nothing inside (feat. iann dior)',
#   'banyan tree - interlude',
#   'jawbreaker',
#   'drunk face',
#   'papercuts - album edit',
#   'sid & nancy',
#   'die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'make up sex (feat. blackbear)',
#   '9 lives',
#   'twin flame',
#   'god save me',
#   'mainstream sellout',
#   '5150',
#   'drug dealer (feat. Lil Wayne)',
#   'emo girl (feat. WILLOW)',
#   'born with horns',
#   'more than life (feat. glaive)',
#   "fake love don't last (feat. iann dior)",
#   'maybe (feat. Bring Me The Horizon) - acoustic version',
#   'wall of fame - interlude',
#   'ay! (feat. Lil Wayne)',
#   'why are you here',
#   'maybe (feat. Bring Me The Horizon)',
#   'last november',
#   'WW4',
#   'papercuts - live from red rocks',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'twin flame',
#   'Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'ay! (feat. Lil Wayne)',
#   'maybe (feat. Bring Me The Horizon)',
#   'acting like that (feat. Machine Gun Kelly)',
#   'emo girl (feat. WILLOW)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'Sueco': ['Paralyzed',
#   'POS',
#   'fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]',
#   'fast',
#   'It Was Fun While It Lasted',
#   'PRIMADONA',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Motel 666',
#   'SOS (feat. Travis Barker)',
#   'Toxic Therapy',
#   'Drunk Dial',
#   'Loser',
#   'Hate You Too',
#   'It’s Going Good!',
#   'Today',
#   'Bad Vibes',
#   'Next Ex',
#   'Salt',
#   'AITA',
#   'Funeral',
#   'Up in Smoke',
#   'Last Thing I Do',
#   'Salt',
#   'SOS (feat. Travis Barker)',
#   'Loser',
#   'Sober/Hungover (feat. Arizona Zervas)',
#   'Paralyzed'],
#  'Jon Caryl': ['Alone'],
#  "Fresh Til' Death": ['In Too Deep (Firelite Remix)'],
#  'MYLKI': ['In Too Deep (Firelite Remix)'],
#  'Firelite': ['In Too Deep (Firelite Remix)'],
#  'In The Valley Below': ['Peaches'],
#  'Hollywood Undead': ['Whatever It Takes'],
#  'Mac Miller': ['Love Lost', 'The Spins'],
#  'The Temper Trap': ['Love Lost'],
#  'Avril Lavigne': ['I’m a Mess (with YUNGBLUD)',
#   'Love Sux',
#   'Bois Lie (feat. Machine Gun Kelly)',
#   'All I Wanted (feat. Mark Hoppus)',
#   'Bite Me',
#   'Head Above Water',
#   'Sk8er Boi',
#   'Sk8er Boi'],
#  'The Home Team': ["She's Quiet"],
#  'Mayberg': ['Hilferuf'],
#  'Panic! At The Disco': ['The Ballad of Mona Lisa',
#   'Crazy = Genius',
#   'I Write Sins Not Tragedies',
#   'High Hopes'],
#  'Harris & Ford': ['99 Luftballons',
#   'Hard, Style & Volksmusik',
#   'Break the Beat'],
#  'Zombic': ['Human Error'],
#  'Danimal': ['Human Error'],
#  'Influencerz': ['Human Error'],
#  'iann dior': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'nothing inside (feat. iann dior)',
#   "fake love don't last (feat. iann dior)",
#   'Mood (feat. iann dior)'],
#  'Travis Barker': ['Sick and Tired (ft. Machine Gun Kelly and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   'bloody valentine - Acoustic',
#   'Misery Business',
#   'Drop Dead (with Kesha and Travis Barker)',
#   'SOS (feat. Travis Barker)',
#   "I Think I'm OKAY (with YUNGBLUD & Travis Barker)"],
#  'KXXMA': ['Get Shaky', 'Herz an Herz'],
#  'TurboKevin': ['Get Shaky'],
#  'Nic D': ['Serotonin'],
#  'Bryce Vine': ['American Dream', 'The Fall'],
#  'Weezer': ['Beverly Hills'],
#  'The Bangles': ['Eternal Flame'],
#  'Cassyette': ['Sad Girl Summer'],
#  'Tammy Wynette': ['Stand By Your Man - Official Audio'],
#  'Wolfpack': ['Phatt Bass 2016 (Mixed)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'Ocarina'],
#  'Warp Brothers': ['Phatt Bass 2016 (Mixed)'],
#  'NWYR': ['The Lone Ranger'],
#  'W&W': ['The Lone Ranger',
#   'Skydance',
#   'Rave Culture',
#   'Chakra - Wildstylez Remix',
#   'God Is a Girl',
#   'Live the Night',
#   'Long Way Down',
#   "Don't Let Me Down (feat. Daya) - W&W Remix",
#   'Supa Dupa Fly 2018',
#   'How Many',
#   'Rave After Rave',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Crowd Control - Radio Edit',
#   'Arcade Mammoth',
#   'Rave Culture'],
#  'Hoodie Allen': ['Call Me Never'],
#  'Oberg': ['Sun Goes Down', 'Take My Hand'],
#  'Joakim Lundell': ['Sun Goes Down'],
#  'Hardwell': ['PACMAN',
#   'I FEEL LIKE DANCING',
#   'Bigroom Never Dies',
#   'Live the Night',
#   'The Underground',
#   'Bella Ciao',
#   'Power',
#   'Ze Willen Mee',
#   'Out of This Town',
#   'Shine a Light',
#   'This Is Love',
#   "Don't Let Me Down (feat. Daya) - Hardwell & Sephyx Remix",
#   'The Underground - Mix Cut',
#   'Bigroom Never Dies - Mix Cut',
#   'Off The Hook',
#   'Unity'],
#  'YROR?': ['Rotten'],
#  'Ben Joel': ['Rotten'],
#  'Carta': ['EDM'],
#  'Canadian Softball': ['Ohio Is for Emo Kids'],
#  'Cher': ['If I Could Turn Back Time'],
#  'Hardstyle Germany': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'High Level': ['Lalalalala (Hardstyle) - High Level Remix'],
#  'Peach Pit': ['Alrighty Aphrodite'],
#  'Ruby Waters': ['Quantum Physics'],
#  'SEB': ['seaside_demo'],
#  'Jnr Choi': ['TO THE MOON'],
#  'Sam Tompkins': ['TO THE MOON'],
#  'Dubdogz': ['Everybody Wants To Party'],
#  'JØRD': ['Everybody Wants To Party'],
#  'Timmy Trumpet': ['Ininna Tora',
#   'Mad World',
#   'Project X',
#   'Dumb (Feat. BOSS)',
#   'The Anthem (Der Alte)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'The King',
#   'The Prayer (feat. Zafrir)',
#   'Bleed',
#   'Garden of Madness 2020 Megamix',
#   'Toca',
#   'Flamenco (feat. Rage)',
#   'Mufasa',
#   'The People',
#   'Hava',
#   'Nah Nah',
#   'World At Our Feet',
#   'Wassup (Listen To The Horns)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Baddest Behaviour',
#   'Scarborough Fair - Spotify Version',
#   'Rockstar (feat. DV8)',
#   'Nightmare - Radio Edit',
#   'Freaks - Extended Mix',
#   'Freaks - Instrumental Mix',
#   'Freaks - Radio Instrumental',
#   'Mantra',
#   'Hipsta',
#   'Take Your Call',
#   'Deja-Vu - Extended Version',
#   'Deja-Vu',
#   'The Underground',
#   'Booty Shake',
#   'Infinity - Original',
#   'Oracle',
#   'PSY or DIE',
#   'The Prophecy',
#   'Punjabi',
#   'Trumpets',
#   'Freaks - Radio Edit',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Al Pacino',
#   'Attention',
#   'The Underground - Mix Cut',
#   'Narco'],
#  'KSHMR': ['Ininna Tora',
#   'Invisible Children',
#   'The Prayer (feat. Zafrir)',
#   'Over and Out (feat. Charlott Boss)',
#   'Toca',
#   'The People',
#   'My Best Life (feat. Mike Waters)',
#   'Toca (feat. Timmy Trumpet & KSHMR)',
#   'Voices',
#   'Good Vibes Soldier (feat. Head Quattaz)',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Wildcard (feat. Sidnie Tipton)',
#   'Neverland',
#   'Harder',
#   'Carry Me Home (feat. Jake Reese)',
#   'Power',
#   'Memories (feat. Sirah) - Radio Edit',
#   'Opa'],
#  'Mildenhaus': ['Ininna Tora'],
#  'Butterfly Boucher': ['Changes'],
#  'David Bowie': ['Changes',
#   'Heroes - Single Version; 1990 Remaster',
#   'Heroes - 2017 Remaster',
#   'Starman - 2012 Remaster',
#   'Under Pressure'],
#  'Coldplay': ['Paradise',
#   'Fix You',
#   'Hymn for the Weekend',
#   'Viva La Vida',
#   'Yellow',
#   'The Scientist',
#   'Viva La Vida',
#   'Hymn for the Weekend - Seeb Remix',
#   'Viva La Vida',
#   'Something Just Like This'],
#  'Eddie Vedder': ['Brother the Cloud'],
#  'RØRY': ['UNCOMPLICATED'],
#  'HBz': ['Gästeliste +1'],
#  'Royal Blood': ['Trouble’s Coming', 'Figure It Out'],
#  'Mr. Green': ['Welcome'],
#  'Dave East': ['Welcome'],
#  'Xzibit': ['My Name (feat. Eminem & Nate Dogg)'],
#  'Eminem': ['My Name (feat. Eminem & Nate Dogg)',
#   'Stan',
#   "When I'm Gone",
#   'Like Toy Soldiers',
#   'Without Me',
#   'Stan - Live At 43rd Grammy Awards',
#   'Mockingbird',
#   'Lose Yourself - From "8 Mile" Soundtrack',
#   'Sing For The Moment',
#   'Intro',
#   'FACK',
#   'My Name Is',
#   'Shake That',
#   "Cleanin' Out My Closet",
#   'Just Lose It',
#   'Guilty Conscience',
#   'The Real Slim Shady',
#   'The Way I Am',
#   'Venom - Remix',
#   'Kings Never Die',
#   'Love The Way You Lie',
#   'Not Afraid',
#   'Remind Me',
#   'Lose Yourself - From "8 Mile" Soundtrack'],
#  'Nate Dogg': ['My Name (feat. Eminem & Nate Dogg)',
#   'Shake That',
#   'Party We Will Throw Now!'],
#  'jxdn': ['ANGELS & DEMONS'],
#  'Graham Lake': ['Run em Down'],
#  'Avelino': ['Run em Down'],
#  'loafers': ['Lay All Your Love On Me'],
#  'Badjack': ['Lay All Your Love On Me'],
#  'Maxim Schunk': ['Lay All Your Love On Me'],
#  'ABBA': ['Lay All Your Love On Me', 'Super Trouper'],
#  'Mark Dekoda': ['Rave Harder Techno Bass'],
#  'Rnbstylerz': ['Like Wooh Wooh'],
#  'TITUS': ['Love Myself'],
#  'Max Bennett Kelly': ['Happy, Healthy, Well-Adjusted'],
#  'Oliver Tree': ['Let Me Down (feat. blink-182)'],
#  'blink-182': ['Let Me Down (feat. blink-182)',
#   'Scumbag (feat. blink-182)',
#   'Bored To Death',
#   'Sober',
#   "She's Out Of Her Mind",
#   'Ransom',
#   'Black Rain',
#   'Run Away',
#   'Remember To Forget Me',
#   'Pin the Grenade',
#   'Darkside',
#   'The First Time',
#   'Heaven',
#   'Blame It On My Youth',
#   'Happy Days',
#   'I Really Wish I Hated You',
#   'No Heart To Speak Of',
#   'On Some Emo Shit',
#   'Generational Divide',
#   'Hungover You',
#   'Home Is Such A Lonely Place',
#   'California',
#   'Teenage Satellites',
#   'Bored To Death',
#   'Misery',
#   "Can't Get You More Pregnant",
#   'Cynical',
#   'Bored To Death (Acoustic)',
#   "Don't Mean Anything",
#   'Built This Pool',
#   '6/8',
#   'Last Train Home',
#   'Good Old Days',
#   'Sober',
#   'Wildfire',
#   'Bottom Of The Ocean',
#   'Los Angeles',
#   "She's Out Of Her Mind",
#   'The Only Thing That Matters',
#   'Long Lost Feeling',
#   'Rabbit Hole',
#   'Brohemian Rhapsody',
#   'Parking Lot',
#   'No Future',
#   "Hey I'm Sorry",
#   'Left Alone',
#   'Kings of the Weekend',
#   'San Diego',
#   'Go',
#   'Easy Target',
#   'Asthenia',
#   'I Miss You',
#   'The Fallen Interlude',
#   'Obvious',
#   "Here's Your Letter",
#   'Feeling This',
#   'Always',
#   'Stockholm Syndrome Interlude',
#   'Anthem Part Two - Live In Chicago',
#   'Down',
#   'Stockholm Syndrome',
#   'All Of This',
#   'Violence',
#   "I'm Lost Without You",
#   'Every Time I Look For You',
#   'Roller Coaster',
#   'First Date',
#   'Anthem Part Two',
#   'Online Songs',
#   'The Rock Show',
#   'Shut Up',
#   'Stay Together For The Kids',
#   'Reckless Abandon',
#   'Happy Holidays, You Bastard',
#   'Story Of A Lonely Guy',
#   'Give Me One Good Reason',
#   'Please Take Me Home',
#   'Going Away To College',
#   'Anthem',
#   'Dysentery Gary',
#   'Mutt',
#   'Dumpweed',
#   'Wendy Clear',
#   "Don't Leave Me",
#   'The Party Song',
#   'Aliens Exist',
#   "Adam's Song",
#   "What's My Age Again?",
#   'All The Small Things'],
#  'Lustra': ["Scotty Doesn't Know"],
#  't-low': ['We Made It', 'Sehnsucht', 'Crashen'],
#  'Miksu / Macloud': ['We Made It', 'Sehnsucht', 'Nachts wach'],
#  'charlieonnafriday': ['Enough'],
#  'Anastacia': ['Left Outside Alone'],
#  'DaCav5': ['Tetris'],
#  'A Boogie Wit da Hoodie': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Offset': ['fast (Remix) [feat. Offset & A Boogie Wit da Hoodie]'],
#  'Arizona Zervas': ['Sober/Hungover (feat. Arizona Zervas)',
#   'Sober/Hungover (feat. Arizona Zervas)'],
#  'Sunrise Skater Kids': ['All the Old Things'],
#  'Christina Rotondo': ['All the Old Things'],
#  'Chri$tian Gate$': ['NUMB'],
#  'Nxvy': ['Emo Chick'],
#  'ALX8': ['Emo Chick'],
#  'JAY-Z': ['Empire State Of Mind', 'Numb / Encore'],
#  'Alicia Keys': ['Empire State Of Mind'],
#  'makko': ['Nachts wach'],
#  '44phantom': ["don't sleep, repeat (feat. Machine Gun Kelly)"],
#  'Matthias Reim': ['Verdammt, ich lieb Dich - 2020 Remastered'],
#  'Electric Callboy': ['Best Day'],
#  'Sido': ['Best Day',
#   'Liebe',
#   'Tausend Tattoos',
#   'Die Nacht von Freitag auf Montag'],
#  'Labrinth': ['When I R.I.P.',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Jealous'],
#  'The Used': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Bert McCracken': ['body bag (feat. YUNGBLUD & Bert McCracken of The Used)'],
#  'Halsey': ['forget me too (feat. Halsey)',
#   'Sorry',
#   'Eastside (with Halsey & Khalid)',
#   'Closer'],
#  'blackbear': ["my ex's best friend (with blackbear)",
#   'make up sex (feat. blackbear)'],
#  'Trippie Redd': ['all I know (feat. Trippie Redd)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Wake Up Call (feat. Trippie Redd)'],
#  'Gunna': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Young Thug': ['die in california (feat. Gunna, Young Thug & Landon Barker)',
#   'Havana (feat. Young Thug)'],
#  'Landon Barker': ['die in california (feat. Gunna, Young Thug & Landon Barker)'],
#  'Lil Wayne': ['drug dealer (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'ay! (feat. Lil Wayne)',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Let It Rock'],
#  'WILLOW': ['emo girl (feat. WILLOW)', 'emo girl (feat. WILLOW)'],
#  'glaive': ['more than life (feat. glaive)'],
#  'Bring Me The Horizon': ['maybe (feat. Bring Me The Horizon) - acoustic version',
#   'maybe (feat. Bring Me The Horizon)',
#   'maybe (feat. Bring Me The Horizon)',
#   'Can You Feel My Heart',
#   'Throne'],
#  'Mark Hoppus': ['All I Wanted (feat. Mark Hoppus)',
#   'Re-Entry (feat. Mark Hoppus)'],
#  'X Ambassadors': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   'Unsteady'],
#  'Bebe Rexha': ['Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)',
#   "I'm a Mess",
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix',
#   'In the Name of Love'],
#  'Dame': ['Mein Haus'],
#  'Solence': ['Good F**King Music'],
#  'The White Stripes': ['Astro',
#   'Seven Nation Army',
#   'Seven Nation Army',
#   'Icky Thump'],
#  'Stand Atlantic': ['deathwish (feat. nothing,nowhere.)'],
#  'nothing,nowhere.': ['deathwish (feat. nothing,nowhere.)'],
#  'Kode': ['Drunk Texts'],
#  'André De Shields': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Hadestown Original Broadway Company': ['Wait for Me (Reprise)',
#   'Wait for Me'],
#  'Anaïs Mitchell': ['Wait for Me (Reprise)', 'Wait for Me'],
#  'Reeve Carney': ['Wait for Me'],
#  'Jewelle Blackman': ['Wait for Me'],
#  'Yvette Gonzalez-Nacer': ['Wait for Me'],
#  'Kay Trinidad': ['Wait for Me'],
#  'Kimberly Marable': ['Wait for Me'],
#  'Timothy Hughes': ['Wait for Me'],
#  'Malcolm Armwood': ['Wait for Me'],
#  'Jessie Shelton': ['Wait for Me'],
#  'Khaila Wilcoxon': ['Wait for Me'],
#  'Ahmad Simmons': ['Wait for Me'],
#  'Afra Hines': ['Wait for Me'],
#  'T. Oliver Reid': ['Wait for Me'],
#  'John Krause': ['Wait for Me'],
#  'AMIICCA': ['Wait for Me'],
#  'Polo G': ['Martin & Gina', 'Patience (feat. YUNGBLUD & Polo G)'],
#  'Nelly Furtado': ['All Good Things (Come To An End)',
#   'Maneater',
#   'Broken Strings'],
#  'Akros': ['Lie'],
#  'Madonna': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Hung Up - Radio Version'],
#  'Justin Timberlake': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Timbaland': ['4 Minutes (feat. Justin Timberlake & Timbaland)',
#   'Ayo Technology'],
#  'Gabry Ponte': ['Mad World',
#   'Monster',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'AXMO': ['Skydance'],
#  'Giin': ['Skydance', 'Long Way Down'],
#  'Kate Bush': ['Running Up That Hill (A Deal With God)'],
#  'Ion Miles': ['Powerade'],
#  'SIRA': ['Powerade'],
#  'BHZ': ['Powerade'],
#  'Goody Grace': ['Scumbag (feat. blink-182)'],
#  'Jay Hoodie': ['Someone That You Hated'],
#  'Alligatoah': ['Trauerfeier Lied', 'Du bist schön'],
#  'Weedmane 2pac Dr Dre SnoopDogg': ['Bad and Boujee'],
#  'Butterfly Migos': ['Bad and Boujee'],
#  'Crazy Town': ['Bad and Boujee', 'Butterfly', 'Butterfly'],
#  'The Offspring': ['Behind Your Walls',
#   "You're Gonna Go Far, Kid",
#   'Self Esteem',
#   'Want You Bad',
#   "The Kids Aren't Alright"],
#  'Glass Animals': ['Heat Waves', 'Heat Waves'],
#  'We Three': ['Sara'],
#  'Sam Smith': ['Stay With Me', 'Dancing With A Stranger (with Normani)'],
#  'Christopher Lawrence': ['Rush Hour'],
#  'YONAKA': ['Seize the Power'],
#  'One Direction': ['Night Changes'],
#  'Cameron Sanderson': ['What Do You Want?'],
#  '4 Non Blondes': ["What's Up?"],
#  'The Bucketheads': ['The Bomb! (These Sounds Fall Into My Mind) - Radio Edit'],
#  'Vigiland': ['Buss It',
#   'Pong Dance',
#   'Another Shot\u202c\u202c\u202c',
#   'Addicted',
#   'Take This Ride',
#   'Be Your Friend\u202c\u202c',
#   'Never Going Home',
#   'Shots & Squats',
#   'Friday Night\u202c\u202c\u202c',
#   'Nice To Meet You',
#   'UFO - Radio Edit'],
#  'M24': ['Buss It'],
#  'Kraftklub': ['Ein Song reicht',
#   'Ganz schön okay (feat. Kraftklub)',
#   'Ich will nicht nach Berlin',
#   '500 K',
#   'Randale - Live'],
#  'Michael Jackson': ["They Don't Care About Us"],
#  'Des Rocs': ['Hanging by a Thread', 'Let Me Live / Let Me Die'],
#  'The Mysterines': ['Hung Up'],
#  'Bassjackers': ['De La Sol',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'The Fever',
#   'Block',
#   'Derp',
#   'Fireflies (feat. Luciana)',
#   'These Heights (feat. Caroline Pennell)',
#   'Memories (feat. Sirah) - Radio Edit',
#   'The Riddle',
#   'The Riddle - Extended Mix',
#   'Switch',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MAKJ': ['De La Sol',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Knockout',
#   'Party Till We Die (feat. Andrew W.K.)',
#   'Derp'],
#  'flora cash': ['Feeling So Down', "You're Somebody Else"],
#  'Austin George': ['Hands On You'],
#  'Betterov': ['Bring mich nach Hause', 'Viertel vor Irgendwas', 'Dussmann'],
#  'Mother Mother': ['Hayloft II'],
#  'Royal & the Serpent': ['FUCKBOI REJECTS'],
#  'grandson': ['Drop Dead (with Kesha and Travis Barker)', 'Blood // Water'],
#  'Kesha': ['Drop Dead (with Kesha and Travis Barker)',
#   'Good Old Days (feat. Kesha)',
#   'Praying',
#   'TiK ToK',
#   'Right Round (feat. Ke$ha)',
#   'Body Talks (feat. Kesha)'],
#  'Crawlers': ['Come Over (Again)'],
#  'A Day To Remember': ['Re-Entry (feat. Mark Hoppus)'],
#  'Fettes Brot': ['An Tagen wie diesen',
#   'Emanuela',
#   'Schwule Mädchen',
#   'Bettina, zieh dir bitte etwas an',
#   'Emanuela'],
#  'Dallerium': ['How Do I Sleep Now'],
#  'Olive': ['How Do I Sleep Now'],
#  'KUMMER': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Fred Rabe': ['DER LETZTE SONG (ALLES WIRD GUT) (feat. Fred Rabe)'],
#  'Lil Nas X': ['INDUSTRY BABY (feat. Jack Harlow)', 'THATS WHAT I WANT'],
#  'Jack Harlow': ['INDUSTRY BABY (feat. Jack Harlow)'],
#  'Jessie J': ['Wild', 'Price Tag', 'Wild - No Rap Edit', 'Who You Are'],
#  'Sofi Tukker': ['House Arrest'],
#  'Gorgon City': ['House Arrest'],
#  'Pixies': ['Where Is My Mind? - Remastered'],
#  'Nickelback': ['Burn it to the Ground',
#   'How You Remind Me',
#   'How You Remind Me'],
#  'Noah Cyrus': ['July', 'Lonely', 'All Falls Down (feat. Juliander)'],
#  'GAYLE': ['abcdefu', 'abcdefu (angrier)'],
#  'Beartooth': ['Hated'],
#  'Zedline': ['Polozhenie - Zedline Remix'],
#  'Pete Yorn': ['Ever Fallen In Love - From the Motion Picture "Shrek 2"'],
#  'Foreigner': ['I Want to Know What Love Is - 1999 Remaster'],
#  'Lostboi Lino': ['Wenn Du weinst'],
#  'Montez': ['Auf & Ab'],
#  'Scooter': ['Suck My Megamix - The Longest Scooter Single In The World',
#   'How Much Is The Fish?',
#   'Hyper Hyper',
#   'Suck My Megamix - The Longest Scooter Single in the World'],
#  'Tom Walker': ['Leave a Light On', 'Just You and I'],
#  'Van Halen': ["Can't Stop Lovin' You"],
#  'Bowling For Soup': ['Girl All the Bad Guys Want',
#   'Almost',
#   'Right About Now',
#   '1985'],
#  'We Were Promised Jetpacks': ['Quiet Little Voices'],
#  'Kid Cudi': ['Erase Me - Main',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix'],
#  'Kanye West': ['Erase Me - Main',
#   'POWER',
#   'Dark Fantasy',
#   'Stronger',
#   'Gold Digger'],
#  'Dido': ['Stan'],
#  'Elton John': ['Stan - Live At 43rd Grammy Awards'],
#  'Dr. Dre': ['Guilty Conscience'],
#  'Dexys Midnight Runners': ['Come On Eileen'],
#  'Counting Crows': ['Accidentally In Love'],
#  'AC/DC': ["It's a Long Way to the Top (If You Wanna Rock 'N' Roll)",
#   'Highway to Hell',
#   'You Shook Me All Night Long'],
#  'Beach House': ['Take Care'],
#  'Alesso': ['When I’m Gone (with Katy Perry)',
#   'Calling (Lose My Mind) - Radio Edit'],
#  'Katy Perry': ['When I’m Gone (with Katy Perry)',
#   'The One That Got Away - Acoustic',
#   'The One That Got Away - Acoustic',
#   'I Kissed A Girl',
#   'Firework'],
#  'Billy Idol': ['White Wedding',
#   'Dancing with Myself - 2001 Remaster',
#   'Dancing With Myself'],
#  'Generation X': ['Dancing with Myself - 2001 Remaster'],
#  'Slade': ['Merry Xmas Everybody'],
#  'Band Aid 30': ["Do They Know It's Christmas? - 2014"],
#  'Watsky': ['Sloppy Seconds'],
#  'Macklemore': ['Penis Song',
#   'Good Old Days (feat. Kesha)',
#   'Glorious (feat. Skylar Grey)',
#   "Can't Hold Us (feat. Ray Dalton)"],
#  'The Airborne Toxic Event': ['Sometime Around Midnight'],
#  'MOD SUN': ['Internet Killed The Rockstar'],
#  'G-Eazy': ['Still Be Friends (feat. Tory Lanez & Tyga)',
#   'My Year',
#   'Me, Myself & I - Marc Stout & Scott Svejda Remix'],
#  'Tory Lanez': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Tyga': ['Still Be Friends (feat. Tory Lanez & Tyga)'],
#  'Steve Aoki': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Hava',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'Pretender (feat. Lil Yachty & AJR)',
#   'Mayhem',
#   'Be Somebody',
#   'Just Hold On',
#   'Lie To Me',
#   'Pursuit Of Happiness - Extended Steve Aoki Remix',
#   'Azukita (Steve Aoki, Daddy Yankee, Play-N-Skillz & Elvis Crespo) (feat. Elvis Crespo)',
#   'Jaleo',
#   'MIC Drop (Steve Aoki Remix) [Full Length Edition]',
#   'MIC Drop (feat. Desiigner) [Steve Aoki Remix]',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Chris Lake': ['Delirious (Boneless) (feat. Kid Ink)'],
#  'Tujamo': ['Delirious (Boneless) (feat. Kid Ink)',
#   'Grapevine - Tujamo Remix'],
#  'Kid Ink': ['Delirious (Boneless) (feat. Kid Ink)', 'Hey Baby', 'I Love You'],
#  'All Time Low': ['Dear Maria, Count Me In', 'Umbrella'],
#  'The All-American Rejects': ['Dirty Little Secret',
#   'Swing, Swing',
#   'Gives You Hell',
#   'Gives You Hell'],
#  'We The Kings': ['Check Yes, Juliet', 'Sad Song (feat. Elena Coats)'],
#  'Love A': ['Too Doof to Fuck'],
#  'Jules Ahoi': ['Robinson Crusoe'],
#  'Bushido': ['Alles wird gut'],
#  'Warren G': ['Party We Will Throw Now!'],
#  'The Game': ['Party We Will Throw Now!'],
#  'Mumford & Sons': ['Ditmas', 'Little Lion Man', 'I Will Wait'],
#  'Axel Black & White': ['Somebody To Love'],
#  'KSI': ['Holiday',
#   'Keep Up',
#   'Creature',
#   'Loose (feat. KSI)',
#   'Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'Patience (feat. YUNGBLUD & Polo G)',
#   'Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)',
#   'Wake Up Call (feat. Trippie Redd, Tobi & P Money) - Yoshi Remix',
#   'Jump Around',
#   'Touch Down',
#   'Uncontrollable (feat. Big Zuu)',
#   'Down Like That (feat. Rick Ross, Lil Baby & S-X)',
#   'Wake Up Call (feat. Trippie Redd)',
#   'Friends With Benefits (KSI vs MNDM)',
#   'Creature',
#   'Earthquake',
#   'Little Boy',
#   "Adam's Apple",
#   'Lamborghini',
#   'Two Birds, One Stone'],
#  'Donots': ['So Long'],
#  'Frank Turner': ['So Long'],
#  'Red Hot Chili Peppers': ['By the Way',
#   'Snow (Hey Oh)',
#   'Californication',
#   "Can't Stop"],
#  'Powfu': ['death bed (coffee for your head)'],
#  'beabadoobee': ['death bed (coffee for your head)'],
#  'Edwin Rosen': ['leichter//kälter'],
#  'Thees Uhlmann': ['Zum Laichen und Sterben ziehen die Lachse den Fluss hinauf'],
#  'Blond': ['Match'],
#  'Saint Motel': ['My Type'],
#  'Philipp Poisel': ['Wie soll ein Mensch das ertragen',
#   'Mein Amerika',
#   'Erkläre mir die Liebe',
#   'Ich will nur - Live',
#   'Liebe meines Lebens',
#   'Wolke 7',
#   'Wie soll ein Mensch das ertragen'],
#  'DJ Gollum': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Scarlet': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'DJ THT': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Ced Tecknoboy': ['Poison - DJ THT & Ced Tecknoboy Radio Edit'],
#  'Tate McRae': ['you broke me first'],
#  'Razz': ['Youth & Enjoyment'],
#  'Twenty One Pilots': ['Addict With A Pen'],
#  'Quietdrive': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'Droo Hastings From Drrt': ['No Sleep (feat. Droo Hastings From Drrt)'],
#  'P!nk': ['Try',
#   'Walk Me Home',
#   'Raise Your Glass',
#   'So What',
#   'What About Us - Cash Cash Remix'],
#  'NF': ['Lie', 'Paralyzed', 'Let You Down'],
#  'Emil Bulls': ['The Jaws of Oblivion'],
#  'ANA': ['Whiskey'],
#  '100 Kilo Herz': ['Laternensong'],
#  'The Weeknd': ['Save Your Tears', 'Blinding Lights', 'The Hills'],
#  'Die Toten Hosen': ['Oberhausen',
#   'Vogelfrei',
#   'Herz brennt',
#   'Steh auf, wenn du am Boden bist',
#   'Auswärtsspiel',
#   'Hier kommt Alex',
#   'Bonnie & Clyde',
#   'Wannsee',
#   'Alles passiert',
#   'Alles aus Liebe'],
#  'Jennifer Rostock': ['K.B.A.G.', 'Alles Cool', 'Hengstin'],
#  'Rainbirds': ['Blueprint'],
#  'Bananafishbones': ['für immer', 'Vanessa'],
#  'Ran-D': ['Zombie - Original Mix'],
#  'Dvbbs': ['Raveology'],
#  'VINAI': ['Raveology', 'Break the Beat', 'Out of This Town'],
#  'Emily Watts': ['La Vie En Rose'],
#  'Metro Station': ['Shake It', 'Shake It'],
#  'Neonschwarz': ['On a Journey'],
#  'The Vamps': ['Somebody To You'],
#  'Kina': ['Can We Kiss Forever?'],
#  'Adriana Proenza': ['Can We Kiss Forever?'],
#  'Alec Benjamin': ['Let Me Down Slowly'],
#  'The Fray': ['You Found Me', 'How to Save a Life'],
#  'Ida Corr': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Fedde Le Grand': ['Let Me Think About It - Radio Edit',
#   'Let Me Think About It (Celebration Mix)'],
#  'Iggy Pop': ['Lust For Life'],
#  'Olivia Rodrigo': ['All I Want', 'good 4 u', 'drivers license'],
#  'Disney': ['All I Want'],
#  'Sarah Connor': ['Wie schön du bist', 'Vincent'],
#  'Ed Sheeran': ['Bad Habits',
#   'Galway Girl',
#   'Castle on the Hill',
#   'Perfect - Robin Schulz Remix',
#   'Photograph',
#   'Happier - Tiësto’s AFTR:HRS Remix'],
#  'Lukas Graham': ['Mama Said'],
#  'Drake': ['One Dance', "God's Plan"],
#  'Wizkid': ['One Dance'],
#  'Kyla': ['One Dance'],
#  'The Kid LAROI': ['STAY (with Justin Bieber)'],
#  'Justin Bieber': ['STAY (with Justin Bieber)'],
#  'Lost Frequencies': ['Love to Go',
#   'Reality',
#   'Reality - Gestört aber GeiL Remix',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Anymore - Lost Frequencies Remix',
#   'Are You With Me - Radio Edit',
#   'Are You With Me - Gestört aber GeiL Remix',
#   'Melody',
#   'So Much Better - Lost Frequencies Remix',
#   'Paris - Lost Frequencies Remix',
#   'Crazy',
#   'Run - Lost Frequencies Radio Edit',
#   'Here with You',
#   'Beautiful Life',
#   'Are You with Me',
#   'Melody',
#   'Like I Love You',
#   'Reality - Gestört aber GeiL Remix',
#   'Are You with Me - Gestört aber GeiL Remix'],
#  'Zonderling': ['Love to Go', 'Crazy'],
#  'Kelvin Jones': ['Love to Go'],
#  'Lipps Inc.': ['Funkytown'],
#  'Cheap Trick': ['Just Got Back'],
#  'Hot Chocolate': ["Every 1's a Winner - Single Version"],
#  'Juju': ['Vermissen (feat. Henning May)'],
#  'Henning May': ['Vermissen (feat. Henning May)'],
#  'Tobi & Manny': ['Rhythm & Vibes',
#   'Destined For Greatness',
#   'Destined For Greatness'],
#  'Irie Révoltés': ['Fäuste hoch'],
#  'Robbie Williams': ['Candy', 'Angels', 'Rock DJ'],
#  'Florence + The Machine': ['Shake It Out'],
#  'Papa Roach': ['Scars', 'Help'],
#  'Radical Face': ['Welcome Home, Son', 'Welcome Home'],
#  'Radiohead': ['Fake Plastic Trees', 'Creep'],
#  'Masked Wolf': ['Astronaut In The Ocean'],
#  'Neil Patrick Harris': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'How I Met Your Mother Cast': ['Nothin\' Suits Me Like a Suit - From "How I Met Your Mother: Season 5"'],
#  'Tom Petty': ["Free Fallin'"],
#  'Julia Michaels': ['All Your Exes',
#   'Hurt Somebody',
#   'Into You',
#   'Lie To Me (feat. Julia Michaels)',
#   'Hurt Somebody'],
#  'Måneskin': ['I WANNA BE YOUR SLAVE'],
#  'Noah Kahan': ['Hurt Somebody', 'False Confidence', 'Hurt Somebody'],
#  'Provinz': ['Chaos'],
#  'Tai Verdes': ['Stuck In The Middle'],
#  'Dua Lipa': ['Levitating (feat. DaBaby)',
#   'Physical - Alok Remix',
#   'Electricity (with Dua Lipa)',
#   'IDGAF',
#   'One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   'Scared to Be Lonely - Acoustic Version',
#   'Scared to Be Lonely'],
#  'DaBaby': ['Levitating (feat. DaBaby)', 'ROCKSTAR (feat. Roddy Ricch)'],
#  'Harry Styles': ['Falling', 'Watermelon Sugar', 'Sign of the Times'],
#  'Finn': ['In Luv With U'],
#  'The Neighbourhood': ['Sweater Weather'],
#  'Moby': ['Extreme Ways', 'Lift Me Up'],
#  'Da Tweekaz': ['Heroes Of Today', 'D.W.X. (10 Years Dirty Workz Mix)'],
#  'Riverdale Cast': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Ashleigh Murray': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Camila Mendes': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Madelaine Petsch': ['Jailhouse Rock (feat. Camila Mendes, Ashleigh Murray & Madelaine Petsch)',
#   'Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Asha Bromfield': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'Hayley Law': ['Milkshake (feat. Ashleigh Murray, Asha Bromfield, Hayley Law & Madelaine Petsch)'],
#  'KJ Apa': ['Kids in America (feat. KJ Apa & Camila Mendes)'],
#  'Kelis': ['Milkshake'],
#  'Juice WRLD': ['Lucid Dreams', 'Come & Go (with Marshmello)'],
#  'ElyOtto': ['SugarCrash!'],
#  'Basstrologe': ['Somebody To Love'],
#  'Marlon Roudette': ['New Age'],
#  'Tears For Fears': ['Shout'],
#  'Prinz Pi': ['Letzte Liebe', 'Kompass ohne Norden', '1,40m'],
#  'Roddy Ricch': ['ROCKSTAR (feat. Roddy Ricch)'],
#  'Bonnie Tyler': ['Holding Out for a Hero - From "Footloose" Soundtrack'],
#  'Marshmello': ['Come & Go (with Marshmello)',
#   'Here With Me',
#   'BIBA',
#   'Everyday',
#   'FRIENDS',
#   'Danger (with Migos & Marshmello)',
#   'Wolves',
#   'Alone',
#   'Bayen Habeit',
#   'Happier',
#   'You Can Cry',
#   'Everyday',
#   'Spotlight',
#   'Silence'],
#  'A$ton Wyld': ['Next Level'],
#  'Jme': ['Keep Up'],
#  'S1mba': ['Loose (feat. KSI)'],
#  'Craig David': ['Really Love (feat. Craig David & Digital Farm Animals)'],
#  'Digital Farm Animals': ['Really Love (feat. Craig David & Digital Farm Animals)',
#   "Don't Play",
#   'All Falls Down (feat. Juliander)'],
#  'Anne-Marie': ["Don't Play",
#   '2002',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Ciao Adios - Burak Yeter Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'FRIENDS'],
#  'Zedd': ['The Middle', 'The Middle', 'Beautiful Now', 'Happy Now'],
#  'Maren Morris': ['The Middle', 'GIRL', 'The Middle'],
#  'Grey': ['The Middle', 'The Middle'],
#  '24kGoldn': ['Mood (feat. iann dior)'],
#  'Our Last Night': ['drivers license'],
#  'Creedence Clearwater Revival': ['Fortunate Son'],
#  'Mark Ronson': ['Valerie (feat. Amy Winehouse) - Version Revisited',
#   'Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Electricity (with Dua Lipa)'],
#  'Amy Winehouse': ['Valerie (feat. Amy Winehouse) - Version Revisited'],
#  'Cornershop': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'Norman Cook': ['Brimful of Asha - Norman Cook Remix Single Version',
#   'Brimful of Asha - Norman Cook Remix'],
#  'NEIKED': ['Sexual'],
#  'Dyo': ['Sexual'],
#  'Capital Cities': ['Safe And Sound'],
#  'George Ezra': ['Hold My Girl', 'Paradise'],
#  'Vance Joy': ['Mess Is Mine'],
#  'Lil Glock Rouge': ['Merry Merry Christmas'],
#  'Sidemen': ['Merry Merry Christmas', 'The Gift'],
#  'Linkin Park': ['Shadow of the Day',
#   'CASTLE OF GLASS',
#   'Numb / Encore',
#   'In the End',
#   'Numb'],
#  'Duncan Laurence': ['Arcade'],
#  'flipturn': ['Chicago'],
#  'Ava Max': ['Kings & Queens',
#   'Sweet but Psycho',
#   'Let It Be Me (feat. Ava Max)'],
#  'Camila Cabello': ['Havana (feat. Young Thug)'],
#  'Silbermond': ['Irgendwas bleibt'],
#  'Jaymes Young': ["I'll Be Good"],
#  'Blue October': ['Hate Me'],
#  'Pickle': ['Sing It'],
#  'Endor': ['Pump It Up'],
#  'Outkast': ['Roses', 'Ms. Jackson'],
#  'Otto Knows': ['Million Voices - Radio Edit'],
#  'Jetta': ["I'd Love To Change The World - Matstubs Remix"],
#  'Matstubs': ["I'd Love To Change The World - Matstubs Remix"],
#  'John Newman': ['Love Me Again'],
#  'Rihanna': ['Disturbia', 'Stay', 'Love The Way You Lie', 'Live Your Life'],
#  'Die Firma': ['Die Eine 2005'],
#  'The Smiths': ['Asleep - 2011 Remaster'],
#  'Edward Sharpe & The Magnetic Zeros': ['Home'],
#  'lovelytheband': ['broken'],
#  'Johnny Cash': ['Hurt'],
#  'James Bay': ['Hold Back The River'],
#  'BANNERS': ['Shine A Light', 'Someone To You', 'Ghosts'],
#  'U2': ['Bad - Remastered 2009',
#   'Beautiful Day',
#   'With Or Without You - Remastered'],
#  'Casper': ['Ganz schön okay (feat. Kraftklub)', 'So perfekt'],
#  'Lewis Capaldi': ['Someone You Loved', 'Bruises'],
#  'Chip Taylor': ['On the Radio (Music from the Netflix Original Series Sex Education)'],
#  'Jerome': ['Light'],
#  'DVBBS': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Dropgun': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Sanjin': ['Pyramids (feat. Sanjin) - Radio Mix'],
#  'Emeli Sandé': ['Clown', 'Read All About It, Pt. III'],
#  'Gwen Stefani': ['Kings Never Die', 'Hollaback Girl'],
#  '5 Seconds of Summer': ['She Looks So Perfect',
#   'Youngblood',
#   'Lie To Me (feat. Julia Michaels)',
#   'Youngblood - R3HAB Remix'],
#  'GAMPER & DADONI': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Emily Roberts': ['Bittersweet Symphony (feat. Emily Roberts)'],
#  'Purple Disco Machine': ['Exotica', 'Hypnotized'],
#  'Mind Enterprises': ['Exotica'],
#  'Fritz Kalkbrenner': ['Good Things', 'Sky and Sand'],
#  'Martin Solveig': ['All Stars'],
#  'ALMA': ['All Stars'],
#  'AWOLNATION': ['Sail'],
#  'Sophie and the Giants': ['Hypnotized'],
#  'Neptunica': ['San Francisco'],
#  'Ellipso': ['San Francisco'],
#  'Emy Perez': ['San Francisco'],
#  'Chord Overstreet': ['Hold On'],
#  'Dimitri Vegas & Like Mike': ['Body Talk (feat. Julian Perretta)',
#   'The Anthem (Der Alte)',
#   'Beast (All as One)',
#   'Carnival - Dimitri Vegas & Like Mike Edit',
#   'Garden of Madness 2020 Megamix',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'Wakanda',
#   'Mammoth',
#   'Ocarina',
#   'The Hum - Original Mix',
#   'Arcade - Original Mix',
#   'Arcade - Radio Edit',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix',
#   'Hey Baby',
#   'All Aboard - Dimitri Vegas & Like Mike Edit',
#   'Ready For Action',
#   'He\'s a Pirate (VIP Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate (Extended Mix) - From "Pirates of the Caribbean: Salazar\'s Revenge" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'He\'s a Pirate - From "Pirates of the Caribbean: Dead Men Tell No Tales" / Hans Zimmer vs Dimitri Vegas & Like Mike',
#   'Complicated (feat. Kiiara)',
#   'Crowd Control - Radio Edit',
#   'Slow Down (feat. Boef, Ronnie Flex, Ali B & I Am Aisha)',
#   'Patser Bounce',
#   'The House Of House',
#   'All I Need (with Gucci Mane)',
#   'When I Grow Up (feat. Wiz Khalifa)',
#   'Unity',
#   'Here We Go (Hey Boy, Hey Girl)',
#   'Opa',
#   'Arcade Mammoth',
#   'All I Need (feat. Gucci Mane) - DVLM X Bassjackers VIP MIX',
#   'The Jungle',
#   'Bounce (feat. Snoop Dogg)'],
#  'MOGUAI': ['Body Talk (feat. Julian Perretta)', 'Mammoth', 'Arcade Mammoth'],
#  'Julian Perretta': ['Body Talk (feat. Julian Perretta)'],
#  'Krunk!': ['La Menta', 'Al Pacino'],
#  'Max Herre': ['Wolke 7'],
#  'Revolverheld': ['Halt dich an mir fest'],
#  'David Guetta': ['Where Them Girls At (feat. Nicki Minaj & Flo Rida)',
#   "Club Can't Handle Me (feat. David Guetta)",
#   'Let It Be Me (feat. Ava Max)',
#   'Flames',
#   "Don't Leave Me Alone (feat. Anne-Marie)",
#   'Like I Do',
#   'Titanium (feat. Sia)',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Like I Do',
#   'Complicated (feat. Kiiara)'],
#  'Sean Paul': ['Temperature'],
#  'Toploader': ['Dancing in the Moonlight'],
#  'Bruce Springsteen': ['Dancing In the Dark'],
#  'Lister': ['Pathways'],
#  'The Lumineers': ['Ophelia'],
#  'Vinnie Paz': ['The Ghost I Used to Be'],
#  'Eamon': ['The Ghost I Used to Be'],
#  'Elena Coats': ['Sad Song (feat. Elena Coats)'],
#  'Dean Lewis': ['Half A Man'],
#  'Pitbull': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Back in Time - featured in "Men In Black 3"',
#   'Bailar (feat. Pitbull & Elvis Crespo)'],
#  'Ne-Yo': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'AFROJACK': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)',
#   'Ten Feet Tall',
#   'Turn up the Speakers - Radio Edit'],
#  'Nayer': ['Give Me Everything (feat. Ne-Yo, Afrojack & Nayer)'],
#  'Coone': ['D.W.X. (10 Years Dirty Workz Mix)',
#   'Words From The Gang (2014 Remix) - Radio Version',
#   'Pump up the Jam'],
#  'Imagine Dragons': ["It's Time",
#   'On Top Of The World',
#   'Thunder',
#   'Thunder',
#   'Radioactive',
#   'Thunder',
#   'Believer - Kaskade Remix'],
#  'Lord Huron': ['The Night We Met'],
#  'Tungevaag': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'Wicked Wonderland',
#   'All For Love - Luca Schreiner Remix'],
#  'Raaban': ['Samsara (feat. Emila)',
#   'All For Love',
#   'Hey Baby (feat. A7S)',
#   'All For Love - Luca Schreiner Remix'],
#  'Emila': ['Samsara (feat. Emila)'],
#  'Brynny': ['Thinking Too Much'],
#  'DJ Antoine': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'The Beatshakers': ['Ma Chérie - DJ Antoine Vs Mad Mark 2K12 Radio Edit'],
#  'Herbert Grönemeyer': ['Glück', 'Flugzeuge im Bauch'],
#  'Elliott Smith': ['Say Yes', 'Say Yes'],
#  'Gloria Gaynor': ['I Will Survive - Single Version'],
#  'Good Charlotte': ['I Just Wanna Live',
#   'The River',
#   'Girls & Boys',
#   'Lifestyles of the Rich & Famous'],
#  'Frittenbude': ['Mindestens in 1000 Jahren'],
#  'Jessica Ricca': ["Hey It’s Delilah (Plain White T's Cover)"],
#  'Adele': ['Someone Like You', 'When We Were Young'],
#  'LUM!X': ['Monster'],
#  'Rosa Anschütz': ['Rigid - Kobosil 44 Rush Mix'],
#  'Kobosil': ['Rigid - Kobosil 44 Rush Mix'],
#  'Stanfour': ['Wishing You Well - Radio Version'],
#  'Bloodhound Gang': ['Uhn Tiss Uhn Tiss Uhn Tiss',
#   'The Ballad Of Chasey Lain',
#   'The Bad Touch',
#   'Foxtrot Uniform Charlie Kilo'],
#  'Drunkenmunky': ['E'],
#  'ZAYN': ['Dusk Till Dawn (feat. Sia) - Radio Edit'],
#  'Sia': ['Dusk Till Dawn (feat. Sia) - Radio Edit',
#   'The Greatest',
#   'Genius (feat. Sia, Diplo, and Labrinth) - Lil Wayne Remix',
#   'Genius - Lil Wayne Remix',
#   'Flames',
#   'Titanium (feat. Sia)'],
#  'Diddy - Dirty Money': ['Coming Home'],
#  'Skylar Grey': ['Coming Home', 'Glorious (feat. Skylar Grey)'],
#  'Snow Patrol': ['Called Out In The Dark',
#   'Chasing Cars',
#   'Chasing Cars',
#   'Chasing Cars'],
#  'B.o.B': ['Price Tag', 'Airplanes (feat. Hayley Williams of Paramore)'],
#  'David Gray': ["This Year's Love"],
#  'The Who': ["Baba O'Riley"],
#  'Broilers': ['Tanzt du noch einmal mit mir?'],
#  'Route 94': ['My Love (feat. Jess Glynne)'],
#  'Jess Glynne': ['My Love (feat. Jess Glynne)', 'Take Me Home'],
#  'My Chemical Romance': ['The Only Hope for Me Is You',
#   "I Don't Love You",
#   'Disenchanted - Live Demo',
#   'Kill All Your Friends - Live Demo',
#   'All the Angels - Live Demo',
#   'House of Wolves - Version 2; Live Demo',
#   'Famous Last Words',
#   'Cancer',
#   'Party at the End of the World - Live Demo',
#   'Dead!',
#   'Emily - Rough Mix',
#   'Not That Kind of Girl - Live Demo',
#   'The Five of Us Are Dying - Rough Mix',
#   'House of Wolves',
#   'The Sharpest Lives',
#   'Sleep',
#   'Blood - Hidden Track',
#   'Disenchanted',
#   'Teenagers',
#   'House of Wolves - Version 1; Live Demo',
#   'Mama - Live Demo',
#   'Welcome to the Black Parade',
#   'Mama',
#   'The End.',
#   'My Way Home Is Through You - Live Demo',
#   'This Is How I Disappear',
#   'Vampire Money',
#   'DESTROYA',
#   'The Only Hope for Me Is You',
#   'Goodnite, Dr. Death',
#   'Party Poison',
#   'Look Alive, Sunshine',
#   'SING',
#   'Bulletproof Heart',
#   'Jet-Star and the Kobra Kid / Traffic Report',
#   "Save Yourself, I'll Hold Them Back",
#   'Planetary (GO!)',
#   'S/C/A/R/E/C/R/O/W',
#   'The Kids from Yesterday',
#   'Summertime',
#   'Welcome to the Black Parade - Steve Aoki 10th Anniversary Remix',
#   'Drowning Lessons',
#   'Cubicles',
#   'Romance',
#   'Demolition Lovers',
#   'This Is the Best Day Ever',
#   'Early Sunsets Over Monroeville',
#   'Skylines and Turnstiles',
#   'Our Lady of Sorrows',
#   'Headfirst for Halos',
#   "Honey, This Mirror Isn't Big Enough for the Two of Us",
#   'Vampires Will Never Hurt You',
#   'Thank You for the Venom',
#   "Give 'Em Hell, Kid",
#   'To the End',
#   "Hang 'Em High",
#   'Cemetery Drive',
#   "It's Not a Fashion Statement, It's a Deathwish",
#   'Interlude',
#   'You Know What They Do to Guys Like Us in Prison',
#   'I Never Told You What I Do for a Living',
#   'The Jetset Life Is Gonna Kill You',
#   'This Is How I Disappear',
#   'Dead!',
#   'Blood - Hidden Track',
#   'The Sharpest Lives',
#   'Sleep',
#   'Disenchanted',
#   'The End.',
#   'House of Wolves',
#   'Kill All Your Friends',
#   'Cancer',
#   'Mama',
#   'The Ghost of You',
#   'Famous Last Words',
#   "I Don't Love You",
#   'Helena',
#   'Welcome to the Black Parade',
#   "I'm Not Okay (I Promise)",
#   'Na Na Na (Na Na Na Na Na Na Na Na Na)',
#   'Teenagers',
#   'Fake Your Death'],
#  'James Arthur': ['Can I Be Him', 'You Can Cry'],
#  'Thomas Rhett': ['Die A Happy Man'],
#  'Anis Don Demina': ['Uno Dos Tres Shurda'],
#  'VOLAC': ['In A Club'],
#  'illusionize': ['In A Club'],
#  'Andre Longo': ['In A Club'],
#  'Popp & Popp': ['Lieblingsfarbe Sonne'],
#  'Flowa': ['Lieblingsfarbe Sonne'],
#  'Neelix': ['You',
#   'Before - Neelix Well Done Remix',
#   'Waterfall',
#   'Makeup (feat. Caroline Harrison)',
#   'Looking Like We Usually Look',
#   'Mosquito',
#   'The Sun',
#   'Angels of Destruction - Neelix Remix',
#   'Expect What',
#   'History',
#   '1000 Sterne'],
#  'AJR': ["I'm Ready", '100 Bad Days', 'Pretender (feat. Lil Yachty & AJR)'],
#  'Calum Scott': ['Dancing On My Own',
#   'Dancing On My Own',
#   'Dancing On My Own - Tiësto Remix'],
#  'Hayley Williams': ['Airplanes (feat. Hayley Williams of Paramore)'],
#  'You Me At Six': ['Underdog'],
#  'Mattafix': ['Big City Life'],
#  'Wrabel': ['Ten Feet Tall', 'Written in the Scars (feat. Wrabel)'],
#  'Yeah Yeah Yeahs': ['Heads Will Roll - A-Trak Remix'],
#  'A-Trak': ['Heads Will Roll - A-Trak Remix'],
#  'DJ Blyatman': ['Gopnik'],
#  'Dom Dolla': ['San Frandisco'],
#  'Ricky Desktop': ['The Banjo Beat, Pt. 1'],
#  'Nathan Dawe': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Lighter (feat. KSI)'],
#  'Ella Henderson': ['Lighter (feat. KSI & Ella Henderson) - Acoustic',
#   'Yours'],
#  'Boyce Avenue': ['The One That Got Away'],
#  'Armin van Buuren': ['You Are',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix',
#   'Blah Blah Blah - Bassjackers Remix',
#   'Turn It Up',
#   'Blah Blah Blah',
#   'Great Spirit',
#   'In And Out of Love - Lost Frequencies Extended Remix',
#   'Blah Blah Blah',
#   'Therapy',
#   'This Is What It Feels Like',
#   'Drowning - Avicii Remix',
#   'United',
#   'Sunny Days',
#   'Wild Wild Son',
#   'Another You',
#   'Off The Hook'],
#  'Sunnery James & Ryan Marciano': ['You Are'],
#  'Will Sparks': ['My Spine Is Tingling',
#   '#SELFIE - Will Sparks Remix',
#   '#Selfie - Will Sparks Remix',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Take Me (feat. Gloria Kim)',
#   'Sick Like That (feat. Luciana)',
#   'Ah Yeah So What - Radio Edit',
#   'Senseless',
#   'Leave The Lights On - Will Sparks Remix',
#   'My Time',
#   'Voices'],
#  'Luciana': ['My Spine Is Tingling',
#   'Sick Like That',
#   'Bad Connection',
#   'Gorilla',
#   'Flakka Flakka',
#   'Sick Like That (feat. Luciana)',
#   'Fireflies (feat. Luciana)'],
#  'Sonar': ['Sonar'],
#  'SCNDL': ['Sonar', 'Bleed'],
#  'Mikky Ekko': ['Stay'],
#  'Alok': ["Don't Ya - Fabio Fusco Remix",
#   'Physical - Alok Remix',
#   'Piece Of Your Heart - Alok Remix',
#   'United'],
#  'FractaLL': ["Don't Ya - Fabio Fusco Remix"],
#  'Bea Jourdan': ["Don't Ya - Fabio Fusco Remix"],
#  'Fabio Fusco': ["Don't Ya - Fabio Fusco Remix"],
#  'Tiësto': ['God Is A Dancer - James Hype Remix',
#   'Grapevine - Tujamo Remix',
#   'On My Way',
#   'Happier - Tiësto’s AFTR:HRS Remix',
#   'BOOM',
#   'Dancing On My Own - Tiësto Remix',
#   'WOW',
#   'Jackie Chan',
#   'Red Lights',
#   'Split (Only U)',
#   'Carry You Home',
#   'Secrets',
#   'Secrets - Radio Edit',
#   'Harder'],
#  'Mabel': ['God Is A Dancer - James Hype Remix'],
#  'James Hype': ['God Is A Dancer - James Hype Remix'],
#  'Chiddy Bang': ['Opposite of Adults'],
#  'Tigerlily': ['Invisible Children', 'Spice Temple - Overdrive Remix'],
#  'BOSS': ['Dumb (Feat. BOSS)', 'Over and Out (feat. Charlott Boss)'],
#  'Mike Williams': ['Wait Another Day', 'The Beat', 'Lullaby'],
#  'Mesto': ['Wait Another Day'],
#  'Angels & Airwaves': ['Surrender',
#   'Chasing Shadows',
#   'The Adventure',
#   'Surrender'],
#  'R3HAB': ['Flashlight',
#   'Wrong Move (feat. Olivia Holt)',
#   'Rumors',
#   'Radio Silence',
#   'Tequila - R3HAB Remix',
#   'Starflight',
#   'Youngblood - R3HAB Remix',
#   'Lullaby',
#   'One Kiss (with Dua Lipa) - R3HAB Remix',
#   "Don't Leave Me Alone (feat. Anne-Marie) - R3HAB Remix",
#   'Freak',
#   "I Just Can't"],
#  'Deorro': ['Flashlight',
#   'Melbourne Bounce - Deorro Remix',
#   'Bootie in Your Face - No Rock Drop',
#   'Focus',
#   'Focus (feat. Lena Leon)',
#   'Shakalaka (Steve Aoki, Deorro, MAKJ & Max Styler)',
#   'I Can Be Somebody (feat. Erin McCarley)',
#   'Bailar (feat. Pitbull & Elvis Crespo)',
#   'Bailar (feat. Elvis Crespo) - Radio Edit',
#   'Five More Hours',
#   'DFTF',
#   'Perdoname (feat. DyCy & Adrian Delgado)',
#   'Tell Me Lies (feat. Lesley Roy)',
#   'Five Hours',
#   'Knockout'],
#  'Von Wegen Lisbeth': ['Bitch'],
#  'Showtek': ['Booyah - Radio Edit', 'We Like to Party - Original Mix'],
#  'We Are Loud': ['Booyah - Radio Edit'],
#  'Sonny Wilson': ['Booyah - Radio Edit'],
#  'Club Madness': ['Pumped Up Kicks - Smithee Hard Edit'],
#  'Snoop Dogg': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Hollywood (feat. Snoop Dogg & Jamie Principle)',
#   'Bounce (feat. Snoop Dogg)'],
#  'Wiz Khalifa': ['Young, Wild & Free (feat. Bruno Mars)',
#   "Don't Kill My High (feat. Wiz Khalifa & Social House)",
#   'Payphone',
#   'When I Grow Up (feat. Wiz Khalifa) - Eastblock Bitches Remix',
#   'When I Grow Up (feat. Wiz Khalifa)'],
#  'Bruno Mars': ['Young, Wild & Free (feat. Bruno Mars)',
#   'Finesse - Remix; feat. Cardi B'],
#  'Ummet Ozcan': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Change My Heart',
#   'The Hum - Short Edit',
#   'The Hum - Original Mix',
#   'Melody - Radio Mix',
#   'Melody - Extended Mix'],
#  'Brennan Heart': ['Beast (All as One)',
#   'Garden of Madness 2020 Megamix',
#   'Blah Blah Blah - Brennan Heart & Toneshifterz Remix'],
#  'Keane': ['Somewhere Only We Know'],
#  'Curtis Waters': ["Stunnin' (feat. Harm Franklin)"],
#  'Harm Franklin': ["Stunnin' (feat. Harm Franklin)"],
#  'Ali As': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Namika': ['Lass sie tanzen (Square Dance) - Megaloh & Trettmann Remix'],
#  'Gnarls Barkley': ['Crazy'],
# ...
#  'The Prince Karma': ['Later Bitches'],
#  'Ozzy Osbourne': ["Mama, I'm Coming Home", 'Dreamer'],
#  'Boston': ['More Than a Feeling'],
#  'Fall Out Boy': ["This Ain't A Scene, It's An Arms Race",
#   "Sugar, We're Goin Down",
#   'Centuries',
#   "I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'The Last Of The Real Ones'],
#  'Fitz and The Tantrums': ['HandClap'],
#  'Die Ärzte': ['Ist das noch Punkrock?', 'Deine Schuld'],
#  'Kodaline': ['All I Want'],
#  'Green Day': ['Holiday',
#   'Holiday / Boulevard of Broken Dreams',
#   'Still Breathing',
#   'When I Come Around',
#   'Boulevard of Broken Dreams',
#   'Wake Me up When September Ends',
#   'Welcome to Paradise',
#   'Basket Case',
#   'Good Riddance (Time of Your Life)',
#   'American Idiot',
#   'Restless Heart Syndrome',
#   'East Jesus Nowhere',
#   '21st Century Breakdown',
#   "Christian's Inferno",
#   'Before the Lobotomy',
#   'The Static Age',
#   'American Eulogy: Mass Hysteria / Modern World',
#   '¿Viva La Gloria? (Little Girl)',
#   'Horseshoes and Handgrenades',
#   'Murder City',
#   '¡Viva La Gloria!',
#   'Last of the American Girls',
#   'Last Night on Earth',
#   'See the Light',
#   'Peacemaker',
#   'Know Your Enemy',
#   '21 Guns',
#   'Song of the Century',
#   'Makeout Party - Demo',
#   '99 Revolutions - Demo',
#   'Stray Heart - Demo',
#   'Angel Blue - Demo',
#   'Nuclear Family - Demo',
#   'Ashley - Demo',
#   'A Little Boy Named Train - Demo',
#   'Oh Love - Demo',
#   'Sex, Drugs & Violence - Demo',
#   'Stay the Night - Acoustic',
#   'Baby Eyes - Demo',
#   'Missing You - Demo',
#   'Carpe Diem - Demo',
#   'Rusty James - Demo',
#   'State of Shock - Demo',
#   'Let Yourself Go - Demo',
#   'Fell for You - Demo',
#   'Stay the Night - Demo',
#   'Drama Queen',
#   'A Little Boy Named Train',
#   'The Forgotten',
#   'Dirty Rotten Bastards',
#   'Sex, Drugs & Violence',
#   'Missing You',
#   'Amanda',
#   '99 Revolutions',
#   'X-Kid',
#   '8th Avenue Serenade',
#   'Brutal Love',
#   'Walk Away',
#   'Fuck Time',
#   'Baby Eyes',
#   "Wow! That's Loud",
#   'Stray Heart',
#   'Lazy Bones',
#   'Stop When the Red Lights Flash',
#   'Ashley',
#   'Nightlife',
#   'Makeout Party',
#   'Lady Cobra',
#   'Wild One',
#   'Amy',
#   'See You Tonight',
#   'Troublemaker',
#   'Sweet 16',
#   'Rusty James',
#   'Oh Love',
#   'Fell for You',
#   'Nuclear Family',
#   'Angel Blue',
#   'Loss of Control',
#   'Let Yourself Go',
#   'Stay the Night',
#   'Carpe Diem',
#   'Kill the DJ',
#   'Holiday / Boulevard of Broken Dreams',
#   'Jesus of Suburbia',
#   "Give Me Novacaine / She's a Rebel",
#   'Homecoming',
#   'Extraordinary Girl / Letterbomb',
#   'Too Much Too Soon',
#   'Wake Me up When September Ends',
#   'American Idiot',
#   'Governator',
#   'Shoplifter',
#   'Whatsername'],
#  'MICAR': ["This Time It's My Life - Radio Edit"],
#  'Breathe Carolina': ['My Love', 'The Fever'],
#  'Robert Falcon': ['My Love'],
#  'The Cure': ["Friday I'm In Love"],
#  'Jon Boden': ['How Long Will I Love You'],
#  'Sam Sweeney': ['How Long Will I Love You'],
#  'Ben Coleman': ['How Long Will I Love You'],
#  'G.R.L.': ['Ugly Heart'],
#  'T.I.': ['Live Your Life'],
#  'Die Antwoord': ['Banana Brain'],
#  'Belik Boom': ['Avada Kadabra'],
#  'Bag Raiders': ['Shooting Stars'],
#  'Alle Farben': ['H.O.L.Y.', 'Please Tell Rosie', 'Fading'],
#  'RHODES': ['H.O.L.Y.'],
#  'YouNotUs': ['Please Tell Rosie'],
#  'Hoobastank': ['The Reason', 'The Reason'],
#  'Three Days Grace': ['I Hate Everything About You'],
#  'Thirty Seconds To Mars': ['The Kill'],
#  'Bon Jovi': ["It's My Life",
#   'You Give Love A Bad Name',
#   "Livin' On A Prayer"],
#  'The Subways': ['Rock & Roll Queen'],
#  'Puddle Of Mudd': ['She Hates Me'],
#  'Third Eye Blind': ['Semi-Charmed Life'],
#  'Caesars': ['Jerk It Out', 'Jerk It Out'],
#  'Nirvana': ['Smells Like Teen Spirit',
#   'Come As You Are',
#   'Smells Like Teen Spirit'],
#  'Escape the Fate': ['Broken Heart'],
#  'Andrew Rayel': ['Horizon'],
#  'Lola Blanc': ['Horizon'],
#  'Philipp Dittberner': ['1,40m'],
#  'John De Sohn': ['Forever Young', 'Happy Kids'],
#  'LIAMOO': ['Forever Young'],
#  'Fox Blanco': ['Change the World'],
#  'Davai': ['Replay (feat. CIRE)'],
#  'CIRE': ['Replay (feat. CIRE)'],
#  'Alvaro Soler': ['La Cintura'],
#  'Matt Simons': ['We Can Do Better'],
#  'Swedish House Mafia': ["Don't You Worry Child (Radio Edit) [feat. John Martin]"],
#  'MIKA': ['Grace Kelly'],
#  'Laurell': ['Change My Heart', 'Good Vibes (feat. Laurell)'],
#  'Kris Kross Amsterdam': ['Whenever (feat. Conor Maynard)'],
#  'The Boy Next Door': ['Whenever (feat. Conor Maynard)'],
#  'Conor Maynard': ['Whenever (feat. Conor Maynard)'],
#  'ItaloBrothers': ['Summer Air', 'Till You Drop'],
#  'Blur': ['Song 2', 'Song 2 - 2012 Remaster'],
#  'XO Cupid': ['True Colors (feat. Maya Avedis)'],
#  'Maya Avedis': ['True Colors (feat. Maya Avedis)'],
#  'Alice Merton': ['Why So Serious', 'Funny Business'],
#  'Richard Smitt': ['All For Love', 'All For Love - Luca Schreiner Remix'],
#  'Smith & Thell': ['Toast', 'Forgive Me Friend'],
#  'Dzeko': ['Heaven (feat. Veronica)', 'Jackie Chan'],
#  'Riggi & Piros': ['Heaven (feat. Veronica)'],
#  'Veronica': ['Heaven (feat. Veronica)'],
#  'Westlife': ["When You're Looking Like That - Single Remix"],
#  'Nico Santos': ['Rooftop', 'Rooftop - HUGEL Remix'],
#  'Swedish Jam Factory': ['Forgive Me Friend'],
#  'A7S': ['Hey Baby (feat. A7S)'],
#  'Train': ['Hey, Soul Sister', 'Hey, Soul Sister'],
#  'Journey': ["Don't Stop Believin'", "Don't Stop Believin'"],
#  'Vargas & Lagola': ['Roads'],
#  'Katrina & The Waves': ['Walking On Sunshine'],
#  'T-Pain': ['Low (feat. T-Pain)'],
#  'Tom Cochrane': ['Life Is A Highway'],
#  'The Cranberries': ['Zombie'],
#  'Spice Girls': ['Wannabe'],
#  'Eurythmics': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Annie Lennox': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'Dave Stewart': ['Sweet Dreams (Are Made of This) - Remastered'],
#  'will.i.am': ['Hall of Fame (feat. will.i.am)'],
#  'TOTO': ['Africa'],
#  'The Rembrandts': ['I\'ll Be There for You (Theme from "Friends\')',
#   "I'll Be There for You (Theme from Friends) - Single Version"],
#  "Guns N' Roses": ["Sweet Child O' Mine"],
#  'Chumbawamba': ['Tubthumping'],
#  'Shakira': ['Whenever, Wherever', "Hips Don't Lie (feat. Wyclef Jean)"],
#  'John Denver': ['Take Me Home, Country Roads - Rerecorded'],
#  'Smash Mouth': ['All Star'],
#  'Hanson': ['MMMBop - Single Version', 'MMMBop'],
#  'Gavin DeGraw': ["I Don't Want to Be - Stripped Version"],
#  'WALK THE MOON': ['Shut Up and Dance'],
#  'Tenacious D': ['Tribute'],
#  'Bryan Adams': ["Summer Of '69", "Summer Of '69"],
#  'American Authors': ['Best Day Of My Life', 'Best Day Of My Life'],
#  'Eiffel 65': ['Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio',
#   'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio'],
#  'Backstreet Boys': ["Everybody (Backstreet's Back) - Extended Version",
#   'I Want It That Way',
#   'I Want It That Way - Anstandslos & Durchgeknallt Remix'],
#  'Rascal Flatts': ['Life is a Highway - From "Cars"'],
#  'The Verve': ['Bitter Sweet Symphony'],
#  'Alien Ant Farm': ['Smooth Criminal'],
#  'The Proclaimers': ["I'm Gonna Be (500 Miles)"],
#  'Kid Rock': ['All Summer Long', 'All Summer Long'],
#  'The Goo Goo Dolls': ['Iris'],
#  '3 Doors Down': ['Kryptonite'],
#  'OneRepublic': ['Counting Stars', 'Bones (feat. OneRepublic)'],
#  'fun.': ['Some Nights', 'We Are Young (feat. Janelle Monáe)'],
#  'R.E.M.': ['Losing My Religion'],
#  'Janelle Monáe': ['We Are Young (feat. Janelle Monáe)'],
#  'Lynyrd Skynyrd': ['Sweet Home Alabama'],
#  'Khalid': ['Vertigo',
#   'Saturday Nights REMIX',
#   'Eastside (with Halsey & Khalid)',
#   'Better',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Ocean (feat. Khalid)',
#   'Silence'],
#  'Pritam': ['BIBA'],
#  'Kane Brown': ['Saturday Nights REMIX'],
#  'benny blanco': ['Eastside (with Halsey & Khalid)'],
#  'Lost Kings': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Social House': ["Don't Kill My High (feat. Wiz Khalifa & Social House)"],
#  'Lizzo': ['Juice'],
#  'Kygo': ['Happy Now'],
#  'Sandro Cavazza': ['Happy Now',
#   'Without You (feat. Sandro Cavazza)',
#   'So Much Better - Lost Frequencies Remix',
#   'Beautiful Life'],
#  'Post Malone': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Wow.',
#   'Better Now',
#   'Jackie Chan'],
#  'Swae Lee': ['Sunflower - Spider-Man: Into the Spider-Verse',
#   'Arms Around You (feat. Maluma & Swae Lee)',
#   'Close To Me (with Diplo) (feat. Swae Lee)'],
#  'Ty James': ['Splash'],
#  'unheard': ['Splash'],
#  'Alec Bailey': ['Grip'],
#  'AUSTN': ["In Betweenin'"],
#  'MOTi': ['Hooked', 'Valencia - Original Mix'],
#  'Sheezan': ['Hooked'],
#  'Emma Sameth': ['Spin With You (feat. Jeremy Zucker)'],
#  'WOLFE': ['Spin With You (feat. Jeremy Zucker)'],
#  'Jeremy Zucker': ['Spin With You (feat. Jeremy Zucker)'],
#  'Galantis': ['Bones (feat. OneRepublic)',
#   'Love on Me',
#   "Don't Care",
#   'In My Head',
#   'Water',
#   "Dancin' to the Sound of a Broken Heart",
#   'Louder, Harder, Better',
#   'Gold Dust',
#   'Forever Tonight',
#   "Kill 'Em with the Love",
#   'Call If You Need Me',
#   'Firebird',
#   'You',
#   'Written in the Scars (feat. Wrabel)',
#   'Hey Alligator',
#   'Call Me Home',
#   'Salvage (Up All Night) (feat. Poo Bear)',
#   'Pillow Fight',
#   'Girls on Boys',
#   'Hello',
#   'Tell Me You Love Me',
#   'True Feeling',
#   'Hunter',
#   'Peanut Butter Jelly',
#   'Love on Me',
#   'Mama Look at Me Now',
#   'Spaceship (feat. Uffie)',
#   'Satisfied (feat. MAX)',
#   'No Money',
#   'Runaway (U & I)'],
#  'Robin Schulz': ['Speechless (feat. Erika Sirola)',
#   'Sugar (feat. Francesco Yates)',
#   'Perfect - Robin Schulz Remix'],
#  'Erika Sirola': ['Speechless (feat. Erika Sirola)'],
#  'Dominic Fike': ['3 Nights'],
#  'Miley Cyrus': ['Nothing Breaks Like a Heart (feat. Miley Cyrus)',
#   'Party In The U.S.A.'],
#  'Rita Ora': ['Only Want You',
#   'Let You Love Me',
#   'Anywhere',
#   'Lonely Together (feat. Rita Ora)'],
#  'Jack & Jack': ['Day Dreaming'],
#  'XXXTENTACION': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Lil Pump': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Maluma': ['Arms Around You (feat. Maluma & Swae Lee)'],
#  'Snakehips': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Rivers Cuomo': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'KYLE': ['Gucci Rock N Rolla (feat. Rivers Cuomo & KYLE)'],
#  'Lennon Stella': ['La Di Da', 'Polaroid'],
#  'Chris Burton': ['Love Letters'],
#  'Chantel Jeffries': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'YG': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Rich The Kid': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'BIA': ['Facts (feat. YG, Rich The Kid & BIA)'],
#  'Ariana Grande': ['thank u, next', '7 rings (feat. 2 Chainz) - Remix'],
#  'Lil Peep': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)",
#   'Spotlight'],
#  'ILOVEMAKONNEN': ["I've Been Waiting (w/ ILoveMakonnen & Fall Out Boy)"],
#  'Niall Horan': ['Slow Hands'],
#  'Gryffin': ['Remember (with ZOHARA)'],
#  'ZOHARA': ['Remember (with ZOHARA)'],
#  'Cardi B': ['Finesse - Remix; feat. Cardi B',
#   'Girls Like You (feat. Cardi B) - Cardi B Version'],
#  'Sabrina Carpenter': ['Sue Me'],
#  'Lauren Daigle': ['Look Up Child'],
#  'Drax Project': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'Hailee Steinfeld': ['Woke Up Late (feat. Hailee Steinfeld)'],
#  'shy martin': ['Forget to Forget'],
#  'Mallrat': ["Nobody's Home"],
#  'Basenji': ["Nobody's Home"],
#  'ARTY': ['Save Me Tonight'],
#  'Maggie Rogers': ['Light On'],
#  'Ellie Goulding': ['Close To Me (with Diplo) (feat. Swae Lee)', 'Burn'],
#  'Silk City': ['Electricity (with Dua Lipa)'],
#  'LÉON': ['You And I'],
#  '2 Chainz': ['7 rings (feat. 2 Chainz) - Remix'],
#  'GASHI': ['My Year'],
#  'Normani': ['Dancing With A Stranger (with Normani)'],
#  'Zeina': ['In My Head'],
#  "Why Don't We": ['Big Plans'],
#  'Big Boi': ["Doin' It (feat. Sleepy Brown)"],
#  'Sleepy Brown': ["Doin' It (feat. Sleepy Brown)"],
#  'Lauv': ["i'm so tired..."],
#  'Troye Sivan': ["i'm so tired...", 'There for You'],
#  'Tyla Yaweh': ['She Bad'],
#  'COIN': ['I Want It All'],
#  'Kehlani': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Ty Dolla $ign': ['Nights Like This (feat. Ty Dolla $ign)'],
#  'Hozier': ['Almost (Sweet Music)'],
#  'Dan + Shay': ['Speechless', 'Tequila - R3HAB Remix'],
#  'Shoffy': ['Cool Again'],
#  'Bazzi': ['Mine'],
#  'Matoma': ['Lonely (feat. MAX)'],
#  'MAX': ['Lonely (feat. MAX)', 'Satisfied (feat. MAX)'],
#  'Shania Twain': ['Man! I Feel Like A Woman!'],
#  'Taylor Swift': ['Shake It Off',
#   'Look What You Made Me Do',
#   'We Are Never Ever Getting Back Together'],
#  'MKTO': ['Classic'],
#  'Little Mix': ['Shout Out to My Ex'],
#  'Keala Settle': ['This Is Me'],
#  'The Greatest Showman Ensemble': ['This Is Me'],
#  'Rachel Platten': ['Fight Song'],
#  'Shawn Mendes': ['Treat You Better', "There's Nothing Holdin' Me Back"],
#  'Wyclef Jean': ["Hips Don't Lie (feat. Wyclef Jean)"],
#  'Kelsea Ballerini': ['This Feeling', 'This Feeling (feat. Kelsea Ballerini)'],
#  'Clean Bandit': ['Symphony (feat. Zara Larsson)'],
#  'Zara Larsson': ['Symphony (feat. Zara Larsson)'],
#  'MØ': ['Final Song'],
#  'Francesco Yates': ['Sugar (feat. Francesco Yates)'],
#  'Kelly Clarkson': ['Since U Been Gone'],
#  'Martin Garrix': ['Like I Do',
#   'Animals',
#   'Turn up the Speakers - Radio Edit',
#   'Forbidden Voices',
#   'Poison',
#   'Forever',
#   'Pizza',
#   'Game Over',
#   'Breach (Walk Alone)',
#   'Yottabyte',
#   'So Far Away (feat. Jamie Scott & Romy Dya)',
#   'In the Name of Love',
#   'Scared to Be Lonely - Acoustic Version',
#   'Ocean (feat. Khalid) - David Guetta Remix',
#   'Scared to Be Lonely',
#   'Ocean (feat. Khalid)',
#   'Like I Do',
#   'High On Life (feat. Bonn)',
#   'There for You',
#   'Burn Out (feat. Dewain Whitmore)'],
#  'Brooks': ['Like I Do', 'Like I Do'],
#  'Jonas Blue': ['Polaroid'],
#  'Liam Payne': ['Polaroid'],
#  'Logic': ['Everyday', 'Everyday'],
#  'Calvin Harris': ['One Kiss (with Dua Lipa)',
#   'One Kiss (with Dua Lipa) - R3HAB Remix'],
#  'Natasha Bedingfield': ['Unwritten'],
#  "Destiny's Child": ['Survivor'],
#  'Sam And The Womp': ['Bom Bom - Radio Edit'],
#  'Daniel Powter': ['Bad Day'],
#  'Scatman John': ['Scatman (ski-ba-bop-ba-dop-bop)'],
#  'Newton Faulkner': ['Dream Catch Me'],
#  'Baha Men': ['Who Let The Dogs Out'],
#  'Gina G': ['Just a Little Bit - Radio Edit'],
#  'Los Del Rio': ['Macarena'],
#  'Gotye': ['Somebody That I Used To Know'],
#  'Kimbra': ['Somebody That I Used To Know'],
#  'Tomcraft': ['Loneliness - Radio Cut'],
#  'Wheatus': ['Teenage Dirtbag', 'Teenage Dirtbag'],
#  'Chesney Hawkes': ['The One and Only'],
#  'Haddaway': ['What Is Love - 7" Mix', 'What Is Love - 7" Mix'],
#  'Of Monsters and Men': ['Little Talks'],
#  'Jet': ['Are You Gonna Be My Girl'],
#  'Andreas Johnson': ['Glorious'],
#  'Icona Pop': ['I Love It (feat. Charli XCX)'],
#  'Charli XCX': ['I Love It (feat. Charli XCX)'],
#  'Lou Bega': ['Mambo No. 5 (A Little Bit of...)'],
#  'Meredith Brooks': ['Bitch'],
#  'Yolanda Be Cool': ['We No Speak Americano'],
#  'Andrew Stanley': ['We No Speak Americano'],
#  'DCup': ['We No Speak Americano'],
#  'Matt Handles': ['We No Speak Americano'],
#  'Carl Douglas': ['Kung Fu Fighting'],
#  'Iglu & Hartly': ['In This City'],
#  'Rogue Traders': ['Voodoo Child'],
#  'Men Without Hats': ['The Safety Dance'],
#  'Marc Cohn': ['Walking in Memphis'],
#  'The Holloways': ['Generator'],
#  'Nizlopi': ['JCB'],
#  'Nena': ['99 Luftballons'],
#  'Bingo Players': ['Get Up (Rattle) - Radio Edit'],
#  'Faul & Wad': ['Changes - Radio Mix'],
#  'PNAU': ['Changes - Radio Mix'],
#  'Kevin Rudolf': ['Let It Rock'],
#  'Vanessa Carlton': ['A Thousand Miles - Single Version'],
#  'Passenger': ['Let Her Go'],
#  'Joan Osborne': ['One Of Us'],
#  'Ian Carey Project': ['Get Shaky'],
#  'The Buggles': ['Video Killed The Radio Star'],
#  'M.V.P.': ['Roc Ya Body (Mic Check 1, 2)'],
#  'DJ Zinc': ['Roc Ya Body (Mic Check 1, 2)'],
#  'Safri Duo': ['Played-A-Live (The Bongo Song)'],
#  'Rednex': ['Cotton Eye Joe'],
#  'Captain Jack': ['Captain Jack - Short Mix'],
#  'A Touch Of Class': ['Around the World (La La La La La) - Radio Version'],
#  'Pete Konemann': ['Around the World (La La La La La) - Radio Version'],
#  'Kaiser Chiefs': ['Ruby'],
#  'Culcha Candela': ['Hamma! - Single Edit'],
#  'Vengaboys': ['We’re Going to Ibiza!', 'Boom, Boom, Boom, Boom!!'],
#  'Spider Murphy Gang': ['Skandal im Sperrbezirk'],
#  'Throttle': ['Baddest Behaviour', 'Tell Me You Love Me'],
#  'Burak Yeter': ['Ciao Adios - Burak Yeter Remix'],
#  'Jan Delay': ['Oh Jonny'],
#  ...}

# %%
me_id = spotify.me()["id"]
me_id
# Out:
# '0gvflng5qihycq9keswkzvzgh'

# %%
def get_top_tracks(artist_name, track_limit=10):
    if artist_name[:2] == "??":
        print(f"{artist_name[2:]} not on Spotify - skipped")
        return None
    print(f"search for: {artist_name}")
    artist_result = spotify.search(q=f"artist:{artist_name}", type="artist")
    best_match = artist_result["artists"]["items"][0]
    print(f"\tbest artist match: {best_match['name']}")
    artist_uri = best_match["uri"]
    tracks = spotify.artist_top_tracks(artist_uri)["tracks"][:track_limit]
    track_info = {track["name"]: track["uri"] for track in tracks}
    return track_info

# %%
with open("lolla_saturday.txt") as f:
    lolla_artists = [line.strip() for line in f.readlines()]

# %%
lolla_artist_tracks = {}
track_limit = 5
for artist_name in lolla_artists:
    track_info = get_top_tracks(artist_name, track_limit)
    if track_info is not None:
        lolla_artist_tracks[artist_name] = track_info
# Out:
# search for: MAGGIE ROGERS
# 	best artist match: Maggie Rogers
# search for: J.I.D
# 	best artist match: J.I.D
# search for: PUSHA T
# 	best artist match: Pusha T
# search for: YUNG GRAVY
# 	best artist match: Yung Gravy
# search for: THE REVIVALISTS
# 	best artist match: The Revivalists
# search for: MEDUZA
# 	best artist match: MEDUZA
# search for: ODESZA
# 	best artist match: ODESZA
# search for: NORA EN PURE
# 	best artist match: Nora En Pure
# search for: AC SLATER
# 	best artist match: AC Slater
# search for: MORGAN WADE
# 	best artist match: Morgan Wade
# search for: SYLVAN ESSO
# 	best artist match: Sylvan Esso
# search for: ALEX G
# 	best artist match: Alex Goot
# search for: THE GARDEN
# 	best artist match: The Gardener & The Tree
# search for: NIKI
# 	best artist match: Niki Istrefi
# search for: DESTROY LONELY
# 	best artist match: Destroy Lonely
# search for: SUKI WATERHOUSE
# 	best artist match: Suki Waterhouse
# search for: KNOCK2
# 	best artist match: Knock2
# search for: IVAN CORNEJO
# 	best artist match: Ivan Cornejo
# search for: THEE SACRED SOULS
# 	best artist match: Thee Sacred Souls
# search for: THE KNOCKS
# 	best artist match: The Knocks
# search for: SOLARDO
# 	best artist match: Solardo
# search for: ZACK FOX
# 	best artist match: Zack Fox
# search for: TOM ODELL
# 	best artist match: Tom Odell
# search for: TOMORROW X TOGETHER
# 	best artist match: TOMORROW X TOGETHER
# search for: JEAN DAWSON
# 	best artist match: Jean Dawson
# search for: BONNIE X CLYDE
# 	best artist match: BONNIE X CLYDE
# search for: REMK
# 	best artist match: RemK
# search for: THE LINDA LINDAS
# 	best artist match: The Linda Lindas
# search for: MAVI
# 	best artist match: Mavi Phoenix
# search for: PARDYALONE
# 	best artist match: Pardyalone
# search for: FRIDAY PILOTS CLUB
# 	best artist match: Friday Pilots Club
# search for: MOTHERFOLK
# 	best artist match: Motherfolk
# search for: ARLIE
# 	best artist match: Arlie
# search for: ARI ABDUL
# 	best artist match: Ari Abdul
# search for: DANIELLE PONDER
# 	best artist match: Danielle Ponder
# search for: AIDAN BISSETT
# 	best artist match: Aidan Bissett
# search for: WINDSER
# 	best artist match: Windser
# search for: ARCY DRIVE
# 	best artist match: Arcy Drive
# search for: LOS APTOS
# 	best artist match: Los Aptos
# search for: USTED SEÑALEMELO
# 	best artist match: Usted Señalemelo
# search for: BENSON
# 	best artist match: Benson Boone
# search for: NOOSH
# 	best artist match: Nooshafarin

# %%
lolla_artist_tracks
# Out:
# {'MAGGIE ROGERS': {'Dawns (feat. Maggie Rogers)': 'spotify:track:42TtHTxWk782ZBiqyOi2d1',
#   'Alaska': 'spotify:track:4HfLQJtVT1KiX1eVedDyTm',
#   'Love You For A Long Time': 'spotify:track:6QTPacyXkZWG9FMwq6L1hJ',
#   'Light On': 'spotify:track:6UnCGAEmrbGIOSmGRZQ1M2',
#   "That's Where I Am": 'spotify:track:49EXOlUTFBGdI098L6SXDh'},
#  'J.I.D': {},
#  'PUSHA T': {"Don't Like.1": 'spotify:track:3YqJ0iaDWM0aqEDQExd2j3',
#   'Scrape It Off (feat. Lil Uzi Vert & Don Toliver)': 'spotify:track:1dp8aQANyTRKssDeAYPiZe',
#   'Dreamin Of The Past (feat. Kanye West)': 'spotify:track:3Wx98ijEDnsxyMYePCuFNI',
#   'Good Goodbye (feat. Pusha T and Stormzy)': 'spotify:track:650OeHTLxZAQmb4aEbGmaA',
#   'Nosetalgia': 'spotify:track:7aK5rlTVxSgcqShPMI1TTH'},
#  'YUNG GRAVY': {'Betty (Get Money)': 'spotify:track:1JCrXIeI6a9qRIkfAEz7J1',
#   'C’est La Vie (with bbno$ & Rich Brian)': 'spotify:track:3QqOcLtTU8zzlQRJCZzttP',
#   'oops!': 'spotify:track:7L6G0wpIUiPXuvoo7qhb06',
#   'Mr. Clean': 'spotify:track:5GxnROd93Y7NGt2ci0TwBw',
#   'Welcome to Chilis': 'spotify:track:3PdcxgzpWzAsUGgkmykIFc'},
#  'THE REVIVALISTS': {'Wish I Knew You': 'spotify:track:2EWpa5XnAuSn0sIkSSIhYk',
#   'Kid': 'spotify:track:24TzmWrz2HHWV3UO5PlvNb',
#   'Soulfight': 'spotify:track:3TQxkQsyJS03EUwl02Qaub',
#   'It Was A Sin': 'spotify:track:2JRkfugsvOPvTLmd0dVppc',
#   'Keep Going': 'spotify:track:6QvAqvSvkfHLzeIilXQ9H7'},
#  'MEDUZA': {'Bad Memories (feat. Elley Duhé & FAST BOY)': 'spotify:track:3rb0tMq42WfggucPm0HHkA',
#   'Paradise (feat. Dermot Kennedy)': 'spotify:track:6ft4hAq6yde8jPZY2i5zLr',
#   'Lose Control': 'spotify:track:7CHi4DtfK4heMlQaudCuHK',
#   'Piece Of Your Heart': 'spotify:track:1DFD5Fotzgn6yYXkYsKiGs',
#   'Tell Me Why - MEDUZA Remix': 'spotify:track:7jrMFjEq0t09f7m3HnnWXl'},
#  'ODESZA': {'The Last Goodbye (feat. Bettye LaVette)': 'spotify:track:2gQK13gXYZRq2MgvPJyHx8',
#   'A Moment Apart': 'spotify:track:59wlTaYOL5tDUgXnbBQ3my',
#   'Sun Models (feat. Madelyn Grant)': 'spotify:track:7jZHUhAmW5oq1cq6s8IxmK',
#   'Hopeful': 'spotify:track:7JXVPV3BIeuDs7JImsuN9P',
#   'Wide Awake (feat. Charlie Houston)': 'spotify:track:5OLfObog5za3O71jQgZFsB'},
#  'NORA EN PURE': {'Come With Me - Radio Mix': 'spotify:track:1Ht4NJdY8adMsW540P5vG0',
#   'Life on Hold': 'spotify:track:14G401PopaB2Fq4mVuCpWn',
#   'Spring Embers': 'spotify:track:2slr1WHisMcjKMEz0RJ8u2',
#   'Gratitude': 'spotify:track:2Beqqspq6QjAUU7zSawzY7',
#   'Birthright': 'spotify:track:4bmZEbZkt0LuV2SCQHAcWo'},
#  'AC SLATER': {'Suffocating': 'spotify:track:0RL0kFseGHilQyinJa0eO8',
#   'Crave The Bassline': 'spotify:track:3QzBzeXfDNR15U6X98zz1q',
#   'Final Fantasy - Original Mix': 'spotify:track:53E9F6JQX1Z7vFLHq2yLV1',
#   'Fly Kicks - Wax Motif Remix': 'spotify:track:30Ek6vDZ77PWTQS9HiV3xB',
#   'Fly With Us': 'spotify:track:0aEIw4siCqZ8hlDrvtlRep'},
#  'MORGAN WADE': {'Wilder Days': 'spotify:track:2vubFQgAJO5SeuVa7ytIHc',
#   'If I Was Your Lover': 'spotify:track:2zWbXUgWEWwubCja3ArCTu',
#   'Take Me Away': 'spotify:track:5UaJtNAZJcN9pWpIuVMnN2',
#   'The Night (Part 2)': 'spotify:track:4GVIjpSUWDTv2vLGetJAuF',
#   'Run': 'spotify:track:7MrYfNLfLW1PA3nJzKtMkZ'},
#  'SYLVAN ESSO': {'Coffee': 'spotify:track:30GGIrrJdSNtecPiFcVP5O',
#   'Die Young': 'spotify:track:1BRwuvjhkgezmv1gcI6lT6',
#   'Hey Mami': 'spotify:track:7bp7QInQ5uIMzYjJqTtjVA',
#   'Funeral Singers': 'spotify:track:5Y42u37PlyQXegnuI1Hpo1',
#   'Radio': 'spotify:track:0idjTHGhGRBdWTmsalq3tF'},
#  'ALEX G': {'Counting Stars': 'spotify:track:59z6KzkGfy3XCBOQX45CU5',
#   'Something Just Like This': 'spotify:track:1uvGuG5AvhT596LoSDGYeb',
#   'Beauty And A Beat': 'spotify:track:692mV5nN8lLqr2DJMd6h8W',
#   "I'm With You": 'spotify:track:3zLsU8qJbhTnd2QUu7pLtJ',
#   'Stand By You': 'spotify:track:3gN2OgbNwTw9ponnQPqluD'},
#  'THE GARDEN': {'Wonders': 'spotify:track:6d1AuFOL1YBzLcruapNbZV',
#   'Here Is Your Song': 'spotify:track:65Md1g0jQ6bOey7rUGmMOX',
#   'Postcards': 'spotify:track:5McQwoSnNSGyZlsikrFQDZ',
#   'Wild Horses': 'spotify:track:4mRPEhDtBxYvgMv5nBRI7H',
#   'Way To Rome': 'spotify:track:6rsQxs7joReZIrMNLKH9Zt'},
#  'NIKI': {'Red Armor': 'spotify:track:4lokwaruKSA4UVymx6JqXc',
#   'One More Cartoon, Please': 'spotify:track:3EKREjUxGtH4wENykFPJ4V',
#   'Worldspawn': 'spotify:track:4UyqpXNMLdzQYQ2CtZ0VDK',
#   'Chambers': 'spotify:track:5hLEUEA0SMEa0RnqeE6i7f',
#   'No Ordinary Love': 'spotify:track:5FPZM0uM0LxlflCcMVvotY'},
#  'DESTROY LONELY': {'if looks could kill': 'spotify:track:1cdqNRXIRrvT4HnApj6yw6',
#   'NOSTYLIST': 'spotify:track:42tD9J0KCPFSc1d2hFTvAf',
#   'Bane': 'spotify:track:2TKwo7J4oyyiYZvck7ky3R',
#   'NEVEREVER': 'spotify:track:610gzNqwaSz89u6YIpDlyZ',
#   'VETERAN (feat. Ken Carson)': 'spotify:track:7pdt56nlqNtHs5H8DRBZiO'},
#  'SUKI WATERHOUSE': {'Good Looking': 'spotify:track:0j3mqDTK4Z6lvrLzFCUUz6',
#   'Moves': 'spotify:track:6TT7B4MigCJCc0tqKYEpZC',
#   'To Love': 'spotify:track:0a64exvT5aKVaRSmAVMaCT',
#   'Johanna': 'spotify:track:6gH2V6XzhDXfTqml6c2w4Z',
#   'Nostalgia': 'spotify:track:3gV7y7IwafryNLEnhh9gKb'},
#  'KNOCK2': {'dashstar* - VIP': 'spotify:track:4FKRT4uPFx2L4exy9DCs1o',
#   'dashstar*': 'spotify:track:0dAfw35k2hBsnbSl74AVJF',
#   'Rock Ur World': 'spotify:track:5PkWhNfVEz2O9n8b6cQFMw',
#   'dashstar* - Yellow Claw Trap Edit': 'spotify:track:0fQlqbTeuXiUZnkmqTurOc',
#   'Make U SWEAT!': 'spotify:track:5uh8m2Lna0Gfk8YGqYVb6d'},
#  'IVAN CORNEJO': {'La Curiosidad': 'spotify:track:0hnvQLkV7yOjslEzflJSK4',
#   'Mentiras': 'spotify:track:3jRZg6U0m9Ir115Wt66ebU',
#   'HASTA LA MUERTE': 'spotify:track:3qAJAUr7yc9bPDx4ESt6ND',
#   'J.': 'spotify:track:4lUsBLTAiufWocWtg4H0my',
#   'Está Dañada': 'spotify:track:6G2xXQRSZlEzYsUEb3uvuR'},
#  'THEE SACRED SOULS': {'Can I Call You Rose?': 'spotify:track:7wnj1zRcZVlPNJ58shwl7h',
#   'Will I See You Again?': 'spotify:track:0gzDu0smnvgwslqwOiQ8f1',
#   'Weak for Your Love': 'spotify:track:6ajuD3Vrq9kJ5viPyggvZM',
#   "It's Our Love": 'spotify:track:2ZA4tDZvsxFO6Yw5OENin7',
#   'Easier Said Than Done': 'spotify:track:7dIPEjXoxkhmNR9S7EQVJ0'},
#  'THE KNOCKS': {'Fireworks (feat. Moss Kena & The Knocks)': 'spotify:track:5Iv4HuT9pKPi5WuE2ii3vs',
#   'Best Friend': 'spotify:track:1zEhH5BmSpKi1mRSIfBDOq',
#   'Brazilian Soul (feat. Sofi Tukker) - Acoustic Bossa Version': 'spotify:track:5iX7aAVoO3dzUOZ1eAvg6f',
#   'Love Letter (feat. The Knocks)': 'spotify:track:5p8QLRVnBk20xuvwiDZtTr',
#   'Slow Song (with Dragonette)': 'spotify:track:6zTbYrkYJSiNOw6jL7nM5H'},
#  'SOLARDO': {'I Can’t Wait (feat. Poppy Baskcomb)': 'spotify:track:3bnla8QwheGOI2AtfWOES1',
#   'Over Again': 'spotify:track:00U3nGjoxrqX04GvjiypUz',
#   'Move Your Body': 'spotify:track:3YXIVMQLRRq2K7kxC7UYx6',
#   'You Make Me Feel': 'spotify:track:4z2ZZU3skkejktx83PbKiR',
#   'XTC': 'spotify:track:0I45yWUWcC9fzdbZhiFxhg'},
#  'ZACK FOX': {'fafo': 'spotify:track:0tgFHDNf2ZNeY1J90oGbUW',
#   'Jesus Is The One (I Got Depression)': 'spotify:track:1YR9iNGXtsbrd8deR9ULDD',
#   'sipping my tea': 'spotify:track:5f4NTBzhDSX8d8eT0HsZEL',
#   'mind your business': 'spotify:track:1Q0IcxJuGUZmd8ZNjeaQqv',
#   "can't fight the devil": 'spotify:track:4GEL1AJUwD6BYlDxod9E4H'},
#  'TOM ODELL': {'Another Love': 'spotify:track:3JvKfv6T31zO0ini8iNItO',
#   'Another Love - Tiësto Remix': 'spotify:track:4Et6tUEO7biKxZEfJXpNj1',
#   'Heal': 'spotify:track:4KlL5Bwlm4yHYxr0B2rHci',
#   'Butterflies (feat. AURORA)': 'spotify:track:1dWUBCoztAMZcqec1CAE6z',
#   'Best Day Of My Life': 'spotify:track:1MtqOE9Uy6SZjPnBi1X7pQ'},
#  'TOMORROW X TOGETHER': {'Sugar Rush Ride': 'spotify:track:0rhI6gvOeCKA502RdJAbfs',
#   'Tinnitus (Wanna be a rock)': 'spotify:track:0f0SbtoKGe41cX5LzlnX6X',
#   'Devil by the Window': 'spotify:track:53H3sGmqiXWO4MwuZAJfyn',
#   '0X1=LOVESONG (I Know I Love You) feat. Seori': 'spotify:track:1Z8TPHiKeCUyClxV6WTTIf',
#   'Good Boy Gone Bad': 'spotify:track:1HsSIPLTQT354yJcQGfEY3'},
#  'JEAN DAWSON': {'MENTHOL*': 'spotify:track:2nMTBUdxkdCZWo7n3upy1e',
#   'BAD FRUIT*': 'spotify:track:0LI2OK0tulkh9mT2NmEBF8',
#   'Power Freaks': 'spotify:track:06dWM8AMMjKE9Obf2L1ojy',
#   'PIRATE RADIO*': 'spotify:track:5ShMDjPL7vYhhdyGGppXm9',
#   'SICK OF IT*': 'spotify:track:25SRFuJqLVrgApeFw4vFCb'},
#  'BONNIE X CLYDE': {'Another You': 'spotify:track:0GZ6PpNaMiViu3J0MDZztp',
#   'Need Ya': 'spotify:track:1W0QlblwswkwbOmZ5FIajf',
#   'Love Is Killing Me - Helion Remix': 'spotify:track:1rtcDdReb05jgxUBLEDL9n',
#   'In Too Deep': 'spotify:track:4VEEGfekFjcTjEOxSmUgBF',
#   'Love Is Killing Me': 'spotify:track:0WDHsTEgyvjw4EM24O0Tyd'},
#  'REMK': {'6am Bounce': 'spotify:track:3o4JurF32L4msnHzp9hcpI',
#   'Remember Me': 'spotify:track:6miku1r04c7k6Si5YsPBQV',
#   'Your Vibe': 'spotify:track:2GHtkrbTsHndIzreO9YNg6',
#   'Take Your Time': 'spotify:track:4JVHZKbaVjyobaBbu1CXj6',
#   'Want To': 'spotify:track:4eRKLoekIhUlkwkszb928L'},
#  'THE LINDA LINDAS': {'Oh!': 'spotify:track:1Wn0A9wVEQXj2JVbdsclpi',
#   'Too Many Things': 'spotify:track:2SU3rA2M4wgHMzHSHNiXkx',
#   'Growing Up': 'spotify:track:4Pa5KeSpeVbr6ubFTiG6If',
#   'Rebel Girl': 'spotify:track:51nLSjsBKMYBJSvUI3q88D',
#   'Talking To Myself': 'spotify:track:3hXqsW8leYpzFZ4EBzrO5x'},
#  'MAVI': {'Grass And The Sun': 'spotify:track:35MN8G5pC6vzrbs6yA1qhe',
#   "bird's eye": 'spotify:track:0IJJdNUNyYs9HLOahc9C2f',
#   'Aventura': 'spotify:track:60xZHF2KCgHnrCardPoZA9',
#   'biggest asshole in the room': 'spotify:track:2OYvrhuXkKNy4c3k7ozkfT',
#   'Los Santos - Crookers Infinity Mix': 'spotify:track:1n85xB0rU2aVL7LG7HQtbO'},
#  'PARDYALONE': {'Not a Home': 'spotify:track:3ZWkJqZCGUNerhkijP3ien',
#   'Sincerely, Fuck You': 'spotify:track:3tbBX2Lei9p0ThuGHRPLsU',
#   'She Likes My Tattoos': 'spotify:track:2Lle3tbO97Dd4I3deOZ92g',
#   'Alone (feat. Travis Barker)': 'spotify:track:1EBtVgTnh8umbKsdsQi0zg',
#   'Read Your Mind': 'spotify:track:3riUOEnx6x0k9M9uvFHsff'},
#  'FRIDAY PILOTS CLUB': {'End of It': 'spotify:track:2U94Nj4SVS7TNsUiObLWPm',
#   'For The Wicked': 'spotify:track:1MsU7LDRTqvMaKbptPp72z',
#   'Better With': 'spotify:track:1O1GLjtl8cMiTLWWLU9hQc',
#   'Gold and Bones': 'spotify:track:2Hvak6OlUkOgk9UR6Om3Lt',
#   'Hot Mess': 'spotify:track:1mlVyUIqGTEkJy8sB5VchH'},
#  'MOTHERFOLK': {'Kill the Sun': 'spotify:track:34uXlhi3eN9jpO95CgeV0o',
#   'Salt Lake City': 'spotify:track:0N8Q3j9oBGUDNckTtQSrJX',
#   "i don't mind": 'spotify:track:5eia9LztLDYxBydI2n9BX4',
#   'Trying to Kill the Moon': 'spotify:track:5UNC7SQ2z5pnspx4UwyF0O',
#   'all I need': 'spotify:track:3HFz9hr04EZBduvYSlXKH3'},
#  'ARLIE': {'didya think': 'spotify:track:4HOg84QsolNLzNp08qZ3sX',
#   'big fat mouth': 'spotify:track:0ZiGRciYMWrDvCPNM0T21o',
#   'landline': 'spotify:track:3OqP3uIygaUiuVzhVyk0X5',
#   'barcelona boots': 'spotify:track:1VpcATIL1OzUeiBqqqSTtV',
#   'tossing and turning': 'spotify:track:0BV558M7jtFWqSc04ODcmt'},
#  'ARI ABDUL': {'BABYDOLL (Speed)': 'spotify:track:5K3SJuYEkvvrLbzOjPyRi1',
#   'BABYDOLL': 'spotify:track:5rPNVwYjVEgkq6YNPki4Zc',
#   'Taste': 'spotify:track:1ghqDkglrXPcxgRobBmLVW',
#   'Stay': 'spotify:track:4WNrx9GTx4RvdnxR6qVysR',
#   'HUSH': 'spotify:track:0Njbfdqov90zIfAXZl7hIf'},
#  'DANIELLE PONDER': {'So Long': 'spotify:track:3T0M3nCkp5WKHQsjoBs8Ih',
#   'Little Bit': 'spotify:track:3PAflYZhStEXU0FY6yN98z',
#   'Some Of Us Are Brave': 'spotify:track:2V6T1pQX1hqp0ja2hk7DZk',
#   'Only The Lonely': 'spotify:track:4oXzEYYm7ZQ3CCmSukXOmo',
#   'Someone Like You': 'spotify:track:2ogZQLXNwWUnlgNDqeh7Cl'},
#  'AIDAN BISSETT': {'Tripping Over Air': 'spotify:track:7mzPAftljnsFmU6131Pqcd',
#   'More Than Friends': 'spotify:track:1Ph96WpdjNlwD6iKRE2Xa3',
#   'Out Of My League': 'spotify:track:7vAMRzLhIxvRGwmyKm3tlk',
#   "All That I'm Craving": 'spotify:track:2O2xeI5k7i1aGJTkQOyNpG',
#   'stuck on us': 'spotify:track:5GIsnSmSyFM8dI3e4dP1G5'},
#  'WINDSER': {'MANIAC (feat. Windser)': 'spotify:track:06ncaphlb6ccM7tdUgGhW4',
#   'Next Year (feat. Windser)': 'spotify:track:4zncVqi72AX54I2JVIUq0N',
#   'Memory': 'spotify:track:4alv8RaCCKQAShJ9Xya9w7',
#   'Friends I Barely Know': 'spotify:track:1LrgCvDcHuPnThKRKkeoqL',
#   'July': 'spotify:track:0kjqOEfgU6ttcZDofnmHPY'},
#  'ARCY DRIVE': {'Roll My Stone': 'spotify:track:2RznsV7SgSkTo0K5NLO7Lk',
#   'Smoke & Fire (Live)': 'spotify:track:524K0DC2JG6b2XSKyU5Cno',
#   "They Don't Dance": 'spotify:track:0HJLeIJPEu5x1CQLYWtn8A',
#   'River (Live)': 'spotify:track:5L7QKqtBhSLF0dYSUSlt3K',
#   'Colorado Kyle (Live)': 'spotify:track:3awYmrxWHNBpmJ81YxSCAn'},
#  'LOS APTOS': {'Enamorado': 'spotify:track:5zC6Pptql0n3P7iAhn3ggg',
#   'Tú Me Llevas a Un Espacio': 'spotify:track:1RDVJCMNBL13V8eQ3XawIi',
#   'Me Voy Contigo': 'spotify:track:6BNaBJvHM85qDtsw9pUCD0',
#   'Eres Tú': 'spotify:track:6tdEUtQiTpvNKOOWEKjjxs',
#   'Tu Labial': 'spotify:track:3vz0ZD15RxM2HNCGgrVrVc'},
#  'USTED SEÑALEMELO': {'Agua Marfil': 'spotify:track:4lOP4BFzkPCECQTcVJgZPL',
#   'Pana': 'spotify:track:3y8hTrsyarUNzZhgZlwG84',
#   'Nuevo Comienzo': 'spotify:track:67tXLMcNhEfTYBsuBQ8aHE',
#   'Nena, dime algo.': 'spotify:track:3arnuYBuNFads3xhmztypA',
#   'Big Bang': 'spotify:track:0DcFIERoYTkM80DJf4Vusx'},
#  'BENSON': {'In The Stars': 'spotify:track:1ei3hzQmrgealgRKFxIcWn',
#   'GHOST TOWN': 'spotify:track:135Lf4Q0CzlMNfOxbEUsLH',
#   'Sugar Sweet': 'spotify:track:5ZzaQW3InamKZ0KdJVQ1GO',
#   'Before You': 'spotify:track:523f4oSjrZx83XDtRLnsIw',
#   'NIGHTS LIKE THESE': 'spotify:track:33vZRjxJScapmRShRJq8I0'},
#  'NOOSH': {'Salam': 'spotify:track:1Ct9qrV2jegazbjZJVsO95',
#   'Shabe Tou Shabe Man': 'spotify:track:7k5ZM2gTeAiUxQDlMNE9GS',
#   'Nazanine Ashegh': 'spotify:track:1TUMpJPwFCHiY8Dq0AZ5C1',
#   'Hamzabon': 'spotify:track:2XgvBYmwzCDgpnnLmQ4wBS',
#   'Gol-e-Aftabgardon': 'spotify:track:58WgHeVNAPNtZIQtIY4l0I'}}

# %%
playlist = spotify.user_playlist_create(me_id, "Lolla Saturday (top 5)", public=False)
playlist
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/1mfI9n8hCxs6lRqBqqIJ89'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/1mfI9n8hCxs6lRqBqqIJ89',
#  'id': '1mfI9n8hCxs6lRqBqqIJ89',
#  'images': [],
#  'name': 'Lolla Saturday (top 5)',
#  'owner': {'display_name': 'makzator',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/0gvflng5qihycq9keswkzvzgh'},
#   'href': 'https://api.spotify.com/v1/users/0gvflng5qihycq9keswkzvzgh',
#   'id': '0gvflng5qihycq9keswkzvzgh',
#   'type': 'user',
#   'uri': 'spotify:user:0gvflng5qihycq9keswkzvzgh'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'MSw4ZDYzYTg4ZDkwMTZlYTUwOGQ0MGE3MmY0NzczNGZlMWZjMGE0M2Nh',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/1mfI9n8hCxs6lRqBqqIJ89/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
#  'uri': 'spotify:playlist:1mfI9n8hCxs6lRqBqqIJ89'}

# %%
playlist_id = playlist["id"]
playlist_id
# Out:
# '1mfI9n8hCxs6lRqBqqIJ89'

# %%
for artist_name, track_info in lolla_artist_tracks.items():
    print(f"adding tracks from {artist_name}")
    track_uris = list(track_info.values())
    try:
        spotify.playlist_add_items(playlist_id, track_uris)
        for track_name in track_info.keys():
            print(f"\tadded track {track_name}")
    except:
        print(f"some error adding songs from {artist_name}")
# Out:
# adding tracks from MAGGIE ROGERS
# HTTP Error for POST to https://api.spotify.com/v1/playlists/1mfI9n8hCxs6lRqBqqIJ89/tracks with Params: {'position': None} returned 400 due to Error parsing JSON.
# 	added track Dawns (feat. Maggie Rogers)
# 	added track Alaska
# 	added track Love You For A Long Time
# 	added track Light On
# 	added track That's Where I Am
# adding tracks from J.I.D
# some error adding songs from J.I.D
# adding tracks from PUSHA T
# 	added track Don't Like.1
# 	added track Scrape It Off (feat. Lil Uzi Vert & Don Toliver)
# 	added track Dreamin Of The Past (feat. Kanye West)
# 	added track Good Goodbye (feat. Pusha T and Stormzy)
# 	added track Nosetalgia
# adding tracks from YUNG GRAVY
# 	added track Betty (Get Money)
# 	added track C’est La Vie (with bbno$ & Rich Brian)
# 	added track oops!
# 	added track Mr. Clean
# 	added track Welcome to Chilis
# adding tracks from THE REVIVALISTS
# 	added track Wish I Knew You
# 	added track Kid
# 	added track Soulfight
# 	added track It Was A Sin
# 	added track Keep Going
# adding tracks from MEDUZA
# 	added track Bad Memories (feat. Elley Duhé & FAST BOY)
# 	added track Paradise (feat. Dermot Kennedy)
# 	added track Lose Control
# 	added track Piece Of Your Heart
# 	added track Tell Me Why - MEDUZA Remix
# adding tracks from ODESZA
# 	added track The Last Goodbye (feat. Bettye LaVette)
# 	added track A Moment Apart
# 	added track Sun Models (feat. Madelyn Grant)
# 	added track Hopeful
# 	added track Wide Awake (feat. Charlie Houston)
# adding tracks from NORA EN PURE
# 	added track Come With Me - Radio Mix
# 	added track Life on Hold
# 	added track Spring Embers
# 	added track Gratitude
# 	added track Birthright
# adding tracks from AC SLATER
# 	added track Suffocating
# 	added track Crave The Bassline
# 	added track Final Fantasy - Original Mix
# 	added track Fly Kicks - Wax Motif Remix
# 	added track Fly With Us
# adding tracks from MORGAN WADE
# 	added track Wilder Days
# 	added track If I Was Your Lover
# 	added track Take Me Away
# 	added track The Night (Part 2)
# 	added track Run
# adding tracks from SYLVAN ESSO
# 	added track Coffee
# 	added track Die Young
# 	added track Hey Mami
# 	added track Funeral Singers
# 	added track Radio
# adding tracks from ALEX G
# 	added track Counting Stars
# 	added track Something Just Like This
# 	added track Beauty And A Beat
# 	added track I'm With You
# 	added track Stand By You
# adding tracks from THE GARDEN
# 	added track Wonders
# 	added track Here Is Your Song
# 	added track Postcards
# 	added track Wild Horses
# 	added track Way To Rome
# adding tracks from NIKI
# 	added track Red Armor
# 	added track One More Cartoon, Please
# 	added track Worldspawn
# 	added track Chambers
# 	added track No Ordinary Love
# adding tracks from DESTROY LONELY
# 	added track if looks could kill
# 	added track NOSTYLIST
# 	added track Bane
# 	added track NEVEREVER
# 	added track VETERAN (feat. Ken Carson)
# adding tracks from SUKI WATERHOUSE
# 	added track Good Looking
# 	added track Moves
# 	added track To Love
# 	added track Johanna
# 	added track Nostalgia
# adding tracks from KNOCK2
# 	added track dashstar* - VIP
# 	added track dashstar*
# 	added track Rock Ur World
# 	added track dashstar* - Yellow Claw Trap Edit
# 	added track Make U SWEAT!
# adding tracks from IVAN CORNEJO
# 	added track La Curiosidad
# 	added track Mentiras
# 	added track HASTA LA MUERTE
# 	added track J.
# 	added track Está Dañada
# adding tracks from THEE SACRED SOULS
# 	added track Can I Call You Rose?
# 	added track Will I See You Again?
# 	added track Weak for Your Love
# 	added track It's Our Love
# 	added track Easier Said Than Done
# adding tracks from THE KNOCKS
# 	added track Fireworks (feat. Moss Kena & The Knocks)
# 	added track Best Friend
# 	added track Brazilian Soul (feat. Sofi Tukker) - Acoustic Bossa Version
# 	added track Love Letter (feat. The Knocks)
# 	added track Slow Song (with Dragonette)
# adding tracks from SOLARDO
# 	added track I Can’t Wait (feat. Poppy Baskcomb)
# 	added track Over Again
# 	added track Move Your Body
# 	added track You Make Me Feel
# 	added track XTC
# adding tracks from ZACK FOX
# 	added track fafo
# 	added track Jesus Is The One (I Got Depression)
# 	added track sipping my tea
# 	added track mind your business
# 	added track can't fight the devil
# adding tracks from TOM ODELL
# 	added track Another Love
# 	added track Another Love - Tiësto Remix
# 	added track Heal
# 	added track Butterflies (feat. AURORA)
# 	added track Best Day Of My Life
# adding tracks from TOMORROW X TOGETHER
# 	added track Sugar Rush Ride
# 	added track Tinnitus (Wanna be a rock)
# 	added track Devil by the Window
# 	added track 0X1=LOVESONG (I Know I Love You) feat. Seori
# 	added track Good Boy Gone Bad
# adding tracks from JEAN DAWSON
# 	added track MENTHOL*
# 	added track BAD FRUIT*
# 	added track Power Freaks
# 	added track PIRATE RADIO*
# 	added track SICK OF IT*
# adding tracks from BONNIE X CLYDE
# 	added track Another You
# 	added track Need Ya
# 	added track Love Is Killing Me - Helion Remix
# 	added track In Too Deep
# 	added track Love Is Killing Me
# adding tracks from REMK
# 	added track 6am Bounce
# 	added track Remember Me
# 	added track Your Vibe
# 	added track Take Your Time
# 	added track Want To
# adding tracks from THE LINDA LINDAS
# 	added track Oh!
# 	added track Too Many Things
# 	added track Growing Up
# 	added track Rebel Girl
# 	added track Talking To Myself
# adding tracks from MAVI
# 	added track Grass And The Sun
# 	added track bird's eye
# 	added track Aventura
# 	added track biggest asshole in the room
# 	added track Los Santos - Crookers Infinity Mix
# adding tracks from PARDYALONE
# 	added track Not a Home
# 	added track Sincerely, Fuck You
# 	added track She Likes My Tattoos
# 	added track Alone (feat. Travis Barker)
# 	added track Read Your Mind
# adding tracks from FRIDAY PILOTS CLUB
# 	added track End of It
# 	added track For The Wicked
# 	added track Better With
# 	added track Gold and Bones
# 	added track Hot Mess
# adding tracks from MOTHERFOLK
# 	added track Kill the Sun
# 	added track Salt Lake City
# 	added track i don't mind
# 	added track Trying to Kill the Moon
# 	added track all I need
# adding tracks from ARLIE
# 	added track didya think
# 	added track big fat mouth
# 	added track landline
# 	added track barcelona boots
# 	added track tossing and turning
# adding tracks from ARI ABDUL
# 	added track BABYDOLL (Speed)
# 	added track BABYDOLL
# 	added track Taste
# 	added track Stay
# 	added track HUSH
# adding tracks from DANIELLE PONDER
# 	added track So Long
# 	added track Little Bit
# 	added track Some Of Us Are Brave
# 	added track Only The Lonely
# 	added track Someone Like You
# adding tracks from AIDAN BISSETT
# 	added track Tripping Over Air
# 	added track More Than Friends
# 	added track Out Of My League
# 	added track All That I'm Craving
# 	added track stuck on us
# adding tracks from WINDSER
# 	added track MANIAC (feat. Windser)
# 	added track Next Year (feat. Windser)
# 	added track Memory
# 	added track Friends I Barely Know
# 	added track July
# adding tracks from ARCY DRIVE
# 	added track Roll My Stone
# 	added track Smoke & Fire (Live)
# 	added track They Don't Dance
# 	added track River (Live)
# 	added track Colorado Kyle (Live)
# adding tracks from LOS APTOS
# 	added track Enamorado
# 	added track Tú Me Llevas a Un Espacio
# 	added track Me Voy Contigo
# 	added track Eres Tú
# 	added track Tu Labial
# adding tracks from USTED SEÑALEMELO
# 	added track Agua Marfil
# 	added track Pana
# 	added track Nuevo Comienzo
# 	added track Nena, dime algo.
# 	added track Big Bang
# adding tracks from BENSON
# 	added track In The Stars
# 	added track GHOST TOWN
# 	added track Sugar Sweet
# 	added track Before You
# 	added track NIGHTS LIKE THESE
# adding tracks from NOOSH
# 	added track Salam
# 	added track Shabe Tou Shabe Man
# 	added track Nazanine Ashegh
# 	added track Hamzabon
# 	added track Gol-e-Aftabgardon
